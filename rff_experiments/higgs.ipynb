# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os
import optuna
from optuna.trial import TrialState
from tab_transformer_pytorch import FTTransformer, TabTransformer
import sys
import time
from torch import Tensor
from typing import Literal

device_in_use='cuda'

# %%
# df_train = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/higgs/train.csv')
# df_test = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/higgs/test.csv')
# df_val = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/higgs/validation.csv') #READ FROM RIGHT SPOT

df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\higgs\train.csv')
df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\higgs\test.csv')
df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\higgs\validation.csv') #READ FROM RIGHT SPOT

# %%
df_train.columns

cont_columns = ['lepton_pT', 'lepton_eta', 'lepton_phi',
       'missing_energy_magnitude', 'missing_energy_phi', 'jet1pt', 'jet1eta',
       'jet1phi', 'jet1b-tag', 'jet2pt', 'jet2eta', 'jet2phi', 'jet2b-tag',
       'jet3pt', 'jet3eta', 'jet3phi', 'jet3b-tag', 'jet4pt', 'jet4eta',
       'jet4phi', 'jet4b-tag', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb',
       'm_wbb', 'm_wwbb']
target = ['class']

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cont_columns + target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
print(target_classes)
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.int64).values

        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return num_features, labels_task1

#Wrapping in Dataset
train_dataset = SingleTaskDataset(df_train, cont_columns, 'class')
val_dataset = SingleTaskDataset(df_val, cont_columns, 'class')
test_dataset = SingleTaskDataset(df_test, cont_columns, 'class')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
#Also try looking to see what other papers have done
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# [2]

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

class MultiHeadAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(MultiHeadAttention, self).__init__()

        self.embed_size = embed_size
        self.heads = heads
        self.head_dim = embed_size // heads
        assert(self.head_dim * heads == embed_size), "Embed size needs to be div by heads"
        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys =nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads*self.head_dim, embed_size)


    def forward(self, values, keys, query):
        N = query.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]

        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = query.reshape(N, query_len, self.heads, self.head_dim)

        values = self.values(values)
        keys = self.keys(keys)
        queries = self.queries(queries)

        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])

        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3) #(batch_size, head_dim, #query_embeddings, #key_embeddings)

        # Calculate simplified attention scores
        avg_attention = attention.mean(dim=0)  # Average across batches
        # print("batch average", avg_attention.shape)
        avg_attention = avg_attention.mean(dim=0).squeeze(dim=0)
        # print("head average", avg_attention.shape)

        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(N, query_len, self.heads*self.head_dim) #(batch_size, n_features, embed_size)
        out = self.fc_out(out)

        return out, avg_attention
    
class TransformerBlock(nn.Module):
    def __init__(self, embed_size, heads, dropout, forward_expansion, pre_norm_on):
        super(TransformerBlock, self).__init__()

        self.pre_norm_on = pre_norm_on
        if self.pre_norm_on:
            self.pre_norm = nn.LayerNorm(embed_size)
        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm1 = nn.LayerNorm(embed_size)
        self.norm2 = nn.LayerNorm(embed_size)

        self.feed_forward = nn.Sequential(nn.Linear(embed_size, forward_expansion*embed_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion*embed_size, embed_size)
                                          )
        self.dropout = nn.Dropout(dropout)

    def forward(self,value,key,query):
        if self.pre_norm_on:
            query = self.pre_norm(query)
            key = self.pre_norm(key)
            value = self.pre_norm(value)
            
        attention, avg_attention = self.attention(value, key, query)
        x = self.dropout(self.norm1(attention + query))
        forward = self.feed_forward(x)
        out = self.dropout(self.norm2(forward + x))
        return out, avg_attention
    
class DecoderBlock(nn.Module):
    def __init__(self, embed_size, heads, forward_expansion, dropout, pre_norm_on):
        super(DecoderBlock, self).__init__()

        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm = nn.LayerNorm(embed_size)
        self.transformer_block = TransformerBlock(embed_size, heads, dropout, forward_expansion, pre_norm_on)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, value, key):
        out, avg_attention = self.transformer_block(value, key, x)

        return out, avg_attention

class Decoder(nn.Module):
    def __init__(self,
                 embed_size,
                 num_layers,
                 heads,
                 forward_expansion,
                 decoder_dropout,
                 pre_norm_on
    ):
        super(Decoder, self).__init__()

        self.layers = nn.ModuleList(
                [
                    DecoderBlock(
                        embed_size,
                        heads,
                        dropout=decoder_dropout,
                        forward_expansion=forward_expansion,
                        pre_norm_on=pre_norm_on
                    )
                    for _ in range(num_layers)
                ]
            )
        self.avg_attention = None

    def forward(self, class_embed, context):
        for layer in self.layers:
            # x is the classification embedding (CLS Token)
            # context are the feature embeddings that will be used as key and value
            x, self.avg_attention = layer(class_embed, context, context)
  
        return x 

class EmbeddingsRFFforIndividualFeatures(nn.Module):
    def __init__(self, sigma, embed_size, input_size, n_cont,  num_target_labels, rff_on, linear_on:bool):
        super(EmbeddingsRFFforIndividualFeatures, self).__init__()

        self.rff_on = rff_on

        self.linear_on = linear_on

        if self.rff_on:
            self.rffs = nn.ModuleList([GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) for _ in range(n_cont)])
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for _ in range(n_cont)])

        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, x):
        x = x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i, r in enumerate(self.rffs):
                input = x[:,i,:]
                out = r(input)
                rff_vectors.append(out)

        embeddings = []
        if self.linear_on:
            x = torch.stack(rff_vectors, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = rff_vectors

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)


        return class_embeddings, context

class EmbeddingsRFFforAllFeatures(nn.Module):
    def __init__(self, sigma, embed_size, input_size, n_cont, num_target_labels, rff_on, linear_on:bool):
        super(EmbeddingsRFFforAllFeatures, self).__init__()

        self.rff_on = rff_on
        self.n_cont = n_cont
        self.linear_on=linear_on

        if self.rff_on:
            self.rff = GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) 
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for _ in range(n_cont)])

        
        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, x):
        x = x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i in range(self.n_cont):
                input = x[:,i,:]
                out = self.rff(input)
                rff_vectors.append(out)
        
        embeddings = []
        if self.linear_on:
            x = torch.stack(rff_vectors, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = rff_vectors

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)

        return class_embeddings, context
    
class PeriodicActivation(nn.Module):
    def __init__(self, sigma, embed_size, n_cont, num_target_labels,trainable: bool, initialization: str, linear_on:bool):
        super(PeriodicActivation, self).__init__()

        self.n = embed_size
        self.sigma = sigma
        self.trainable = trainable
        self.initialization = initialization
        self.linear_on = linear_on
        self.n_cont = n_cont

        if self.initialization == 'log-linear':
            coefficients = self.sigma ** (torch.arange(self.n//2) / self.n)
            coefficients = coefficients[None]
        else:
            assert self.initialization == 'normal'
            coefficients = torch.normal(0.0, self.sigma, (1, self.n//2))

        if self.trainable:
            self.coefficients = nn.Parameter(coefficients)
        else:
            self.register_buffer('coefficients', coefficients)

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=embed_size, out_features=embed_size) for _ in range(n_cont)])

        
        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, x):
        x = x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)

        temp = []
        for i in range(self.n_cont):
            input = x[:,i,:]
            out = torch.cat([torch.cos(self.coefficients * input), torch.sin(self.coefficients * input)], dim=-1)
            temp.append(out)
        
        embeddings = []
        if self.linear_on:
            x = torch.stack(temp, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = temp

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)

        return class_embeddings, context


class classificationHead(nn.Module):
    def __init__(self, embed_size, dropout, mlp_scale_classification, num_target_classes):
        super(classificationHead, self).__init__()
        
        #flattening the embeddings out so each sample in batch is represented with a 460 dimensional vector
        self.input = embed_size
        self.lin1 = nn.Linear(self.input, mlp_scale_classification*self.input)
        self.drop = nn.Dropout(dropout)
        self.lin2 = nn.Linear(mlp_scale_classification*self.input, mlp_scale_classification*self.input)
        self.lin3 = nn.Linear(mlp_scale_classification*self.input, self.input)
        self.lin4 = nn.Linear(self.input, num_target_classes)
        self.relu = nn.ReLU()
        self.initialize_weights()

    def initialize_weights(self): #he_initialization.
        torch.nn.init.kaiming_normal_(self.lin1.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin1.bias)

        torch.nn.init.kaiming_normal_(self.lin3.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin3.bias)

    def forward(self, x):

        x= torch.reshape(x, (-1, self.input))

        x = self.lin1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin2(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin3(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin4(x)
  
        return x

class CATTransformer(nn.Module):
    def __init__(self, 
                 rff_on = True,
                 sigma=4,
                 embed_size=20,
                 input_size=1,
                 n_cont = 0,
                 num_layers=1,
                 heads=1,
                 forward_expansion=4, # Determines how wide the MLP is in the encoder. Its a scaling factor. 
                 decoder_dropout=0,
                 classification_dropout = 0,
                 pre_norm_on = False,
                 mlp_scale_classification = 4,
                 targets_classes : list=  [3,8],
                embedding_scheme ="rff_unique",
                trainable=True,
                linear_on=True
                 ):
        super(CATTransformer, self).__init__()

        assert(embedding_scheme in ['rff_unique', 'rff', 'log-linear_periodic', 'normal_periodic']), "wrong embedding_scheme"

        if embedding_scheme == 'rff_unique':
            self.embeddings = EmbeddingsRFFforIndividualFeatures(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, 
                                     n_cont=n_cont, num_target_labels=len(targets_classes), linear_on=linear_on)
        elif embedding_scheme == 'log-linear_periodic':
            self.embeddings = PeriodicActivation(sigma=sigma, embed_size=embed_size, n_cont=n_cont, 
                                                 num_target_labels=len(target_classes),trainable=trainable,initialization='log-linear', linear_on=linear_on)
        elif embedding_scheme == 'normal_periodic':
            self.embeddings = PeriodicActivation(sigma=sigma, embed_size=embed_size, n_cont=n_cont, 
                                                 num_target_labels=len(target_classes),trainable=trainable,initialization='normal',linear_on=linear_on)
        else:
            self.embeddings = EmbeddingsRFFforAllFeatures(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, 
                                     n_cont=n_cont, num_target_labels=len(targets_classes),linear_on=linear_on)
            
        self.decoder = Decoder(embed_size=embed_size, num_layers=num_layers, heads=heads, forward_expansion=forward_expansion, 
                               decoder_dropout=decoder_dropout, pre_norm_on=pre_norm_on)
        self.classifying_heads = nn.ModuleList([classificationHead(embed_size=embed_size, dropout=classification_dropout, 
                                                                   mlp_scale_classification=mlp_scale_classification, 
                                                                   num_target_classes=x) for x in targets_classes])
        
    def forward(self, x):
        class_embed, context = self.embeddings(x)

        x = self.decoder(class_embed, context)
        
        probability_dist_raw = []
        for i, e in enumerate(self.classifying_heads):
            input = x[:, i,:]
            output = e(input)
            probability_dist_raw.append(output)
        
        return probability_dist_raw
    
    # Training and Testing Loops
def train(dataloader, model, loss_function, optimizer, device_in_use):
    model.train()

    total_loss = 0

    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    total_correct_2 = 0
    total_samples_2 = 0
    all_targets_2 = []
    all_predictions_2 = []

    for (features,labels_task1) in dataloader:
        features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)


        task_predictions = model(features) #contains a list of the tensor outputs for each task

        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()

        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    # accuracy_2 = total_correct_2 / total_samples_2

    # # precision = precision_score(all_targets, all_predictions, average='weighted')
    # recall = recall_score(all_targets, all_predictions, average='weighted')
    # f1 = f1_score(all_targets, all_predictions, average='weighted')

    return avg_loss, accuracy_1

def test(dataloader, model, loss_function, device_in_use):
  model.eval()
  total_loss = 0
  
  total_correct_1 = 0
  total_samples_1 = 0
  all_targets_1 = []
  all_predictions_1 = []

  total_correct_2 = 0
  total_samples_2 = 0
  all_targets_2 = []
  all_predictions_2 = []

  with torch.no_grad():
    for (features,labels_task1) in dataloader:
      features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)

      #compute prediction error
      task_predictions = model(features) #contains a list of the tensor outputs for each task

      loss = loss_function(task_predictions, labels_task1)
      total_loss += loss.item()

      #computing accuracy for first target
      y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
      _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
      total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
      total_samples_1 += labels_task1.size(0)
      all_targets_1.extend(labels_task1.cpu().numpy())
      all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

  avg = total_loss/len(dataloader)
  accuracy_1 = total_correct_1 / total_samples_1
  # accuracy_2 = total_correct_2 / total_samples_2
  # recall = recall_score(all_targets, all_predictions, average='weighted')
  f1_1 = f1_score(all_targets_1, all_predictions_1, average='weighted')
  # f1_2 = f1_score(all_targets_2, all_predictions_2, average="weighted")

  return avg, accuracy_1, all_predictions_1, all_targets_1, f1_1

def format_metric(value): # Used to format the metrics output
    return f"{value:.4f}"

# %% [markdown]
# # Normal RFF to each feature

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       embedding_scheme='rff_unique',
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.65075, Accuracy 0.59854                             | Test: Loss 0.60445, Accuracy 0.66753, F1 0.66652
# Epoch [ 2/100]       | Train: Loss 0.59484, Accuracy 0.67759                             | Test: Loss 0.59394, Accuracy 0.67820, F1 0.67836
# Epoch [ 3/100]       | Train: Loss 0.58682, Accuracy 0.68545                             | Test: Loss 0.58979, Accuracy 0.68017, F1 0.67934
# Epoch [ 4/100]       | Train: Loss 0.58147, Accuracy 0.69044                             | Test: Loss 0.58490, Accuracy 0.68344, F1 0.68359
# Epoch [ 5/100]       | Train: Loss 0.57452, Accuracy 0.69061                             | Test: Loss 0.58134, Accuracy 0.68854, F1 0.68836
# Epoch [ 6/100]       | Train: Loss 0.56966, Accuracy 0.69439                             | Test: Loss 0.57726, Accuracy 0.68799, F1 0.68776
# Epoch [ 7/100]       | Train: Loss 0.56660, Accuracy 0.69534                             | Test: Loss 0.58128, Accuracy 0.68623, F1 0.68616
# Epoch [ 8/100]       | Train: Loss 0.56403, Accuracy 0.69687                             | Test: Loss 0.57519, Accuracy 0.69119, F1 0.69090
# Epoch [ 9/100]       | Train: Loss 0.56189, Accuracy 0.69788                             | Test: Loss 0.57564, Accuracy 0.68792, F1 0.68620
# Epoch [10/100]       | Train: Loss 0.55876, Accuracy 0.69853                             | Test: Loss 0.57372, Accuracy 0.68976, F1 0.68832
# Epoch [11/100]       | Train: Loss 0.55835, Accuracy 0.70015                             | Test: Loss 0.58154, Accuracy 0.68296, F1 0.68219
# Epoch [12/100]       | Train: Loss 0.55820, Accuracy 0.70056                             | Test: Loss 0.57654, Accuracy 0.68636, F1 0.68382
# Epoch [13/100]       | Train: Loss 0.55661, Accuracy 0.69986                             | Test: Loss 0.58065, Accuracy 0.68684, F1 0.68329
# Epoch [14/100]       | Train: Loss 0.55619, Accuracy 0.70178                             | Test: Loss 0.57763, Accuracy 0.68704, F1 0.68358
# Epoch [15/100]       | Train: Loss 0.55488, Accuracy 0.70163                             | Test: Loss 0.57676, Accuracy 0.68976, F1 0.68653
# Epoch [16/100]       | Train: Loss 0.55406, Accuracy 0.70248                             | Test: Loss 0.57652, Accuracy 0.68922, F1 0.68783
# Epoch [17/100]       | Train: Loss 0.55410, Accuracy 0.70210                             | Test: Loss 0.57504, Accuracy 0.69336, F1 0.69339
# Epoch [18/100]       | Train: Loss 0.55228, Accuracy 0.70277                             | Test: Loss 0.57482, Accuracy 0.69207, F1 0.69095
# Epoch [19/100]       | Train: Loss 0.55174, Accuracy 0.70295                             | Test: Loss 0.57994, Accuracy 0.69166, F1 0.69120
# Epoch [20/100]       | Train: Loss 0.55040, Accuracy 0.70414                             | Test: Loss 0.57556, Accuracy 0.69323, F1 0.69248
# Epoch [21/100]       | Train: Loss 0.54993, Accuracy 0.70640                             | Test: Loss 0.57510, Accuracy 0.69384, F1 0.69271
# Epoch [22/100]       | Train: Loss 0.54757, Accuracy 0.70685                             | Test: Loss 0.57694, Accuracy 0.68928, F1 0.68776
# Epoch [23/100]       | Train: Loss 0.54677, Accuracy 0.70825                             | Test: Loss 0.58070, Accuracy 0.69092, F1 0.69106
# Epoch [24/100]       | Train: Loss 0.54627, Accuracy 0.71132                             | Test: Loss 0.57507, Accuracy 0.69262, F1 0.69254
# Epoch [25/100]       | Train: Loss 0.54389, Accuracy 0.71113                             | Test: Loss 0.57623, Accuracy 0.68894, F1 0.68862
# Epoch [26/100]       | Train: Loss 0.54285, Accuracy 0.71338                             | Test: Loss 0.57847, Accuracy 0.69411, F1 0.69406
# Epoch [27/100]       | Train: Loss 0.54053, Accuracy 0.71482                             | Test: Loss 0.57565, Accuracy 0.68820, F1 0.68564
# Epoch [28/100]       | Train: Loss 0.53861, Accuracy 0.71631                             | Test: Loss 0.57841, Accuracy 0.68657, F1 0.68211
# Epoch [29/100]       | Train: Loss 0.53797, Accuracy 0.71752                             | Test: Loss 0.57835, Accuracy 0.69119, F1 0.69010
# Epoch [30/100]       | Train: Loss 0.53597, Accuracy 0.71976                             | Test: Loss 0.57821, Accuracy 0.69017, F1 0.68809
# Epoch [31/100]       | Train: Loss 0.53471, Accuracy 0.71945                             | Test: Loss 0.57771, Accuracy 0.68650, F1 0.68223
# Epoch [32/100]       | Train: Loss 0.53366, Accuracy 0.72164                             | Test: Loss 0.58076, Accuracy 0.68779, F1 0.68487
# Epoch [33/100]       | Train: Loss 0.53037, Accuracy 0.72299                             | Test: Loss 0.58269, Accuracy 0.68990, F1 0.68849
# Epoch [34/100]       | Train: Loss 0.52937, Accuracy 0.72336                             | Test: Loss 0.57980, Accuracy 0.68459, F1 0.67966
# Epoch [35/100]       | Train: Loss 0.52748, Accuracy 0.72586                             | Test: Loss 0.57804, Accuracy 0.68922, F1 0.68934
# Epoch [36/100]       | Train: Loss 0.52616, Accuracy 0.72801                             | Test: Loss 0.57941, Accuracy 0.68480, F1 0.68263
# Epoch [37/100]       | Train: Loss 0.52371, Accuracy 0.73064                             | Test: Loss 0.58302, Accuracy 0.68575, F1 0.68196
# Epoch [38/100]       | Train: Loss 0.52223, Accuracy 0.72990                             | Test: Loss 0.58624, Accuracy 0.68806, F1 0.68815
# Epoch [39/100]       | Train: Loss 0.51886, Accuracy 0.73263                             | Test: Loss 0.58858, Accuracy 0.68833, F1 0.68691
# Epoch [40/100]       | Train: Loss 0.51634, Accuracy 0.73386                             | Test: Loss 0.59709, Accuracy 0.68874, F1 0.68693
# Epoch [41/100]       | Train: Loss 0.51564, Accuracy 0.73687                             | Test: Loss 0.59512, Accuracy 0.68310, F1 0.67815
# Epoch [42/100]       | Train: Loss 0.51275, Accuracy 0.73605                             | Test: Loss 0.60297, Accuracy 0.69003, F1 0.68933
# Epoch [43/100]       | Train: Loss 0.50928, Accuracy 0.74004                             | Test: Loss 0.59475, Accuracy 0.68514, F1 0.68384
# Epoch [44/100]       | Train: Loss 0.50580, Accuracy 0.74335                             | Test: Loss 0.59177, Accuracy 0.68466, F1 0.68410
# Epoch [45/100]       | Train: Loss 0.50404, Accuracy 0.74619                             | Test: Loss 0.60076, Accuracy 0.68303, F1 0.68153
# Epoch [46/100]       | Train: Loss 0.50116, Accuracy 0.74768                             | Test: Loss 0.60071, Accuracy 0.68323, F1 0.68190
# Epoch [47/100]       | Train: Loss 0.49811, Accuracy 0.75014                             | Test: Loss 0.60647, Accuracy 0.68174, F1 0.68124
# Epoch [48/100]       | Train: Loss 0.49493, Accuracy 0.75203                             | Test: Loss 0.60747, Accuracy 0.68473, F1 0.68308
# Epoch [49/100]       | Train: Loss 0.49172, Accuracy 0.75361                             | Test: Loss 0.62214, Accuracy 0.68221, F1 0.67992
# Epoch [50/100]       | Train: Loss 0.48937, Accuracy 0.75416                             | Test: Loss 0.61788, Accuracy 0.68221, F1 0.68224
# Epoch [51/100]       | Train: Loss 0.48537, Accuracy 0.75853                             | Test: Loss 0.62355, Accuracy 0.68235, F1 0.68032
# Epoch [52/100]       | Train: Loss 0.48261, Accuracy 0.76079                             | Test: Loss 0.61938, Accuracy 0.67820, F1 0.67767
# Epoch [53/100]       | Train: Loss 0.47738, Accuracy 0.76239                             | Test: Loss 0.63640, Accuracy 0.67888, F1 0.67880
# Epoch [54/100]       | Train: Loss 0.47500, Accuracy 0.76538                             | Test: Loss 0.64710, Accuracy 0.67283, F1 0.67074
# Epoch [55/100]       | Train: Loss 0.47141, Accuracy 0.76767                             | Test: Loss 0.63919, Accuracy 0.67575, F1 0.67448
# Epoch [56/100]       | Train: Loss 0.46702, Accuracy 0.77058                             | Test: Loss 0.65239, Accuracy 0.67630, F1 0.67604
# Epoch [57/100]       | Train: Loss 0.46267, Accuracy 0.77233                             | Test: Loss 0.64998, Accuracy 0.67419, F1 0.67261
# Epoch [58/100]       | Train: Loss 0.45850, Accuracy 0.77577                             | Test: Loss 0.67447, Accuracy 0.67317, F1 0.67074
# Epoch [59/100]       | Train: Loss 0.45485, Accuracy 0.77705                             | Test: Loss 0.66548, Accuracy 0.67249, F1 0.67175
# Epoch [60/100]       | Train: Loss 0.44867, Accuracy 0.78173                             | Test: Loss 0.69398, Accuracy 0.67521, F1 0.67485
# Epoch [61/100]       | Train: Loss 0.44480, Accuracy 0.78318                             | Test: Loss 0.68070, Accuracy 0.66841, F1 0.66705
# Epoch [62/100]       | Train: Loss 0.43982, Accuracy 0.78518                             | Test: Loss 0.68940, Accuracy 0.67344, F1 0.67299
# Epoch [63/100]       | Train: Loss 0.43360, Accuracy 0.79015                             | Test: Loss 0.69853, Accuracy 0.67018, F1 0.66838
# Epoch [64/100]       | Train: Loss 0.42911, Accuracy 0.79209                             | Test: Loss 0.72158, Accuracy 0.67079, F1 0.67079
# Epoch [65/100]       | Train: Loss 0.42136, Accuracy 0.79531                             | Test: Loss 0.74879, Accuracy 0.66692, F1 0.66651
# Epoch [66/100]       | Train: Loss 0.41868, Accuracy 0.79698                             | Test: Loss 0.73417, Accuracy 0.66909, F1 0.66852
# Epoch [67/100]       | Train: Loss 0.41077, Accuracy 0.80226                             | Test: Loss 0.78055, Accuracy 0.67541, F1 0.67501
# Epoch [68/100]       | Train: Loss 0.40606, Accuracy 0.80603                             | Test: Loss 0.78602, Accuracy 0.66671, F1 0.66642
# Epoch [69/100]       | Train: Loss 0.39827, Accuracy 0.80961                             | Test: Loss 0.79598, Accuracy 0.66766, F1 0.66774
# Epoch [70/100]       | Train: Loss 0.39218, Accuracy 0.81167                             | Test: Loss 0.78691, Accuracy 0.66494, F1 0.66364
# Epoch [71/100]       | Train: Loss 0.38778, Accuracy 0.81617                             | Test: Loss 0.83576, Accuracy 0.66216, F1 0.66195
# Epoch [72/100]       | Train: Loss 0.37900, Accuracy 0.82098                             | Test: Loss 0.84320, Accuracy 0.66528, F1 0.66430
# Epoch [73/100]       | Train: Loss 0.37347, Accuracy 0.82318                             | Test: Loss 0.86964, Accuracy 0.65957, F1 0.65824
# Epoch [74/100]       | Train: Loss 0.36385, Accuracy 0.82796                             | Test: Loss 0.92255, Accuracy 0.66141, F1 0.66134
# Epoch [75/100]       | Train: Loss 0.35819, Accuracy 0.83017                             | Test: Loss 0.94450, Accuracy 0.65481, F1 0.65383
# Epoch [76/100]       | Train: Loss 0.34690, Accuracy 0.83802                             | Test: Loss 0.94085, Accuracy 0.65298, F1 0.65146
# Epoch [77/100]       | Train: Loss 0.33943, Accuracy 0.84098                             | Test: Loss 0.99750, Accuracy 0.65787, F1 0.65799
# Epoch [78/100]       | Train: Loss 0.33141, Accuracy 0.84741                             | Test: Loss 1.04158, Accuracy 0.64965, F1 0.64958
# Epoch [79/100]       | Train: Loss 0.32525, Accuracy 0.84852                             | Test: Loss 0.99231, Accuracy 0.64903, F1 0.64900
# Epoch [80/100]       | Train: Loss 0.31609, Accuracy 0.85526                             | Test: Loss 1.05073, Accuracy 0.65101, F1 0.65109
# Epoch [81/100]       | Train: Loss 0.30459, Accuracy 0.85940                             | Test: Loss 1.11481, Accuracy 0.65407, F1 0.65410
# Epoch [82/100]       | Train: Loss 0.29218, Accuracy 0.86676                             | Test: Loss 1.16748, Accuracy 0.65855, F1 0.65870
# Epoch [83/100]       | Train: Loss 0.28505, Accuracy 0.87055                             | Test: Loss 1.22778, Accuracy 0.65087, F1 0.64968
# Epoch [84/100]       | Train: Loss 0.27474, Accuracy 0.87589                             | Test: Loss 1.22980, Accuracy 0.65053, F1 0.65063
# Epoch [85/100]       | Train: Loss 0.26323, Accuracy 0.88184                             | Test: Loss 1.25620, Accuracy 0.64822, F1 0.64838
# Epoch [86/100]       | Train: Loss 0.25283, Accuracy 0.88679                             | Test: Loss 1.30017, Accuracy 0.65277, F1 0.65287
# Epoch [87/100]       | Train: Loss 0.24496, Accuracy 0.89135                             | Test: Loss 1.47122, Accuracy 0.64659, F1 0.64622
# Epoch [88/100]       | Train: Loss 0.23497, Accuracy 0.89575                             | Test: Loss 1.43588, Accuracy 0.64992, F1 0.64985
# Epoch [89/100]       | Train: Loss 0.22023, Accuracy 0.90321                             | Test: Loss 1.42928, Accuracy 0.64591, F1 0.64592
# Epoch [90/100]       | Train: Loss 0.21385, Accuracy 0.90803                             | Test: Loss 1.49660, Accuracy 0.63924, F1 0.63938
# Epoch [91/100]       | Train: Loss 0.20024, Accuracy 0.91342                             | Test: Loss 1.65329, Accuracy 0.64727, F1 0.64643
# Epoch [92/100]       | Train: Loss 0.19146, Accuracy 0.91828                             | Test: Loss 1.60389, Accuracy 0.63802, F1 0.63786
# Epoch [93/100]       | Train: Loss 0.18345, Accuracy 0.92301                             | Test: Loss 1.59138, Accuracy 0.63251, F1 0.63264
# Epoch [94/100]       | Train: Loss 0.17642, Accuracy 0.92577                             | Test: Loss 1.73550, Accuracy 0.64203, F1 0.64176
# Epoch [95/100]       | Train: Loss 0.16296, Accuracy 0.93207                             | Test: Loss 1.85492, Accuracy 0.65930, F1 0.65854
# Epoch [96/100]       | Train: Loss 0.15279, Accuracy 0.93547                             | Test: Loss 1.91310, Accuracy 0.64849, F1 0.64770
# Epoch [97/100]       | Train: Loss 0.14746, Accuracy 0.94012                             | Test: Loss 1.82043, Accuracy 0.64217, F1 0.64174
# Epoch [98/100]       | Train: Loss 0.14323, Accuracy 0.94245                             | Test: Loss 2.10122, Accuracy 0.65624, F1 0.65614
# Epoch [99/100]       | Train: Loss 0.13781, Accuracy 0.94573                             | Test: Loss 1.91397, Accuracy 0.64169, F1 0.64181
# Epoch [100/100]      | Train: Loss 0.12038, Accuracy 0.95265                             | Test: Loss 2.01989, Accuracy 0.63952, F1 0.63955
# Confusion Matrix for income
# [[4396 2633]
#  [2669 5010]]
# Best accuracy 0.6941120478651074
# Best F1 0.6940613801894018
# 100 epochs of training and evaluation took, 136.15625

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=True,
                       mlp_scale_classification=8,
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       embedding_scheme='rff_unique',
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.63743, Accuracy 0.61866                             | Test: Loss 0.60364, Accuracy 0.66658, F1 0.66653
# Epoch [ 2/100]       | Train: Loss 0.59373, Accuracy 0.67787                             | Test: Loss 0.59737, Accuracy 0.67297, F1 0.67282
# Epoch [ 3/100]       | Train: Loss 0.58248, Accuracy 0.68370                             | Test: Loss 0.58824, Accuracy 0.67847, F1 0.67765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=49'>50</a> for t in range(epochs):
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=50'>51</a>   train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=51'>52</a>   test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=52'>53</a>   train_losses.append(train_loss)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=53'>54</a>   train_accuracies_1.append(train_accuracy_1)
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 4
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=451'>452</a> features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=453'>454</a> #compute prediction error
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=454'>455</a> task_predictions = model(features) #contains a list of the tensor outputs for each task
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=456'>457</a> loss = loss_function(task_predictions, labels_task1)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=457'>458</a> total_loss += loss.item()
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=375'>376</a> def forward(self, x):
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=376'>377</a>     class_embed, context = self.embeddings(x)
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=378'>379</a>     x = self.decoder(class_embed, context)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=380'>381</a>     probability_dist_raw = []
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=381'>382</a>     for i, e in enumerate(self.classifying_heads):
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=112'>113</a> def forward(self, class_embed, context):
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=113'>114</a>     for layer in self.layers:
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=114'>115</a>         # x is the classification embedding (CLS Token)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=115'>116</a>         # context are the feature embeddings that will be used as key and value
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=116'>117</a>         x, self.avg_attention = layer(class_embed, context, context)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=118'>119</a>     return x
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=82'>83</a> def forward(self, x, value, key):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=83'>84</a>     out, avg_attention = self.transformer_block(value, key, x)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=85'>86</a>     return out, avg_attention
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=64'>65</a>     key = self.pre_norm(key)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=65'>66</a>     value = self.pre_norm(value)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=67'>68</a> attention, avg_attention = self.attention(value, key, query)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=68'>69</a> x = self.dropout(self.norm1(attention + query))
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=69'>70</a> forward = self.feed_forward(x)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 7 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=36'>37</a> avg_attention = avg_attention.mean(dim=0).squeeze(dim=0)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=37'>38</a> # print("head average", avg_attention.shape)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=39'>40</a> out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(N, query_len, self.heads*self.head_dim) #(batch_size, n_features, embed_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=40'>41</a> out = self.fc_out(out)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X45sZmlsZQ%3D%3D?line=42'>43</a> return out, avg_attention
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\functional.py:373, in einsum(*args)
#     370     _operands = operands[0]
#     371     # recurse incase operands contains value that has torch function
#     372     # in the original implementation this line is omitted
# --> 373     return einsum(equation, *_operands)
#     375 if len(operands) <= 2 or not opt_einsum.enabled:
#     376     # the path for contracting 0 or 1 time(s) is already optimized
#     377     # or the user has disabled using opt_einsum
#     378     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\functional.py:378, in einsum(*args)
#     373     return einsum(equation, *_operands)
#     375 if len(operands) <= 2 or not opt_einsum.enabled:
#     376     # the path for contracting 0 or 1 time(s) is already optimized
#     377     # or the user has disabled using opt_einsum
# --> 378     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     380 path = None
#     381 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %% [markdown]
# # Mixed Normal RFF

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       embedding_scheme='rff',
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.64686, Accuracy 0.60353                             | Test: Loss 0.60855, Accuracy 0.65828, F1 0.65152
# Epoch [ 2/100]       | Train: Loss 0.59638, Accuracy 0.67652                             | Test: Loss 0.59602, Accuracy 0.67174, F1 0.67080
# Epoch [ 3/100]       | Train: Loss 0.58818, Accuracy 0.68240                             | Test: Loss 0.59262, Accuracy 0.67739, F1 0.67635
# Epoch [ 4/100]       | Train: Loss 0.57970, Accuracy 0.68695                             | Test: Loss 0.58175, Accuracy 0.68106, F1 0.68058
# Epoch [ 5/100]       | Train: Loss 0.57166, Accuracy 0.69004                             | Test: Loss 0.58653, Accuracy 0.68323, F1 0.68195
# Epoch [ 6/100]       | Train: Loss 0.56945, Accuracy 0.69053                             | Test: Loss 0.58319, Accuracy 0.68507, F1 0.68296
# Epoch [ 7/100]       | Train: Loss 0.56534, Accuracy 0.69515                             | Test: Loss 0.57633, Accuracy 0.68589, F1 0.68411
# Epoch [ 8/100]       | Train: Loss 0.56427, Accuracy 0.69366                             | Test: Loss 0.58185, Accuracy 0.68412, F1 0.68412
# Epoch [ 9/100]       | Train: Loss 0.56114, Accuracy 0.69588                             | Test: Loss 0.57700, Accuracy 0.68561, F1 0.68363
# Epoch [10/100]       | Train: Loss 0.55998, Accuracy 0.69744                             | Test: Loss 0.58044, Accuracy 0.68548, F1 0.68335
# Epoch [11/100]       | Train: Loss 0.55922, Accuracy 0.69833                             | Test: Loss 0.57622, Accuracy 0.68364, F1 0.68084
# Epoch [12/100]       | Train: Loss 0.55856, Accuracy 0.69675                             | Test: Loss 0.57464, Accuracy 0.69051, F1 0.69007
# Epoch [13/100]       | Train: Loss 0.55679, Accuracy 0.69869                             | Test: Loss 0.57671, Accuracy 0.68507, F1 0.68075
# Epoch [14/100]       | Train: Loss 0.55534, Accuracy 0.69964                             | Test: Loss 0.57548, Accuracy 0.68833, F1 0.68703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 9 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=47'>48</a> start_time = time.process_time()
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=49'>50</a> for t in range(epochs):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=50'>51</a>   train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=51'>52</a>   test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=52'>53</a>   train_losses.append(train_loss)
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\higgs.ipynb Cell 9 line 4
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=419'>420</a>     all_predictions_1.extend(y_pred_labels_1.cpu().numpy())
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=421'>422</a>     loss.backward()
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=422'>423</a>     optimizer.step()
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=423'>424</a>     optimizer.zero_grad()
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/higgs.ipynb#X13sZmlsZQ%3D%3D?line=425'>426</a> avg_loss = total_loss/len(dataloader)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\optim\optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\optim\optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\optim\adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\optim\adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\optim\adam.py:505, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     503     denom = torch._foreach_add(max_exp_avg_sq_sqrt, eps)
#     504 else:
# --> 505     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#     506     torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#     507     denom = torch._foreach_add(exp_avg_sq_sqrt, eps)
#
# KeyboardInterrupt:

# %% [markdown]
# # Trainable Normal RFF to each feature

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                    
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                     
                       embedding_scheme='normal_periodic',
                       trainable=True,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.70901, Accuracy 0.70014                             | Test: Loss 0.62322, Accuracy 0.72465, F1 0.71807
# Epoch [ 2/100]       | Train: Loss 0.55615, Accuracy 0.75735                             | Test: Loss 0.48600, Accuracy 0.79322, F1 0.78873
# Epoch [ 3/100]       | Train: Loss 0.44603, Accuracy 0.80979                             | Test: Loss 0.38961, Accuracy 0.83404, F1 0.83181
# Epoch [ 4/100]       | Train: Loss 0.36205, Accuracy 0.84797                             | Test: Loss 0.32142, Accuracy 0.87036, F1 0.86951
# Epoch [ 5/100]       | Train: Loss 0.30321, Accuracy 0.87453                             | Test: Loss 0.26983, Accuracy 0.89166, F1 0.89092
# Epoch [ 6/100]       | Train: Loss 0.26417, Accuracy 0.89169                             | Test: Loss 0.23268, Accuracy 0.90792, F1 0.90708
# Epoch [ 7/100]       | Train: Loss 0.23492, Accuracy 0.90455                             | Test: Loss 0.20904, Accuracy 0.91580, F1 0.91572
# Epoch [ 8/100]       | Train: Loss 0.21245, Accuracy 0.91391                             | Test: Loss 0.18711, Accuracy 0.92499, F1 0.92475
# Epoch [ 9/100]       | Train: Loss 0.19452, Accuracy 0.92109                             | Test: Loss 0.17816, Accuracy 0.92849, F1 0.92855
# Epoch [10/100]       | Train: Loss 0.17958, Accuracy 0.92758                             | Test: Loss 0.16339, Accuracy 0.93480, F1 0.93472
# Epoch [11/100]       | Train: Loss 0.16789, Accuracy 0.93207                             | Test: Loss 0.15400, Accuracy 0.93802, F1 0.93802
# Epoch [12/100]       | Train: Loss 0.15689, Accuracy 0.93689                             | Test: Loss 0.14731, Accuracy 0.94109, F1 0.94088
# Epoch [13/100]       | Train: Loss 0.14849, Accuracy 0.93989                             | Test: Loss 0.13977, Accuracy 0.94359, F1 0.94364
# Epoch [14/100]       | Train: Loss 0.14077, Accuracy 0.94358                             | Test: Loss 0.13121, Accuracy 0.94689, F1 0.94687
# Epoch [15/100]       | Train: Loss 0.13345, Accuracy 0.94616                             | Test: Loss 0.12778, Accuracy 0.94785, F1 0.94784
# Epoch [16/100]       | Train: Loss 0.12749, Accuracy 0.94817                             | Test: Loss 0.12549, Accuracy 0.94985, F1 0.94982
# Epoch [17/100]       | Train: Loss 0.12234, Accuracy 0.95019                             | Test: Loss 0.12224, Accuracy 0.95082, F1 0.95081
# Epoch [18/100]       | Train: Loss 0.11714, Accuracy 0.95266                             | Test: Loss 0.11655, Accuracy 0.95359, F1 0.95353
# Epoch [19/100]       | Train: Loss 0.11378, Accuracy 0.95395                             | Test: Loss 0.11314, Accuracy 0.95429, F1 0.95435
# Epoch [20/100]       | Train: Loss 0.10848, Accuracy 0.95624                             | Test: Loss 0.11087, Accuracy 0.95603, F1 0.95600
# Epoch [21/100]       | Train: Loss 0.10543, Accuracy 0.95729                             | Test: Loss 0.10808, Accuracy 0.95629, F1 0.95624
# Epoch [22/100]       | Train: Loss 0.10196, Accuracy 0.95873                             | Test: Loss 0.10743, Accuracy 0.95656, F1 0.95659
# Epoch [23/100]       | Train: Loss 0.09830, Accuracy 0.96017                             | Test: Loss 0.10084, Accuracy 0.95956, F1 0.95950
# Epoch [24/100]       | Train: Loss 0.09533, Accuracy 0.96181                             | Test: Loss 0.09935, Accuracy 0.96025, F1 0.96029
# Epoch [25/100]       | Train: Loss 0.09289, Accuracy 0.96265                             | Test: Loss 0.10174, Accuracy 0.95858, F1 0.95855
# Epoch [26/100]       | Train: Loss 0.08983, Accuracy 0.96341                             | Test: Loss 0.09747, Accuracy 0.96112, F1 0.96109
# Epoch [27/100]       | Train: Loss 0.08783, Accuracy 0.96421                             | Test: Loss 0.09826, Accuracy 0.96051, F1 0.96053
# Epoch [28/100]       | Train: Loss 0.08561, Accuracy 0.96527                             | Test: Loss 0.09811, Accuracy 0.95995, F1 0.95995
# Epoch [29/100]       | Train: Loss 0.08327, Accuracy 0.96616                             | Test: Loss 0.09396, Accuracy 0.96180, F1 0.96182
# Epoch [30/100]       | Train: Loss 0.08137, Accuracy 0.96719                             | Test: Loss 0.09086, Accuracy 0.96378, F1 0.96381
# Epoch [31/100]       | Train: Loss 0.07973, Accuracy 0.96748                             | Test: Loss 0.08963, Accuracy 0.96395, F1 0.96394
# Epoch [32/100]       | Train: Loss 0.07739, Accuracy 0.96856                             | Test: Loss 0.09550, Accuracy 0.96127, F1 0.96134
# Epoch [33/100]       | Train: Loss 0.07529, Accuracy 0.96927                             | Test: Loss 0.09261, Accuracy 0.96282, F1 0.96281
# Epoch [34/100]       | Train: Loss 0.07437, Accuracy 0.96958                             | Test: Loss 0.08888, Accuracy 0.96479, F1 0.96480
# Epoch [35/100]       | Train: Loss 0.07257, Accuracy 0.97068                             | Test: Loss 0.08818, Accuracy 0.96525, F1 0.96526
# Epoch [36/100]       | Train: Loss 0.07087, Accuracy 0.97118                             | Test: Loss 0.08887, Accuracy 0.96453, F1 0.96452
# Epoch [37/100]       | Train: Loss 0.06998, Accuracy 0.97162                             | Test: Loss 0.08782, Accuracy 0.96482, F1 0.96478
# Epoch [38/100]       | Train: Loss 0.06808, Accuracy 0.97232                             | Test: Loss 0.08899, Accuracy 0.96529, F1 0.96527
# Epoch [39/100]       | Train: Loss 0.06717, Accuracy 0.97277                             | Test: Loss 0.08758, Accuracy 0.96527, F1 0.96530
# Epoch [40/100]       | Train: Loss 0.06603, Accuracy 0.97314                             | Test: Loss 0.08654, Accuracy 0.96620, F1 0.96620
# Epoch [41/100]       | Train: Loss 0.06493, Accuracy 0.97338                             | Test: Loss 0.08387, Accuracy 0.96657, F1 0.96656
# Epoch [42/100]       | Train: Loss 0.06280, Accuracy 0.97469                             | Test: Loss 0.08598, Accuracy 0.96654, F1 0.96659
# Epoch [43/100]       | Train: Loss 0.06189, Accuracy 0.97484                             | Test: Loss 0.08570, Accuracy 0.96640, F1 0.96640
# Epoch [44/100]       | Train: Loss 0.06104, Accuracy 0.97530                             | Test: Loss 0.08501, Accuracy 0.96683, F1 0.96683
# Epoch [45/100]       | Train: Loss 0.06038, Accuracy 0.97547                             | Test: Loss 0.08225, Accuracy 0.96744, F1 0.96746
# Epoch [46/100]       | Train: Loss 0.05889, Accuracy 0.97587                             | Test: Loss 0.08609, Accuracy 0.96655, F1 0.96658
# Epoch [47/100]       | Train: Loss 0.05811, Accuracy 0.97615                             | Test: Loss 0.08521, Accuracy 0.96725, F1 0.96726
# Epoch [48/100]       | Train: Loss 0.05705, Accuracy 0.97717                             | Test: Loss 0.08696, Accuracy 0.96634, F1 0.96638
# Epoch [49/100]       | Train: Loss 0.05627, Accuracy 0.97738                             | Test: Loss 0.08357, Accuracy 0.96818, F1 0.96822
# Epoch [50/100]       | Train: Loss 0.05524, Accuracy 0.97740                             | Test: Loss 0.08457, Accuracy 0.96754, F1 0.96757
# Epoch [51/100]       | Train: Loss 0.05425, Accuracy 0.97785                             | Test: Loss 0.08255, Accuracy 0.96833, F1 0.96830
# Epoch [52/100]       | Train: Loss 0.05330, Accuracy 0.97812                             | Test: Loss 0.08744, Accuracy 0.96739, F1 0.96742
# Epoch [53/100]       | Train: Loss 0.05278, Accuracy 0.97860                             | Test: Loss 0.08476, Accuracy 0.96883, F1 0.96881
# Epoch [54/100]       | Train: Loss 0.05275, Accuracy 0.97824                             | Test: Loss 0.08476, Accuracy 0.96861, F1 0.96865
# Epoch [55/100]       | Train: Loss 0.05151, Accuracy 0.97911                             | Test: Loss 0.08286, Accuracy 0.96915, F1 0.96917
# Epoch [56/100]       | Train: Loss 0.05064, Accuracy 0.97962                             | Test: Loss 0.08240, Accuracy 0.96880, F1 0.96881
# Epoch [57/100]       | Train: Loss 0.04914, Accuracy 0.98003                             | Test: Loss 0.08541, Accuracy 0.96862, F1 0.96859
# Epoch [58/100]       | Train: Loss 0.04921, Accuracy 0.97983                             | Test: Loss 0.08469, Accuracy 0.96924, F1 0.96926
# Epoch [59/100]       | Train: Loss 0.04828, Accuracy 0.98046                             | Test: Loss 0.08467, Accuracy 0.96834, F1 0.96834
# Epoch [60/100]       | Train: Loss 0.04803, Accuracy 0.98031                             | Test: Loss 0.08281, Accuracy 0.96935, F1 0.96937
# Epoch [61/100]       | Train: Loss 0.04681, Accuracy 0.98072                             | Test: Loss 0.08542, Accuracy 0.96886, F1 0.96886
# Epoch [62/100]       | Train: Loss 0.04631, Accuracy 0.98130                             | Test: Loss 0.08434, Accuracy 0.96929, F1 0.96930
# Epoch [63/100]       | Train: Loss 0.04594, Accuracy 0.98111                             | Test: Loss 0.08726, Accuracy 0.96837, F1 0.96837
# Epoch [64/100]       | Train: Loss 0.04536, Accuracy 0.98150                             | Test: Loss 0.08467, Accuracy 0.96969, F1 0.96969
# Epoch [65/100]       | Train: Loss 0.04460, Accuracy 0.98194                             | Test: Loss 0.08676, Accuracy 0.96909, F1 0.96910
# Epoch [66/100]       | Train: Loss 0.04436, Accuracy 0.98212                             | Test: Loss 0.08514, Accuracy 0.96930, F1 0.96934
# Epoch [67/100]       | Train: Loss 0.04381, Accuracy 0.98235                             | Test: Loss 0.08498, Accuracy 0.96958, F1 0.96958
# Epoch [68/100]       | Train: Loss 0.04223, Accuracy 0.98277                             | Test: Loss 0.08506, Accuracy 0.96955, F1 0.96956
# Epoch [69/100]       | Train: Loss 0.04207, Accuracy 0.98310                             | Test: Loss 0.08583, Accuracy 0.97017, F1 0.97019
# Epoch [70/100]       | Train: Loss 0.04236, Accuracy 0.98280                             | Test: Loss 0.08639, Accuracy 0.96933, F1 0.96935
# Epoch [71/100]       | Train: Loss 0.04123, Accuracy 0.98330                             | Test: Loss 0.08656, Accuracy 0.96985, F1 0.96988
# Epoch [72/100]       | Train: Loss 0.04040, Accuracy 0.98351                             | Test: Loss 0.08763, Accuracy 0.96913, F1 0.96914
# Epoch [73/100]       | Train: Loss 0.04026, Accuracy 0.98357                             | Test: Loss 0.08614, Accuracy 0.96951, F1 0.96951
# Epoch [74/100]       | Train: Loss 0.03969, Accuracy 0.98400                             | Test: Loss 0.09001, Accuracy 0.96904, F1 0.96907
# Epoch [75/100]       | Train: Loss 0.03948, Accuracy 0.98422                             | Test: Loss 0.08784, Accuracy 0.96979, F1 0.96981
# Epoch [76/100]       | Train: Loss 0.03825, Accuracy 0.98462                             | Test: Loss 0.08771, Accuracy 0.96990, F1 0.96993
# Epoch [77/100]       | Train: Loss 0.03852, Accuracy 0.98459                             | Test: Loss 0.08666, Accuracy 0.97004, F1 0.97005
# Epoch [78/100]       | Train: Loss 0.03806, Accuracy 0.98469                             | Test: Loss 0.08752, Accuracy 0.97021, F1 0.97022
# Epoch [79/100]       | Train: Loss 0.03771, Accuracy 0.98477                             | Test: Loss 0.08542, Accuracy 0.97095, F1 0.97098
# Epoch [80/100]       | Train: Loss 0.03683, Accuracy 0.98496                             | Test: Loss 0.08731, Accuracy 0.97010, F1 0.97012
# Epoch [81/100]       | Train: Loss 0.03632, Accuracy 0.98540                             | Test: Loss 0.08999, Accuracy 0.96981, F1 0.96983
# Epoch [82/100]       | Train: Loss 0.03644, Accuracy 0.98550                             | Test: Loss 0.09032, Accuracy 0.97027, F1 0.97027
# Epoch [83/100]       | Train: Loss 0.03592, Accuracy 0.98529                             | Test: Loss 0.09101, Accuracy 0.97030, F1 0.97031
# Epoch [84/100]       | Train: Loss 0.03556, Accuracy 0.98548                             | Test: Loss 0.09173, Accuracy 0.97022, F1 0.97023
# Epoch [85/100]       | Train: Loss 0.03516, Accuracy 0.98591                             | Test: Loss 0.09251, Accuracy 0.97012, F1 0.97011
# Epoch [86/100]       | Train: Loss 0.03475, Accuracy 0.98599                             | Test: Loss 0.09283, Accuracy 0.96976, F1 0.96976
# Epoch [87/100]       | Train: Loss 0.03413, Accuracy 0.98633                             | Test: Loss 0.09355, Accuracy 0.96955, F1 0.96957
# Epoch [88/100]       | Train: Loss 0.03382, Accuracy 0.98654                             | Test: Loss 0.09311, Accuracy 0.97078, F1 0.97079
# Epoch [89/100]       | Train: Loss 0.03363, Accuracy 0.98674                             | Test: Loss 0.09106, Accuracy 0.97049, F1 0.97053
# Epoch [90/100]       | Train: Loss 0.03354, Accuracy 0.98639                             | Test: Loss 0.09140, Accuracy 0.97061, F1 0.97061
# Epoch [91/100]       | Train: Loss 0.03268, Accuracy 0.98674                             | Test: Loss 0.09331, Accuracy 0.97047, F1 0.97045
# Epoch [92/100]       | Train: Loss 0.03278, Accuracy 0.98688                             | Test: Loss 0.09333, Accuracy 0.97016, F1 0.97018
# Epoch [93/100]       | Train: Loss 0.03205, Accuracy 0.98712                             | Test: Loss 0.09425, Accuracy 0.97059, F1 0.97059
# Epoch [94/100]       | Train: Loss 0.03226, Accuracy 0.98703                             | Test: Loss 0.09508, Accuracy 0.97021, F1 0.97019
# Epoch [95/100]       | Train: Loss 0.03105, Accuracy 0.98736                             | Test: Loss 0.09465, Accuracy 0.97057, F1 0.97056
# Epoch [96/100]       | Train: Loss 0.03121, Accuracy 0.98746                             | Test: Loss 0.09199, Accuracy 0.97084, F1 0.97083
# Epoch [97/100]       | Train: Loss 0.03113, Accuracy 0.98748                             | Test: Loss 0.09540, Accuracy 0.97031, F1 0.97031
# Epoch [98/100]       | Train: Loss 0.03056, Accuracy 0.98778                             | Test: Loss 0.09712, Accuracy 0.97005, F1 0.97009
# Epoch [99/100]       | Train: Loss 0.03030, Accuracy 0.98793                             | Test: Loss 0.09478, Accuracy 0.97014, F1 0.97013
# Epoch [100/100]      | Train: Loss 0.03031, Accuracy 0.98780                             | Test: Loss 0.09661, Accuracy 0.97050, F1 0.97051
# Confusion Matrix for income
# [[41046  1042     0     0    17     3    96]
#  [ 1167 55446    60     0   154    67    18]
#  [    3    72  6844    39    13   123     0]
#  [    0     0    25   490     0    18     0]
#  [   23   148    20     0  1762     9     0]
#  [    5    63    84    24     1  3283     0]
#  [  115    16     0     0     3     0  3904]]
# Best accuracy 0.9709473937850142
# Best F1 0.9709755721094147
# 100 epochs of training and evaluation took, 9869.586433606997

# %% [markdown]
# # Trainable Log-Linear RFF to each feature

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                  
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                     
                       embedding_scheme='log-linear_periodic',
                       trainable=True,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.70018, Accuracy 0.70035                             | Test: Loss 0.59104, Accuracy 0.74221, F1 0.73523
# Epoch [ 2/100]       | Train: Loss 0.55068, Accuracy 0.76077                             | Test: Loss 0.49736, Accuracy 0.78254, F1 0.77744
# Epoch [ 3/100]       | Train: Loss 0.45527, Accuracy 0.80565                             | Test: Loss 0.39577, Accuracy 0.83227, F1 0.83041
# Epoch [ 4/100]       | Train: Loss 0.37279, Accuracy 0.84286                             | Test: Loss 0.32280, Accuracy 0.86727, F1 0.86588
# Epoch [ 5/100]       | Train: Loss 0.31701, Accuracy 0.86839                             | Test: Loss 0.27588, Accuracy 0.88867, F1 0.88793
# Epoch [ 6/100]       | Train: Loss 0.27623, Accuracy 0.88674                             | Test: Loss 0.24771, Accuracy 0.89981, F1 0.89922
# Epoch [ 7/100]       | Train: Loss 0.24736, Accuracy 0.89879                             | Test: Loss 0.22706, Accuracy 0.90829, F1 0.90769
# Epoch [ 8/100]       | Train: Loss 0.22668, Accuracy 0.90790                             | Test: Loss 0.19961, Accuracy 0.92065, F1 0.92042
# Epoch [ 9/100]       | Train: Loss 0.20880, Accuracy 0.91501                             | Test: Loss 0.18794, Accuracy 0.92541, F1 0.92533
# Epoch [10/100]       | Train: Loss 0.19557, Accuracy 0.91996                             | Test: Loss 0.17559, Accuracy 0.92951, F1 0.92937
# Epoch [11/100]       | Train: Loss 0.18316, Accuracy 0.92549                             | Test: Loss 0.17410, Accuracy 0.92899, F1 0.92870
# Epoch [12/100]       | Train: Loss 0.17189, Accuracy 0.92997                             | Test: Loss 0.16101, Accuracy 0.93558, F1 0.93549
# Epoch [13/100]       | Train: Loss 0.16389, Accuracy 0.93366                             | Test: Loss 0.15442, Accuracy 0.93709, F1 0.93712
# Epoch [14/100]       | Train: Loss 0.15609, Accuracy 0.93653                             | Test: Loss 0.14316, Accuracy 0.94165, F1 0.94160
# Epoch [15/100]       | Train: Loss 0.14913, Accuracy 0.93905                             | Test: Loss 0.14302, Accuracy 0.94298, F1 0.94291
# Epoch [16/100]       | Train: Loss 0.14324, Accuracy 0.94172                             | Test: Loss 0.13433, Accuracy 0.94592, F1 0.94590
# Epoch [17/100]       | Train: Loss 0.13719, Accuracy 0.94437                             | Test: Loss 0.13059, Accuracy 0.94714, F1 0.94699
# Epoch [18/100]       | Train: Loss 0.13260, Accuracy 0.94594                             | Test: Loss 0.12748, Accuracy 0.94879, F1 0.94879
# Epoch [19/100]       | Train: Loss 0.12787, Accuracy 0.94805                             | Test: Loss 0.12667, Accuracy 0.94885, F1 0.94877
# Epoch [20/100]       | Train: Loss 0.12276, Accuracy 0.94992                             | Test: Loss 0.12153, Accuracy 0.95054, F1 0.95056
# Epoch [21/100]       | Train: Loss 0.11963, Accuracy 0.95160                             | Test: Loss 0.11644, Accuracy 0.95256, F1 0.95250
# Epoch [22/100]       | Train: Loss 0.11590, Accuracy 0.95320                             | Test: Loss 0.11725, Accuracy 0.95268, F1 0.95264
# Epoch [23/100]       | Train: Loss 0.11322, Accuracy 0.95411                             | Test: Loss 0.11557, Accuracy 0.95361, F1 0.95358
# Epoch [24/100]       | Train: Loss 0.10905, Accuracy 0.95570                             | Test: Loss 0.11241, Accuracy 0.95437, F1 0.95441
# Epoch [25/100]       | Train: Loss 0.10675, Accuracy 0.95654                             | Test: Loss 0.11091, Accuracy 0.95488, F1 0.95488
# Epoch [26/100]       | Train: Loss 0.10459, Accuracy 0.95750                             | Test: Loss 0.10670, Accuracy 0.95634, F1 0.95633
# Epoch [27/100]       | Train: Loss 0.10131, Accuracy 0.95884                             | Test: Loss 0.10468, Accuracy 0.95794, F1 0.95793
# Epoch [28/100]       | Train: Loss 0.09918, Accuracy 0.95914                             | Test: Loss 0.10591, Accuracy 0.95689, F1 0.95684
# Epoch [29/100]       | Train: Loss 0.09669, Accuracy 0.96090                             | Test: Loss 0.10251, Accuracy 0.95841, F1 0.95841
# Epoch [30/100]       | Train: Loss 0.09472, Accuracy 0.96177                             | Test: Loss 0.09960, Accuracy 0.95961, F1 0.95963
# Epoch [31/100]       | Train: Loss 0.09239, Accuracy 0.96236                             | Test: Loss 0.10145, Accuracy 0.95936, F1 0.95937
# Epoch [32/100]       | Train: Loss 0.09119, Accuracy 0.96269                             | Test: Loss 0.10035, Accuracy 0.96006, F1 0.96005
# Epoch [33/100]       | Train: Loss 0.08947, Accuracy 0.96354                             | Test: Loss 0.09901, Accuracy 0.96010, F1 0.96014
# Epoch [34/100]       | Train: Loss 0.08656, Accuracy 0.96482                             | Test: Loss 0.09738, Accuracy 0.96040, F1 0.96040
# Epoch [35/100]       | Train: Loss 0.08588, Accuracy 0.96484                             | Test: Loss 0.09545, Accuracy 0.96199, F1 0.96197
# Epoch [36/100]       | Train: Loss 0.08450, Accuracy 0.96521                             | Test: Loss 0.09322, Accuracy 0.96247, F1 0.96250
# Epoch [37/100]       | Train: Loss 0.08260, Accuracy 0.96623                             | Test: Loss 0.09597, Accuracy 0.96181, F1 0.96179
# Epoch [38/100]       | Train: Loss 0.08102, Accuracy 0.96697                             | Test: Loss 0.09448, Accuracy 0.96257, F1 0.96262
# Epoch [39/100]       | Train: Loss 0.07919, Accuracy 0.96786                             | Test: Loss 0.09485, Accuracy 0.96226, F1 0.96230
# Epoch [40/100]       | Train: Loss 0.07839, Accuracy 0.96809                             | Test: Loss 0.09416, Accuracy 0.96305, F1 0.96306
# Epoch [41/100]       | Train: Loss 0.07796, Accuracy 0.96808                             | Test: Loss 0.09075, Accuracy 0.96341, F1 0.96344
# Epoch [42/100]       | Train: Loss 0.07666, Accuracy 0.96825                             | Test: Loss 0.09324, Accuracy 0.96302, F1 0.96303
# Epoch [43/100]       | Train: Loss 0.07516, Accuracy 0.96925                             | Test: Loss 0.09233, Accuracy 0.96348, F1 0.96346
# Epoch [44/100]       | Train: Loss 0.07405, Accuracy 0.96983                             | Test: Loss 0.09248, Accuracy 0.96343, F1 0.96349
# Epoch [45/100]       | Train: Loss 0.07247, Accuracy 0.97024                             | Test: Loss 0.09513, Accuracy 0.96244, F1 0.96245
# Epoch [46/100]       | Train: Loss 0.07134, Accuracy 0.97093                             | Test: Loss 0.08765, Accuracy 0.96528, F1 0.96525
# Epoch [47/100]       | Train: Loss 0.07067, Accuracy 0.97141                             | Test: Loss 0.09212, Accuracy 0.96352, F1 0.96353
# Epoch [48/100]       | Train: Loss 0.06932, Accuracy 0.97167                             | Test: Loss 0.09008, Accuracy 0.96479, F1 0.96477
# Epoch [49/100]       | Train: Loss 0.06839, Accuracy 0.97192                             | Test: Loss 0.09024, Accuracy 0.96490, F1 0.96490
# Epoch [50/100]       | Train: Loss 0.06807, Accuracy 0.97210                             | Test: Loss 0.09016, Accuracy 0.96460, F1 0.96464
# Epoch [51/100]       | Train: Loss 0.06626, Accuracy 0.97300                             | Test: Loss 0.09321, Accuracy 0.96348, F1 0.96351
# Epoch [52/100]       | Train: Loss 0.06553, Accuracy 0.97351                             | Test: Loss 0.09064, Accuracy 0.96482, F1 0.96485
# Epoch [53/100]       | Train: Loss 0.06556, Accuracy 0.97331                             | Test: Loss 0.09415, Accuracy 0.96375, F1 0.96375
# Epoch [54/100]       | Train: Loss 0.06411, Accuracy 0.97393                             | Test: Loss 0.08942, Accuracy 0.96609, F1 0.96609
# Epoch [55/100]       | Train: Loss 0.06371, Accuracy 0.97402                             | Test: Loss 0.08634, Accuracy 0.96611, F1 0.96616
# Epoch [56/100]       | Train: Loss 0.06236, Accuracy 0.97457                             | Test: Loss 0.08868, Accuracy 0.96590, F1 0.96592
# Epoch [57/100]       | Train: Loss 0.06182, Accuracy 0.97461                             | Test: Loss 0.08531, Accuracy 0.96695, F1 0.96694
# Epoch [58/100]       | Train: Loss 0.06165, Accuracy 0.97478                             | Test: Loss 0.08714, Accuracy 0.96671, F1 0.96671
# Epoch [59/100]       | Train: Loss 0.06032, Accuracy 0.97539                             | Test: Loss 0.08790, Accuracy 0.96617, F1 0.96617
# Epoch [60/100]       | Train: Loss 0.05938, Accuracy 0.97582                             | Test: Loss 0.08659, Accuracy 0.96697, F1 0.96699
# Epoch [61/100]       | Train: Loss 0.05934, Accuracy 0.97593                             | Test: Loss 0.08688, Accuracy 0.96671, F1 0.96674
# Epoch [62/100]       | Train: Loss 0.05778, Accuracy 0.97630                             | Test: Loss 0.08905, Accuracy 0.96658, F1 0.96659
# Epoch [63/100]       | Train: Loss 0.05738, Accuracy 0.97665                             | Test: Loss 0.08773, Accuracy 0.96705, F1 0.96703
# Epoch [64/100]       | Train: Loss 0.05769, Accuracy 0.97656                             | Test: Loss 0.08667, Accuracy 0.96683, F1 0.96686
# Epoch [65/100]       | Train: Loss 0.05654, Accuracy 0.97672                             | Test: Loss 0.08791, Accuracy 0.96693, F1 0.96693
# Epoch [66/100]       | Train: Loss 0.05562, Accuracy 0.97735                             | Test: Loss 0.08898, Accuracy 0.96683, F1 0.96684
# Epoch [67/100]       | Train: Loss 0.05480, Accuracy 0.97738                             | Test: Loss 0.08660, Accuracy 0.96818, F1 0.96821
# Epoch [68/100]       | Train: Loss 0.05492, Accuracy 0.97747                             | Test: Loss 0.08564, Accuracy 0.96807, F1 0.96806
# Epoch [69/100]       | Train: Loss 0.05390, Accuracy 0.97830                             | Test: Loss 0.08838, Accuracy 0.96705, F1 0.96705
# Epoch [70/100]       | Train: Loss 0.05316, Accuracy 0.97852                             | Test: Loss 0.08757, Accuracy 0.96726, F1 0.96727
# Epoch [71/100]       | Train: Loss 0.05339, Accuracy 0.97810                             | Test: Loss 0.08630, Accuracy 0.96804, F1 0.96807
# Epoch [72/100]       | Train: Loss 0.05226, Accuracy 0.97835                             | Test: Loss 0.08681, Accuracy 0.96841, F1 0.96839
# Epoch [73/100]       | Train: Loss 0.05210, Accuracy 0.97855                             | Test: Loss 0.08712, Accuracy 0.96805, F1 0.96805
# Epoch [74/100]       | Train: Loss 0.05139, Accuracy 0.97921                             | Test: Loss 0.08544, Accuracy 0.96811, F1 0.96814
# Epoch [75/100]       | Train: Loss 0.05100, Accuracy 0.97920                             | Test: Loss 0.08850, Accuracy 0.96776, F1 0.96780
# Epoch [76/100]       | Train: Loss 0.04976, Accuracy 0.97957                             | Test: Loss 0.09028, Accuracy 0.96718, F1 0.96720
# Epoch [77/100]       | Train: Loss 0.04957, Accuracy 0.97976                             | Test: Loss 0.09028, Accuracy 0.96677, F1 0.96681
# Epoch [78/100]       | Train: Loss 0.04946, Accuracy 0.97970                             | Test: Loss 0.09058, Accuracy 0.96763, F1 0.96763
# Epoch [79/100]       | Train: Loss 0.04890, Accuracy 0.97979                             | Test: Loss 0.08689, Accuracy 0.96859, F1 0.96857
# Epoch [80/100]       | Train: Loss 0.04816, Accuracy 0.98031                             | Test: Loss 0.08665, Accuracy 0.96863, F1 0.96866
# Epoch [81/100]       | Train: Loss 0.04807, Accuracy 0.98034                             | Test: Loss 0.08795, Accuracy 0.96847, F1 0.96847
# Epoch [82/100]       | Train: Loss 0.04744, Accuracy 0.98059                             | Test: Loss 0.08594, Accuracy 0.96899, F1 0.96899
# Epoch [83/100]       | Train: Loss 0.04699, Accuracy 0.98073                             | Test: Loss 0.08886, Accuracy 0.96818, F1 0.96822
# Epoch [84/100]       | Train: Loss 0.04625, Accuracy 0.98113                             | Test: Loss 0.08834, Accuracy 0.96824, F1 0.96827
# Epoch [85/100]       | Train: Loss 0.04615, Accuracy 0.98104                             | Test: Loss 0.08854, Accuracy 0.96878, F1 0.96878
# Epoch [86/100]       | Train: Loss 0.04596, Accuracy 0.98142                             | Test: Loss 0.08738, Accuracy 0.96896, F1 0.96899
# Epoch [87/100]       | Train: Loss 0.04581, Accuracy 0.98137                             | Test: Loss 0.08788, Accuracy 0.96838, F1 0.96840
# Epoch [88/100]       | Train: Loss 0.04526, Accuracy 0.98152                             | Test: Loss 0.09014, Accuracy 0.96849, F1 0.96851
# Epoch [89/100]       | Train: Loss 0.04398, Accuracy 0.98219                             | Test: Loss 0.09026, Accuracy 0.96809, F1 0.96810
# Epoch [90/100]       | Train: Loss 0.04497, Accuracy 0.98172                             | Test: Loss 0.08929, Accuracy 0.96874, F1 0.96876
# Epoch [91/100]       | Train: Loss 0.04398, Accuracy 0.98200                             | Test: Loss 0.09252, Accuracy 0.96773, F1 0.96773
# Epoch [92/100]       | Train: Loss 0.04338, Accuracy 0.98240                             | Test: Loss 0.08684, Accuracy 0.96945, F1 0.96946
# Epoch [93/100]       | Train: Loss 0.04335, Accuracy 0.98235                             | Test: Loss 0.08807, Accuracy 0.96979, F1 0.96980
# Epoch [94/100]       | Train: Loss 0.04266, Accuracy 0.98232                             | Test: Loss 0.09065, Accuracy 0.96880, F1 0.96882
# Epoch [95/100]       | Train: Loss 0.04283, Accuracy 0.98257                             | Test: Loss 0.08873, Accuracy 0.96897, F1 0.96898
# Epoch [96/100]       | Train: Loss 0.04218, Accuracy 0.98293                             | Test: Loss 0.09109, Accuracy 0.96866, F1 0.96867
# Epoch [97/100]       | Train: Loss 0.04181, Accuracy 0.98283                             | Test: Loss 0.09320, Accuracy 0.96772, F1 0.96773
# Epoch [98/100]       | Train: Loss 0.04082, Accuracy 0.98332                             | Test: Loss 0.09186, Accuracy 0.96927, F1 0.96929
# Epoch [99/100]       | Train: Loss 0.04121, Accuracy 0.98331                             | Test: Loss 0.09005, Accuracy 0.96893, F1 0.96894
# Epoch [100/100]      | Train: Loss 0.04082, Accuracy 0.98346                             | Test: Loss 0.09182, Accuracy 0.96896, F1 0.96892
# Confusion Matrix for income
# [[40834  1249     0     0    14     2   105]
#  [ 1102 55532    73     0   125    60    20]
#  [    3    58  6870    28    10   125     0]
#  [    0     0    41   475     0    17     0]
#  [   24   198    23     0  1706    11     0]
#  [    6    70    89    17     3  3275     0]
#  [  114    17     0     0     3     0  3904]]
# Best accuracy 0.9697856337616069
# Best F1 0.9698009920264065
# 100 epochs of training and evaluation took, 9861.767207673998

# %% [markdown]
# # Log-Linear RFF to each feature

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.69703, Accuracy 0.70673                             | Test: Loss 0.60324, Accuracy 0.74253, F1 0.73672
# Epoch [ 2/100]       | Train: Loss 0.55970, Accuracy 0.75824                             | Test: Loss 0.50378, Accuracy 0.78209, F1 0.77630
# Epoch [ 3/100]       | Train: Loss 0.47543, Accuracy 0.79461                             | Test: Loss 0.43131, Accuracy 0.81469, F1 0.81223
# Epoch [ 4/100]       | Train: Loss 0.39748, Accuracy 0.83167                             | Test: Loss 0.34499, Accuracy 0.85832, F1 0.85673
# Epoch [ 5/100]       | Train: Loss 0.33471, Accuracy 0.86089                             | Test: Loss 0.29385, Accuracy 0.87998, F1 0.87919
# Epoch [ 6/100]       | Train: Loss 0.28897, Accuracy 0.88158                             | Test: Loss 0.25457, Accuracy 0.89563, F1 0.89473
# Epoch [ 7/100]       | Train: Loss 0.25633, Accuracy 0.89515                             | Test: Loss 0.22647, Accuracy 0.90865, F1 0.90797
# Epoch [ 8/100]       | Train: Loss 0.23248, Accuracy 0.90552                             | Test: Loss 0.20907, Accuracy 0.91617, F1 0.91606
# Epoch [ 9/100]       | Train: Loss 0.21348, Accuracy 0.91317                             | Test: Loss 0.18995, Accuracy 0.92399, F1 0.92396
# Epoch [10/100]       | Train: Loss 0.19763, Accuracy 0.92027                             | Test: Loss 0.17778, Accuracy 0.92841, F1 0.92799
# Epoch [11/100]       | Train: Loss 0.18596, Accuracy 0.92499                             | Test: Loss 0.16963, Accuracy 0.93111, F1 0.93075
# Epoch [12/100]       | Train: Loss 0.17431, Accuracy 0.92984                             | Test: Loss 0.16546, Accuracy 0.93293, F1 0.93262
# Epoch [13/100]       | Train: Loss 0.16492, Accuracy 0.93339                             | Test: Loss 0.14884, Accuracy 0.93936, F1 0.93922
# Epoch [14/100]       | Train: Loss 0.15659, Accuracy 0.93638                             | Test: Loss 0.14498, Accuracy 0.94101, F1 0.94100
# Epoch [15/100]       | Train: Loss 0.14991, Accuracy 0.93939                             | Test: Loss 0.14080, Accuracy 0.94221, F1 0.94222
# Epoch [16/100]       | Train: Loss 0.14278, Accuracy 0.94227                             | Test: Loss 0.13907, Accuracy 0.94317, F1 0.94302
# Epoch [17/100]       | Train: Loss 0.13732, Accuracy 0.94451                             | Test: Loss 0.13159, Accuracy 0.94686, F1 0.94687
# Epoch [18/100]       | Train: Loss 0.13215, Accuracy 0.94639                             | Test: Loss 0.12391, Accuracy 0.94908, F1 0.94910
# Epoch [19/100]       | Train: Loss 0.12772, Accuracy 0.94809                             | Test: Loss 0.12273, Accuracy 0.95019, F1 0.95007
# Epoch [20/100]       | Train: Loss 0.12248, Accuracy 0.95034                             | Test: Loss 0.12242, Accuracy 0.95069, F1 0.95066
# Epoch [21/100]       | Train: Loss 0.11983, Accuracy 0.95155                             | Test: Loss 0.11741, Accuracy 0.95218, F1 0.95222
# Epoch [22/100]       | Train: Loss 0.11551, Accuracy 0.95287                             | Test: Loss 0.11622, Accuracy 0.95272, F1 0.95265
# Epoch [23/100]       | Train: Loss 0.11255, Accuracy 0.95455                             | Test: Loss 0.11587, Accuracy 0.95247, F1 0.95251
# Epoch [24/100]       | Train: Loss 0.10939, Accuracy 0.95569                             | Test: Loss 0.11373, Accuracy 0.95374, F1 0.95375
# Epoch [25/100]       | Train: Loss 0.10604, Accuracy 0.95718                             | Test: Loss 0.10816, Accuracy 0.95606, F1 0.95611
# Epoch [26/100]       | Train: Loss 0.10379, Accuracy 0.95776                             | Test: Loss 0.10863, Accuracy 0.95599, F1 0.95611
# Epoch [27/100]       | Train: Loss 0.10181, Accuracy 0.95868                             | Test: Loss 0.10340, Accuracy 0.95800, F1 0.95797
# Epoch [28/100]       | Train: Loss 0.09885, Accuracy 0.95980                             | Test: Loss 0.10421, Accuracy 0.95815, F1 0.95819
# Epoch [29/100]       | Train: Loss 0.09628, Accuracy 0.96086                             | Test: Loss 0.10229, Accuracy 0.95849, F1 0.95848
# Epoch [30/100]       | Train: Loss 0.09452, Accuracy 0.96143                             | Test: Loss 0.10115, Accuracy 0.95890, F1 0.95893
# Epoch [31/100]       | Train: Loss 0.09262, Accuracy 0.96226                             | Test: Loss 0.10194, Accuracy 0.95900, F1 0.95896
# Epoch [32/100]       | Train: Loss 0.09093, Accuracy 0.96302                             | Test: Loss 0.09916, Accuracy 0.96001, F1 0.95995
# Epoch [33/100]       | Train: Loss 0.08891, Accuracy 0.96384                             | Test: Loss 0.10079, Accuracy 0.95894, F1 0.95894
# Epoch [34/100]       | Train: Loss 0.08599, Accuracy 0.96491                             | Test: Loss 0.09887, Accuracy 0.96016, F1 0.96012
# Epoch [35/100]       | Train: Loss 0.08602, Accuracy 0.96456                             | Test: Loss 0.09575, Accuracy 0.96197, F1 0.96202
# Epoch [36/100]       | Train: Loss 0.08310, Accuracy 0.96591                             | Test: Loss 0.09370, Accuracy 0.96253, F1 0.96252
# Epoch [37/100]       | Train: Loss 0.08250, Accuracy 0.96637                             | Test: Loss 0.09385, Accuracy 0.96245, F1 0.96247
# Epoch [38/100]       | Train: Loss 0.08100, Accuracy 0.96710                             | Test: Loss 0.09396, Accuracy 0.96217, F1 0.96215
# Epoch [39/100]       | Train: Loss 0.08025, Accuracy 0.96730                             | Test: Loss 0.09404, Accuracy 0.96209, F1 0.96212
# Epoch [40/100]       | Train: Loss 0.07831, Accuracy 0.96814                             | Test: Loss 0.09708, Accuracy 0.96172, F1 0.96172
# Epoch [41/100]       | Train: Loss 0.07676, Accuracy 0.96878                             | Test: Loss 0.09199, Accuracy 0.96369, F1 0.96368
# Epoch [42/100]       | Train: Loss 0.07623, Accuracy 0.96879                             | Test: Loss 0.09319, Accuracy 0.96370, F1 0.96370
# Epoch [43/100]       | Train: Loss 0.07456, Accuracy 0.96941                             | Test: Loss 0.09208, Accuracy 0.96416, F1 0.96416
# Epoch [44/100]       | Train: Loss 0.07421, Accuracy 0.96985                             | Test: Loss 0.08962, Accuracy 0.96397, F1 0.96398
# Epoch [45/100]       | Train: Loss 0.07222, Accuracy 0.97071                             | Test: Loss 0.08967, Accuracy 0.96491, F1 0.96492
# Epoch [46/100]       | Train: Loss 0.07120, Accuracy 0.97121                             | Test: Loss 0.09175, Accuracy 0.96401, F1 0.96402
# Epoch [47/100]       | Train: Loss 0.07073, Accuracy 0.97116                             | Test: Loss 0.09066, Accuracy 0.96490, F1 0.96493
# Epoch [48/100]       | Train: Loss 0.06917, Accuracy 0.97158                             | Test: Loss 0.08792, Accuracy 0.96570, F1 0.96572
# Epoch [49/100]       | Train: Loss 0.06821, Accuracy 0.97214                             | Test: Loss 0.08873, Accuracy 0.96506, F1 0.96510
# Epoch [50/100]       | Train: Loss 0.06748, Accuracy 0.97210                             | Test: Loss 0.09027, Accuracy 0.96458, F1 0.96458
# Epoch [51/100]       | Train: Loss 0.06619, Accuracy 0.97275                             | Test: Loss 0.09240, Accuracy 0.96473, F1 0.96473
# Epoch [52/100]       | Train: Loss 0.06566, Accuracy 0.97290                             | Test: Loss 0.08867, Accuracy 0.96489, F1 0.96489
# Epoch [53/100]       | Train: Loss 0.06481, Accuracy 0.97352                             | Test: Loss 0.08648, Accuracy 0.96666, F1 0.96669
# Epoch [54/100]       | Train: Loss 0.06391, Accuracy 0.97391                             | Test: Loss 0.09115, Accuracy 0.96458, F1 0.96461
# Epoch [55/100]       | Train: Loss 0.06289, Accuracy 0.97434                             | Test: Loss 0.08927, Accuracy 0.96584, F1 0.96582
# Epoch [56/100]       | Train: Loss 0.06257, Accuracy 0.97439                             | Test: Loss 0.08933, Accuracy 0.96616, F1 0.96613
# Epoch [57/100]       | Train: Loss 0.06216, Accuracy 0.97460                             | Test: Loss 0.08646, Accuracy 0.96661, F1 0.96660
# Epoch [58/100]       | Train: Loss 0.06041, Accuracy 0.97533                             | Test: Loss 0.08833, Accuracy 0.96695, F1 0.96698
# Epoch [59/100]       | Train: Loss 0.06054, Accuracy 0.97513                             | Test: Loss 0.08770, Accuracy 0.96584, F1 0.96589
# Epoch [60/100]       | Train: Loss 0.05968, Accuracy 0.97551                             | Test: Loss 0.08937, Accuracy 0.96590, F1 0.96590
# Epoch [61/100]       | Train: Loss 0.05925, Accuracy 0.97573                             | Test: Loss 0.08606, Accuracy 0.96648, F1 0.96654
# Epoch [62/100]       | Train: Loss 0.05850, Accuracy 0.97612                             | Test: Loss 0.08835, Accuracy 0.96602, F1 0.96604
# Epoch [63/100]       | Train: Loss 0.05798, Accuracy 0.97620                             | Test: Loss 0.08749, Accuracy 0.96718, F1 0.96717
# Epoch [64/100]       | Train: Loss 0.05751, Accuracy 0.97658                             | Test: Loss 0.08584, Accuracy 0.96734, F1 0.96736
# Epoch [65/100]       | Train: Loss 0.05676, Accuracy 0.97710                             | Test: Loss 0.08298, Accuracy 0.96843, F1 0.96845
# Epoch [66/100]       | Train: Loss 0.05542, Accuracy 0.97735                             | Test: Loss 0.08408, Accuracy 0.96810, F1 0.96811
# Epoch [67/100]       | Train: Loss 0.05532, Accuracy 0.97758                             | Test: Loss 0.08611, Accuracy 0.96698, F1 0.96701
# Epoch [68/100]       | Train: Loss 0.05481, Accuracy 0.97760                             | Test: Loss 0.08696, Accuracy 0.96705, F1 0.96704
# Epoch [69/100]       | Train: Loss 0.05393, Accuracy 0.97797                             | Test: Loss 0.08756, Accuracy 0.96698, F1 0.96699
# Epoch [70/100]       | Train: Loss 0.05356, Accuracy 0.97832                             | Test: Loss 0.08591, Accuracy 0.96750, F1 0.96751
# Epoch [71/100]       | Train: Loss 0.05277, Accuracy 0.97846                             | Test: Loss 0.08472, Accuracy 0.96846, F1 0.96848
# Epoch [72/100]       | Train: Loss 0.05258, Accuracy 0.97845                             | Test: Loss 0.08771, Accuracy 0.96766, F1 0.96769
# Epoch [73/100]       | Train: Loss 0.05145, Accuracy 0.97905                             | Test: Loss 0.08641, Accuracy 0.96798, F1 0.96800
# Epoch [74/100]       | Train: Loss 0.05091, Accuracy 0.97910                             | Test: Loss 0.08877, Accuracy 0.96752, F1 0.96753
# Epoch [75/100]       | Train: Loss 0.05046, Accuracy 0.97896                             | Test: Loss 0.09154, Accuracy 0.96712, F1 0.96712
# Epoch [76/100]       | Train: Loss 0.05048, Accuracy 0.97948                             | Test: Loss 0.08584, Accuracy 0.96831, F1 0.96834
# Epoch [77/100]       | Train: Loss 0.05026, Accuracy 0.97938                             | Test: Loss 0.08892, Accuracy 0.96748, F1 0.96753
# Epoch [78/100]       | Train: Loss 0.04903, Accuracy 0.98000                             | Test: Loss 0.08660, Accuracy 0.96850, F1 0.96852
# Epoch [79/100]       | Train: Loss 0.04922, Accuracy 0.97985                             | Test: Loss 0.08711, Accuracy 0.96823, F1 0.96822
# Epoch [80/100]       | Train: Loss 0.04822, Accuracy 0.98025                             | Test: Loss 0.08885, Accuracy 0.96753, F1 0.96753
# Epoch [81/100]       | Train: Loss 0.04811, Accuracy 0.98053                             | Test: Loss 0.08946, Accuracy 0.96798, F1 0.96796
# Epoch [82/100]       | Train: Loss 0.04822, Accuracy 0.98012                             | Test: Loss 0.08757, Accuracy 0.96806, F1 0.96806
# Epoch [83/100]       | Train: Loss 0.04746, Accuracy 0.98052                             | Test: Loss 0.08773, Accuracy 0.96781, F1 0.96782
# Epoch [84/100]       | Train: Loss 0.04705, Accuracy 0.98079                             | Test: Loss 0.08606, Accuracy 0.96914, F1 0.96916
# Epoch [85/100]       | Train: Loss 0.04584, Accuracy 0.98126                             | Test: Loss 0.08778, Accuracy 0.96893, F1 0.96893
# Epoch [86/100]       | Train: Loss 0.04639, Accuracy 0.98122                             | Test: Loss 0.08331, Accuracy 0.96977, F1 0.96978
# Epoch [87/100]       | Train: Loss 0.04569, Accuracy 0.98145                             | Test: Loss 0.08918, Accuracy 0.96866, F1 0.96867
# Epoch [88/100]       | Train: Loss 0.04480, Accuracy 0.98180                             | Test: Loss 0.08851, Accuracy 0.96855, F1 0.96856
# Epoch [89/100]       | Train: Loss 0.04460, Accuracy 0.98186                             | Test: Loss 0.08973, Accuracy 0.96841, F1 0.96842
# Epoch [90/100]       | Train: Loss 0.04479, Accuracy 0.98173                             | Test: Loss 0.09161, Accuracy 0.96792, F1 0.96793
# Epoch [91/100]       | Train: Loss 0.04433, Accuracy 0.98201                             | Test: Loss 0.08838, Accuracy 0.96798, F1 0.96800
# Epoch [92/100]       | Train: Loss 0.04371, Accuracy 0.98229                             | Test: Loss 0.08730, Accuracy 0.96946, F1 0.96946
# Epoch [93/100]       | Train: Loss 0.04345, Accuracy 0.98214                             | Test: Loss 0.08952, Accuracy 0.96886, F1 0.96888
# Epoch [94/100]       | Train: Loss 0.04316, Accuracy 0.98243                             | Test: Loss 0.09018, Accuracy 0.96890, F1 0.96890
# Epoch [95/100]       | Train: Loss 0.04272, Accuracy 0.98239                             | Test: Loss 0.09198, Accuracy 0.96763, F1 0.96767
# Epoch [96/100]       | Train: Loss 0.04244, Accuracy 0.98262                             | Test: Loss 0.08893, Accuracy 0.96851, F1 0.96852
# Epoch [97/100]       | Train: Loss 0.04189, Accuracy 0.98307                             | Test: Loss 0.09337, Accuracy 0.96785, F1 0.96786
# Epoch [98/100]       | Train: Loss 0.04164, Accuracy 0.98307                             | Test: Loss 0.09053, Accuracy 0.96938, F1 0.96939
# Epoch [99/100]       | Train: Loss 0.04142, Accuracy 0.98283                             | Test: Loss 0.08861, Accuracy 0.96972, F1 0.96973
# Epoch [100/100]      | Train: Loss 0.04049, Accuracy 0.98370                             | Test: Loss 0.09207, Accuracy 0.96880, F1 0.96884
# Confusion Matrix for income
# [[40991  1061     0     0    23     3   126]
#  [ 1313 55238    75     0   184    74    28]
#  [    3    60  6856    41    16   118     0]
#  [    0     0    32   489     0    12     0]
#  [   23   128    18     0  1785     8     0]
#  [    6    50    90    28     0  3286     0]
#  [   89    14     0     0     2     0  3933]]
# Best accuracy 0.9697684225020008
# Best F1 0.9697825531209306
# 100 epochs of training and evaluation took, 5476.910426646995
