# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")
# Out:
# GPU is available and being used

# %%
df = pd.read_csv(r'/home/cscadmin/CyberResearch/FlowClassification/datasets/covertype/covtype.csv')
# df = pd.read_csv(r'C:\Users\smbm2\projects\FlowClassification\datasets\covertype\covtype.csv')

le = LabelEncoder()
df['Cover_Type'] = le.fit_transform(df['Cover_Type'])

class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.int64).values

        # self.scalar = StandardScaler()
        # self.x = self.scalar.fit_transform(df.drop(columns=[task1_column])).astype(np.float32)
        self.x = df.drop(task1_column, axis=1).astype(np.float32).values

    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        features = self.x[idx]
        labels_task1 = self.task1_labels[idx]

        return features, labels_task1
        # return self.x[index], self.task1_labels[index], self.task2_labels[index]

# df = df.sample(frac=.1, random_state=42)
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Separate the 'Cover_Type' column from the training and test DataFrames
train_target = train_df['Cover_Type']
test_target = test_df['Cover_Type']

# Drop the 'Cover_Type' column from the DataFrames
train_df = train_df.drop(columns=['Cover_Type'])
test_df = test_df.drop(columns=['Cover_Type'])

# Create a StandardScaler object and fit it to the training data
scaler = StandardScaler()
scaler.fit(train_df)

# Transform the training and test DataFrames without scaling 'Cover_Type'
train_scaled = scaler.transform(train_df)
test_scaled = scaler.transform(test_df)

# Convert the scaled arrays back to DataFrames
train_df = pd.DataFrame(train_scaled, columns=train_df.columns)
test_df = pd.DataFrame(test_scaled, columns=test_df.columns)

train_target = train_target.reset_index(drop=True)
test_target = test_target.reset_index(drop=True)

# Add the 'Cover_Type' column back to the DataFrames
train_df['Cover_Type'] = train_target
test_df['Cover_Type'] = test_target

print(f"{len(train_df)}, {len(test_df)}")

# Create datasets for train, validation, and test
train_dataset = SingleTaskDataset(train_df, "Cover_Type")
# val_dataset = SingleTaskDataset(val_df, "Cover_Type")
test_dataset = SingleTaskDataset(test_df, "Cover_Type")

# Define batch size
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)  # No need to shuffle validation data
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# 464809, 116203

# %%
df['Cover_Type'].value_counts()
# Out:
# Cover_Type
# 1    283301
# 0    211840
# 2     35754
# 6     20510
# 5     17367
# 4      9493
# 3      2747
# Name: count, dtype: int64

# %%
train_df['Cover_Type'].value_counts()
# Out:
# Cover_Type
# 1    226801
# 0    169283
# 2     28633
# 6     16495
# 5     13878
# 4      7498
# 3      2221
# Name: count, dtype: int64

# %%
# each task loss is scaled by its own learnable parameter, then regularization is applied 
class UncertaintyLoss(nn.Module):
    def __init__(self, num_tasks):
        super(UncertaintyLoss, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]
        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
#All layers of the model
class MultiHeadAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(MultiHeadAttention, self).__init__()

        self.embed_size = embed_size
        self.heads = heads
        self.head_dim = embed_size // heads
        assert(self.head_dim * heads == embed_size), "Embed size needs to be div by heads"
        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys =nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads*self.head_dim, embed_size)


    def forward(self, values, keys, query):
        N = query.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]

        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = query.reshape(N, query_len, self.heads, self.head_dim)

        values = self.values(values)
        keys = self.keys(keys)
        queries = self.queries(queries)

        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])

        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3) #(batch_size, head_dim, #query_embeddings, #key_embeddings)

        # Calculate simplified attention scores
        avg_attention = attention.mean(dim=0)  # Average across batches
        # print("batch average", avg_attention.shape)
        avg_attention = avg_attention.mean(dim=0).squeeze(dim=0)
        # print("head average", avg_attention.shape)

        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(N, query_len, self.heads*self.head_dim) #(batch_size, n_features, embed_size)
        out = self.fc_out(out)

        return out, avg_attention
    
class TransformerBlock(nn.Module):
    def __init__(self, embed_size, heads, dropout, forward_expansion, pre_norm_on):
        super(TransformerBlock, self).__init__()

        self.pre_norm_on = pre_norm_on
        if self.pre_norm_on:
            self.pre_norm = nn.LayerNorm(embed_size)
        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm1 = nn.LayerNorm(embed_size)
        self.norm2 = nn.LayerNorm(embed_size)

        self.feed_forward = nn.Sequential(nn.Linear(embed_size, forward_expansion*embed_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion*embed_size, embed_size)
                                          )
        self.dropout = nn.Dropout(dropout)

    def forward(self,value,key,query):
        if self.pre_norm_on:
            query = self.pre_norm(query)
            key = self.pre_norm(key)
            value = self.pre_norm(value)
            
        attention, avg_attention = self.attention(value, key, query)
        x = self.dropout(self.norm1(attention + query))
        forward = self.feed_forward(x)
        out = self.dropout(self.norm2(forward + x))
        return out, avg_attention
    
class DecoderBlock(nn.Module):
    def __init__(self, embed_size, heads, forward_expansion, dropout, pre_norm_on):
        super(DecoderBlock, self).__init__()

        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm = nn.LayerNorm(embed_size)
        self.transformer_block = TransformerBlock(embed_size, heads, dropout, forward_expansion, pre_norm_on)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, value, key):
        out, avg_attention = self.transformer_block(value, key, x)

        return out, avg_attention

class Decoder(nn.Module):
    def __init__(self,
                 embed_size,
                 num_layers,
                 heads,
                 forward_expansion,
                 decoder_dropout,
                 pre_norm_on
    ):
        super(Decoder, self).__init__()

        self.layers = nn.ModuleList(
                [
                    DecoderBlock(
                        embed_size,
                        heads,
                        dropout=decoder_dropout,
                        forward_expansion=forward_expansion,
                        pre_norm_on=pre_norm_on
                    )
                    for _ in range(num_layers)
                ]
            )
        self.avg_attention = None

    def forward(self, class_embed, context):
        for layer in self.layers:
            # x is the classification embedding (CLS Token)
            # context are the feature embeddings that will be used as key and value
            x, self.avg_attention = layer(class_embed, context, context)
  
        return x 

class Embeddings(nn.Module):
    def __init__(self, sigma, embed_size, input_size, embedding_dropout, n_features, num_target_labels, rff_on):
        super(Embeddings, self).__init__()

        self.rff_on = rff_on

        if self.rff_on:
            self.rffs = nn.ModuleList([GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) for _ in range(n_features)])
            self.dropout = nn.Dropout(embedding_dropout)
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        self.embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for _ in range(n_features)])

        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, x):
        x = x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i, r in enumerate(self.rffs):
                input = x[:,i,:]
                out = r(input)
                rff_vectors.append(out)
        
            x = torch.stack(rff_vectors, dim=1)
        
        embeddings = []
        for i, e in enumerate(self.embeddings):
            goin_in = x[:,i,:]
            goin_out = e(goin_in)
            embeddings.append(goin_out)

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)
        
        # class_embed = self.classification_embedding(torch.tensor([0], device=x.device))  # use index 0 for the classification embedding
        # class_embed = class_embed.repeat(x.size(0), 1) # -> (batch_size, embed_size)
        # class_embed = class_embed.unsqueeze(1)

        context = torch.stack(embeddings, dim=1)

        return class_embeddings, context

class classificationHead(nn.Module):
    def __init__(self, embed_size, dropout, mlp_scale_classification, num_target_classes):
        super(classificationHead, self).__init__()
        
        #flattening the embeddings out so each sample in batch is represented with a 460 dimensional vector
        self.input = embed_size
        self.lin1 = nn.Linear(self.input, mlp_scale_classification*self.input)
        self.drop = nn.Dropout(dropout)
        self.lin2 = nn.Linear(mlp_scale_classification*self.input, mlp_scale_classification*self.input)
        self.lin3 = nn.Linear(mlp_scale_classification*self.input, self.input)
        self.lin4 = nn.Linear(self.input, num_target_classes)
        self.relu = nn.ReLU()
        self.initialize_weights()

    def initialize_weights(self): #he_initialization.
        torch.nn.init.kaiming_normal_(self.lin1.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin1.bias)

        torch.nn.init.kaiming_normal_(self.lin3.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin3.bias)

    def forward(self, x):

        x= torch.reshape(x, (-1, self.input))

        x = self.lin1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin2(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin3(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin4(x)
  
        return x


# DEFAULT PARAMETERS SET UP FOR VPN DATASET. BE CAREFUL AND MAKE SURE YOU SET THEM UP HOW YOU WANT.
class Classifier(nn.Module):
    def __init__(self, 
                 rff_on = False,
                 sigma=4,
                 embed_size=20,
                 input_size=1,
                 embedding_dropout = 0,
                 n_features=23, # YOU WILL PROBABLY NEED TO CHANGE
                 num_layers=1,
                 heads=1,
                 forward_expansion=4, # Determines how wide the MLP is in the encoder. Its a scaling factor. 
                 decoder_dropout=0,
                 classification_dropout = 0,
                 pre_norm_on = False,
                 mlp_scale_classification = 4,
                 targets_classes : list=  [3,8]
                 ):
        super(Classifier, self).__init__()

        self.embeddings = Embeddings(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, embedding_dropout=embedding_dropout, n_features=n_features, num_target_labels=len(targets_classes))
        self.decoder = Decoder(embed_size=embed_size, num_layers=num_layers, heads=heads, forward_expansion=forward_expansion, decoder_dropout=decoder_dropout, pre_norm_on=pre_norm_on)
        self.classifying_heads = nn.ModuleList([classificationHead(embed_size=embed_size, dropout=classification_dropout, mlp_scale_classification=mlp_scale_classification, num_target_classes=x) for x in targets_classes])
        
    def forward(self, x):
        class_embed, context = self.embeddings(x)

        x = self.decoder(class_embed, context)
        
        probability_dist_raw = []
        for i, e in enumerate(self.classifying_heads):
            input = x[:, i,:]
            output = e(input)
            probability_dist_raw.append(output)
        
        return probability_dist_raw

# Training and Testing Loops
def train(dataloader, model, loss_function, optimizer, device_in_use):
    model.train()

    total_loss = 0

    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    total_correct_2 = 0
    total_samples_2 = 0
    all_targets_2 = []
    all_predictions_2 = []

    for (features,labels_task1,) in dataloader:
        features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)


        task_predictions = model(features) #contains a list of the tensor outputs for each task

        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()

        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

        # #computing accuaracy for second target
        # y_pred_softmax_2 = torch.softmax(task_predictions[1], dim=1)
        # _, y_pred_labels_2 = torch.max(y_pred_softmax_2, dim=1)
        # total_correct_2 += (y_pred_labels_2 == labels_task2).sum().item()
        # total_samples_2 += labels_task2.size(0)
        # all_targets_2.extend(labels_task2.cpu().numpy())
        # all_predictions_2.extend(y_pred_labels_2.cpu().numpy())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    # accuracy_2 = total_correct_2 / total_samples_2

    # # precision = precision_score(all_targets, all_predictions, average='weighted')
    # recall = recall_score(all_targets, all_predictions, average='weighted')
    # f1 = f1_score(all_targets, all_predictions, average='weighted')

    return avg_loss, accuracy_1

def test(dataloader, model, loss_function, device_in_use):
  model.eval()
  total_loss = 0
  
  total_correct_1 = 0
  total_samples_1 = 0
  all_targets_1 = []
  all_predictions_1 = []

  total_correct_2 = 0
  total_samples_2 = 0
  all_targets_2 = []
  all_predictions_2 = []

  with torch.no_grad():
    for (features,labels_task1) in dataloader:
      features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)

      #compute prediction error
      task_predictions = model(features) #contains a list of the tensor outputs for each task

      loss = loss_function(task_predictions, labels_task1)
      total_loss += loss.item()

      #computing accuracy for first target
      y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
      _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
      total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
      total_samples_1 += labels_task1.size(0)
      all_targets_1.extend(labels_task1.cpu().numpy())
      all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

      # #computing accuaracy for second target
      # y_pred_softmax_2 = torch.softmax(task_predictions[1], dim=1)
      # _, y_pred_labels_2 = torch.max(y_pred_softmax_2, dim=1)
      # total_correct_2 += (y_pred_labels_2 == labels_task2).sum().item()
      # total_samples_2 += labels_task2.size(0)
      # all_targets_2.extend(labels_task2.cpu().numpy())
      # all_predictions_2.extend(y_pred_labels_2.cpu().numpy())

  avg = total_loss/len(dataloader)
  accuracy_1 = total_correct_1 / total_samples_1
  # accuracy_2 = total_correct_2 / total_samples_2
  # recall = recall_score(all_targets, all_predictions, average='weighted')
  f1_1 = f1_score(all_targets_1, all_predictions_1, average='weighted')
  # f1_2 = f1_score(all_targets_2, all_predictions_2, average="weighted")

  return avg, accuracy_1, all_predictions_1, all_targets_1, f1_1

def format_metric(value): # Used to format the metrics output
    return f"{value:.4f}"

class EarlyStopping:
    def __init__(self, patience=5):
        self.patience = patience
        self.counter = 0
        self.best_metric = float('-inf')
        self.early_stop = False

    def __call__(self, metric):
        if metric > self.best_metric:
            self.best_metric = metric
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
model = Classifier(n_features=54,targets_classes=[7],
                   rff_on= True, sigma=1, num_layers= 1, 
                   embed_size= 160, heads= 10, forward_expansion= 6, 
                   pre_norm_on= True, mlp_scale_classification= 5).to(device_in_use) # Instantiate the model
loss_functions = UncertaintyLoss(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
early_stopping = EarlyStopping(patience=5)
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
train_accuracies_2 = []
train_recalls = [] 
train_f1_scores = [] 
test_losses = []
test_accuracies_1 = []
test_accuracies_2 = []
test_recalls = []  
test_f1_scores = [] 
all_attention_scores = []

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  # test_f1_scores.append(test_f1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, covertype Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, covertype Accuracy {format_metric(test_accuracy_1)}, covertype F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

  if early_stopping(test_accuracy_1):
    break

  # total_attention = model.decoder.avg_attention
  # all_attention_scores.append(total_attention.tolist()) #UPDATED
  # model.decoder.avg_attention = None

# Save the model after pre-training
torch.save(model.state_dict(), 'final_model_trained.pth')

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve for covertype')
plt.legend()


# plt.subplot(1, 3, 3)
# plt.plot(range(1, epochs+1), train_accuracies_2, label='Train Accuracy')
# plt.plot(range(1, epochs+1), test_accuracies_2, label='Test Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.title('Training and Test Accuracy Curve for Traffic Type')
# plt.legend()
# plt.tight_layout()
# plt.tight_layout()
# plt.show()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for covertype")
print(conf_matrix_1)

# # Display confusion matrix for the second task (Application Type) on test data
# conf_matrix_2 = confusion_matrix(all_targets_2, all_predictions_2)
# print("Confusion Matrix for Application Type")
# print(conf_matrix_2)

# print(f"Best accuracy: {max(test_accuracies)}")

# # Plot attention scores for each feature over epochs

# # all_attention_scores = all_attention_scores.cpu().numpy() #CUDA tensor needs to be converted to cpu tensor
# all_attention_scores = torch.tensor(all_attention_scores)
# plt.figure(figsize=(10, 6))

# features = df.drop("class1", axis=1).columns.tolist()

# for feature_idx in range(all_attention_scores.shape[1]):
#     plt.plot(all_attention_scores[:, feature_idx], label=features[feature_idx])

# plt.xlabel('Epochs')
# plt.ylabel('Attention Scores')
# plt.title('Attention Scores for Each Feature over Epochs')
# plt.legend(loc = 'lower left')
# plt.show()

# last_epoch_attention_scores = all_attention_scores[-1]
# top_scores, top_indices = torch.topk(last_epoch_attention_scores, k=10)

# # Display the top 10 attention scores and the corresponding feature
# for i in range(10):
#     print(f"{i+1}. {features[int(top_indices[i])]}: {top_scores[i]}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.5617, covertype Accuracy 0.7578                     | Test: Loss 0.3996, covertype Accuracy 0.8331, covertype F1 0.8292
# Epoch [ 2/100]       | Train: Loss 0.2942, covertype Accuracy 0.8804                     | Test: Loss 0.2303, covertype Accuracy 0.9081, covertype F1 0.9080
# Epoch [ 3/100]       | Train: Loss 0.1985, covertype Accuracy 0.9208                     | Test: Loss 0.1787, covertype Accuracy 0.9282, covertype F1 0.9280
# Epoch [ 4/100]       | Train: Loss 0.1603, covertype Accuracy 0.9365                     | Test: Loss 0.1581, covertype Accuracy 0.9374, covertype F1 0.9372
# Epoch [ 5/100]       | Train: Loss 0.1398, covertype Accuracy 0.9444                     | Test: Loss 0.1372, covertype Accuracy 0.9456, covertype F1 0.9457
# Epoch [ 6/100]       | Train: Loss 0.1243, covertype Accuracy 0.9505                     | Test: Loss 0.1397, covertype Accuracy 0.9445, covertype F1 0.9442
# Epoch [ 7/100]       | Train: Loss 0.1145, covertype Accuracy 0.9545                     | Test: Loss 0.1257, covertype Accuracy 0.9506, covertype F1 0.9506
# Epoch [ 8/100]       | Train: Loss 0.1069, covertype Accuracy 0.9575                     | Test: Loss 0.1237, covertype Accuracy 0.9523, covertype F1 0.9521
# Epoch [ 9/100]       | Train: Loss 0.0999, covertype Accuracy 0.9602                     | Test: Loss 0.1180, covertype Accuracy 0.9538, covertype F1 0.9538
# Epoch [10/100]       | Train: Loss 0.0941, covertype Accuracy 0.9624                     | Test: Loss 0.1098, covertype Accuracy 0.9571, covertype F1 0.9569
# Epoch [11/100]       | Train: Loss 0.0897, covertype Accuracy 0.9643                     | Test: Loss 0.1098, covertype Accuracy 0.9571, covertype F1 0.9570
# Epoch [12/100]       | Train: Loss 0.0853, covertype Accuracy 0.9660                     | Test: Loss 0.1056, covertype Accuracy 0.9593, covertype F1 0.9593
# Epoch [13/100]       | Train: Loss 0.0816, covertype Accuracy 0.9677                     | Test: Loss 0.1024, covertype Accuracy 0.9601, covertype F1 0.9600
# Epoch [14/100]       | Train: Loss 0.0788, covertype Accuracy 0.9687                     | Test: Loss 0.1004, covertype Accuracy 0.9610, covertype F1 0.9610
# Epoch [15/100]       | Train: Loss 0.0753, covertype Accuracy 0.9699                     | Test: Loss 0.1021, covertype Accuracy 0.9604, covertype F1 0.9604
# Epoch [16/100]       | Train: Loss 0.0729, covertype Accuracy 0.9709                     | Test: Loss 0.0959, covertype Accuracy 0.9631, covertype F1 0.9630
# Epoch [17/100]       | Train: Loss 0.0695, covertype Accuracy 0.9724                     | Test: Loss 0.0969, covertype Accuracy 0.9634, covertype F1 0.9634
# Epoch [18/100]       | Train: Loss 0.0675, covertype Accuracy 0.9733                     | Test: Loss 0.0992, covertype Accuracy 0.9631, covertype F1 0.9632
# Epoch [19/100]       | Train: Loss 0.0649, covertype Accuracy 0.9742                     | Test: Loss 0.0939, covertype Accuracy 0.9650, covertype F1 0.9650
# Epoch [20/100]       | Train: Loss 0.0633, covertype Accuracy 0.9748                     | Test: Loss 0.0940, covertype Accuracy 0.9645, covertype F1 0.9645
# Epoch [21/100]       | Train: Loss 0.0611, covertype Accuracy 0.9755                     | Test: Loss 0.0943, covertype Accuracy 0.9652, covertype F1 0.9652
# Epoch [22/100]       | Train: Loss 0.0592, covertype Accuracy 0.9765                     | Test: Loss 0.0948, covertype Accuracy 0.9663, covertype F1 0.9662
# Epoch [23/100]       | Train: Loss 0.0570, covertype Accuracy 0.9773                     | Test: Loss 0.0958, covertype Accuracy 0.9657, covertype F1 0.9657
# Epoch [24/100]       | Train: Loss 0.0560, covertype Accuracy 0.9778                     | Test: Loss 0.0928, covertype Accuracy 0.9661, covertype F1 0.9661
# Epoch [25/100]       | Train: Loss 0.0542, covertype Accuracy 0.9784                     | Test: Loss 0.0959, covertype Accuracy 0.9659, covertype F1 0.9658
# Epoch [26/100]       | Train: Loss 0.0527, covertype Accuracy 0.9793                     | Test: Loss 0.0957, covertype Accuracy 0.9664, covertype F1 0.9664
# Epoch [27/100]       | Train: Loss 0.0513, covertype Accuracy 0.9796                     | Test: Loss 0.1002, covertype Accuracy 0.9660, covertype F1 0.9660
# Epoch [28/100]       | Train: Loss 0.0503, covertype Accuracy 0.9804                     | Test: Loss 0.0952, covertype Accuracy 0.9668, covertype F1 0.9668
# Epoch [29/100]       | Train: Loss 0.0488, covertype Accuracy 0.9812                     | Test: Loss 0.0923, covertype Accuracy 0.9686, covertype F1 0.9686
# Epoch [30/100]       | Train: Loss 0.0478, covertype Accuracy 0.9813                     | Test: Loss 0.0911, covertype Accuracy 0.9679, covertype F1 0.9679
# Epoch [31/100]       | Train: Loss 0.0463, covertype Accuracy 0.9819                     | Test: Loss 0.0921, covertype Accuracy 0.9673, covertype F1 0.9673
# Epoch [32/100]       | Train: Loss 0.0456, covertype Accuracy 0.9822                     | Test: Loss 0.0962, covertype Accuracy 0.9668, covertype F1 0.9668
# Epoch [33/100]       | Train: Loss 0.0435, covertype Accuracy 0.9830                     | Test: Loss 0.0989, covertype Accuracy 0.9675, covertype F1 0.9674
# Epoch [34/100]       | Train: Loss 0.0426, covertype Accuracy 0.9835                     | Test: Loss 0.0933, covertype Accuracy 0.9688, covertype F1 0.9688
# Epoch [35/100]       | Train: Loss 0.0423, covertype Accuracy 0.9836                     | Test: Loss 0.0984, covertype Accuracy 0.9665, covertype F1 0.9665
# Epoch [36/100]       | Train: Loss 0.0411, covertype Accuracy 0.9842                     | Test: Loss 0.1019, covertype Accuracy 0.9675, covertype F1 0.9675
# Epoch [37/100]       | Train: Loss 0.0403, covertype Accuracy 0.9844                     | Test: Loss 0.0986, covertype Accuracy 0.9685, covertype F1 0.9684
# Epoch [38/100]       | Train: Loss 0.0392, covertype Accuracy 0.9848                     | Test: Loss 0.0969, covertype Accuracy 0.9693, covertype F1 0.9692
# Epoch [39/100]       | Train: Loss 0.0383, covertype Accuracy 0.9854                     | Test: Loss 0.0986, covertype Accuracy 0.9681, covertype F1 0.9681
# Epoch [40/100]       | Train: Loss 0.0373, covertype Accuracy 0.9855                     | Test: Loss 0.0949, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [41/100]       | Train: Loss 0.0369, covertype Accuracy 0.9857                     | Test: Loss 0.1016, covertype Accuracy 0.9687, covertype F1 0.9687
# Epoch [42/100]       | Train: Loss 0.0369, covertype Accuracy 0.9861                     | Test: Loss 0.0970, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [43/100]       | Train: Loss 0.0346, covertype Accuracy 0.9865                     | Test: Loss 0.1068, covertype Accuracy 0.9686, covertype F1 0.9686
# Epoch [44/100]       | Train: Loss 0.0344, covertype Accuracy 0.9869                     | Test: Loss 0.1009, covertype Accuracy 0.9691, covertype F1 0.9691
# Epoch [45/100]       | Train: Loss 0.0342, covertype Accuracy 0.9868                     | Test: Loss 0.0986, covertype Accuracy 0.9701, covertype F1 0.9701
# Epoch [46/100]       | Train: Loss 0.0334, covertype Accuracy 0.9872                     | Test: Loss 0.0981, covertype Accuracy 0.9692, covertype F1 0.9691
# Epoch [47/100]       | Train: Loss 0.0320, covertype Accuracy 0.9878                     | Test: Loss 0.1082, covertype Accuracy 0.9677, covertype F1 0.9676
# Epoch [48/100]       | Train: Loss 0.0327, covertype Accuracy 0.9876                     | Test: Loss 0.1046, covertype Accuracy 0.9695, covertype F1 0.9695
# Epoch [49/100]       | Train: Loss 0.0308, covertype Accuracy 0.9883                     | Test: Loss 0.1103, covertype Accuracy 0.9685, covertype F1 0.9685
# Epoch [50/100]       | Train: Loss 0.0305, covertype Accuracy 0.9885                     | Test: Loss 0.1030, covertype Accuracy 0.9701, covertype F1 0.9700
# Epoch [51/100]       | Train: Loss 0.0300, covertype Accuracy 0.9886                     | Test: Loss 0.1022, covertype Accuracy 0.9707, covertype F1 0.9708
# Epoch [52/100]       | Train: Loss 0.0293, covertype Accuracy 0.9891                     | Test: Loss 0.1022, covertype Accuracy 0.9702, covertype F1 0.9701
# Epoch [53/100]       | Train: Loss 0.0289, covertype Accuracy 0.9892                     | Test: Loss 0.1055, covertype Accuracy 0.9700, covertype F1 0.9700
# Epoch [54/100]       | Train: Loss 0.0286, covertype Accuracy 0.9896                     | Test: Loss 0.1030, covertype Accuracy 0.9704, covertype F1 0.9704
# Epoch [55/100]       | Train: Loss 0.0292, covertype Accuracy 0.9890                     | Test: Loss 0.1069, covertype Accuracy 0.9707, covertype F1 0.9707
# Epoch [56/100]       | Train: Loss 0.0278, covertype Accuracy 0.9895                     | Test: Loss 0.1129, covertype Accuracy 0.9698, covertype F1 0.9698
# Epoch [57/100]       | Train: Loss 0.0271, covertype Accuracy 0.9899                     | Test: Loss 0.1099, covertype Accuracy 0.9686, covertype F1 0.9686
# Epoch [58/100]       | Train: Loss 0.0270, covertype Accuracy 0.9900                     | Test: Loss 0.1107, covertype Accuracy 0.9697, covertype F1 0.9696
# Epoch [59/100]       | Train: Loss 0.0255, covertype Accuracy 0.9907                     | Test: Loss 0.1045, covertype Accuracy 0.9710, covertype F1 0.9710
# Epoch [60/100]       | Train: Loss 0.0252, covertype Accuracy 0.9906                     | Test: Loss 0.1169, covertype Accuracy 0.9684, covertype F1 0.9684
# Epoch [61/100]       | Train: Loss 0.0276, covertype Accuracy 0.9900                     | Test: Loss 0.1082, covertype Accuracy 0.9679, covertype F1 0.9679
# Epoch [62/100]       | Train: Loss 0.0238, covertype Accuracy 0.9911                     | Test: Loss 0.1059, covertype Accuracy 0.9716, covertype F1 0.9716
# Epoch [63/100]       | Train: Loss 0.0239, covertype Accuracy 0.9912                     | Test: Loss 0.1151, covertype Accuracy 0.9691, covertype F1 0.9691
# Epoch [64/100]       | Train: Loss 0.0245, covertype Accuracy 0.9910                     | Test: Loss 0.1115, covertype Accuracy 0.9704, covertype F1 0.9704
# Epoch [65/100]       | Train: Loss 0.0238, covertype Accuracy 0.9912                     | Test: Loss 0.1169, covertype Accuracy 0.9705, covertype F1 0.9705
# Epoch [66/100]       | Train: Loss 0.0235, covertype Accuracy 0.9916                     | Test: Loss 0.1143, covertype Accuracy 0.9697, covertype F1 0.9696
# Epoch [67/100]       | Train: Loss 0.0243, covertype Accuracy 0.9912                     | Test: Loss 0.1113, covertype Accuracy 0.9700, covertype F1 0.9700
# Epoch [68/100]       | Train: Loss 0.0224, covertype Accuracy 0.9920                     | Test: Loss 0.1172, covertype Accuracy 0.9705, covertype F1 0.9705
# Epoch [69/100]       | Train: Loss 0.0230, covertype Accuracy 0.9916                     | Test: Loss 0.1130, covertype Accuracy 0.9693, covertype F1 0.9693
# Epoch [70/100]       | Train: Loss 0.0221, covertype Accuracy 0.9920                     | Test: Loss 0.1132, covertype Accuracy 0.9707, covertype F1 0.9707
# Epoch [71/100]       | Train: Loss 0.0226, covertype Accuracy 0.9919                     | Test: Loss 0.1163, covertype Accuracy 0.9700, covertype F1 0.9700
# Epoch [72/100]       | Train: Loss 0.0212, covertype Accuracy 0.9923                     | Test: Loss 0.1171, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [73/100]       | Train: Loss 0.0220, covertype Accuracy 0.9922                     | Test: Loss 0.1138, covertype Accuracy 0.9703, covertype F1 0.9703
# Epoch [74/100]       | Train: Loss 0.0216, covertype Accuracy 0.9922                     | Test: Loss 0.1233, covertype Accuracy 0.9702, covertype F1 0.9701
# Epoch [75/100]       | Train: Loss 0.0208, covertype Accuracy 0.9926                     | Test: Loss 0.1213, covertype Accuracy 0.9695, covertype F1 0.9695
# Epoch [76/100]       | Train: Loss 0.0208, covertype Accuracy 0.9926                     | Test: Loss 0.1234, covertype Accuracy 0.9688, covertype F1 0.9688
# Epoch [77/100]       | Train: Loss 0.0201, covertype Accuracy 0.9926                     | Test: Loss 0.1256, covertype Accuracy 0.9703, covertype F1 0.9703
# Epoch [78/100]       | Train: Loss 0.0213, covertype Accuracy 0.9926                     | Test: Loss 0.1204, covertype Accuracy 0.9706, covertype F1 0.9706
# Epoch [79/100]       | Train: Loss 0.0190, covertype Accuracy 0.9932                     | Test: Loss 0.1287, covertype Accuracy 0.9697, covertype F1 0.9697
# Epoch [80/100]       | Train: Loss 0.0209, covertype Accuracy 0.9926                     | Test: Loss 0.1208, covertype Accuracy 0.9701, covertype F1 0.9700
# Epoch [81/100]       | Train: Loss 0.0190, covertype Accuracy 0.9932                     | Test: Loss 0.1251, covertype Accuracy 0.9695, covertype F1 0.9695
# Epoch [82/100]       | Train: Loss 0.0194, covertype Accuracy 0.9931                     | Test: Loss 0.1230, covertype Accuracy 0.9700, covertype F1 0.9700
# Epoch [83/100]       | Train: Loss 0.0200, covertype Accuracy 0.9930                     | Test: Loss 0.1238, covertype Accuracy 0.9706, covertype F1 0.9706
# Epoch [84/100]       | Train: Loss 0.0177, covertype Accuracy 0.9937                     | Test: Loss 0.1378, covertype Accuracy 0.9683, covertype F1 0.9683
# Epoch [85/100]       | Train: Loss 0.0182, covertype Accuracy 0.9935                     | Test: Loss 0.1328, covertype Accuracy 0.9695, covertype F1 0.9695
# Epoch [86/100]       | Train: Loss 0.0191, covertype Accuracy 0.9933                     | Test: Loss 0.1288, covertype Accuracy 0.9707, covertype F1 0.9707
# Epoch [87/100]       | Train: Loss 0.0186, covertype Accuracy 0.9936                     | Test: Loss 0.1290, covertype Accuracy 0.9700, covertype F1 0.9700
# Epoch [88/100]       | Train: Loss 0.0184, covertype Accuracy 0.9936                     | Test: Loss 0.1280, covertype Accuracy 0.9703, covertype F1 0.9703
# Epoch [89/100]       | Train: Loss 0.0184, covertype Accuracy 0.9935                     | Test: Loss 0.1341, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [90/100]       | Train: Loss 0.0177, covertype Accuracy 0.9939                     | Test: Loss 0.1300, covertype Accuracy 0.9697, covertype F1 0.9697
# Epoch [91/100]       | Train: Loss 0.0174, covertype Accuracy 0.9940                     | Test: Loss 0.1308, covertype Accuracy 0.9707, covertype F1 0.9707
# Epoch [92/100]       | Train: Loss 0.0174, covertype Accuracy 0.9939                     | Test: Loss 0.1254, covertype Accuracy 0.9702, covertype F1 0.9702
# Epoch [93/100]       | Train: Loss 0.0176, covertype Accuracy 0.9939                     | Test: Loss 0.1373, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [94/100]       | Train: Loss 0.0177, covertype Accuracy 0.9940                     | Test: Loss 0.1417, covertype Accuracy 0.9688, covertype F1 0.9688
# Epoch [95/100]       | Train: Loss 0.0171, covertype Accuracy 0.9941                     | Test: Loss 0.1398, covertype Accuracy 0.9697, covertype F1 0.9697
# Epoch [96/100]       | Train: Loss 0.0164, covertype Accuracy 0.9942                     | Test: Loss 0.1315, covertype Accuracy 0.9707, covertype F1 0.9707
# Epoch [97/100]       | Train: Loss 0.0180, covertype Accuracy 0.9938                     | Test: Loss 0.1323, covertype Accuracy 0.9706, covertype F1 0.9706
# Epoch [98/100]       | Train: Loss 0.0173, covertype Accuracy 0.9941                     | Test: Loss 0.1343, covertype Accuracy 0.9713, covertype F1 0.9713
# Epoch [99/100]       | Train: Loss 0.0148, covertype Accuracy 0.9949                     | Test: Loss 0.1362, covertype Accuracy 0.9699, covertype F1 0.9699
# Epoch [100/100]      | Train: Loss 0.0165, covertype Accuracy 0.9944                     | Test: Loss 0.1352, covertype Accuracy 0.9695, covertype F1 0.9695
# Confusion Matrix for covertype
# [[41192  1184     0     0    39     3   139]
#  [ 1157 55019    69     0   181    53    21]
#  [    2    59  6901    26    10   123     0]
#  [    0     1    40   472     0    12     1]
#  [   16   123    16     0  1836     4     0]
#  [    2    41   101    18    11  3316     0]
#  [   78    17     0     0     0     0  3920]]
