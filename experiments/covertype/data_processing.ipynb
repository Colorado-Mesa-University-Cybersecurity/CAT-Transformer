# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # MAKING TRAIN/TEST/VAL SPLIT
# **EXAMPLE WITH COVTYPE DATASET**
# 1. Read in dataset
# 1. Remove Nan's
# 2. Label Encode non-numerical features
# 3. Split
# 4. Save datasets

# %%
#reading in dataset
df = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\covertype\covtype.csv')

#label encode all non-numerical features
le = LabelEncoder()
df['Cover_Type'] = le.fit_transform(df['Cover_Type'])\

#Split based of ft-transformer paper: 371847 92962 116203
df_train, df_temp = train_test_split(df, train_size=371847, random_state=42)
df_val, df_test = train_test_split(df_temp, train_size=92962, random_state=42)

assert(df_train.shape[0] == 371847)
assert(df_val.shape[0] == 92962)
assert(df_test.shape[0] == 116203)

# %%
df_train['Soil_Type34'].value_counts()
# Out:
# 0    370803
# 1      1044
# Name: Soil_Type34, dtype: int64

# %%
df_train['Cover_Type'].value_counts()
# Out:
# 1    181218
# 0    135568
# 2     22995
# 6     13228
# 5     11078
# 4      5965
# 3      1795
# Name: Cover_Type, dtype: int64

# %%
df_val.head()
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 512442       3247      94     21                               541
# 247104       2185      96     21                               330
# 116974       2828     129     24                                85
# 47874        3257      27      8                               618
# 195857       3094      11      5                               247
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 512442                              86                             1266
# 247104                              78                              420
# 116974                              26                             4436
# 47874                               66                             3617
# 195857                              52                             1786
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 512442            248             203             73
# ...

# %%
df_test.head()
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 300052       2407     268     15                               175
# 448759       3003     114      9                               342
# 301501       3070      76     11                                60
# 67552        2985     253     10                               626
# 568640       2515      95     11                               285
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 300052                              36                             1501
# 448759                              67                              218
# 301501                               2                              812
# 67552                               87                             5877
# 568640                              72                              864
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 300052            179             245            204
# ...

# %%
#save csvs in a dataset folder in your directory
df_train.to_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\covertype\train.csv', index=False)
df_val.to_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\covertype\validation.csv', index=False)
df_test.to_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\covertype\test.csv', index=False)
