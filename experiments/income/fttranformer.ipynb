# %%
import pandas as pd
import numpy as np
import torch 
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
from tab_transformer_pytorch import FTTransformer
from sklearn.metrics import f1_score

# %%
df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\train.csv')
df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\test.csv')
df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\validation.csv')

# %%
df_train.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   27          4  153475          9             13               4
# 1   38          4  122076         15             10               2
# 2   39          5  206362          8             11               2
# 3   32          4  137076         15             10               2
# 4   46          4  198660         11              9               0
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0          12             1     4    0             0             0
# 1          14             0     4    1          7298             0
# 2           3             0     4    1             0             0
# 3           4             0     4    1         15024             0
# 4           8             1     4    1             0             0
#
#    hours-per-week  native-country  income
# 0              40              39       0
# 1              43              39       1
# 2              40              39       0
# 3              60              39       1
# 4              40              39       0

# %%
cat_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

for x in cat_columns:
    print(len(df_train[x].value_counts()))
# Out:
# 10
# 16
# 7
# 16
# 6
# 5
# 2
# 42

# %%
class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, cat_columns, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.float32).values

        self.cate = df[cat_columns].astype(np.int64).values
        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        cat_features = self.cate[idx]
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return cat_features, num_features, labels_task1
        # return self.x[index], self.task1_labels[index], self.task2_labels[index]

cat_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
num_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
train_dataset = SingleTaskDataset(df_train, cat_columns, num_columns, 'income')
val_dataset = SingleTaskDataset(df_val, cat_columns, num_columns, 'income')
test_dataset = SingleTaskDataset(df_test, cat_columns, num_columns, 'income')

batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
for cat,num,label in train_dataloader:
    print("cat",cat)
    print("num",num)
    print("label",label)
# Out:
# cat tensor([[ 2, 11,  2, 14,  0,  2,  1, 39]])
# num tensor([[5.4000e+01, 2.8882e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  6,  2,  7,  0,  4,  1, 39]])
# num tensor([[3.3000e+01, 2.9246e+05, 5.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  4,  1,  4,  1, 39]])
# num tensor([[2.3000e+01, 2.1373e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 1, 10,  2, 10,  0,  4,  1, 39]])
# num tensor([[3.3000e+01, 3.3162e+05, 1.6000e+01, 0.0000e+00, 1.8480e+03, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  4,  3,  1,  4,  1, 39]])
# num tensor([[3.1000e+01, 2.0878e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  6,  1,  4,  4,  0, 39]])
# num tensor([[2.7000e+01, 2.1648e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 13,  0,  4,  1, 39]])
# num tensor([[5.0000e+01, 9.2811e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  7,  2,  4,  0, 39]])
# num tensor([[2.0000e+01, 1.1679e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 1.4529e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  5,  0,  4,  1, 39]])
# num tensor([[6.2000e+01, 2.6662e+05, 9.0000e+00, 6.4180e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4, 10,  1,  4,  0, 39]])
# num tensor([[2.2000e+01, 1.8478e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  1,  3,  0,  4,  1, 39]])
# num tensor([[3.1000e+01, 1.0832e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.8000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  8,  2, 11,  0,  2,  1, 39]])
# num tensor([[2.8000e+01, 2.1899e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.6000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 14,  4, 10,  1,  4,  1, 39]])
# num tensor([[4.2000e+01, 2.0057e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 3.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0, 10,  1,  4,  1, 39]])
# num tensor([[3.2000e+01, 7.1540e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  2, 14,  0,  4,  1, 39]])
# num tensor([[6.3000e+01, 2.3738e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[5.0000e+01, 2.2150e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  6,  1,  4,  1, 39]])
# num tensor([[3.4000e+01, 1.1871e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  4,  3,  3,  4,  1, 39]])
# num tensor([[2.3000e+01, 3.0850e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 1.8000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  9,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 1.6819e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  4,  8,  1,  4,  0, 39]])
# num tensor([[1.8000e+01, 2.2084e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 1.8941e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.5000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  4,  1,  3,  4,  0, 39]])
# num tensor([[4.0000e+01, 9.6554e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 11,  2,  4,  0,  4,  1, 12]])
# num tensor([[6.4000e+01, 1.1918e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 14,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 1.4484e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.2000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 11,  2,  8,  5,  4,  0, 39]])
# num tensor([[3.0000e+01, 2.3482e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 7.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  6,  0,  4,  1, 39]])
# num tensor([[3.3000e+01, 4.0110e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  4,  4,  1,  4,  0, 39]])
# num tensor([[2.9000e+01, 1.9722e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  3,  3,  1,  4,  1, 31]])
# num tensor([[4.5000e+01, 1.2589e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  5,  0,  5,  1,  4,  1, 39]])
# num tensor([[3.4000e+01, 1.5653e+05, 4.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  2, 10,  0,  4,  1, 39]])
# num tensor([[2.7000e+01, 2.0908e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.4000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2,  4,  0,  2,  1, 39]])
# num tensor([[3.6000e+01, 2.9238e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 1.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[5.4000e+01, 1.3769e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 5,  9,  2,  5,  0,  4,  1, 39]])
# num tensor([[4.4000e+01, 7.9521e+04, 1.3000e+01, 1.5024e+04, 0.0000e+00, 5.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  7,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 2.9594e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  4,  1,  4,  0, 39]])
# num tensor([[2.6000e+01, 6.6638e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 15,  0, 12,  1,  4,  0, 39]])
# num tensor([[4.9000e+01, 1.0617e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  7,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.2000e+01, 3.0951e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  1,  1,  4,  0, 39]])
# num tensor([[2.1000e+01, 1.5254e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 11,  2,  0,  5,  4,  0, 39]])
# num tensor([[2.4000e+01, 1.5214e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  5,  2,  0, 39]])
# num tensor([[5.7000e+01, 1.4208e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.8000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4, 10,  3,  4,  0, 39]])
# num tensor([[2.0000e+01, 1.3894e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 1.0000e+01]])
# label tensor([0.])
# cat tensor([[ 1,  7,  4,  1,  3,  2,  1, 39]])
# num tensor([[2.3000e+01, 4.8210e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  7,  3,  4,  1, 39]])
# num tensor([[3.1000e+01, 1.9810e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  0,  2,  1, 39]])
# num tensor([[4.5000e+01, 2.0365e+05, 9.0000e+00, 7.2980e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.1000e+01, 2.1790e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  4, 10,  3,  4,  0, 39]])
# num tensor([[1.8000e+01, 1.3118e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 1.6000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  0, 12,  1,  4,  1, 39]])
# num tensor([[4.4000e+01, 2.7436e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  8,  4,  4,  0, 39]])
# num tensor([[3.3000e+01, 1.7188e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 15,  0,  3,  1,  4,  1, 39]])
# num tensor([[3.9000e+01, 1.6306e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 9.9000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  1,  4,  0, 39]])
# num tensor([[2.3000e+01, 1.9721e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  4,  1,  4,  1, 39]])
# num tensor([[4.5000e+01, 1.3863e+05, 1.0000e+01, 0.0000e+00, 1.8760e+03, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  7,  3,  1,  1, 35]])
# num tensor([[3.0000e+01, 1.0025e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.3000e+01, 1.8348e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  1,  3,  4,  0, 39]])
# num tensor([[3.7000e+01, 1.8412e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 14,  4, 10,  1,  4,  1, 10]])
# num tensor([[4.3000e+01, 3.0644e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 6.6000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  1,  0,  3,  1,  4,  1, 39]])
# num tensor([[2.9000e+01, 2.1315e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 5.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  8,  1,  4,  1, 39]])
# num tensor([[3.8000e+01, 1.0389e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  9,  4, 10,  1,  2,  0, 39]])
# num tensor([[2.6000e+01, 2.6523e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  1,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 3.7785e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0,  0,  4,  0,  3,  4,  1, 39]])
# num tensor([[1.7000e+01, 2.2837e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 14,  0,  4,  1, 39]])
# num tensor([[3.1000e+01, 3.0385e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  2,  5,  8,  4,  4,  0, 26]])
# num tensor([[3.6000e+01, 1.1251e+05, 8.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  4,  3,  1,  4,  1, 39]])
# num tensor([[2.2000e+01, 1.8645e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 14,  0,  2,  1, 39]])
# num tensor([[3.9000e+01, 4.3359e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 6,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 2.0841e+05, 1.3000e+01, 0.0000e+00, 2.0020e+03, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 13,  0,  4,  1, 39]])
# num tensor([[4.4000e+01, 2.1065e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  7,  3,  4,  1, 39]])
# num tensor([[3.5000e+01, 2.0044e+05, 9.0000e+00, 0.0000e+00, 1.9740e+03, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5,  8,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.9000e+01, 2.0636e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  8,  0,  4,  1, 39]])
# num tensor([[3.2000e+01, 2.0318e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  1,  4,  1, 39]])
# num tensor([[3.0000e+01, 7.2630e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 11,  4,  0,  3,  2,  0, 39]])
# num tensor([[2.0000e+01, 2.3280e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 14,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 1.6161e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  8,  3,  2,  1, 39]])
# num tensor([[2.4000e+01, 5.1123e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.9000e+01, 2.5794e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4,  3,  1,  2,  1, 39]])
# num tensor([[2.7000e+01, 1.0843e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 12,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 2.2343e+05, 1.4000e+01, 7.6880e+03, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  0,  8,  1,  4,  0, 39]])
# num tensor([[6.9000e+01, 1.2544e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.2000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 11,  6, 10,  4,  2,  0, 39]])
# num tensor([[6.6000e+01, 1.0264e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  4,  5,  3,  4,  2,  0, 39]])
# num tensor([[5.2000e+01, 2.4362e+05, 3.0000e+00, 4.1010e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 6.7716e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  8,  4, 12,  1,  4,  0, 39]])
# num tensor([[2.8000e+01, 1.2014e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  4,  7,  3,  4,  1, 39]])
# num tensor([[1.8000e+01, 7.1607e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  4,  7,  3,  4,  1, 32]])
# num tensor([[2.5000e+01, 6.9739e+04, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  0, 12,  4,  4,  0, 39]])
# num tensor([[3.2000e+01, 2.1054e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 2.4266e+04, 1.1000e+01, 7.6880e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1,  2]])
# num tensor([[3.8000e+01, 3.3832e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 14,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 9.9835e+04, 1.5000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  1,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 1.7077e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  7,  3,  4,  1, 39]])
# num tensor([[4.1000e+01, 1.0616e+05, 9.0000e+00, 1.4344e+04, 0.0000e+00, 4.8000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 15,  4,  3,  1,  4,  1, 39]])
# num tensor([[3.2000e+01, 2.4529e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[5.2000e+01, 2.0686e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4, 12,  4,  4,  0,  0]])
# num tensor([[2.6000e+01, 2.4356e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 12,  0, 10,  1,  4,  0, 39]])
# num tensor([[5.7000e+01, 1.7608e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 15,  4,  8,  1,  4,  0, 39]])
# num tensor([[2.5000e+01, 2.1472e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[2.4000e+01, 1.9097e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.8000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 15,  2, 11,  0,  4,  1, 39]])
# num tensor([[2.9000e+01, 3.8374e+05, 1.0000e+01, 0.0000e+00, 1.4850e+03, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 0,  5,  6,  0,  1,  4,  0, 39]])
# num tensor([[6.4000e+01, 1.6992e+05, 4.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+00]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  7,  1,  4,  1, 39]])
# num tensor([[4.3000e+01, 1.6200e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 14,  0,  4,  1, 39]])
# num tensor([[4.9000e+01, 1.4484e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.2000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  3,  3,  2,  4,  1, 31]])
# num tensor([[5.5000e+01, 1.4181e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  3,  7,  1,  1,  1, 42]])
# num tensor([[3.6000e+01, 1.0446e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 15,  2,  8,  5,  4,  0, 39]])
# num tensor([[3.6000e+01, 1.3542e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  4,  1,  1,  4,  1, 39]])
# num tensor([[2.4000e+01, 1.7791e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 15,  4, 10,  1,  4,  0, 39]])
# num tensor([[6.7000e+01, 1.7639e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  0, 12,  3,  4,  1, 39]])
# num tensor([[2.2000e+01, 1.5471e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.0000e+01, 1.9832e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  0,  8,  4,  4,  0, 39]])
# num tensor([[5.0000e+01, 1.7120e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  7,  1,  4,  1, 39]])
# num tensor([[2.8000e+01, 9.4128e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 8, 11,  2,  1,  5,  4,  0, 39]])
# num tensor([[5.2000e+01, 1.9826e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 15,  0,  1,  1,  4,  0, 39]])
# num tensor([[5.6000e+01, 1.5345e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  5,  3,  1,  2,  1, 39]])
# num tensor([[4.1000e+01, 1.2464e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  1,  4,  5,  3,  4,  1, 39]])
# num tensor([[1.7000e+01, 3.3230e+04, 7.0000e+00, 0.0000e+00, 0.0000e+00, 1.5000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  9,  4,  4,  1,  4,  1, 39]])
# num tensor([[2.5000e+01, 1.5703e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  5,  4,  1,  4,  1, 39]])
# num tensor([[3.7000e+01, 2.0811e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 15,  3, 13,  4,  4,  1, 39]])
# num tensor([[2.2000e+01, 2.2966e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 12,  2,  4,  1, 39]])
# num tensor([[4.0000e+01, 2.2466e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 4.8495e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.2000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  1,  2,  4,  0, 39]])
# num tensor([[3.2000e+01, 1.8166e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5,  9,  2,  4,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 1.1387e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4,  4,  1,  2,  0, 23]])
# num tensor([[2.8000e+01, 1.6109e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  6,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 1.4874e+05, 9.0000e+00, 0.0000e+00, 1.7400e+03, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  4,  5,  4,  0, 39]])
# num tensor([[3.8000e+01, 3.9606e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  1,  1,  4,  0, 39]])
# num tensor([[2.3000e+01, 6.4292e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  7,  0,  2,  1, 39]])
# num tensor([[3.0000e+01, 2.8791e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  7,  0,  4,  1, 39]])
# num tensor([[2.4000e+01, 5.3942e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  6,  0,  6,  1,  4,  0, 39]])
# num tensor([[4.9000e+01, 1.6686e+05, 5.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  3, 10,  3,  2,  0, 39]])
# num tensor([[3.8000e+01, 2.5411e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 15,  0,  5,  1,  4,  1, 39]])
# num tensor([[3.8000e+01, 2.1705e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  0,  4,  4,  4,  1, 39]])
# num tensor([[4.2000e+01, 2.9888e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[5.9000e+01, 5.3304e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  1,  3,  4,  0, 39]])
# num tensor([[2.2000e+01, 1.2227e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  1,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 3.5010e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  9,  3, 10,  1,  4,  0, 39]])
# num tensor([[5.6000e+01, 1.1024e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 1,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.8000e+01, 1.1361e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7,  0,  2,  4,  0,  4,  1, 39]])
# num tensor([[6.4000e+01, 5.5085e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2,  5,  0,  4,  1, 39]])
# num tensor([[3.1000e+01, 2.4644e+05, 1.0000e+01, 7.2980e+03, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4,  1,  3,  4,  0, 39]])
# num tensor([[6.6000e+01, 1.2348e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  1,  4,  1, 39]])
# num tensor([[3.1000e+01, 1.9328e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  5, 10,  4,  4,  0, 39]])
# num tensor([[3.9000e+01, 3.3437e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  8,  2,  1,  0, 36]])
# num tensor([[4.7000e+01, 3.4899e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 1.7394e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  9,  0,  4,  1,  4,  0, 39]])
# num tensor([[4.7000e+01, 2.2415e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  4,  6,  3,  4,  1, 39]])
# num tensor([[1.9000e+01, 1.8304e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 2.4000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  7,  0,  4,  1, 39]])
# num tensor([[3.2000e+01, 1.3157e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  1,  4, 12,  1,  0,  1, 39]])
# num tensor([[2.9000e+01, 9.7254e+04, 7.0000e+00, 4.1010e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  5,  0,  4,  1, 39]])
# num tensor([[2.7000e+01, 3.2280e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[6.9000e+01, 1.8504e+05, 9.0000e+00, 9.3860e+03, 0.0000e+00, 1.2000e+01]])
# label tensor([1.])
# cat tensor([[ 1,  7,  2, 11,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 1.6971e+05, 1.2000e+01, 1.5024e+04, 0.0000e+00, 7.2000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  0,  8,  4,  2,  0, 39]])
# num tensor([[4.7000e+01, 1.4587e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  7,  0, 13,  1,  2,  0, 39]])
# num tensor([[4.2000e+01, 1.1901e+05, 1.2000e+01, 0.0000e+00, 1.9740e+03, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 12,  0,  4,  1, 39]])
# num tensor([[5.7000e+01, 1.1284e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7,  9,  2, 10,  0,  4,  1, 16]])
# num tensor([[2.9000e+01, 2.1488e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  5,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 5.4317e+04, 9.0000e+00, 0.0000e+00, 1.6720e+03, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  5,  4,  0, 39]])
# num tensor([[3.8000e+01, 9.5654e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 12,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 1.2308e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7, 12,  0, 10,  4,  4,  0, 39]])
# num tensor([[3.7000e+01, 1.1536e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  1,  0,  4,  1, 11]])
# num tensor([[4.2000e+01, 1.2172e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  1,  3,  2,  0, 39]])
# num tensor([[4.1000e+01, 2.1646e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  1,  3,  4,  0, 39]])
# num tensor([[4.6000e+01, 1.6443e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  7,  0,  1,  3,  1,  1, 39]])
# num tensor([[5.5000e+01, 1.1113e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 15,  2,  1,  5,  4,  0, 39]])
# num tensor([[2.8000e+01, 2.3747e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7, 11,  5,  8,  1,  4,  0, 39]])
# num tensor([[3.4000e+01, 3.2174e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0,  9,  2,  0,  0,  4,  1, 39]])
# num tensor([[4.3000e+01, 2.0051e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[5.1000e+01, 1.4428e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 2.7147e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4, 12,  3,  4,  1, 39]])
# num tensor([[2.2000e+01, 2.0895e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  1,  1,  1, 30]])
# num tensor([[2.7000e+01, 1.3377e+05, 1.3000e+01, 2.2020e+03, 0.0000e+00, 5.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  1,  1,  4,  0, 39]])
# num tensor([[2.6000e+01, 6.1996e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  5,  8,  1,  4,  0, 39]])
# num tensor([[2.4000e+01, 3.7425e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.8000e+01, 8.3444e+04, 9.0000e+00, 7.2980e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2,  1,  0,  4,  1, 39]])
# num tensor([[4.4000e+01, 2.8317e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7,  7,  6, 10,  1,  4,  0, 39]])
# num tensor([[6.2000e+01, 1.0148e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4,  1,  1,  4,  0, 39]])
# num tensor([[3.1000e+01, 9.7933e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4, 14,  3,  4,  1, 39]])
# num tensor([[2.1000e+01, 2.0372e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  4,  5,  4,  0, 39]])
# num tensor([[3.3000e+01, 6.9748e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.8000e+01, 2.0358e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  5, 10,  1,  4,  0, 39]])
# num tensor([[6.2000e+01, 9.6460e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  4,  1,  4,  0, 39]])
# num tensor([[4.8000e+01, 1.8504e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4,  1,  3,  4,  1, 39]])
# num tensor([[1.9000e+01, 2.9905e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 15,  0,  1,  1,  2,  0, 39]])
# num tensor([[5.0000e+01, 1.5478e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  7,  0,  4,  1, 39]])
# num tensor([[4.0000e+01, 2.7416e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  7,  1,  4,  1, 39]])
# num tensor([[3.6000e+01, 1.5836e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 15,  4,  0,  2,  4,  0, 39]])
# num tensor([[1.9000e+01, 1.4040e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  3,  2,  4,  1, 39]])
# num tensor([[4.3000e+01, 2.1289e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  3,  1,  4,  1, 39]])
# num tensor([[5.9000e+01, 1.1082e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.8000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[5.3000e+01, 1.1075e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  8,  2,  5,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 2.8996e+04, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4, 12,  1,  4,  0, 39]])
# num tensor([[2.2000e+01, 1.9943e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 1.7000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  6,  0,  4,  1, 39]])
# num tensor([[6.2000e+01, 1.9919e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.5000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.1000e+01, 1.8010e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  5,  2, 14,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 3.1740e+04, 4.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  3,  0,  0, 39]])
# num tensor([[3.0000e+01, 6.0426e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  1,  4,  1,  3,  4,  0, 39]])
# num tensor([[1.8000e+01, 5.9342e+04, 7.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+00]])
# label tensor([0.])
# cat tensor([[6, 9, 2, 4, 0, 2, 1, 0]])
# num tensor([[3.2000e+01, 6.2165e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  5, 12,  4,  4,  0, 39]])
# num tensor([[2.3000e+01, 3.3884e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  2, 14,  0,  2,  1, 39]])
# num tensor([[5.5000e+01, 2.3940e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  4,  1,  4,  0, 39]])
# num tensor([[3.6000e+01, 2.3357e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+00]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 1.9150e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.2000e+01, 3.6271e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 0, 11,  2,  0,  5,  1,  0, 39]])
# num tensor([[5.5000e+01, 1.0514e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  9,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 2.4890e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 12,  2, 14,  0,  4,  1, 39]])
# num tensor([[6.8000e+01, 1.4089e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 1.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  7,  0,  4,  1, 39]])
# num tensor([[4.1000e+01, 1.4544e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  4,  3,  4,  0, 39]])
# num tensor([[2.1000e+01, 2.7753e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 14,  2,  4,  0,  4,  1,  0]])
# num tensor([[5.5000e+01, 1.8387e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 5, 10,  2,  4,  0,  4,  1, 39]])
# num tensor([[5.3000e+01, 1.2827e+05, 1.6000e+01, 0.0000e+00, 0.0000e+00, 7.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  1,  2,  7,  0,  4,  1, 39]])
# num tensor([[5.1000e+01, 1.1476e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 4.8000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  7,  2, 13,  0,  2,  1, 39]])
# num tensor([[5.0000e+01, 2.2179e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 11,  0,  0,  1,  1,  0,  3]])
# num tensor([[3.3000e+01, 1.6300e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.1000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  5,  5,  4,  0, 39]])
# num tensor([[3.9000e+01, 1.7895e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 14,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 2.8225e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  4,  4,  4,  0, 39]])
# num tensor([[4.5000e+01, 2.2064e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 12,  2,  4,  5,  4,  0, 39]])
# num tensor([[4.4000e+01, 4.0240e+05, 1.4000e+01, 0.0000e+00, 1.9020e+03, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 10,  5,  4,  0, 39]])
# num tensor([[3.9000e+01, 1.0392e+05, 1.3000e+01, 7.6880e+03, 0.0000e+00, 3.2000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 12,  0,  3,  1,  4,  1, 39]])
# num tensor([[4.5000e+01, 2.4689e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 2.1328e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[4, 9, 4, 8, 1, 1, 1, 3]])
# num tensor([[3.0000e+01, 1.8277e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 1.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 12,  4, 10,  1,  4,  0, 39]])
# num tensor([[3.5000e+01, 1.1476e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 3.8000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 12,  4, 10,  1,  4,  0, 39]])
# num tensor([[2.9000e+01, 1.1653e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 1, 11,  2, 14,  0,  1,  1, 30]])
# num tensor([[4.9000e+01, 2.5262e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  2,  5,  0,  4,  1,  8]])
# num tensor([[4.2000e+01, 1.0433e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  5,  2,  4,  0,  4,  1, 39]])
# num tensor([[8.2000e+01, 1.2194e+05, 4.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 9, 11,  0, 15,  1,  4,  0, 39]])
# num tensor([[2.6000e+01, 1.5701e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  7,  4,  7,  3,  1,  1, 39]])
# num tensor([[5.2000e+01, 6.5624e+04, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  4,  1,  4,  0, 39]])
# num tensor([[2.6000e+01, 2.1280e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  8,  3,  4,  0, 39]])
# num tensor([[2.0000e+01, 2.1834e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.5000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  2, 14,  0,  4,  1, 39]])
# num tensor([[3.8000e+01, 1.6744e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  2,  3,  3,  3,  1, 39]])
# num tensor([[4.2000e+01, 3.6753e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.3000e+01]])
# label tensor([1.])
# cat tensor([[ 9,  0,  2, 15,  5,  4,  0, 39]])
# num tensor([[6.6000e+01, 5.9056e+04, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  5,  7,  4,  4,  0, 39]])
# num tensor([[3.8000e+01, 2.2257e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  7,  4, 10,  1,  4,  0, 39]])
# num tensor([[2.6000e+01, 1.2411e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 3.6000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  9,  2,  1,  0,  4,  1, 39]])
# num tensor([[4.0000e+01, 6.7874e+04, 1.3000e+01, 0.0000e+00, 1.8870e+03, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  0, 14,  1,  4,  1, 39]])
# num tensor([[5.3000e+01, 1.4632e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 12,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.4000e+01, 1.1663e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 15,  4,  7,  3,  4,  1, 39]])
# num tensor([[2.5000e+01, 3.0545e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 3.4200e+05, 1.1000e+01, 0.0000e+00, 1.9020e+03, 4.2000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 3.4570e+05, 1.3000e+01, 0.0000e+00, 1.9770e+03, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  7,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 1.6114e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  2,  1,  5,  1,  0,  3]])
# num tensor([[3.6000e+01, 1.3062e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.0000e+01, 2.9393e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  3,  2,  1,  0]])
# num tensor([[3.0000e+01, 1.7911e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 1,  2,  4,  8,  4,  2,  0, 39]])
# num tensor([[5.2000e+01, 2.9623e+04, 8.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[5.1000e+01, 3.0496e+05, 9.0000e+00, 7.6880e+03, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7,  1,  6,  8,  4,  4,  0, 39]])
# num tensor([[6.1000e+01, 1.5991e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 3.2000e+01]])
# label tensor([1.])
# cat tensor([[ 2, 11,  2,  1,  5,  4,  0, 39]])
# num tensor([[5.9000e+01, 4.2054e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.8000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.8000e+01, 7.5104e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  3,  3,  4,  1, 39]])
# num tensor([[3.4000e+01, 8.4119e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  6,  4,  4,  1,  4,  0, 39]])
# num tensor([[3.5000e+01, 2.0625e+05, 5.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  1,  0,  2,  1, 39]])
# num tensor([[2.4000e+01, 1.4832e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  7,  4,  6,  1,  4,  1, 39]])
# num tensor([[2.4000e+01, 3.2267e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 4.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 14,  0,  4,  1, 39]])
# num tensor([[4.9000e+01, 3.4446e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 15,  0,  3,  1,  4,  0, 39]])
# num tensor([[5.7000e+01, 2.8364e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 11,  0,  4,  1, 39]])
# num tensor([[2.5000e+01, 3.3085e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 7.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  0, 13,  4,  4,  0, 39]])
# num tensor([[3.3000e+01, 3.1407e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  1,  4,  5,  3,  2,  1, 39]])
# num tensor([[2.0000e+01, 1.6453e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4,  8,  1,  4,  1, 39]])
# num tensor([[2.2000e+01, 2.1540e+05, 1.0000e+01, 0.0000e+00, 1.6020e+03, 1.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 14,  0,  4,  1, 39]])
# num tensor([[5.8000e+01, 2.0524e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  6,  2,  8,  5,  2,  0, 39]])
# num tensor([[6.4000e+01, 2.1339e+05, 5.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 15,  4,  0,  3,  4,  0, 39]])
# num tensor([[1.8000e+01, 1.6379e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.1000e+01, 1.1226e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  6,  2,  7,  0,  4,  1, 39]])
# num tensor([[2.9000e+01, 2.1046e+05, 5.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  3,  1,  4,  4,  0, 39]])
# num tensor([[4.5000e+01, 1.9009e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[3.2000e+01, 1.1212e+05, 1.3000e+01, 7.6880e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  8,  3,  4,  0, 39]])
# num tensor([[3.3000e+01, 1.6794e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.5000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 12,  4, 10,  3,  4,  1, 39]])
# num tensor([[2.5000e+01, 3.3413e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 9, 11,  6, 15,  1,  4,  0, 39]])
# num tensor([[4.9000e+01, 1.7427e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 8.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  0,  8,  4,  4,  0, 39]])
# num tensor([[3.7000e+01, 1.3146e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.3000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4,  6,  3,  4,  1, 39]])
# num tensor([[2.2000e+01, 1.9720e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  7,  0,  4,  1, 39]])
# num tensor([[2.7000e+01, 3.1659e+04, 1.3000e+01, 0.0000e+00, 1.8870e+03, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7, 15,  2, 10,  5,  2,  0, 39]])
# num tensor([[3.2000e+01, 4.3871e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  4,  4,  8,  2,  4,  1, 26]])
# num tensor([[2.0000e+01, 5.2862e+05, 3.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  1,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 2.1961e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  7,  1,  2,  0, 39]])
# num tensor([[3.2000e+01, 2.7894e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  5,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 3.4458e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 11,  4,  8,  1,  4,  0, 39]])
# num tensor([[2.4000e+01, 1.3730e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.1000e+01, 2.1364e+05, 9.0000e+00, 3.9080e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 12,  1,  4,  1, 39]])
# num tensor([[3.4000e+01, 5.7426e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 14,  2,  4,  0,  4,  1, 39]])
# num tensor([[5.6000e+01, 1.9313e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 1.6000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.1000e+01, 1.6582e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  4,  0,  4,  1, 39]])
# num tensor([[5.7000e+01, 1.9985e+05, 1.3000e+01, 1.5024e+04, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  4,  1,  1,  4,  0, 39]])
# num tensor([[4.9000e+01, 4.7403e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.9000e+01, 3.4999e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 5, 14,  2, 10,  0,  4,  1, 39]])
# num tensor([[5.6000e+01, 1.2414e+05, 1.5000e+01, 9.9999e+04, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 1,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 3.4176e+05, 1.3000e+01, 7.6880e+03, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 2.9696e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2,  8,  0,  4,  1, 39]])
# num tensor([[3.8000e+01, 3.6989e+04, 1.3000e+01, 3.9080e+03, 0.0000e+00, 7.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  1,  4, 14,  3,  4,  1, 39]])
# num tensor([[4.0000e+01, 2.0150e+05, 7.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 4.6871e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  2, 12,  0,  4,  1, 12]])
# num tensor([[4.9000e+01, 1.7905e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 3.9788e+05, 9.0000e+00, 5.0130e+03, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 10,  0,  4,  1, 39]])
# num tensor([[2.5000e+01, 1.1275e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1,  4]])
# num tensor([[6.0000e+01, 1.6034e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[3.0000e+01, 1.0365e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2,  9,  2, 11,  0,  4,  1, 39]])
# num tensor([[3.7000e+01, 3.1223e+05, 1.3000e+01, 5.1780e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 11,  2,  5,  0,  4,  1, 26]])
# num tensor([[3.4000e+01, 2.6435e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 13,  0,  4,  1, 39]])
# num tensor([[2.9000e+01, 6.6095e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  3,  2,  3,  0,  4,  1, 26]])
# num tensor([[3.9000e+01, 3.2442e+05, 2.0000e+00, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  2,  1, 39]])
# num tensor([[4.4000e+01, 1.5725e+05, 1.3000e+01, 0.0000e+00, 1.9770e+03, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  6,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 1.6642e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.2000e+01, 1.0048e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4, 12,  3,  4,  1, 42]])
# num tensor([[2.1000e+01, 1.6387e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 14,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.8000e+01, 2.4689e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1, 39]])
# num tensor([[5.1000e+01, 3.5595e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6,  8,  2,  5,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 4.0666e+04, 1.1000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  0,  8,  4,  4,  0, 39]])
# num tensor([[4.9000e+01, 1.7507e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 1, 15,  4,  4,  4,  4,  0, 39]])
# num tensor([[3.9000e+01, 1.2705e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[5, 9, 2, 4, 0, 4, 1, 0]])
# num tensor([[4.2000e+01, 1.9120e+05, 1.3000e+01, 0.0000e+00, 1.9770e+03, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2,  1,  5,  4,  0, 39]])
# num tensor([[3.2000e+01, 4.0209e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+00]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4, 10,  1,  4,  1, 39]])
# num tensor([[3.8000e+01, 1.5231e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.1000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.2000e+01, 1.0497e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 15,  2,  0,  5,  4,  0, 39]])
# num tensor([[3.3000e+01, 3.1666e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 11,  2,  0,  0,  4,  1, 39]])
# num tensor([[6.8000e+01, 1.1754e+05, 9.0000e+00, 1.4090e+03, 0.0000e+00, 1.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  5,  4,  0,  2]])
# num tensor([[4.3000e+01, 1.0676e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# ...
# label tensor([0.])
# cat tensor([[ 4,  2,  4, 12,  3,  4,  0, 39]])
# num tensor([[1.7000e+01, 1.5302e+05, 8.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[3.6000e+01, 1.7354e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 12,  4, 10,  1,  1,  1, 10]])
# num tensor([[2.4000e+01, 1.6026e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  0, 12,  1,  4,  0, 39]])
# num tensor([[2.8000e+01, 2.7037e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 1.8316e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4, 13,  3,  4,  0, 39]])
# num tensor([[1.8000e+01, 1.6413e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 2.1474e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 12,  0,  4,  1, 39]])
# num tensor([[5.4000e+01, 2.0078e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4,  1,  3,  4,  0, 39]])
# num tensor([[1.8000e+01, 3.1149e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.6000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4, 12,  1,  4,  0, 39]])
# num tensor([[3.0000e+01, 2.6972e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  4,  1,  4,  0, 39]])
# num tensor([[4.6000e+01, 1.1667e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  0,  1,  4,  2,  0, 39]])
# num tensor([[4.0000e+01, 1.5828e+05, 9.0000e+00, 0.0000e+00, 6.2500e+02, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 14,  2, 10,  0,  4,  1, 39]])
# num tensor([[3.4000e+01, 1.9226e+05, 1.5000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  4,  3,  1,  1,  1,  1]])
# num tensor([[2.7000e+01, 2.9247e+05, 1.0000e+01, 0.0000e+00, 1.8760e+03, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  6, 14,  4,  4,  1, 39]])
# num tensor([[4.2000e+01, 2.5733e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 10,  3, 10,  1,  1,  1,  3]])
# num tensor([[3.8000e+01, 1.0008e+05, 1.6000e+01, 2.7828e+04, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 1.8587e+05, 1.3000e+01, 0.0000e+00, 1.9020e+03, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2, 13,  0,  4,  1, 39]])
# num tensor([[5.4000e+01, 2.0045e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[7.0000e+01, 3.6311e+04, 1.3000e+01, 2.0051e+04, 0.0000e+00, 3.5000e+01]])
# label tensor([1.])
# cat tensor([[ 1, 12,  0, 13,  1,  4,  0, 39]])
# num tensor([[3.6000e+01, 3.2744e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 6, 11,  4,  3,  3,  4,  1, 39]])
# num tensor([[3.6000e+01, 2.5829e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  0,  3,  1,  4,  1, 39]])
# num tensor([[2.8000e+01, 2.8240e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  4, 12,  1,  4,  0, 39]])
# num tensor([[2.4000e+01, 3.7639e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2,  4,  5,  4,  0, 39]])
# num tensor([[3.7000e+01, 1.3437e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 3.7000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  0,  4, 12,  3,  4,  0, 39]])
# num tensor([[2.2000e+01, 1.2682e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  3,  1,  4,  1, 39]])
# num tensor([[2.3000e+01, 2.0996e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  1,  3,  5,  2,  0, 39]])
# num tensor([[4.3000e+01, 2.1384e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.2000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2, 12,  0,  4,  1, 39]])
# num tensor([[5.8000e+01, 5.6392e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0,  9,  2,  0,  0,  4,  1, 39]])
# num tensor([[5.7000e+01, 2.4127e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 8.0000e+00]])
# label tensor([0.])
# cat tensor([[ 4,  8,  4,  3,  3,  2,  1, 39]])
# num tensor([[2.1000e+01, 2.0237e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 7, 15,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.4000e+01, 9.6249e+04, 1.0000e+01, 3.4110e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  0,  4,  4,  1,  4,  1, 39]])
# num tensor([[2.6000e+01, 1.9564e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 7.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4, 12,  3,  4,  0,  8]])
# num tensor([[2.0000e+01, 2.8998e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4, 12,  1,  4,  1, 39]])
# num tensor([[3.0000e+01, 1.8756e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 11,  6,  3,  1,  4,  1, 39]])
# num tensor([[6.6000e+01, 2.1246e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 11,  2,  4,  0,  1,  1, 35]])
# num tensor([[4.1000e+01, 1.5308e+05, 9.0000e+00, 0.0000e+00, 1.8870e+03, 7.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  8,  1,  2,  1, 39]])
# num tensor([[5.7000e+01, 1.5797e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.8000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  1,  0,  1,  1, 40]])
# num tensor([[6.3000e+01, 1.3534e+05, 9.0000e+00, 2.1050e+03, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 15,  2,  1,  5,  4,  0, 39]])
# num tensor([[5.2000e+01, 4.9069e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 7, 15,  2, 11,  0,  1,  1, 39]])
# num tensor([[4.3000e+01, 1.1419e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6, 10,  2, 10,  0,  4,  1, 42]])
# num tensor([[6.2000e+01, 5.6317e+04, 1.6000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 0, 15,  0,  0,  1,  4,  0, 39]])
# num tensor([[3.9000e+01, 2.0476e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 2.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  3,  0,  4,  1, 39]])
# num tensor([[4.0000e+01, 1.4910e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 12,  0, 10,  1,  4,  1,  2]])
# num tensor([[4.3000e+01, 2.1454e+05, 1.4000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  4, 14,  1,  4,  1, 33]])
# num tensor([[3.6000e+01, 1.9666e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  2,  3,  0,  4,  1, 39]])
# num tensor([[2.5000e+01, 3.3241e+05, 1.1000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2,  3,  0,  4,  1, 39]])
# num tensor([[5.6000e+01, 1.8656e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 10,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 1.8241e+05, 1.6000e+01, 0.0000e+00, 0.0000e+00, 5.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 15,  2,  8,  0,  4,  1, 39]])
# num tensor([[4.5000e+01, 1.0333e+05, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  3,  3,  4,  1, 39]])
# num tensor([[2.8000e+01, 2.4579e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4,  8,  4,  2,  0, 14]])
# num tensor([[4.8000e+01, 1.6932e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.2000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  4,  2,  4,  0, 39]])
# num tensor([[2.5000e+01, 2.2929e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 2.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2, 12,  0,  0,  1, 39]])
# num tensor([[4.1000e+01, 1.4731e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  4, 13,  1,  4,  1, 39]])
# num tensor([[2.5000e+01, 1.7652e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  7,  4,  8,  4,  4,  0, 39]])
# num tensor([[2.2000e+01, 3.8251e+04, 1.2000e+01, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  8,  0, 13,  1,  4,  0, 39]])
# num tensor([[2.9000e+01, 1.7712e+05, 1.1000e+01, 2.1740e+03, 0.0000e+00, 4.5000e+01]])
# label tensor([0.])
# cat tensor([[ 5, 11,  2,  4,  0,  4,  1,  2]])
# num tensor([[4.1000e+01, 6.7671e+04, 9.0000e+00, 0.0000e+00, 0.0000e+00, 5.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4, 12,  3,  4,  1,  8]])
# num tensor([[2.4000e+01, 1.4000e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 1, 11,  2,  1,  0,  4,  1, 39]])
# num tensor([[2.4000e+01, 1.0416e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 6,  9,  2,  3,  0,  4,  1, 39]])
# num tensor([[3.5000e+01, 1.8759e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 7.0000e+00]])
# label tensor([0.])
# cat tensor([[ 4, 11,  2,  4,  0,  4,  1, 39]])
# num tensor([[3.3000e+01, 7.6107e+04, 9.0000e+00, 4.3860e+03, 0.0000e+00, 6.0000e+01]])
# label tensor([1.])
# cat tensor([[ 2, 11,  0, 13,  4,  4,  1, 39]])
# num tensor([[5.2000e+01, 1.8783e+05, 9.0000e+00, 4.9340e+03, 0.0000e+00, 3.6000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 14,  2,  4,  0,  4,  1, 39]])
# num tensor([[4.7000e+01, 2.9491e+05, 1.5000e+01, 9.9999e+04, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  2, 12,  0,  4,  1, 39]])
# num tensor([[4.0000e+01, 1.3714e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  5,  7,  3,  4,  1, 26]])
# num tensor([[2.7000e+01, 4.9226e+05, 6.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  0,  2, 14,  0,  4,  1, 39]])
# num tensor([[5.8000e+01, 2.2225e+05, 6.0000e+00, 0.0000e+00, 1.8870e+03, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  7,  4,  1,  2,  2,  0, 39]])
# num tensor([[2.7000e+01, 2.8529e+05, 1.2000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 0, 11,  4,  0,  3,  2,  1, 39]])
# num tensor([[1.9000e+01, 2.5275e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  4,  0,  7,  4,  4,  0, 26]])
# num tensor([[5.0000e+01, 3.1330e+05, 3.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 11,  6,  8,  4,  4,  0, 39]])
# num tensor([[7.6000e+01, 1.1620e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.3000e+01]])
# label tensor([0.])
# cat tensor([[ 4, 15,  2, 12,  0,  4,  1, 39]])
# num tensor([[2.8000e+01, 8.7632e+04, 1.0000e+01, 0.0000e+00, 0.0000e+00, 4.3000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  3,  1,  4,  1, 39]])
# num tensor([[7.1000e+01, 1.8240e+05, 1.3000e+01, 1.1678e+04, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  2,  4, 12,  3,  4,  0, 39]])
# num tensor([[3.3000e+01, 1.7189e+05, 8.0000e+00, 0.0000e+00, 0.0000e+00, 3.5000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  4,  1,  1,  2,  1, 39]])
# num tensor([[3.8000e+01, 2.2779e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat tensor([[ 2, 12,  4, 10,  1,  4,  1, 39]])
# num tensor([[5.2000e+01, 1.8286e+05, 1.4000e+01, 1.0520e+04, 0.0000e+00, 4.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  6,  6,  1,  4,  1, 39]])
# num tensor([[8.0000e+01, 1.0774e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+01]])
# label tensor([0.])
# cat tensor([[ 4,  9,  2, 10,  0,  4,  1, 39]])
# num tensor([[4.6000e+01, 7.0754e+04, 1.3000e+01, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([1.])
# cat tensor([[ 4,  9,  4, 10,  1,  4,  0, 39]])
# num tensor([[2.7000e+01, 6.6087e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 6.0000e+01]])
# label tensor([0.])
# cat tensor([[ 5,  9,  2, 12,  0,  4,  1, 39]])
# num tensor([[3.8000e+01, 3.1223e+05, 1.3000e+01, 0.0000e+00, 0.0000e+00, 5.5000e+01]])
# label tensor([1.])
# cat tensor([[ 4, 11,  4,  3,  3,  4,  1, 39]])
# num tensor([[3.6000e+01, 1.8585e+05, 9.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+01]])
# label tensor([0.])
# cat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\smbm2\projects\CAT-Transformer\experiments\income\fttranformer.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> for cat,num,label in train_dataloader:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     print("cat",cat)
#       <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     print("num",num)
#       <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     print("label",label)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor.py:426, in Tensor.__repr__(self, tensor_contents)
#     422     return handle_torch_function(
#     423         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     424     )
#     425 # All strings are unicode in Python 3.
# --> 426 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor_str.py:636, in _str(self, tensor_contents)
#     634 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     635     guard = torch._C._DisableFuncTorch()
# --> 636     return _str_intern(self, tensor_contents=tensor_contents)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor_str.py:567, in _str_intern(inp, tensor_contents)
#     565                     tensor_str = _tensor_str(self.to_dense(), indent)
#     566                 else:
# --> 567                     tensor_str = _tensor_str(self, indent)
#     569 if self.layout != torch.strided:
#     570     suffixes.append("layout=" + str(self.layout))
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor_str.py:328, in _tensor_str(self, indent)
#     326 else:
#     327     formatter = _Formatter(get_summarized_data(self) if summarize else self)
# --> 328     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor_str.py:276, in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     260     slices = (
#     261         [
#     262             _tensor_str_with_formatter(
#    (...)
#     273         ]
#     274     )
#     275 else:
# --> 276     slices = [
#     277         _tensor_str_with_formatter(
#     278             self[i], indent + 1, summarize, formatter1, formatter2
#     279         )
#     280         for i in range(0, self.size(0))
#     281     ]
#     283 tensor_str = ("," + "\n" * (dim - 1) + " " * (indent + 1)).join(slices)
#     284 return "[" + tensor_str + "]"
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\_tensor_str.py:276, in <listcomp>(.0)
#     260     slices = (
#     261         [
#     262             _tensor_str_with_formatter(
#    (...)
#     273         ]
#     274     )
#     275 else:
# --> 276     slices = [
#     277         _tensor_str_with_formatter(
#     278             self[i], indent + 1, summarize, formatter1, formatter2
#     279         )
#     280         for i in range(0, self.size(0))
#     281     ]
#     283 tensor_str = ("," + "\n" * (dim - 1) + " " * (indent + 1)).join(slices)
#     284 return "[" + tensor_str + "]"
#
# KeyboardInterrupt:

# %%
class UncertaintyLoss(nn.Module):
    def __init__(self, num_tasks):
        super(UncertaintyLoss, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, prediction, labels_task1):

        #task 1
        target = labels_task1
        # prediction = predictions[0]
        loss_fn = self.loss_fns[0]
        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
# Training and Testing Loops
def train(dataloader, model, loss_function, optimizer, device_in_use):
    model.train()

    total_loss = 0

    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    total_correct_2 = 0
    total_samples_2 = 0
    all_targets_2 = []
    all_predictions_2 = []

    for (cat, num,labels_task1) in dataloader:
        cat, num,labels_task1 = cat.to(device_in_use), num.to(device_in_use),labels_task1.to(device_in_use)

        task_predictions = model(cat,num) #contains a list of the tensor outputs for each task
        task_predictions = task_predictions.squeeze(1)
        print("prediction shape",task_predictions.shape)
        print("labels shape", labels_task1.shape)
        print("pred",task_predictions)
        print("label",labels_task1)
        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()

        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

        # #computing accuaracy for second target
        # y_pred_softmax_2 = torch.softmax(task_predictions[1], dim=1)
        # _, y_pred_labels_2 = torch.max(y_pred_softmax_2, dim=1)
        # total_correct_2 += (y_pred_labels_2 == labels_task2).sum().item()
        # total_samples_2 += labels_task2.size(0)
        # all_targets_2.extend(labels_task2.cpu().numpy())
        # all_predictions_2.extend(y_pred_labels_2.cpu().numpy())

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    # accuracy_2 = total_correct_2 / total_samples_2

    # # precision = precision_score(all_targets, all_predictions, average='weighted')
    # recall = recall_score(all_targets, all_predictions, average='weighted')
    # f1 = f1_score(all_targets, all_predictions, average='weighted')

    return avg_loss, accuracy_1

def test(dataloader, model, loss_function, device_in_use):
  model.eval()
  total_loss = 0
  
  total_correct_1 = 0
  total_samples_1 = 0
  all_targets_1 = []
  all_predictions_1 = []

  total_correct_2 = 0
  total_samples_2 = 0
  all_targets_2 = []
  all_predictions_2 = []

  with torch.no_grad():
    for (cat, num,labels_task1) in dataloader:
        cat, num,labels_task1 = cat.to(device_in_use), num.to(device_in_use),labels_task1.to(device_in_use)


        task_predictions = model(cat,num) #contains a list of the tensor outputs for each task

        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()

        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions[0], dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

        # #computing accuaracy for second target
        # y_pred_softmax_2 = torch.softmax(task_predictions[1], dim=1)
        # _, y_pred_labels_2 = torch.max(y_pred_softmax_2, dim=1)
        # total_correct_2 += (y_pred_labels_2 == labels_task2).sum().item()
        # total_samples_2 += labels_task2.size(0)
        # all_targets_2.extend(labels_task2.cpu().numpy())
        # all_predictions_2.extend(y_pred_labels_2.cpu().numpy())

    avg = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    # accuracy_2 = total_correct_2 / total_samples_2
    # recall = recall_score(all_targets, all_predictions, average='weighted')
    f1_1 = f1_score(all_targets_1, all_predictions_1, average='weighted')
    # f1_2 = f1_score(all_targets_2, all_predictions_2, average="weighted")

    return avg, accuracy_1, all_predictions_1, all_targets_1, f1_1

# %%
model = FTTransformer(
    categories = (10, 5, 6, 5, 8),      # tuple containing the number of unique values within each category
    num_continuous = 10,                # number of continuous values
    dim = 32,                           # dimension, paper set at 32
    dim_out = 1,                        # binary prediction, but could be anything
    depth = 6,                          # depth, paper recommended 6
    heads = 8,                          # heads, paper recommends 8
    attn_dropout = 0.1,                 # post-attention dropout
    ff_dropout = 0.1                    # feed forward dropout
)

x_categ = torch.randint(0, 5, (1, 5))     # category values, from 0 - max number of categories, in the order as passed into the constructor above
x_numer = torch.randn(1, 10)              # numerical value
print("cat", x_categ)
print("num", x_numer)
pred = model(x_categ, x_numer) # (1, 1)

pred
# Out:
# cat tensor([[1, 4, 1, 1, 3]])
# num tensor([[ 0.4573, -1.3225,  0.9457,  0.8144, -0.0355, -0.1469,  1.4954, -0.1654,
#           1.8017,  1.0640]])
# tensor([[-0.0220]], grad_fn=<AddmmBackward0>)

# %%
model = FTTransformer(categories=(10,16,7,16,6,5,2,42),
                      num_continuous=6, 
                      dim = 32,                           # dimension, paper set at 32
                      dim_out = 1,                        # binary prediction, but could be anything
                      depth = 6,                          # depth, paper recommended 6
                      heads = 8,                          # heads, paper recommends 8
                      attn_dropout = 0.1,                 # post-attention dropout
                      ff_dropout = 0.1 )

optimizer = torch.optim.Adam(model.parameters(), lr = 0.01)
loss_function = UncertaintyLoss(1)
for epoch in range(5):
    train_loss, train_accuracy = train(train_dataloader, model, loss_function, optimizer, 'cpu')
        
    # Validation loop
    val_loss, val_accuracy, _, _, _ = test(val_dataloader, model, loss_function, 'cpu')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\smbm2\projects\CAT-Transformer\experiments\income\fttranformer.ipynb Cell 9 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a> loss_function = UncertaintyLoss(1)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> for epoch in range(5):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>     train_loss, train_accuracy = train(train_dataloader, model, loss_function, optimizer, 'cpu')
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>     # Validation loop
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a>     val_loss, val_accuracy, _, _, _ = test(val_dataloader, model, loss_function, 'cpu')
#
# c:\Users\smbm2\projects\CAT-Transformer\experiments\income\fttranformer.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=33'>34</a> for (cat, num,labels_task1) in dataloader:
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a>     cat, num,labels_task1 = cat.to(device_in_use), num.to(device_in_use),labels_task1.to(device_in_use)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>     task_predictions = model(cat,num) #contains a list of the tensor outputs for each task
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a>     task_predictions = task_predictions.squeeze(1)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/experiments/income/fttranformer.ipynb#X10sZmlsZQ%3D%3D?line=38'>39</a>     print("prediction shape",task_predictions.shape)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\tab_transformer_pytorch\ft_transformer.py:190, in FTTransformer.forward(self, x_categ, x_numer, return_attn)
#     187 if self.num_unique_categories > 0:
#     188     x_categ = x_categ + self.categories_offset
# --> 190     x_categ = self.categorical_embeds(x_categ)
#     192     xs.append(x_categ)
#     194 # add numerically embedded tokens
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\sparse.py:162, in Embedding.forward(self, input)
#     161 def forward(self, input: Tensor) -> Tensor:
# --> 162     return F.embedding(
#     163         input, self.weight, self.padding_idx, self.max_norm,
#     164         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self
