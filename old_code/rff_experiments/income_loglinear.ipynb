# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tab_transformer_pytorch import FTTransformer, TabTransformer
import sys
import time
from torch import Tensor
from typing import Literal
sys.path.append('../model/')
from updatedModel import train, test

device_in_use='cuda'

# %%
# df_train = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/train.csv')
# df_test = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/test.csv')
# df_val = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/validation.csv') #READ FROM RIGHT SPOT

df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\train.csv')
df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\test.csv')
df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\validation.csv') #READ FROM RIGHT SPOT

# %%
cont_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
       'hours-per-week']
cat_columns = ['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'race', 'sex', 'native-country']
target = ['income']

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cont_columns + cat_columns+target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

cat_features = (10,16,7,16,6,5,2,43)

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]

# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, cat_columns, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.float32).values

        self.cate = df[cat_columns].astype(np.int64).values
        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        cat_features = self.cate[idx]
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return cat_features, num_features, labels_task1

#Wrapping in Dataset
train_dataset = SingleTaskDataset(df_train, cat_columns, cont_columns, 'income')
val_dataset = SingleTaskDataset(df_val, cat_columns, cont_columns, 'income')
test_dataset = SingleTaskDataset(df_test, cat_columns, cont_columns, 'income')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
#Also try looking to see what other papers have done
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

class MultiHeadAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(MultiHeadAttention, self).__init__()

        self.embed_size = embed_size
        self.heads = heads
        self.head_dim = embed_size // heads
        assert(self.head_dim * heads == embed_size), "Embed size needs to be div by heads"
        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys =nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads*self.head_dim, embed_size)


    def forward(self, values, keys, query):
        N = query.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]

        values = values.reshape(N, value_len, self.heads, self.head_dim)
        keys = keys.reshape(N, key_len, self.heads, self.head_dim)
        queries = query.reshape(N, query_len, self.heads, self.head_dim)

        values = self.values(values)
        keys = self.keys(keys)
        queries = self.queries(queries)

        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])

        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3) #(batch_size, head_dim, #query_embeddings, #key_embeddings)

        # Calculate simplified attention scores
        avg_attention = attention.mean(dim=0)  # Average across batches
        # print("batch average", avg_attention.shape)
        avg_attention = avg_attention.mean(dim=0).squeeze(dim=0)
        # print("head average", avg_attention.shape)

        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(N, query_len, self.heads*self.head_dim) #(batch_size, n_features, embed_size)
        out = self.fc_out(out)

        return out, avg_attention
    
class TransformerBlock(nn.Module):
    def __init__(self, embed_size, heads, dropout, forward_expansion, pre_norm_on):
        super(TransformerBlock, self).__init__()

        self.pre_norm_on = pre_norm_on
        if self.pre_norm_on:
            self.pre_norm = nn.LayerNorm(embed_size)
        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm1 = nn.LayerNorm(embed_size)
        self.norm2 = nn.LayerNorm(embed_size)

        self.feed_forward = nn.Sequential(nn.Linear(embed_size, forward_expansion*embed_size),
                                          nn.ReLU(),
                                          nn.Linear(forward_expansion*embed_size, embed_size)
                                          )
        self.dropout = nn.Dropout(dropout)

    def forward(self,value,key,query):
        if self.pre_norm_on:
            query = self.pre_norm(query)
            key = self.pre_norm(key)
            value = self.pre_norm(value)
            
        attention, avg_attention = self.attention(value, key, query)
        x = self.dropout(self.norm1(attention + query))
        forward = self.feed_forward(x)
        out = self.dropout(self.norm2(forward + x))
        return out, avg_attention
    
class DecoderBlock(nn.Module):
    def __init__(self, embed_size, heads, forward_expansion, dropout, pre_norm_on):
        super(DecoderBlock, self).__init__()

        self.attention = MultiHeadAttention(embed_size, heads)
        self.norm = nn.LayerNorm(embed_size)
        self.transformer_block = TransformerBlock(embed_size, heads, dropout, forward_expansion, pre_norm_on)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, value, key):
        out, avg_attention = self.transformer_block(value, key, x)

        return out, avg_attention

class Decoder(nn.Module):
    def __init__(self,
                 embed_size,
                 num_layers,
                 heads,
                 forward_expansion,
                 decoder_dropout,
                 pre_norm_on
    ):
        super(Decoder, self).__init__()

        self.layers = nn.ModuleList(
                [
                    DecoderBlock(
                        embed_size,
                        heads,
                        dropout=decoder_dropout,
                        forward_expansion=forward_expansion,
                        pre_norm_on=pre_norm_on
                    )
                    for _ in range(num_layers)
                ]
            )
        self.avg_attention = None

    def forward(self, class_embed, context):
        for layer in self.layers:
            # x is the classification embedding (CLS Token)
            # context are the feature embeddings that will be used as key and value
            x, self.avg_attention = layer(class_embed, context, context)
  
        return x 

class EmbeddingsRFFforIndividualFeatures(nn.Module):
    def __init__(self, sigma, embed_size, input_size, n_cont, cat_feat, num_target_labels, rff_on, linear_on:bool):
        super(EmbeddingsRFFforIndividualFeatures, self).__init__()

        self.rff_on = rff_on

        self.linear_on = linear_on

        if self.rff_on:
            self.rffs = nn.ModuleList([GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) for _ in range(n_cont)])
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for _ in range(n_cont)])

        self.cat_embeddings = nn.ModuleList([nn.Embedding(num_classes, embed_size) for num_classes in cat_feat])

        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, cat_x, cont_x):
        x = cont_x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i, r in enumerate(self.rffs):
                input = x[:,i,:]
                out = r(input)
                rff_vectors.append(out)

        embeddings = []
        if self.linear_on:
            x = torch.stack(rff_vectors, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = rff_vectors

        #embedding cat features
        cat_x = cat_x.unsqueeze(2)
        for i, e in enumerate(self.cat_embeddings):

            goin_in = cat_x[:,i,:]
  
            goin_out = e(goin_in)
            goin_out=goin_out.squeeze(1)
            embeddings.append(goin_out)

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)


        return class_embeddings, context

class EmbeddingsRFFforAllFeatures(nn.Module):
    def __init__(self, sigma, embed_size, input_size, n_cont, cat_feat, num_target_labels, rff_on, linear_on:bool):
        super(EmbeddingsRFFforAllFeatures, self).__init__()

        self.rff_on = rff_on
        self.n_cont = n_cont
        self.linear_on=linear_on

        if self.rff_on:
            self.rff = GaussianEncoding(sigma=sigma, input_size=input_size, encoded_size=embed_size//2) 
            self.mlp_in = embed_size
        else:
            self.mlp_in = input_size

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=self.mlp_in, out_features=embed_size) for _ in range(n_cont)])

        self.cat_embeddings = nn.ModuleList([nn.Embedding(num_classes, embed_size) for num_classes in cat_feat])

        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, cat_x, cont_x):
        x = cont_x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)
        rff_vectors = []
        if self.rff_on:
            for i in range(self.n_cont):
                input = x[:,i,:]
                out = self.rff(input)
                rff_vectors.append(out)
        
        embeddings = []
        if self.linear_on:
            x = torch.stack(rff_vectors, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = rff_vectors

        #embedding cat features
        cat_x = cat_x.unsqueeze(2)
        for i, e in enumerate(self.cat_embeddings):

            goin_in = cat_x[:,i,:]
  
            goin_out = e(goin_in)
            goin_out=goin_out.squeeze(1)
            embeddings.append(goin_out)

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)

        return class_embeddings, context
    
class PeriodicActivation(nn.Module):
    def __init__(self, sigma, embed_size, input_size, n_cont, cat_feat, num_target_labels,trainable: bool, initialization: str, linear_on:bool):
        super(PeriodicActivation, self).__init__()

        self.n = embed_size
        self.sigma = sigma
        self.trainable = trainable
        self.initialization = initialization
        self.linear_on = linear_on
        self.n_cont = n_cont

        if self.initialization == 'log-linear':
            coefficients = self.sigma ** (torch.arange(self.n//2) / self.n)
            coefficients = coefficients[None]
        else:
            assert self.initialization == 'normal'
            coefficients = torch.normal(0.0, self.sigma, (1, self.n//2))

        if self.trainable:
            self.coefficients = nn.Parameter(coefficients)
        else:
            self.register_buffer('coefficients', coefficients)

        if self.linear_on:
            self.cont_embeddings = nn.ModuleList([nn.Linear(in_features=embed_size, out_features=embed_size) for _ in range(n_cont)])

        self.cat_embeddings = nn.ModuleList([nn.Embedding(num_classes, embed_size) for num_classes in cat_feat])

        # Classifcation Embeddings for each target label
        self.target_label_embeddings = nn.ModuleList([nn.Embedding(1, embed_size) for _ in range(num_target_labels)])


    def forward(self, cat_x, cont_x):
        x = cont_x.unsqueeze(2) #(batch_size, n_features) -> (batch_size, n_features, 1)

        temp = []
        for i in range(self.n_cont):
            input = x[:,i,:]
            out = torch.cat([torch.cos(self.coefficients * input), torch.sin(self.coefficients * input)], dim=-1)
            temp.append(out)
        
        embeddings = []
        if self.linear_on:
            x = torch.stack(temp, dim=1)
            for i, e in enumerate(self.cont_embeddings):
                goin_in = x[:,i,:]
                goin_out = e(goin_in)
                embeddings.append(goin_out)
        else:
            embeddings = temp
        
        #embedding cat features
        cat_x = cat_x.unsqueeze(2)
        for i, e in enumerate(self.cat_embeddings):
            goin_in = cat_x[:,i,:]
            goin_out = e(goin_in)
            goin_out=goin_out.squeeze(1)
            embeddings.append(goin_out)

        target_label_embeddings_ = []
        for e in self.target_label_embeddings:
            input = torch.tensor([0], device=x.device)
            temp = e(input)
            temp = temp.repeat(x.size(0), 1)
            tmep = temp.unsqueeze(1)
            target_label_embeddings_.append(temp)

        class_embeddings = torch.stack(target_label_embeddings_, dim=1)

        context = torch.stack(embeddings, dim=1)

        return class_embeddings, context


class classificationHead(nn.Module):
    def __init__(self, embed_size, dropout, mlp_scale_classification, num_target_classes):
        super(classificationHead, self).__init__()
        
        #flattening the embeddings out so each sample in batch is represented with a 460 dimensional vector
        self.input = embed_size
        self.lin1 = nn.Linear(self.input, mlp_scale_classification*self.input)
        self.drop = nn.Dropout(dropout)
        self.lin2 = nn.Linear(mlp_scale_classification*self.input, mlp_scale_classification*self.input)
        self.lin3 = nn.Linear(mlp_scale_classification*self.input, self.input)
        self.lin4 = nn.Linear(self.input, num_target_classes)
        self.relu = nn.ReLU()
        self.initialize_weights()

    def initialize_weights(self): #he_initialization.
        torch.nn.init.kaiming_normal_(self.lin1.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin1.bias)

        torch.nn.init.kaiming_normal_(self.lin3.weight, nonlinearity='relu')
        torch.nn.init.zeros_(self.lin3.bias)

    def forward(self, x):

        x= torch.reshape(x, (-1, self.input))

        x = self.lin1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin2(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin3(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.lin4(x)
  
        return x

class CATTransformer(nn.Module):
    def __init__(self, 
                 rff_on = True,
                 sigma=4,
                 embed_size=20,
                 input_size=1,
                 n_cont = 0,
                 cat_feat:list = [],
                 num_layers=1,
                 heads=1,
                 forward_expansion=4, # Determines how wide the MLP is in the encoder. Its a scaling factor. 
                 decoder_dropout=0,
                 classification_dropout = 0,
                 pre_norm_on = False,
                 mlp_scale_classification = 4,
                 targets_classes : list=  [3,8],
                embedding_scheme ="rff_unique",
                trainable=True,
                linear_on=True
                 ):
        super(CATTransformer, self).__init__()

        assert(embedding_scheme in ['rff_unique', 'rff', 'log-linear_periodic', 'normal_periodic']), "wrong embedding_scheme"

        if embedding_scheme == 'rff_unique':
            self.embeddings = EmbeddingsRFFforIndividualFeatures(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, 
                                     n_cont=n_cont, cat_feat=cat_feat, num_target_labels=len(targets_classes), linear_on=linear_on)
        elif embedding_scheme == 'log-linear_periodic':
            self.embeddings = PeriodicActivation(sigma=sigma, embed_size=embed_size, input_size=input_size, n_cont=n_cont, cat_feat=cat_feat, 
                                                 num_target_labels=len(target_classes),trainable=trainable,initialization='log-linear', linear_on=linear_on)
        elif embedding_scheme == 'normal_periodic':
            self.embeddings = PeriodicActivation(sigma=sigma, embed_size=embed_size, input_size=input_size, n_cont=n_cont, cat_feat=cat_feat, 
                                                 num_target_labels=len(target_classes),trainable=trainable,initialization='normal',linear_on=linear_on)
        else:
            self.embeddings = EmbeddingsRFFforAllFeatures(rff_on=rff_on, sigma=sigma, embed_size=embed_size, input_size=input_size, 
                                     n_cont=n_cont, cat_feat=cat_feat, num_target_labels=len(targets_classes),linear_on=linear_on)
            
        self.decoder = Decoder(embed_size=embed_size, num_layers=num_layers, heads=heads, forward_expansion=forward_expansion, 
                               decoder_dropout=decoder_dropout, pre_norm_on=pre_norm_on)
        self.classifying_heads = nn.ModuleList([classificationHead(embed_size=embed_size, dropout=classification_dropout, 
                                                                   mlp_scale_classification=mlp_scale_classification, 
                                                                   num_target_classes=x) for x in targets_classes])
        
    def forward(self, cat_x, cont_x):
        class_embed, context = self.embeddings(cat_x, cont_x)

        x = self.decoder(class_embed, context)
        
        probability_dist_raw = []
        for i, e in enumerate(self.classifying_heads):
            input = x[:, i,:]
            output = e(input)
            probability_dist_raw.append(output)
        
        return probability_dist_raw

def format_metric(value): # Used to format the metrics output
    return f"{value:.4f}"

# %% [markdown]
# # Log-Linear RFF

# %% [markdown]
# $\sigma = -2$

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=-2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 200 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 2/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 3/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 4/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 5/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 6/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 7/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 8/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [ 9/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [10/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [11/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [12/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [13/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [14/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [15/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [16/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [17/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [18/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [19/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [20/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [21/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [22/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [23/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [24/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [25/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [26/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [27/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [28/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [29/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [30/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [31/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [32/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [33/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [34/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [35/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [36/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [37/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [38/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [39/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [40/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [41/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [42/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [43/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [44/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [45/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [46/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [47/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [48/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [49/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [50/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [51/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [52/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [53/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [54/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [55/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [56/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [57/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [58/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [59/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [60/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [61/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [62/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [63/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [64/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [65/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [66/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [67/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [68/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [69/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [70/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [71/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [72/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [73/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [74/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [75/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [76/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [77/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [78/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [79/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [80/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [81/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [82/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [83/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [84/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [85/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [86/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [87/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [88/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [89/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [90/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [91/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [92/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [93/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [94/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [95/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [96/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [97/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [98/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [99/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [100/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [101/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [102/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [103/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [104/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [105/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [106/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [107/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [108/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [109/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [110/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [111/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [112/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [113/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [114/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [115/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [116/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [117/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [118/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [119/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [120/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [121/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [122/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [123/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [124/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [125/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [126/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [127/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [128/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [129/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [130/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [131/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [132/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [133/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [134/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [135/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [136/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [137/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [138/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [139/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [140/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [141/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [142/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [143/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [144/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [145/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [146/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [147/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [148/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [149/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [150/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [151/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [152/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [153/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [154/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [155/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [156/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [157/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [158/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [159/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [160/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [161/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [162/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [163/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [164/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [165/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [166/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [167/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [168/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [169/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [170/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [171/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [172/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [173/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [174/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [175/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [176/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [177/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [178/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [179/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [180/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [181/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [182/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [183/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [184/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [185/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [186/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [187/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [188/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [189/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [190/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [191/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [192/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [193/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [194/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [195/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [196/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [197/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [198/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [199/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Epoch [200/200]      | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# Confusion Matrix for income
# [[42204     0     0     0     0     0     0]
#  [56912     0     0     0     0     0     0]
#  [ 7094     0     0     0     0     0     0]
#  [  533     0     0     0     0     0     0]
#  [ 1962     0     0     0     0     0     0]
#  [ 3460     0     0     0     0     0     0]
#  [ 4038     0     0     0     0     0     0]]
# Best accuracy 0.36319200020653514
# Best F1 0.19352876042998868
# 100 epochs of training and evaluation took, 744.359375

# %% [markdown]
# $\sigma = -1$

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=-1,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 200 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/200]       | Train: Loss nan, Accuracy 0.36458                                 | Test: Loss nan, Accuracy 0.36319, F1 0.19353
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\covertype_loglinear.ipynb Cell 9 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=50'>51</a> start_time = time.process_time()
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=52'>53</a> for t in range(epochs):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=53'>54</a>   train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=54'>55</a>   test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
#      <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=55'>56</a>   train_losses.append(train_loss)
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\covertype_loglinear.ipynb Cell 9 line 4
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=404'>405</a> for (features,labels_task1) in dataloader:
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=405'>406</a>     features,labels_task1 = features.to(device_in_use),labels_task1.to(device_in_use)
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=408'>409</a>     task_predictions = model(features) #contains a list of the tensor outputs for each task
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=410'>411</a>     loss = loss_function(task_predictions, labels_task1)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=411'>412</a>     total_loss += loss.item()
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\covertype_loglinear.ipynb Cell 9 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=375'>376</a> def forward(self, x):
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=376'>377</a>     class_embed, context = self.embeddings(x)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=378'>379</a>     x = self.decoder(class_embed, context)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=380'>381</a>     probability_dist_raw = []
#
# File c:\Users\smbm2\AppData\Local\miniconda3\envs\ml-env\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\smbm2\projects\CAT-Transformer\rff_experiments\covertype_loglinear.ipynb Cell 9 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=265'>266</a> for i in range(self.n_cont):
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=266'>267</a>     input = x[:,i,:]
# --> <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=267'>268</a>     out = torch.cat([torch.cos(self.coefficients * input), torch.sin(self.coefficients * input)], dim=-1)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=268'>269</a>     temp.append(out)
#     <a href='vscode-notebook-cell:/c%3A/Users/smbm2/projects/CAT-Transformer/rff_experiments/covertype_loglinear.ipynb#X45sZmlsZQ%3D%3D?line=270'>271</a> embeddings = []
#
# KeyboardInterrupt:

# %% [markdown]
# $\sigma = -0.5$

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=-0.5,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 200 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")

# %% [markdown]
# $\sigma = 0.5$

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=0.5,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       cat_feat=cat_features,
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 200 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/200]       | Train: Loss 0.42499, Accuracy 0.80239                             | Test: Loss 0.34102, Accuracy 0.83872, F1 0.83734
# Epoch [ 2/200]       | Train: Loss 0.32541, Accuracy 0.84849                             | Test: Loss 0.32744, Accuracy 0.84895, F1 0.83968
# Epoch [ 3/200]       | Train: Loss 0.31711, Accuracy 0.85077                             | Test: Loss 0.32608, Accuracy 0.84497, F1 0.82708
# Epoch [ 4/200]       | Train: Loss 0.31328, Accuracy 0.85399                             | Test: Loss 0.32720, Accuracy 0.84531, F1 0.82835
# Epoch [ 5/200]       | Train: Loss 0.30857, Accuracy 0.85662                             | Test: Loss 0.31517, Accuracy 0.85532, F1 0.84939
# Epoch [ 6/200]       | Train: Loss 0.30738, Accuracy 0.85762                             | Test: Loss 0.31214, Accuracy 0.85498, F1 0.85082
# Epoch [ 7/200]       | Train: Loss 0.30593, Accuracy 0.85814                             | Test: Loss 0.31256, Accuracy 0.85282, F1 0.84083
# Epoch [ 8/200]       | Train: Loss 0.30424, Accuracy 0.85981                             | Test: Loss 0.31688, Accuracy 0.85407, F1 0.85365
# Epoch [ 9/200]       | Train: Loss 0.30390, Accuracy 0.85914                             | Test: Loss 0.30937, Accuracy 0.85839, F1 0.85410
# Epoch [10/200]       | Train: Loss 0.30263, Accuracy 0.86031                             | Test: Loss 0.31028, Accuracy 0.85805, F1 0.84912
# Epoch [11/200]       | Train: Loss 0.30252, Accuracy 0.85788                             | Test: Loss 0.30809, Accuracy 0.85748, F1 0.85274
# Epoch [12/200]       | Train: Loss 0.30017, Accuracy 0.86028                             | Test: Loss 0.31176, Accuracy 0.85783, F1 0.85168
# Epoch [13/200]       | Train: Loss 0.30099, Accuracy 0.85990                             | Test: Loss 0.31121, Accuracy 0.85771, F1 0.85145
# Epoch [14/200]       | Train: Loss 0.30241, Accuracy 0.85993                             | Test: Loss 0.31160, Accuracy 0.85896, F1 0.85312
# Epoch [15/200]       | Train: Loss 0.30037, Accuracy 0.85963                             | Test: Loss 0.31122, Accuracy 0.85737, F1 0.84682
# Epoch [16/200]       | Train: Loss 0.30138, Accuracy 0.85846                             | Test: Loss 0.31154, Accuracy 0.85748, F1 0.85283
# Epoch [17/200]       | Train: Loss 0.29842, Accuracy 0.85955                             | Test: Loss 0.30875, Accuracy 0.85851, F1 0.85181
# Epoch [18/200]       | Train: Loss 0.29940, Accuracy 0.85928                             | Test: Loss 0.31447, Accuracy 0.85805, F1 0.85343
# Epoch [19/200]       | Train: Loss 0.29968, Accuracy 0.85966                             | Test: Loss 0.31038, Accuracy 0.85464, F1 0.84205
# Epoch [20/200]       | Train: Loss 0.29812, Accuracy 0.86051                             | Test: Loss 0.31318, Accuracy 0.85589, F1 0.84339
# Epoch [21/200]       | Train: Loss 0.29857, Accuracy 0.86004                             | Test: Loss 0.30882, Accuracy 0.85817, F1 0.85268
# Epoch [22/200]       | Train: Loss 0.29831, Accuracy 0.86077                             | Test: Loss 0.31071, Accuracy 0.85578, F1 0.85274
# Epoch [23/200]       | Train: Loss 0.29849, Accuracy 0.85922                             | Test: Loss 0.31024, Accuracy 0.85817, F1 0.84886
# Epoch [24/200]       | Train: Loss 0.29756, Accuracy 0.85998                             | Test: Loss 0.30959, Accuracy 0.85555, F1 0.85365
# Epoch [25/200]       | Train: Loss 0.29782, Accuracy 0.85984                             | Test: Loss 0.31026, Accuracy 0.85623, F1 0.85182
# Epoch [26/200]       | Train: Loss 0.29721, Accuracy 0.86001                             | Test: Loss 0.30552, Accuracy 0.85942, F1 0.85266
# Epoch [27/200]       | Train: Loss 0.29677, Accuracy 0.86107                             | Test: Loss 0.31107, Accuracy 0.85908, F1 0.85291
# Epoch [28/200]       | Train: Loss 0.29901, Accuracy 0.85928                             | Test: Loss 0.30780, Accuracy 0.85726, F1 0.85266
# Epoch [29/200]       | Train: Loss 0.29706, Accuracy 0.85975                             | Test: Loss 0.30751, Accuracy 0.85896, F1 0.85073
# Epoch [30/200]       | Train: Loss 0.29568, Accuracy 0.86022                             | Test: Loss 0.30832, Accuracy 0.85851, F1 0.85236
# Epoch [31/200]       | Train: Loss 0.29749, Accuracy 0.86010                             | Test: Loss 0.31046, Accuracy 0.85760, F1 0.85587
# Epoch [32/200]       | Train: Loss 0.29597, Accuracy 0.86045                             | Test: Loss 0.30789, Accuracy 0.85794, F1 0.84909
# Epoch [33/200]       | Train: Loss 0.29635, Accuracy 0.86165                             | Test: Loss 0.30998, Accuracy 0.85805, F1 0.84846
# Epoch [34/200]       | Train: Loss 0.29527, Accuracy 0.86054                             | Test: Loss 0.30843, Accuracy 0.85657, F1 0.85295
# Epoch [35/200]       | Train: Loss 0.29495, Accuracy 0.86016                             | Test: Loss 0.30852, Accuracy 0.85862, F1 0.85522
# Epoch [36/200]       | Train: Loss 0.29524, Accuracy 0.86066                             | Test: Loss 0.30712, Accuracy 0.85919, F1 0.85379
# Epoch [37/200]       | Train: Loss 0.29520, Accuracy 0.86186                             | Test: Loss 0.31081, Accuracy 0.85828, F1 0.84947
# Epoch [38/200]       | Train: Loss 0.29420, Accuracy 0.86148                             | Test: Loss 0.30793, Accuracy 0.85919, F1 0.85431
# Epoch [39/200]       | Train: Loss 0.29353, Accuracy 0.86171                             | Test: Loss 0.30501, Accuracy 0.85976, F1 0.85387
# Epoch [40/200]       | Train: Loss 0.29388, Accuracy 0.86241                             | Test: Loss 0.30687, Accuracy 0.85919, F1 0.85304
# Epoch [41/200]       | Train: Loss 0.29322, Accuracy 0.86203                             | Test: Loss 0.30598, Accuracy 0.85987, F1 0.85102
# Epoch [42/200]       | Train: Loss 0.29329, Accuracy 0.86191                             | Test: Loss 0.30653, Accuracy 0.85965, F1 0.85214
# Epoch [43/200]       | Train: Loss 0.29378, Accuracy 0.86104                             | Test: Loss 0.30956, Accuracy 0.85987, F1 0.85248
# Epoch [44/200]       | Train: Loss 0.29244, Accuracy 0.86276                             | Test: Loss 0.30953, Accuracy 0.85680, F1 0.84413
# Epoch [45/200]       | Train: Loss 0.29360, Accuracy 0.86238                             | Test: Loss 0.30780, Accuracy 0.86067, F1 0.85425
# Epoch [46/200]       | Train: Loss 0.29134, Accuracy 0.86224                             | Test: Loss 0.30619, Accuracy 0.85942, F1 0.85427
# Epoch [47/200]       | Train: Loss 0.29217, Accuracy 0.86314                             | Test: Loss 0.30867, Accuracy 0.85839, F1 0.84696
# Epoch [48/200]       | Train: Loss 0.29179, Accuracy 0.86221                             | Test: Loss 0.30839, Accuracy 0.85953, F1 0.85694
# Epoch [49/200]       | Train: Loss 0.29054, Accuracy 0.86390                             | Test: Loss 0.30573, Accuracy 0.86146, F1 0.85713
# Epoch [50/200]       | Train: Loss 0.28874, Accuracy 0.86399                             | Test: Loss 0.30777, Accuracy 0.86317, F1 0.86028
# Epoch [51/200]       | Train: Loss 0.28717, Accuracy 0.86405                             | Test: Loss 0.30536, Accuracy 0.86203, F1 0.85523
# Epoch [52/200]       | Train: Loss 0.28617, Accuracy 0.86452                             | Test: Loss 0.30669, Accuracy 0.86169, F1 0.85672
# Epoch [53/200]       | Train: Loss 0.28419, Accuracy 0.86604                             | Test: Loss 0.30588, Accuracy 0.86215, F1 0.85440
# Epoch [54/200]       | Train: Loss 0.28297, Accuracy 0.86709                             | Test: Loss 0.29914, Accuracy 0.86419, F1 0.85696
# Epoch [55/200]       | Train: Loss 0.28307, Accuracy 0.86738                             | Test: Loss 0.30088, Accuracy 0.86385, F1 0.85662
# Epoch [56/200]       | Train: Loss 0.28201, Accuracy 0.86724                             | Test: Loss 0.30623, Accuracy 0.85999, F1 0.84788
# Epoch [57/200]       | Train: Loss 0.28112, Accuracy 0.86697                             | Test: Loss 0.30093, Accuracy 0.86510, F1 0.86008
# Epoch [58/200]       | Train: Loss 0.28114, Accuracy 0.86750                             | Test: Loss 0.29891, Accuracy 0.86328, F1 0.85540
# Epoch [59/200]       | Train: Loss 0.28003, Accuracy 0.86809                             | Test: Loss 0.30112, Accuracy 0.86397, F1 0.85613
# Epoch [60/200]       | Train: Loss 0.28065, Accuracy 0.86785                             | Test: Loss 0.29892, Accuracy 0.86351, F1 0.85825
# Epoch [61/200]       | Train: Loss 0.27885, Accuracy 0.86911                             | Test: Loss 0.30112, Accuracy 0.86328, F1 0.85923
# Epoch [62/200]       | Train: Loss 0.27861, Accuracy 0.86870                             | Test: Loss 0.30343, Accuracy 0.86647, F1 0.86340
# Epoch [63/200]       | Train: Loss 0.27727, Accuracy 0.86984                             | Test: Loss 0.30381, Accuracy 0.86340, F1 0.85669
# Epoch [64/200]       | Train: Loss 0.27755, Accuracy 0.86993                             | Test: Loss 0.30349, Accuracy 0.86397, F1 0.85948
# Epoch [65/200]       | Train: Loss 0.27765, Accuracy 0.86949                             | Test: Loss 0.30023, Accuracy 0.86499, F1 0.85833
# Epoch [66/200]       | Train: Loss 0.27696, Accuracy 0.87101                             | Test: Loss 0.30106, Accuracy 0.86647, F1 0.86135
# Epoch [67/200]       | Train: Loss 0.27590, Accuracy 0.87016                             | Test: Loss 0.30442, Accuracy 0.86397, F1 0.85768
# Epoch [68/200]       | Train: Loss 0.27540, Accuracy 0.87037                             | Test: Loss 0.30131, Accuracy 0.86647, F1 0.86147
# Epoch [69/200]       | Train: Loss 0.27356, Accuracy 0.87081                             | Test: Loss 0.30612, Accuracy 0.86567, F1 0.86143
# Epoch [70/200]       | Train: Loss 0.27467, Accuracy 0.87136                             | Test: Loss 0.30766, Accuracy 0.86056, F1 0.86012
# Epoch [71/200]       | Train: Loss 0.27303, Accuracy 0.87160                             | Test: Loss 0.30192, Accuracy 0.86658, F1 0.86160
# Epoch [72/200]       | Train: Loss 0.27246, Accuracy 0.87265                             | Test: Loss 0.31542, Accuracy 0.86556, F1 0.85981
# Epoch [73/200]       | Train: Loss 0.27217, Accuracy 0.87315                             | Test: Loss 0.30317, Accuracy 0.86647, F1 0.86218
# Epoch [74/200]       | Train: Loss 0.27062, Accuracy 0.87364                             | Test: Loss 0.30584, Accuracy 0.86545, F1 0.85918
# Epoch [75/200]       | Train: Loss 0.27186, Accuracy 0.87247                             | Test: Loss 0.30686, Accuracy 0.86419, F1 0.85643
# Epoch [76/200]       | Train: Loss 0.26929, Accuracy 0.87397                             | Test: Loss 0.30359, Accuracy 0.86533, F1 0.86038
# Epoch [77/200]       | Train: Loss 0.26851, Accuracy 0.87435                             | Test: Loss 0.31181, Accuracy 0.86465, F1 0.85952
# Epoch [78/200]       | Train: Loss 0.26799, Accuracy 0.87487                             | Test: Loss 0.30944, Accuracy 0.86510, F1 0.86040
# Epoch [79/200]       | Train: Loss 0.26830, Accuracy 0.87443                             | Test: Loss 0.30961, Accuracy 0.86249, F1 0.86059
# Epoch [80/200]       | Train: Loss 0.26496, Accuracy 0.87552                             | Test: Loss 0.30648, Accuracy 0.86715, F1 0.86255
# Epoch [81/200]       | Train: Loss 0.26359, Accuracy 0.87692                             | Test: Loss 0.31427, Accuracy 0.86419, F1 0.85960
# Epoch [82/200]       | Train: Loss 0.26210, Accuracy 0.87648                             | Test: Loss 0.31685, Accuracy 0.86647, F1 0.86170
# Epoch [83/200]       | Train: Loss 0.26178, Accuracy 0.87774                             | Test: Loss 0.30980, Accuracy 0.86442, F1 0.85825
# Epoch [84/200]       | Train: Loss 0.26169, Accuracy 0.87803                             | Test: Loss 0.31416, Accuracy 0.86203, F1 0.86182
# Epoch [85/200]       | Train: Loss 0.26083, Accuracy 0.87832                             | Test: Loss 0.32275, Accuracy 0.86169, F1 0.85235
# Epoch [86/200]       | Train: Loss 0.25741, Accuracy 0.88063                             | Test: Loss 0.31651, Accuracy 0.86658, F1 0.86172
# Epoch [87/200]       | Train: Loss 0.25765, Accuracy 0.87949                             | Test: Loss 0.31744, Accuracy 0.86351, F1 0.85670
# Epoch [88/200]       | Train: Loss 0.25733, Accuracy 0.87970                             | Test: Loss 0.31649, Accuracy 0.85839, F1 0.85607
# Epoch [89/200]       | Train: Loss 0.25407, Accuracy 0.88066                             | Test: Loss 0.31644, Accuracy 0.86385, F1 0.85871
# Epoch [90/200]       | Train: Loss 0.25328, Accuracy 0.88128                             | Test: Loss 0.32386, Accuracy 0.86192, F1 0.85748
# Epoch [91/200]       | Train: Loss 0.25096, Accuracy 0.88271                             | Test: Loss 0.32685, Accuracy 0.86146, F1 0.85938
# Epoch [92/200]       | Train: Loss 0.24972, Accuracy 0.88271                             | Test: Loss 0.33297, Accuracy 0.85874, F1 0.85787
# Epoch [93/200]       | Train: Loss 0.24892, Accuracy 0.88306                             | Test: Loss 0.33170, Accuracy 0.85737, F1 0.85488
# Epoch [94/200]       | Train: Loss 0.24460, Accuracy 0.88473                             | Test: Loss 0.34373, Accuracy 0.86181, F1 0.85820
# Epoch [95/200]       | Train: Loss 0.24371, Accuracy 0.88701                             | Test: Loss 0.33560, Accuracy 0.86272, F1 0.85863
# Epoch [96/200]       | Train: Loss 0.24032, Accuracy 0.88751                             | Test: Loss 0.34310, Accuracy 0.85510, F1 0.85287
# Epoch [97/200]       | Train: Loss 0.24072, Accuracy 0.88777                             | Test: Loss 0.34557, Accuracy 0.85987, F1 0.85612
# Epoch [98/200]       | Train: Loss 0.23760, Accuracy 0.88704                             | Test: Loss 0.35079, Accuracy 0.85635, F1 0.85157
# Epoch [99/200]       | Train: Loss 0.23337, Accuracy 0.89157                             | Test: Loss 0.35865, Accuracy 0.85384, F1 0.85185
# Epoch [100/200]      | Train: Loss 0.23255, Accuracy 0.89096                             | Test: Loss 0.35544, Accuracy 0.85453, F1 0.85125
# Epoch [101/200]      | Train: Loss 0.22896, Accuracy 0.89298                             | Test: Loss 0.36938, Accuracy 0.85214, F1 0.85072
# Epoch [102/200]      | Train: Loss 0.22437, Accuracy 0.89479                             | Test: Loss 0.36876, Accuracy 0.85521, F1 0.85081
# Epoch [103/200]      | Train: Loss 0.22249, Accuracy 0.89649                             | Test: Loss 0.36823, Accuracy 0.85657, F1 0.85379
# Epoch [104/200]      | Train: Loss 0.22022, Accuracy 0.89596                             | Test: Loss 0.37059, Accuracy 0.85771, F1 0.85307
# Epoch [105/200]      | Train: Loss 0.21729, Accuracy 0.89997                             | Test: Loss 0.39418, Accuracy 0.85805, F1 0.85592
# Epoch [106/200]      | Train: Loss 0.21185, Accuracy 0.90093                             | Test: Loss 0.39270, Accuracy 0.85305, F1 0.85029
# Epoch [107/200]      | Train: Loss 0.21025, Accuracy 0.90117                             | Test: Loss 0.40230, Accuracy 0.85419, F1 0.85054
# Epoch [108/200]      | Train: Loss 0.20767, Accuracy 0.90389                             | Test: Loss 0.39267, Accuracy 0.85202, F1 0.85051
# Epoch [109/200]      | Train: Loss 0.20340, Accuracy 0.90438                             | Test: Loss 0.45155, Accuracy 0.84679, F1 0.84301
# Epoch [110/200]      | Train: Loss 0.20192, Accuracy 0.90681                             | Test: Loss 0.42629, Accuracy 0.85601, F1 0.85055
# Epoch [111/200]      | Train: Loss 0.19810, Accuracy 0.90810                             | Test: Loss 0.41658, Accuracy 0.84952, F1 0.84843
# Epoch [112/200]      | Train: Loss 0.19448, Accuracy 0.90953                             | Test: Loss 0.41135, Accuracy 0.84861, F1 0.84593
# Epoch [113/200]      | Train: Loss 0.19657, Accuracy 0.90848                             | Test: Loss 0.43225, Accuracy 0.85407, F1 0.84897
# Epoch [114/200]      | Train: Loss 0.18965, Accuracy 0.91079                             | Test: Loss 0.44338, Accuracy 0.85441, F1 0.85132
# Epoch [115/200]      | Train: Loss 0.18868, Accuracy 0.91190                             | Test: Loss 0.43138, Accuracy 0.85339, F1 0.85128
# Epoch [116/200]      | Train: Loss 0.18239, Accuracy 0.91418                             | Test: Loss 0.44598, Accuracy 0.85396, F1 0.85014
# Epoch [117/200]      | Train: Loss 0.18281, Accuracy 0.91486                             | Test: Loss 0.42792, Accuracy 0.84042, F1 0.83954
# Epoch [118/200]      | Train: Loss 0.17890, Accuracy 0.91567                             | Test: Loss 0.48508, Accuracy 0.84076, F1 0.84130
# Epoch [119/200]      | Train: Loss 0.17557, Accuracy 0.91819                             | Test: Loss 0.47686, Accuracy 0.84258, F1 0.84007
# Epoch [120/200]      | Train: Loss 0.17104, Accuracy 0.91986                             | Test: Loss 0.50078, Accuracy 0.84884, F1 0.84567
# Epoch [121/200]      | Train: Loss 0.17170, Accuracy 0.91974                             | Test: Loss 0.49880, Accuracy 0.84406, F1 0.84447
# Epoch [122/200]      | Train: Loss 0.16995, Accuracy 0.92141                             | Test: Loss 0.52255, Accuracy 0.84975, F1 0.84876
# Epoch [123/200]      | Train: Loss 0.16648, Accuracy 0.92214                             | Test: Loss 0.52660, Accuracy 0.84622, F1 0.84499
# Epoch [124/200]      | Train: Loss 0.16179, Accuracy 0.92521                             | Test: Loss 0.49936, Accuracy 0.83872, F1 0.83629
# Epoch [125/200]      | Train: Loss 0.15984, Accuracy 0.92439                             | Test: Loss 0.50417, Accuracy 0.84634, F1 0.84248
# Epoch [126/200]      | Train: Loss 0.15790, Accuracy 0.92530                             | Test: Loss 0.53354, Accuracy 0.84929, F1 0.84537
# Epoch [127/200]      | Train: Loss 0.15757, Accuracy 0.92752                             | Test: Loss 0.53164, Accuracy 0.83951, F1 0.83633
# Epoch [128/200]      | Train: Loss 0.15406, Accuracy 0.92828                             | Test: Loss 0.54679, Accuracy 0.83735, F1 0.83524
# Epoch [129/200]      | Train: Loss 0.15310, Accuracy 0.92837                             | Test: Loss 0.54404, Accuracy 0.84838, F1 0.84491
# Epoch [130/200]      | Train: Loss 0.15381, Accuracy 0.92919                             | Test: Loss 0.56260, Accuracy 0.84816, F1 0.84371
# Epoch [131/200]      | Train: Loss 0.14927, Accuracy 0.93068                             | Test: Loss 0.57950, Accuracy 0.84406, F1 0.84156
# Epoch [132/200]      | Train: Loss 0.14445, Accuracy 0.93226                             | Test: Loss 0.60380, Accuracy 0.84361, F1 0.84063
# Epoch [133/200]      | Train: Loss 0.14372, Accuracy 0.93299                             | Test: Loss 0.60021, Accuracy 0.84167, F1 0.83964
# Epoch [134/200]      | Train: Loss 0.14165, Accuracy 0.93372                             | Test: Loss 0.62246, Accuracy 0.84258, F1 0.84085
# Epoch [135/200]      | Train: Loss 0.13828, Accuracy 0.93495                             | Test: Loss 0.63783, Accuracy 0.84338, F1 0.84200
# Epoch [136/200]      | Train: Loss 0.14066, Accuracy 0.93355                             | Test: Loss 0.62916, Accuracy 0.83997, F1 0.83977
# Epoch [137/200]      | Train: Loss 0.13676, Accuracy 0.93738                             | Test: Loss 0.61925, Accuracy 0.84270, F1 0.84049
# Epoch [138/200]      | Train: Loss 0.13836, Accuracy 0.93571                             | Test: Loss 0.64059, Accuracy 0.84020, F1 0.83778
# Epoch [139/200]      | Train: Loss 0.13299, Accuracy 0.93723                             | Test: Loss 0.66974, Accuracy 0.84622, F1 0.84325
# Epoch [140/200]      | Train: Loss 0.13317, Accuracy 0.93764                             | Test: Loss 0.67755, Accuracy 0.84349, F1 0.84117
# Epoch [141/200]      | Train: Loss 0.13177, Accuracy 0.93875                             | Test: Loss 0.69301, Accuracy 0.84645, F1 0.84301
# Epoch [142/200]      | Train: Loss 0.13006, Accuracy 0.93887                             | Test: Loss 0.65442, Accuracy 0.83792, F1 0.83544
# Epoch [143/200]      | Train: Loss 0.13245, Accuracy 0.93849                             | Test: Loss 0.69302, Accuracy 0.83951, F1 0.83807
# Epoch [144/200]      | Train: Loss 0.12719, Accuracy 0.94144                             | Test: Loss 0.70142, Accuracy 0.84452, F1 0.84248
# Epoch [145/200]      | Train: Loss 0.12617, Accuracy 0.93998                             | Test: Loss 0.68786, Accuracy 0.83530, F1 0.83231
# Epoch [146/200]      | Train: Loss 0.12482, Accuracy 0.94095                             | Test: Loss 0.69814, Accuracy 0.84065, F1 0.83936
# Epoch [147/200]      | Train: Loss 0.12307, Accuracy 0.94279                             | Test: Loss 0.72478, Accuracy 0.84406, F1 0.84018
# Epoch [148/200]      | Train: Loss 0.11981, Accuracy 0.94405                             | Test: Loss 0.70738, Accuracy 0.83326, F1 0.83130
# Epoch [149/200]      | Train: Loss 0.12421, Accuracy 0.94188                             | Test: Loss 0.70555, Accuracy 0.83428, F1 0.83392
# Epoch [150/200]      | Train: Loss 0.12556, Accuracy 0.94168                             | Test: Loss 0.68368, Accuracy 0.83701, F1 0.83744
# Epoch [151/200]      | Train: Loss 0.12981, Accuracy 0.93981                             | Test: Loss 0.65155, Accuracy 0.84054, F1 0.83883
# Epoch [152/200]      | Train: Loss 0.12048, Accuracy 0.94293                             | Test: Loss 0.69400, Accuracy 0.83326, F1 0.83226
# Epoch [153/200]      | Train: Loss 0.11588, Accuracy 0.94633                             | Test: Loss 0.74479, Accuracy 0.83405, F1 0.83288
# Epoch [154/200]      | Train: Loss 0.11343, Accuracy 0.94691                             | Test: Loss 0.75405, Accuracy 0.83041, F1 0.82933
# Epoch [155/200]      | Train: Loss 0.11591, Accuracy 0.94595                             | Test: Loss 0.71158, Accuracy 0.83815, F1 0.83641
# Epoch [156/200]      | Train: Loss 0.11610, Accuracy 0.94498                             | Test: Loss 0.77832, Accuracy 0.83883, F1 0.83853
# Epoch [157/200]      | Train: Loss 0.11187, Accuracy 0.94647                             | Test: Loss 0.74402, Accuracy 0.83246, F1 0.83063
# Epoch [158/200]      | Train: Loss 0.11300, Accuracy 0.94694                             | Test: Loss 0.71642, Accuracy 0.82780, F1 0.82937
# Epoch [159/200]      | Train: Loss 0.10973, Accuracy 0.94887                             | Test: Loss 0.74080, Accuracy 0.83747, F1 0.83689
# Epoch [160/200]      | Train: Loss 0.10934, Accuracy 0.94914                             | Test: Loss 0.74223, Accuracy 0.83769, F1 0.83739
# Epoch [161/200]      | Train: Loss 0.10811, Accuracy 0.94905                             | Test: Loss 0.75840, Accuracy 0.83530, F1 0.83438
# Epoch [162/200]      | Train: Loss 0.10599, Accuracy 0.94943                             | Test: Loss 0.84379, Accuracy 0.83144, F1 0.83005
# Epoch [163/200]      | Train: Loss 0.10725, Accuracy 0.94955                             | Test: Loss 0.77948, Accuracy 0.83701, F1 0.83622
# Epoch [164/200]      | Train: Loss 0.10453, Accuracy 0.95115                             | Test: Loss 0.82731, Accuracy 0.83519, F1 0.83342
# Epoch [165/200]      | Train: Loss 0.10499, Accuracy 0.95072                             | Test: Loss 0.82683, Accuracy 0.83667, F1 0.83638
# Epoch [166/200]      | Train: Loss 0.10603, Accuracy 0.95083                             | Test: Loss 0.81775, Accuracy 0.83053, F1 0.82925
# Epoch [167/200]      | Train: Loss 0.10894, Accuracy 0.94890                             | Test: Loss 0.81630, Accuracy 0.83132, F1 0.83208
# Epoch [168/200]      | Train: Loss 0.10335, Accuracy 0.95241                             | Test: Loss 0.77947, Accuracy 0.83883, F1 0.83698
# Epoch [169/200]      | Train: Loss 0.09984, Accuracy 0.95311                             | Test: Loss 0.88029, Accuracy 0.83565, F1 0.83451
# Epoch [170/200]      | Train: Loss 0.10060, Accuracy 0.95270                             | Test: Loss 0.84392, Accuracy 0.83565, F1 0.83445
# Epoch [171/200]      | Train: Loss 0.10206, Accuracy 0.95259                             | Test: Loss 0.80919, Accuracy 0.83474, F1 0.83325
# Epoch [172/200]      | Train: Loss 0.10515, Accuracy 0.95110                             | Test: Loss 0.82844, Accuracy 0.83587, F1 0.83451
# Epoch [173/200]      | Train: Loss 0.09997, Accuracy 0.95335                             | Test: Loss 0.86947, Accuracy 0.83212, F1 0.83223
# Epoch [174/200]      | Train: Loss 0.09885, Accuracy 0.95341                             | Test: Loss 0.85150, Accuracy 0.83553, F1 0.83345
# Epoch [175/200]      | Train: Loss 0.09456, Accuracy 0.95499                             | Test: Loss 0.88369, Accuracy 0.83201, F1 0.83046
# Epoch [176/200]      | Train: Loss 0.09850, Accuracy 0.95338                             | Test: Loss 0.85020, Accuracy 0.83553, F1 0.83306
# Epoch [177/200]      | Train: Loss 0.09562, Accuracy 0.95484                             | Test: Loss 0.91868, Accuracy 0.83860, F1 0.83634
# Epoch [178/200]      | Train: Loss 0.09136, Accuracy 0.95683                             | Test: Loss 0.89516, Accuracy 0.83132, F1 0.83010
# Epoch [179/200]      | Train: Loss 0.09242, Accuracy 0.95633                             | Test: Loss 0.90484, Accuracy 0.83565, F1 0.83295
# Epoch [180/200]      | Train: Loss 0.09493, Accuracy 0.95501                             | Test: Loss 0.94920, Accuracy 0.82928, F1 0.82847
# Epoch [181/200]      | Train: Loss 0.09336, Accuracy 0.95554                             | Test: Loss 0.95994, Accuracy 0.83337, F1 0.83300
# Epoch [182/200]      | Train: Loss 0.09298, Accuracy 0.95665                             | Test: Loss 0.95577, Accuracy 0.83667, F1 0.83452
# Epoch [183/200]      | Train: Loss 0.09629, Accuracy 0.95557                             | Test: Loss 0.88468, Accuracy 0.83235, F1 0.83126
# Epoch [184/200]      | Train: Loss 0.09485, Accuracy 0.95525                             | Test: Loss 0.93666, Accuracy 0.83474, F1 0.83263
# Epoch [185/200]      | Train: Loss 0.09006, Accuracy 0.95700                             | Test: Loss 0.92711, Accuracy 0.83303, F1 0.82945
# Epoch [186/200]      | Train: Loss 0.09014, Accuracy 0.95727                             | Test: Loss 0.97271, Accuracy 0.83530, F1 0.83331
# Epoch [187/200]      | Train: Loss 0.08624, Accuracy 0.95879                             | Test: Loss 1.05229, Accuracy 0.83530, F1 0.83328
# Epoch [188/200]      | Train: Loss 0.08691, Accuracy 0.95876                             | Test: Loss 1.00300, Accuracy 0.83201, F1 0.83102
# Epoch [189/200]      | Train: Loss 0.09015, Accuracy 0.95771                             | Test: Loss 0.99660, Accuracy 0.82791, F1 0.82624
# Epoch [190/200]      | Train: Loss 0.09416, Accuracy 0.95654                             | Test: Loss 0.97712, Accuracy 0.82950, F1 0.82935
# Epoch [191/200]      | Train: Loss 0.08622, Accuracy 0.95885                             | Test: Loss 0.97875, Accuracy 0.83189, F1 0.83072
# Epoch [192/200]      | Train: Loss 0.08649, Accuracy 0.96016                             | Test: Loss 0.95883, Accuracy 0.82928, F1 0.82853
# Epoch [193/200]      | Train: Loss 0.08529, Accuracy 0.95987                             | Test: Loss 1.04085, Accuracy 0.83292, F1 0.83219
# Epoch [194/200]      | Train: Loss 0.08475, Accuracy 0.96043                             | Test: Loss 1.06920, Accuracy 0.83508, F1 0.83542
# Epoch [195/200]      | Train: Loss 0.08329, Accuracy 0.96086                             | Test: Loss 0.97848, Accuracy 0.83633, F1 0.83448
# Epoch [196/200]      | Train: Loss 0.08275, Accuracy 0.96177                             | Test: Loss 1.00435, Accuracy 0.83314, F1 0.83031
# Epoch [197/200]      | Train: Loss 0.08829, Accuracy 0.95797                             | Test: Loss 0.91909, Accuracy 0.83337, F1 0.83256
# Epoch [198/200]      | Train: Loss 0.08300, Accuracy 0.96122                             | Test: Loss 1.01799, Accuracy 0.83292, F1 0.83306
# Epoch [199/200]      | Train: Loss 0.08281, Accuracy 0.96154                             | Test: Loss 1.03736, Accuracy 0.82404, F1 0.82409
# Epoch [200/200]      | Train: Loss 0.08276, Accuracy 0.96110                             | Test: Loss 1.08475, Accuracy 0.84008, F1 0.83826
# Confusion Matrix for income
# [[6041  636]
#  [ 770 1345]]
# Best accuracy 0.8671519563239308
# Best F1 0.8625473656395479
# 100 epochs of training and evaluation took, 172.40625

# %% [markdown]
# $\sigma = 1$

# %%
class LossFunction(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunction, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
model = CATTransformer(rff_on=True,
                       sigma=1,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                   
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       cat_feat=cat_features,
              
                       embedding_scheme='log-linear_periodic',
                       trainable=False,
                       linear_on=True).to(device_in_use)

def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = LossFunction(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 200 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/200]       | Train: Loss 0.41820, Accuracy 0.80435                             | Test: Loss 0.36171, Accuracy 0.83712, F1 0.81524
# Epoch [ 2/200]       | Train: Loss 0.32874, Accuracy 0.84691                             | Test: Loss 0.32782, Accuracy 0.85066, F1 0.84524
# Epoch [ 3/200]       | Train: Loss 0.31805, Accuracy 0.85177                             | Test: Loss 0.32226, Accuracy 0.85191, F1 0.84159
# Epoch [ 4/200]       | Train: Loss 0.31591, Accuracy 0.85264                             | Test: Loss 0.32239, Accuracy 0.85134, F1 0.84797
# Epoch [ 5/200]       | Train: Loss 0.30984, Accuracy 0.85659                             | Test: Loss 0.31458, Accuracy 0.85475, F1 0.84769
# Epoch [ 6/200]       | Train: Loss 0.30784, Accuracy 0.85764                             | Test: Loss 0.31649, Accuracy 0.85453, F1 0.84928
# Epoch [ 7/200]       | Train: Loss 0.30627, Accuracy 0.85887                             | Test: Loss 0.31796, Accuracy 0.85282, F1 0.83876
# Epoch [ 8/200]       | Train: Loss 0.30813, Accuracy 0.85706                             | Test: Loss 0.32031, Accuracy 0.84634, F1 0.82772
# Epoch [ 9/200]       | Train: Loss 0.30559, Accuracy 0.85650                             | Test: Loss 0.31331, Accuracy 0.85635, F1 0.85041
# Epoch [10/200]       | Train: Loss 0.30451, Accuracy 0.85729                             | Test: Loss 0.31446, Accuracy 0.85077, F1 0.83574
# Epoch [11/200]       | Train: Loss 0.30426, Accuracy 0.85881                             | Test: Loss 0.31453, Accuracy 0.85771, F1 0.85267
# Epoch [12/200]       | Train: Loss 0.30403, Accuracy 0.85773                             | Test: Loss 0.32636, Accuracy 0.85396, F1 0.84156
# Epoch [13/200]       | Train: Loss 0.30215, Accuracy 0.85934                             | Test: Loss 0.31244, Accuracy 0.85430, F1 0.84157
# Epoch [14/200]       | Train: Loss 0.30148, Accuracy 0.85826                             | Test: Loss 0.30969, Accuracy 0.85874, F1 0.85221
# Epoch [15/200]       | Train: Loss 0.30202, Accuracy 0.85800                             | Test: Loss 0.31323, Accuracy 0.85612, F1 0.84611
# Epoch [16/200]       | Train: Loss 0.30286, Accuracy 0.85940                             | Test: Loss 0.30829, Accuracy 0.85726, F1 0.84851
# Epoch [17/200]       | Train: Loss 0.30139, Accuracy 0.85990                             | Test: Loss 0.31089, Accuracy 0.85760, F1 0.85042
# Epoch [18/200]       | Train: Loss 0.30101, Accuracy 0.85890                             | Test: Loss 0.30951, Accuracy 0.85714, F1 0.84919
# Epoch [19/200]       | Train: Loss 0.30055, Accuracy 0.85864                             | Test: Loss 0.31117, Accuracy 0.85669, F1 0.84723
# Epoch [20/200]       | Train: Loss 0.30012, Accuracy 0.85864                             | Test: Loss 0.31110, Accuracy 0.85680, F1 0.84828
# Epoch [21/200]       | Train: Loss 0.29916, Accuracy 0.86118                             | Test: Loss 0.30957, Accuracy 0.85919, F1 0.85176
# Epoch [22/200]       | Train: Loss 0.29734, Accuracy 0.86118                             | Test: Loss 0.30615, Accuracy 0.85930, F1 0.85352
# Epoch [23/200]       | Train: Loss 0.29805, Accuracy 0.86086                             | Test: Loss 0.30875, Accuracy 0.85828, F1 0.84997
# Epoch [24/200]       | Train: Loss 0.29689, Accuracy 0.86130                             | Test: Loss 0.30874, Accuracy 0.85794, F1 0.85185
# Epoch [25/200]       | Train: Loss 0.29652, Accuracy 0.86124                             | Test: Loss 0.30623, Accuracy 0.85976, F1 0.85470
# Epoch [26/200]       | Train: Loss 0.29461, Accuracy 0.86262                             | Test: Loss 0.31205, Accuracy 0.85987, F1 0.85193
# Epoch [27/200]       | Train: Loss 0.29469, Accuracy 0.86344                             | Test: Loss 0.30879, Accuracy 0.85783, F1 0.84862
# Epoch [28/200]       | Train: Loss 0.29371, Accuracy 0.86344                             | Test: Loss 0.30427, Accuracy 0.85976, F1 0.85052
# Epoch [29/200]       | Train: Loss 0.29234, Accuracy 0.86379                             | Test: Loss 0.31515, Accuracy 0.85726, F1 0.85533
# Epoch [30/200]       | Train: Loss 0.29092, Accuracy 0.86463                             | Test: Loss 0.30780, Accuracy 0.86033, F1 0.85217
# Epoch [31/200]       | Train: Loss 0.29128, Accuracy 0.86376                             | Test: Loss 0.30855, Accuracy 0.85805, F1 0.85615
# Epoch [32/200]       | Train: Loss 0.28991, Accuracy 0.86425                             | Test: Loss 0.30392, Accuracy 0.86101, F1 0.85347
# Epoch [33/200]       | Train: Loss 0.28925, Accuracy 0.86382                             | Test: Loss 0.30456, Accuracy 0.85987, F1 0.85080
# Epoch [34/200]       | Train: Loss 0.28886, Accuracy 0.86624                             | Test: Loss 0.30615, Accuracy 0.86078, F1 0.85130
# Epoch [35/200]       | Train: Loss 0.28816, Accuracy 0.86540                             | Test: Loss 0.29986, Accuracy 0.86249, F1 0.85803
# Epoch [36/200]       | Train: Loss 0.28823, Accuracy 0.86513                             | Test: Loss 0.30161, Accuracy 0.86181, F1 0.85389
# Epoch [37/200]       | Train: Loss 0.28740, Accuracy 0.86525                             | Test: Loss 0.30835, Accuracy 0.86090, F1 0.85790
# Epoch [38/200]       | Train: Loss 0.28683, Accuracy 0.86642                             | Test: Loss 0.30397, Accuracy 0.85942, F1 0.84999
# Epoch [39/200]       | Train: Loss 0.28691, Accuracy 0.86613                             | Test: Loss 0.30850, Accuracy 0.86124, F1 0.85351
# Epoch [40/200]       | Train: Loss 0.28612, Accuracy 0.86683                             | Test: Loss 0.30119, Accuracy 0.86374, F1 0.85849
# Epoch [41/200]       | Train: Loss 0.28440, Accuracy 0.86838                             | Test: Loss 0.30341, Accuracy 0.86272, F1 0.85826
# Epoch [42/200]       | Train: Loss 0.28499, Accuracy 0.86668                             | Test: Loss 0.30630, Accuracy 0.86203, F1 0.85819
# Epoch [43/200]       | Train: Loss 0.28433, Accuracy 0.86686                             | Test: Loss 0.30823, Accuracy 0.86192, F1 0.85598
# Epoch [44/200]       | Train: Loss 0.28548, Accuracy 0.86610                             | Test: Loss 0.30196, Accuracy 0.86272, F1 0.85430
# Epoch [45/200]       | Train: Loss 0.28394, Accuracy 0.86721                             | Test: Loss 0.30474, Accuracy 0.86203, F1 0.85323
# Epoch [46/200]       | Train: Loss 0.28386, Accuracy 0.86718                             | Test: Loss 0.30256, Accuracy 0.86408, F1 0.86160
# Epoch [47/200]       | Train: Loss 0.28302, Accuracy 0.86774                             | Test: Loss 0.30569, Accuracy 0.86306, F1 0.85914
# Epoch [48/200]       | Train: Loss 0.28216, Accuracy 0.86797                             | Test: Loss 0.30563, Accuracy 0.86203, F1 0.85804
# Epoch [49/200]       | Train: Loss 0.28205, Accuracy 0.86738                             | Test: Loss 0.30086, Accuracy 0.86465, F1 0.85877
# Epoch [50/200]       | Train: Loss 0.28149, Accuracy 0.86844                             | Test: Loss 0.29813, Accuracy 0.86488, F1 0.86005
# Epoch [51/200]       | Train: Loss 0.28096, Accuracy 0.86888                             | Test: Loss 0.30453, Accuracy 0.86385, F1 0.86105
# Epoch [52/200]       | Train: Loss 0.28060, Accuracy 0.87040                             | Test: Loss 0.30645, Accuracy 0.86317, F1 0.85721
# Epoch [53/200]       | Train: Loss 0.28091, Accuracy 0.86697                             | Test: Loss 0.30197, Accuracy 0.86556, F1 0.86199
# Epoch [54/200]       | Train: Loss 0.28012, Accuracy 0.86940                             | Test: Loss 0.30586, Accuracy 0.86158, F1 0.85665
# Epoch [55/200]       | Train: Loss 0.28004, Accuracy 0.86841                             | Test: Loss 0.30545, Accuracy 0.86431, F1 0.86226
# Epoch [56/200]       | Train: Loss 0.27935, Accuracy 0.86911                             | Test: Loss 0.29991, Accuracy 0.86556, F1 0.86073
# Epoch [57/200]       | Train: Loss 0.27768, Accuracy 0.87019                             | Test: Loss 0.30481, Accuracy 0.86385, F1 0.85678
# Epoch [58/200]       | Train: Loss 0.27770, Accuracy 0.86975                             | Test: Loss 0.30508, Accuracy 0.86101, F1 0.85095
# Epoch [59/200]       | Train: Loss 0.27720, Accuracy 0.86987                             | Test: Loss 0.30586, Accuracy 0.86363, F1 0.86042
# Epoch [60/200]       | Train: Loss 0.27531, Accuracy 0.87110                             | Test: Loss 0.30996, Accuracy 0.86158, F1 0.85206
# Epoch [61/200]       | Train: Loss 0.27554, Accuracy 0.87174                             | Test: Loss 0.30250, Accuracy 0.86283, F1 0.85659
# Epoch [62/200]       | Train: Loss 0.27403, Accuracy 0.87133                             | Test: Loss 0.30658, Accuracy 0.86351, F1 0.85568
# Epoch [63/200]       | Train: Loss 0.27482, Accuracy 0.87163                             | Test: Loss 0.30720, Accuracy 0.86203, F1 0.86015
# Epoch [64/200]       | Train: Loss 0.27387, Accuracy 0.87160                             | Test: Loss 0.30075, Accuracy 0.86590, F1 0.86141
# Epoch [65/200]       | Train: Loss 0.27215, Accuracy 0.87209                             | Test: Loss 0.30330, Accuracy 0.86488, F1 0.86065
# Epoch [66/200]       | Train: Loss 0.27129, Accuracy 0.87215                             | Test: Loss 0.30540, Accuracy 0.86419, F1 0.86053
# Epoch [67/200]       | Train: Loss 0.27010, Accuracy 0.87271                             | Test: Loss 0.31055, Accuracy 0.86158, F1 0.85601
# Epoch [68/200]       | Train: Loss 0.26904, Accuracy 0.87356                             | Test: Loss 0.30944, Accuracy 0.85919, F1 0.85008
# Epoch [69/200]       | Train: Loss 0.26836, Accuracy 0.87265                             | Test: Loss 0.30557, Accuracy 0.86146, F1 0.85458
# Epoch [70/200]       | Train: Loss 0.26792, Accuracy 0.87341                             | Test: Loss 0.30636, Accuracy 0.86533, F1 0.85975
# Epoch [71/200]       | Train: Loss 0.26597, Accuracy 0.87593                             | Test: Loss 0.30921, Accuracy 0.86363, F1 0.86066
# Epoch [72/200]       | Train: Loss 0.26563, Accuracy 0.87537                             | Test: Loss 0.31076, Accuracy 0.86203, F1 0.85893
# Epoch [73/200]       | Train: Loss 0.26414, Accuracy 0.87625                             | Test: Loss 0.30993, Accuracy 0.86215, F1 0.86035
# Epoch [74/200]       | Train: Loss 0.26205, Accuracy 0.87692                             | Test: Loss 0.31816, Accuracy 0.86215, F1 0.85924
# Epoch [75/200]       | Train: Loss 0.26102, Accuracy 0.87809                             | Test: Loss 0.31185, Accuracy 0.86317, F1 0.85870
# Epoch [76/200]       | Train: Loss 0.25993, Accuracy 0.87926                             | Test: Loss 0.31421, Accuracy 0.86226, F1 0.85853
# Epoch [77/200]       | Train: Loss 0.25905, Accuracy 0.87920                             | Test: Loss 0.32144, Accuracy 0.86021, F1 0.85129
# Epoch [78/200]       | Train: Loss 0.25638, Accuracy 0.87882                             | Test: Loss 0.31964, Accuracy 0.86158, F1 0.85720
# Epoch [79/200]       | Train: Loss 0.25703, Accuracy 0.87905                             | Test: Loss 0.31448, Accuracy 0.86101, F1 0.85827
# Epoch [80/200]       | Train: Loss 0.25397, Accuracy 0.88195                             | Test: Loss 0.32152, Accuracy 0.86363, F1 0.85817
# Epoch [81/200]       | Train: Loss 0.25026, Accuracy 0.88242                             | Test: Loss 0.31753, Accuracy 0.86112, F1 0.85627
# Epoch [82/200]       | Train: Loss 0.24857, Accuracy 0.88201                             | Test: Loss 0.32145, Accuracy 0.86090, F1 0.85920
# Epoch [83/200]       | Train: Loss 0.24590, Accuracy 0.88379                             | Test: Loss 0.32342, Accuracy 0.85862, F1 0.85334
# Epoch [84/200]       | Train: Loss 0.24332, Accuracy 0.88564                             | Test: Loss 0.32840, Accuracy 0.85760, F1 0.85427
# Epoch [85/200]       | Train: Loss 0.24086, Accuracy 0.88713                             | Test: Loss 0.32938, Accuracy 0.86021, F1 0.85682
# Epoch [86/200]       | Train: Loss 0.23800, Accuracy 0.88827                             | Test: Loss 0.33923, Accuracy 0.85805, F1 0.85495
# Epoch [87/200]       | Train: Loss 0.23700, Accuracy 0.88991                             | Test: Loss 0.33444, Accuracy 0.85350, F1 0.85411
# Epoch [88/200]       | Train: Loss 0.23307, Accuracy 0.89078                             | Test: Loss 0.33913, Accuracy 0.85817, F1 0.85363
# Epoch [89/200]       | Train: Loss 0.23104, Accuracy 0.89210                             | Test: Loss 0.34560, Accuracy 0.85692, F1 0.85050
# Epoch [90/200]       | Train: Loss 0.22781, Accuracy 0.89222                             | Test: Loss 0.35519, Accuracy 0.85669, F1 0.85056
# Epoch [91/200]       | Train: Loss 0.22384, Accuracy 0.89447                             | Test: Loss 0.35121, Accuracy 0.85555, F1 0.85168
# Epoch [92/200]       | Train: Loss 0.22085, Accuracy 0.89657                             | Test: Loss 0.35877, Accuracy 0.85146, F1 0.85018
# Epoch [93/200]       | Train: Loss 0.21813, Accuracy 0.89777                             | Test: Loss 0.36363, Accuracy 0.85623, F1 0.85041
# Epoch [94/200]       | Train: Loss 0.21485, Accuracy 0.89965                             | Test: Loss 0.36783, Accuracy 0.84622, F1 0.84351
# Epoch [95/200]       | Train: Loss 0.20900, Accuracy 0.90193                             | Test: Loss 0.39406, Accuracy 0.85532, F1 0.85165
# Epoch [96/200]       | Train: Loss 0.20939, Accuracy 0.90245                             | Test: Loss 0.37239, Accuracy 0.84861, F1 0.84550
# Epoch [97/200]       | Train: Loss 0.20368, Accuracy 0.90558                             | Test: Loss 0.39221, Accuracy 0.84838, F1 0.84629
# Epoch [98/200]       | Train: Loss 0.19862, Accuracy 0.90772                             | Test: Loss 0.38620, Accuracy 0.84986, F1 0.84807
# Epoch [99/200]       | Train: Loss 0.19916, Accuracy 0.90789                             | Test: Loss 0.40106, Accuracy 0.84907, F1 0.84513
# Epoch [100/200]      | Train: Loss 0.19344, Accuracy 0.90982                             | Test: Loss 0.40708, Accuracy 0.85134, F1 0.84956
# Epoch [101/200]      | Train: Loss 0.19005, Accuracy 0.91138                             | Test: Loss 0.39957, Accuracy 0.84145, F1 0.84124
# Epoch [102/200]      | Train: Loss 0.18792, Accuracy 0.91313                             | Test: Loss 0.42544, Accuracy 0.85237, F1 0.84943
# Epoch [103/200]      | Train: Loss 0.18545, Accuracy 0.91380                             | Test: Loss 0.43194, Accuracy 0.84713, F1 0.84307
# Epoch [104/200]      | Train: Loss 0.17766, Accuracy 0.91720                             | Test: Loss 0.44566, Accuracy 0.85362, F1 0.85000
# Epoch [105/200]      | Train: Loss 0.17942, Accuracy 0.91544                             | Test: Loss 0.43321, Accuracy 0.84645, F1 0.84209
# Epoch [106/200]      | Train: Loss 0.17750, Accuracy 0.91652                             | Test: Loss 0.43558, Accuracy 0.84247, F1 0.84052
# Epoch [107/200]      | Train: Loss 0.17227, Accuracy 0.92085                             | Test: Loss 0.45588, Accuracy 0.83997, F1 0.83695
# Epoch [108/200]      | Train: Loss 0.16960, Accuracy 0.92161                             | Test: Loss 0.49925, Accuracy 0.84907, F1 0.84779
# Epoch [109/200]      | Train: Loss 0.16693, Accuracy 0.92296                             | Test: Loss 0.48383, Accuracy 0.84145, F1 0.83723
# Epoch [110/200]      | Train: Loss 0.16276, Accuracy 0.92527                             | Test: Loss 0.49432, Accuracy 0.83656, F1 0.83601
# Epoch [111/200]      | Train: Loss 0.16381, Accuracy 0.92451                             | Test: Loss 0.49743, Accuracy 0.84668, F1 0.84380
# Epoch [112/200]      | Train: Loss 0.15854, Accuracy 0.92696                             | Test: Loss 0.49620, Accuracy 0.83292, F1 0.83359
# Epoch [113/200]      | Train: Loss 0.15983, Accuracy 0.92635                             | Test: Loss 0.51750, Accuracy 0.84895, F1 0.84563
# Epoch [114/200]      | Train: Loss 0.15109, Accuracy 0.92928                             | Test: Loss 0.52196, Accuracy 0.84281, F1 0.84004
# Epoch [115/200]      | Train: Loss 0.15164, Accuracy 0.92968                             | Test: Loss 0.51890, Accuracy 0.84145, F1 0.84025
# Epoch [116/200]      | Train: Loss 0.14919, Accuracy 0.93009                             | Test: Loss 0.53360, Accuracy 0.84099, F1 0.83758
# Epoch [117/200]      | Train: Loss 0.14673, Accuracy 0.93191                             | Test: Loss 0.55389, Accuracy 0.84111, F1 0.83747
# Epoch [118/200]      | Train: Loss 0.14490, Accuracy 0.93138                             | Test: Loss 0.54780, Accuracy 0.84315, F1 0.84163
# Epoch [119/200]      | Train: Loss 0.14176, Accuracy 0.93410                             | Test: Loss 0.56427, Accuracy 0.83781, F1 0.83531
# Epoch [120/200]      | Train: Loss 0.14235, Accuracy 0.93396                             | Test: Loss 0.55722, Accuracy 0.83906, F1 0.83502
# Epoch [121/200]      | Train: Loss 0.13745, Accuracy 0.93785                             | Test: Loss 0.56428, Accuracy 0.83724, F1 0.83622
# Epoch [122/200]      | Train: Loss 0.13755, Accuracy 0.93527                             | Test: Loss 0.59340, Accuracy 0.84247, F1 0.84102
# Epoch [123/200]      | Train: Loss 0.13506, Accuracy 0.93632                             | Test: Loss 0.64061, Accuracy 0.84304, F1 0.84024
# Epoch [124/200]      | Train: Loss 0.13522, Accuracy 0.93764                             | Test: Loss 0.60007, Accuracy 0.83235, F1 0.83248
# Epoch [125/200]      | Train: Loss 0.13304, Accuracy 0.93767                             | Test: Loss 0.60409, Accuracy 0.83348, F1 0.83359
# Epoch [126/200]      | Train: Loss 0.13436, Accuracy 0.93831                             | Test: Loss 0.61780, Accuracy 0.83724, F1 0.83614
# Epoch [127/200]      | Train: Loss 0.13130, Accuracy 0.93811                             | Test: Loss 0.64509, Accuracy 0.84031, F1 0.83803
# Epoch [128/200]      | Train: Loss 0.12819, Accuracy 0.94150                             | Test: Loss 0.59993, Accuracy 0.83815, F1 0.83678
# Epoch [129/200]      | Train: Loss 0.12529, Accuracy 0.94133                             | Test: Loss 0.61704, Accuracy 0.83747, F1 0.83634
# Epoch [130/200]      | Train: Loss 0.12250, Accuracy 0.94291                             | Test: Loss 0.62120, Accuracy 0.83246, F1 0.82843
# Epoch [131/200]      | Train: Loss 0.12343, Accuracy 0.94361                             | Test: Loss 0.68566, Accuracy 0.84111, F1 0.83948
# Epoch [132/200]      | Train: Loss 0.12341, Accuracy 0.94241                             | Test: Loss 0.63312, Accuracy 0.83644, F1 0.83464
# Epoch [133/200]      | Train: Loss 0.12288, Accuracy 0.94212                             | Test: Loss 0.61594, Accuracy 0.83337, F1 0.83205
# Epoch [134/200]      | Train: Loss 0.12384, Accuracy 0.94367                             | Test: Loss 0.65891, Accuracy 0.84088, F1 0.83711
# Epoch [135/200]      | Train: Loss 0.11824, Accuracy 0.94530                             | Test: Loss 0.68113, Accuracy 0.83508, F1 0.83260
# Epoch [136/200]      | Train: Loss 0.11724, Accuracy 0.94507                             | Test: Loss 0.68765, Accuracy 0.83758, F1 0.83587
# Epoch [137/200]      | Train: Loss 0.11293, Accuracy 0.94644                             | Test: Loss 0.69176, Accuracy 0.83178, F1 0.83009
# Epoch [138/200]      | Train: Loss 0.11429, Accuracy 0.94788                             | Test: Loss 0.68188, Accuracy 0.83348, F1 0.83068
# Epoch [139/200]      | Train: Loss 0.11258, Accuracy 0.94685                             | Test: Loss 0.74707, Accuracy 0.83724, F1 0.83566
# Epoch [140/200]      | Train: Loss 0.11277, Accuracy 0.94802                             | Test: Loss 0.69927, Accuracy 0.83292, F1 0.83106
# Epoch [141/200]      | Train: Loss 0.11116, Accuracy 0.94715                             | Test: Loss 0.71434, Accuracy 0.83792, F1 0.83626
# Epoch [142/200]      | Train: Loss 0.10973, Accuracy 0.94905                             | Test: Loss 0.73094, Accuracy 0.83872, F1 0.83697
# Epoch [143/200]      | Train: Loss 0.10814, Accuracy 0.94949                             | Test: Loss 0.78085, Accuracy 0.83576, F1 0.83280
# Epoch [144/200]      | Train: Loss 0.10563, Accuracy 0.94963                             | Test: Loss 0.77537, Accuracy 0.82712, F1 0.82611
# Epoch [145/200]      | Train: Loss 0.10853, Accuracy 0.94960                             | Test: Loss 0.76250, Accuracy 0.84031, F1 0.83900
# Epoch [146/200]      | Train: Loss 0.10760, Accuracy 0.94919                             | Test: Loss 0.76306, Accuracy 0.83246, F1 0.83159
# Epoch [147/200]      | Train: Loss 0.10594, Accuracy 0.94960                             | Test: Loss 0.76396, Accuracy 0.83451, F1 0.83293
# Epoch [148/200]      | Train: Loss 0.10427, Accuracy 0.95162                             | Test: Loss 0.84281, Accuracy 0.83303, F1 0.82883
# Epoch [149/200]      | Train: Loss 0.10683, Accuracy 0.95074                             | Test: Loss 0.72790, Accuracy 0.82837, F1 0.82868
# Epoch [150/200]      | Train: Loss 0.10231, Accuracy 0.95153                             | Test: Loss 0.77985, Accuracy 0.83678, F1 0.83540
# Epoch [151/200]      | Train: Loss 0.10136, Accuracy 0.95346                             | Test: Loss 0.79376, Accuracy 0.83610, F1 0.83550
# Epoch [152/200]      | Train: Loss 0.09906, Accuracy 0.95323                             | Test: Loss 0.78488, Accuracy 0.83019, F1 0.82947
# Epoch [153/200]      | Train: Loss 0.09827, Accuracy 0.95376                             | Test: Loss 0.82338, Accuracy 0.83474, F1 0.83310
# Epoch [154/200]      | Train: Loss 0.09616, Accuracy 0.95461                             | Test: Loss 0.80024, Accuracy 0.83223, F1 0.83058
# Epoch [155/200]      | Train: Loss 0.09764, Accuracy 0.95478                             | Test: Loss 0.82162, Accuracy 0.83178, F1 0.83032
# Epoch [156/200]      | Train: Loss 0.09641, Accuracy 0.95452                             | Test: Loss 0.87862, Accuracy 0.83701, F1 0.83517
# Epoch [157/200]      | Train: Loss 0.09724, Accuracy 0.95440                             | Test: Loss 0.85822, Accuracy 0.83030, F1 0.82737
# Epoch [158/200]      | Train: Loss 0.09708, Accuracy 0.95431                             | Test: Loss 0.87099, Accuracy 0.82950, F1 0.82838
# Epoch [159/200]      | Train: Loss 0.09532, Accuracy 0.95583                             | Test: Loss 0.88206, Accuracy 0.83235, F1 0.82908
# Epoch [160/200]      | Train: Loss 0.09660, Accuracy 0.95563                             | Test: Loss 0.86075, Accuracy 0.83246, F1 0.83110
# Epoch [161/200]      | Train: Loss 0.09541, Accuracy 0.95542                             | Test: Loss 0.78756, Accuracy 0.83144, F1 0.83057
# Epoch [162/200]      | Train: Loss 0.09267, Accuracy 0.95633                             | Test: Loss 0.87904, Accuracy 0.83041, F1 0.82970
# Epoch [163/200]      | Train: Loss 0.09024, Accuracy 0.95838                             | Test: Loss 0.87239, Accuracy 0.82939, F1 0.82802
# Epoch [164/200]      | Train: Loss 0.09140, Accuracy 0.95773                             | Test: Loss 0.90444, Accuracy 0.83098, F1 0.82866
# Epoch [165/200]      | Train: Loss 0.08951, Accuracy 0.95817                             | Test: Loss 0.86998, Accuracy 0.82905, F1 0.82881
# Epoch [166/200]      | Train: Loss 0.09173, Accuracy 0.95709                             | Test: Loss 0.82353, Accuracy 0.82370, F1 0.82350
# Epoch [167/200]      | Train: Loss 0.09168, Accuracy 0.95782                             | Test: Loss 0.91677, Accuracy 0.83053, F1 0.82808
# Epoch [168/200]      | Train: Loss 0.08962, Accuracy 0.95797                             | Test: Loss 0.86256, Accuracy 0.82950, F1 0.82800
# Epoch [169/200]      | Train: Loss 0.08893, Accuracy 0.95882                             | Test: Loss 0.86867, Accuracy 0.82973, F1 0.82700
# Epoch [170/200]      | Train: Loss 0.08785, Accuracy 0.96010                             | Test: Loss 0.92206, Accuracy 0.83235, F1 0.83053
# Epoch [171/200]      | Train: Loss 0.08497, Accuracy 0.96066                             | Test: Loss 0.91533, Accuracy 0.82803, F1 0.82664
# Epoch [172/200]      | Train: Loss 0.08425, Accuracy 0.95984                             | Test: Loss 0.94586, Accuracy 0.83064, F1 0.82941
# Epoch [173/200]      | Train: Loss 0.08444, Accuracy 0.96089                             | Test: Loss 0.91104, Accuracy 0.83303, F1 0.82968
# Epoch [174/200]      | Train: Loss 0.08334, Accuracy 0.96198                             | Test: Loss 0.96958, Accuracy 0.82621, F1 0.82654
# Epoch [175/200]      | Train: Loss 0.08518, Accuracy 0.96022                             | Test: Loss 0.95873, Accuracy 0.83110, F1 0.82946
# Epoch [176/200]      | Train: Loss 0.08447, Accuracy 0.96174                             | Test: Loss 0.91503, Accuracy 0.82473, F1 0.82243
# Epoch [177/200]      | Train: Loss 0.08244, Accuracy 0.96183                             | Test: Loss 0.94169, Accuracy 0.82825, F1 0.82678
# Epoch [178/200]      | Train: Loss 0.08422, Accuracy 0.96072                             | Test: Loss 1.01673, Accuracy 0.83292, F1 0.83061
# Epoch [179/200]      | Train: Loss 0.08239, Accuracy 0.96206                             | Test: Loss 0.95062, Accuracy 0.82803, F1 0.82676
# Epoch [180/200]      | Train: Loss 0.08397, Accuracy 0.96142                             | Test: Loss 0.92141, Accuracy 0.82598, F1 0.82424
# Epoch [181/200]      | Train: Loss 0.08131, Accuracy 0.96209                             | Test: Loss 0.94446, Accuracy 0.83121, F1 0.82871
# Epoch [182/200]      | Train: Loss 0.08130, Accuracy 0.96250                             | Test: Loss 0.95294, Accuracy 0.83326, F1 0.83115
# Epoch [183/200]      | Train: Loss 0.07966, Accuracy 0.96280                             | Test: Loss 0.98855, Accuracy 0.83223, F1 0.82954
# Epoch [184/200]      | Train: Loss 0.07899, Accuracy 0.96282                             | Test: Loss 0.92401, Accuracy 0.83007, F1 0.82912
# Epoch [185/200]      | Train: Loss 0.07820, Accuracy 0.96344                             | Test: Loss 0.99452, Accuracy 0.82803, F1 0.82766
# Epoch [186/200]      | Train: Loss 0.07826, Accuracy 0.96367                             | Test: Loss 0.98138, Accuracy 0.82700, F1 0.82535
# Epoch [187/200]      | Train: Loss 0.07563, Accuracy 0.96540                             | Test: Loss 1.00613, Accuracy 0.82905, F1 0.82736
# Epoch [188/200]      | Train: Loss 0.07985, Accuracy 0.96271                             | Test: Loss 0.92650, Accuracy 0.82905, F1 0.82793
# Epoch [189/200]      | Train: Loss 0.07732, Accuracy 0.96452                             | Test: Loss 0.95218, Accuracy 0.82939, F1 0.82866
# Epoch [190/200]      | Train: Loss 0.07279, Accuracy 0.96595                             | Test: Loss 1.02068, Accuracy 0.82791, F1 0.82651
# Epoch [191/200]      | Train: Loss 0.07572, Accuracy 0.96414                             | Test: Loss 1.04595, Accuracy 0.82894, F1 0.82705
# Epoch [192/200]      | Train: Loss 0.07650, Accuracy 0.96511                             | Test: Loss 1.03315, Accuracy 0.82677, F1 0.82572
# Epoch [193/200]      | Train: Loss 0.07136, Accuracy 0.96709                             | Test: Loss 1.01986, Accuracy 0.82905, F1 0.82699
# Epoch [194/200]      | Train: Loss 0.07109, Accuracy 0.96689                             | Test: Loss 1.01914, Accuracy 0.82564, F1 0.82394
# Epoch [195/200]      | Train: Loss 0.07138, Accuracy 0.96669                             | Test: Loss 1.02660, Accuracy 0.82131, F1 0.82020
# Epoch [196/200]      | Train: Loss 0.07395, Accuracy 0.96595                             | Test: Loss 1.02361, Accuracy 0.82495, F1 0.82428
# Epoch [197/200]      | Train: Loss 0.07296, Accuracy 0.96578                             | Test: Loss 1.00742, Accuracy 0.82632, F1 0.82547
# Epoch [198/200]      | Train: Loss 0.07251, Accuracy 0.96595                             | Test: Loss 1.02739, Accuracy 0.82894, F1 0.82699
# Epoch [199/200]      | Train: Loss 0.07131, Accuracy 0.96592                             | Test: Loss 1.00714, Accuracy 0.82734, F1 0.82649
# Epoch [200/200]      | Train: Loss 0.07258, Accuracy 0.96633                             | Test: Loss 1.01250, Accuracy 0.82507, F1 0.82510
# Confusion Matrix for income
# [[5907  770]
#  [ 768 1347]]
# Best accuracy 0.8659008189262967
# Best F1 0.8614095545362668
# 100 epochs of training and evaluation took, 143.640625
