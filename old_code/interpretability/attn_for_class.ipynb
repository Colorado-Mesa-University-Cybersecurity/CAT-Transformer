# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import pickle
from interpretability.helpers import AttentionScoresLog
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '/home/wdwatson2/projects/CAT-Transformer/model')
from testingModel import CATTransformer, MyFTTransformer, Combined_Dataset, train, test, EarlyStopping

device_in_use = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device_in_use)
# Out:
# cuda

# %%
df_train = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/helena/train.csv')
df_test = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/helena/test.csv')
df_val = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/helena/validation.csv')

cont_columns = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27']
target = ['class']

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cont_columns + target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put one of them in the list"

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
print("target classes",target_classes)
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

#Wrapping in Dataset
train_dataset = Combined_Dataset(df_train, cat_columns=[], num_columns=cont_columns, task1_column='class')
val_dataset = Combined_Dataset(df_val, cat_columns=[], num_columns=cont_columns, task1_column='class')
test_dataset = Combined_Dataset(df_test, cat_columns=[], num_columns=cont_columns, task1_column='class')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# target classes [100]

# %%
attention_log = AttentionScoresLog()

models = ["CAT", "FT"]
num_layers = [1,2,5]
datasets = ["Helena"]

for model in models:
    for layer in num_layers:
        attention_log.add_model_layers(model, layer)

attention_log.add_new_dataset('Helena')

# %%
model = CATTransformer(n_cont=len(cont_columns),
                       cat_feat=[],
                       targets_classes=target_classes,
                       get_attn=True,
                       num_layers=5).to(device_in_use)
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001)

early_stopping = EarlyStopping(patience=5, verbose=True)

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 

train_attns = []
test_attns = []

epochs = 200

for t in range(epochs):
    train_loss, train_acc, train_attn = train(regression_on=False, 
                                  get_attn=True,
                                   dataloader=train_dataloader, 
                                   model=model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_acc, test_attn = test(regression_on=False,
                               get_attn=True,
                               dataloader=test_dataloader,
                               model=model,
                               loss_function=loss_function,
                               device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_accuracies_1.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies_1.append(test_acc)
    train_attns.append(train_attn)
    test_attns.append(test_attn)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, Accuracy {(train_acc)}"
    test_metrics = f"Test: Loss {(test_loss)}, Accuracy {(test_acc)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_acc, model)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break


attention_log.add_attention_scores('CAT', 5, 'Helena', train_attns, test_attns)
# Out:
# Epoch [ 1/200]  | Train: Loss 4.1720277890146775, Accuracy 0.08451475776234196      | Test: Loss 3.778957941593268, Accuracy 0.12239263803680982
# Validation score improved. Saving model...
# Epoch [ 2/200]  | Train: Loss 3.6109285048266364, Accuracy 0.18338190503319673      | Test: Loss 3.2908753064962535, Accuracy 0.252760736196319
# Validation score improved. Saving model...
# Epoch [ 3/200]  | Train: Loss 3.2722764747768807, Accuracy 0.24800052588908122      | Test: Loss 3.1240287866347876, Accuracy 0.28016359918200406
# Validation score improved. Saving model...
# Epoch [ 4/200]  | Train: Loss 3.1335298482266216, Accuracy 0.27289260906720425      | Test: Loss 3.023346858146863, Accuracy 0.30081799591002045
# Validation score improved. Saving model...
# Epoch [ 5/200]  | Train: Loss 3.049218971636042, Accuracy 0.2854043867914192        | Test: Loss 2.9642440478006997, Accuracy 0.3062372188139059
# Validation score improved. Saving model...
# Epoch [ 6/200]  | Train: Loss 2.988158147428289, Accuracy 0.2965137936323597        | Test: Loss 2.9148067327646108, Accuracy 0.3116564417177914
# Validation score improved. Saving model...
# Epoch [ 7/200]  | Train: Loss 2.9425065837092905, Accuracy 0.3033941757784254       | Test: Loss 2.872151790521084, Accuracy 0.3201431492842536
# Validation score improved. Saving model...
# Epoch [ 8/200]  | Train: Loss 2.9008053094981103, Accuracy 0.3100773495190306       | Test: Loss 2.8394277890523276, Accuracy 0.32423312883435584
# Validation score improved. Saving model...
# Epoch [ 9/200]  | Train: Loss 2.8659681141709483, Accuracy 0.3161688980432544       | Test: Loss 2.8135500259888477, Accuracy 0.33210633946830265
# Validation score improved. Saving model...
# Epoch [10/200]  | Train: Loss 2.8363765671266523, Accuracy 0.32081425159410126      | Test: Loss 2.7934978680732923, Accuracy 0.3341513292433538
# Validation score improved. Saving model...
# Epoch [11/200]  | Train: Loss 2.806214734828672, Accuracy 0.32817669873129257       | Test: Loss 2.7774380842844644, Accuracy 0.33517382413087937
# Validation score improved. Saving model...
# Epoch [12/200]  | Train: Loss 2.786797937734167, Accuracy 0.3306527598220742        | Test: Loss 2.7684435294224667, Accuracy 0.33773006134969324
# Validation score improved. Saving model...
# Epoch [13/200]  | Train: Loss 2.7650004005964908, Accuracy 0.3313758573087626       | Test: Loss 2.750493483665662, Accuracy 0.3392638036809816
# Validation score improved. Saving model...
# Epoch [14/200]  | Train: Loss 2.7492320604164506, Accuracy 0.33569253018384204      | Test: Loss 2.742806715843005, Accuracy 0.34427402862985684
# Validation score improved. Saving model...
# Epoch [15/200]  | Train: Loss 2.731241124968289, Accuracy 0.33823432740977716       | Test: Loss 2.7254960598089757, Accuracy 0.34386503067484664
# EarlyStopping counter: 1 out of 5
# Epoch [16/200]  | Train: Loss 2.7118205997530973, Accuracy 0.3395271380677959       | Test: Loss 2.7261508917197204, Accuracy 0.34570552147239264
# Validation score improved. Saving model...
# Epoch [17/200]  | Train: Loss 2.702479434412951, Accuracy 0.3427262966452659        | Test: Loss 2.704367148570525, Accuracy 0.3520449897750511
# Validation score improved. Saving model...
# Epoch [18/200]  | Train: Loss 2.686742715995405, Accuracy 0.34603501544799176       | Test: Loss 2.695684335170648, Accuracy 0.35194274028629857
# EarlyStopping counter: 1 out of 5
# Epoch [19/200]  | Train: Loss 2.6759658792165406, Accuracy 0.3478098910971361       | Test: Loss 2.6850668283609243, Accuracy 0.35276073619631904
# Validation score improved. Saving model...
# Epoch [20/200]  | Train: Loss 2.6678510125122923, Accuracy 0.3500449196923549       | Test: Loss 2.6892283268463917, Accuracy 0.35102249488752557
# EarlyStopping counter: 1 out of 5
# Epoch [21/200]  | Train: Loss 2.650430253098131, Accuracy 0.3519950917019085        | Test: Loss 2.6953527743999777, Accuracy 0.3528629856850716
# Validation score improved. Saving model...
# Epoch [22/200]  | Train: Loss 2.6452109280911236, Accuracy 0.35359467099064357      | Test: Loss 2.668482340299166, Accuracy 0.35572597137014317
# Validation score improved. Saving model...
# Epoch [23/200]  | Train: Loss 2.636655134861696, Accuracy 0.35742927887459736       | Test: Loss 2.674748255656316, Accuracy 0.36165644171779143
# Validation score improved. Saving model...
# Epoch [24/200]  | Train: Loss 2.627132266593379, Accuracy 0.3585687052172579        | Test: Loss 2.6568197225913024, Accuracy 0.35695296523517384
# EarlyStopping counter: 1 out of 5
# Epoch [25/200]  | Train: Loss 2.614687641239699, Accuracy 0.3594451870193045        | Test: Loss 2.665262534068181, Accuracy 0.35695296523517384
# EarlyStopping counter: 2 out of 5
# Epoch [26/200]  | Train: Loss 2.610088930449672, Accuracy 0.3607160856322721        | Test: Loss 2.6573818585811515, Accuracy 0.35971370143149284
# EarlyStopping counter: 3 out of 5
# Epoch [27/200]  | Train: Loss 2.59845747361636, Accuracy 0.36284155400223506        | Test: Loss 2.651976933846107, Accuracy 0.36175869120654397
# Validation score improved. Saving model...
# Epoch [28/200]  | Train: Loss 2.588960948603113, Accuracy 0.3631483226329513        | Test: Loss 2.654159576464922, Accuracy 0.3632924335378323
# Validation score improved. Saving model...
# Epoch [29/200]  | Train: Loss 2.581901678159916, Accuracy 0.36577776803909107       | Test: Loss 2.633678748057439, Accuracy 0.36032719836400817
# EarlyStopping counter: 1 out of 5
# Epoch [30/200]  | Train: Loss 2.570219538065308, Accuracy 0.3664570414356772        | Test: Loss 2.644205716940073, Accuracy 0.3604294478527607
# EarlyStopping counter: 2 out of 5
# Epoch [31/200]  | Train: Loss 2.5667396057917418, Accuracy 0.366435129390626        | Test: Loss 2.6347258946834464, Accuracy 0.37024539877300616
# Validation score improved. Saving model...
# Epoch [32/200]  | Train: Loss 2.5565700291255333, Accuracy 0.3677936761837982       | Test: Loss 2.629032917511769, Accuracy 0.36666666666666664
# EarlyStopping counter: 1 out of 5
# Epoch [33/200]  | Train: Loss 2.5486527754607815, Accuracy 0.37189122860836604      | Test: Loss 2.633223686462794, Accuracy 0.37065439672801637
# Validation score improved. Saving model...
# Epoch [34/200]  | Train: Loss 2.546362816954458, Accuracy 0.37169402020290554       | Test: Loss 2.6295200372353578, Accuracy 0.3689161554192229
# EarlyStopping counter: 1 out of 5
# Epoch [35/200]  | Train: Loss 2.5373583079716346, Accuracy 0.37377566448276617      | Test: Loss 2.623766996921637, Accuracy 0.36881390593047036
# EarlyStopping counter: 2 out of 5
# Epoch [36/200]  | Train: Loss 2.529683771080145, Accuracy 0.37511229923088724       | Test: Loss 2.617349624633789, Accuracy 0.3716768916155419
# Validation score improved. Saving model...
# Epoch [37/200]  | Train: Loss 2.5211182932613947, Accuracy 0.37688717488003154      | Test: Loss 2.6140583906418238, Accuracy 0.3694274028629857
# EarlyStopping counter: 1 out of 5
# Epoch [38/200]  | Train: Loss 2.516136299964436, Accuracy 0.3763612857988036        | Test: Loss 2.607952723136315, Accuracy 0.37014314928425357
# EarlyStopping counter: 2 out of 5
# Epoch [39/200]  | Train: Loss 2.507965752532362, Accuracy 0.37870587461927824       | Test: Loss 2.6103808268522606, Accuracy 0.37321063394683024
# Validation score improved. Saving model...
# Epoch [40/200]  | Train: Loss 2.5012227463322643, Accuracy 0.37787321690733394      | Test: Loss 2.610845840894259, Accuracy 0.3749488752556237
# Validation score improved. Saving model...
# Epoch [41/200]  | Train: Loss 2.496939751023021, Accuracy 0.3815544404759296        | Test: Loss 2.596888621648153, Accuracy 0.3740286298568507
# EarlyStopping counter: 1 out of 5
# Epoch [42/200]  | Train: Loss 2.493738756499477, Accuracy 0.3806341345837807        | Test: Loss 2.5993158389360476, Accuracy 0.3774028629856851
# Validation score improved. Saving model...
# Epoch [43/200]  | Train: Loss 2.4818061330464967, Accuracy 0.3827815149987948       | Test: Loss 2.6045279869666467, Accuracy 0.37566462167689163
# EarlyStopping counter: 1 out of 5
# Epoch [44/200]  | Train: Loss 2.475868223765709, Accuracy 0.38560816881039506       | Test: Loss 2.606307463768201, Accuracy 0.37617586912065437
# EarlyStopping counter: 2 out of 5
# Epoch [45/200]  | Train: Loss 2.4710676203892885, Accuracy 0.3857396410807021       | Test: Loss 2.6129205899360852, Accuracy 0.3754601226993865
# EarlyStopping counter: 3 out of 5
# Epoch [46/200]  | Train: Loss 2.462726834100052, Accuracy 0.3871420119639766        | Test: Loss 2.5986187152373486, Accuracy 0.37750511247443763
# Validation score improved. Saving model...
# Epoch [47/200]  | Train: Loss 2.4592464622838537, Accuracy 0.3864627385673905       | Test: Loss 2.5967951004321757, Accuracy 0.37617586912065437
# EarlyStopping counter: 1 out of 5
# Epoch [48/200]  | Train: Loss 2.4535774425421346, Accuracy 0.388259526261586        | Test: Loss 2.6008172585414004, Accuracy 0.3768916155419223
# EarlyStopping counter: 2 out of 5
# Epoch [49/200]  | Train: Loss 2.4472317469186624, Accuracy 0.3907355873523676       | Test: Loss 2.5926313950465274, Accuracy 0.37791411042944784
# Validation score improved. Saving model...
# Epoch [50/200]  | Train: Loss 2.4388513565063477, Accuracy 0.3917654534697723       | Test: Loss 2.5950216941344433, Accuracy 0.37566462167689163
# EarlyStopping counter: 1 out of 5
# Epoch [51/200]  | Train: Loss 2.429558439627706, Accuracy 0.39286105572233054       | Test: Loss 2.5876633570744443, Accuracy 0.3768916155419223
# EarlyStopping counter: 2 out of 5
# Epoch [52/200]  | Train: Loss 2.423989920642789, Accuracy 0.39417577842540047       | Test: Loss 2.592404304406582, Accuracy 0.3806748466257669
# Validation score improved. Saving model...
# Epoch [53/200]  | Train: Loss 2.416561385106774, Accuracy 0.3969586081468984        | Test: Loss 2.580234393095359, Accuracy 0.38139059304703476
# Validation score improved. Saving model...
# Epoch [54/200]  | Train: Loss 2.412953633835862, Accuracy 0.3976597935885356        | Test: Loss 2.588897466659546, Accuracy 0.37811860940695297
# EarlyStopping counter: 1 out of 5
# Epoch [55/200]  | Train: Loss 2.4058987042091413, Accuracy 0.39709008041720534      | Test: Loss 2.5727242200802536, Accuracy 0.38169734151329243
# Validation score improved. Saving model...
# Epoch [56/200]  | Train: Loss 2.400186441464131, Accuracy 0.40042071126498235       | Test: Loss 2.586965243021647, Accuracy 0.38006134969325156
# EarlyStopping counter: 1 out of 5
# Epoch [57/200]  | Train: Loss 2.389713468498358, Accuracy 0.4012752810219778        | Test: Loss 2.5816445717444787, Accuracy 0.37852760736196317
# EarlyStopping counter: 2 out of 5
# Epoch [58/200]  | Train: Loss 2.3834183668957074, Accuracy 0.40147248942743824      | Test: Loss 2.5830932152576938, Accuracy 0.3829243353783231
# Validation score improved. Saving model...
# Epoch [59/200]  | Train: Loss 2.3817916955361818, Accuracy 0.40177925805815456      | Test: Loss 2.593627746288593, Accuracy 0.38210633946830264
# EarlyStopping counter: 1 out of 5
# Epoch [60/200]  | Train: Loss 2.3712548243932883, Accuracy 0.4038609023380152       | Test: Loss 2.589160081667778, Accuracy 0.3814928425357873
# EarlyStopping counter: 2 out of 5
# Epoch [61/200]  | Train: Loss 2.3665053564742955, Accuracy 0.40668755614961544      | Test: Loss 2.5881632352486634, Accuracy 0.3872188139059305
# Validation score improved. Saving model...
# Epoch [62/200]  | Train: Loss 2.36249897733081, Accuracy 0.40655608387930847        | Test: Loss 2.583286872276893, Accuracy 0.38271983640081797
# EarlyStopping counter: 1 out of 5
# Epoch [63/200]  | Train: Loss 2.3513969096391563, Accuracy 0.4081337511229923       | Test: Loss 2.5818062073145156, Accuracy 0.3829243353783231
# EarlyStopping counter: 2 out of 5
# Epoch [64/200]  | Train: Loss 2.3517057003255664, Accuracy 0.4081994872581458       | Test: Loss 2.565656203490037, Accuracy 0.38415132924335377
# EarlyStopping counter: 3 out of 5
# Epoch [65/200]  | Train: Loss 2.3394443229590047, Accuracy 0.41071937243902973      | Test: Loss 2.5857309928307166, Accuracy 0.38169734151329243
# EarlyStopping counter: 4 out of 5
# Epoch [66/200]  | Train: Loss 2.339654054055667, Accuracy 0.40957994609636916       | Test: Loss 2.5716159099187608, Accuracy 0.38517382413087936
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
train_scores, test_scores = attention_log.get_attention_scores('CAT', 5, 'Helena')
print(np.array(test_scores).shape)
avg_test = np.array(test_scores).squeeze(0)
avg_test = avg_test.mean(1)
# Out:
# (1, 66, 39, 5, 27)

# %%
avg_test = avg_test.mean(1)
epochs = range(1, avg_test.shape[0]+1)  
num_features = avg_test.shape[1]

plt.figure(figsize=(10, 8))

# Plotting all features for the current layer
for feature_idx in range(num_features):
    plt.plot(epochs, avg_test[:, feature_idx], label=f'Feature {feature_idx + 1}')

plt.title(f'Attention Scores Across Features Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Attention Scores')
plt.legend(ncol=3) 
plt.grid(True)
plt.show()

# %%
df_val['class'].value_counts()
# Out:
# class
# 76    574
# 35    480
# 51    457
# 33    385
# 32    343
#      ...
# 2      15
# 27     15
# 37     14
# 26     13
# 52      9
# Name: count, Length: 100, dtype: int64

# %%
sample_class76 = df_val.loc[df_val['class'] == 76]

sample_class76.shape
sample_class76 = sample_class76.sample(n=5)
input_class76 = sample_class76.drop('class', axis=1)
target_class76 = sample_class76['class']

# %%
#Now lets take model in evaluation mode and run certain samples through
#it

class_76_dataset = Combined_Dataset(sample_class76, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_76_dataset, batch_size=batch_size)

# Define your evaluation function
def evaluate(model, dataloader, loss_function, device_in_use):
    model.eval()  # Set model to evaluation mode
    loss_vals = []
    accuracies = []
    attentions = []

    with torch.no_grad():
        for (cat_x, cont_x, labels) in dataloader:
            cat_x,cont_x,labels=cat_x.to(device_in_use),cont_x.to(device_in_use),labels.to(device_in_use)

            predictions, attention = model(cat_x, cont_x)

            loss = loss_function(predictions, labels.long())
            loss_vals.append(loss.item())

            _, predicted = torch.max(predictions, 1)
            accuracy = (predicted == labels).sum().item() / labels.size(0)
            accuracies.append(accuracy)

            attentions.append(attention.cpu().numpy())  # Assuming attn is a tensor of attention scores

    avg_loss = np.mean(loss_vals)
    avg_accuracy = np.mean(accuracies)
    all_attentions = np.concatenate(attentions, axis=0) if attentions else None

    return avg_loss, avg_accuracy, all_attentions

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")
# Out:
# Sample: Loss 2.4679887294769287, Accuracy 0.6

# %%
sample_attentions_76 = sample_attentions.mean(0)
sample_attentions_76
# Out:
# array([0.03466678, 0.03513404, 0.03786559, 0.03434005, 0.04133718,
#        0.03738388, 0.03647209, 0.03525802, 0.03623598, 0.03349295,
#        0.03225653, 0.03361596, 0.03746707, 0.034221  , 0.04454351,
#        0.03329536, 0.03345006, 0.03613587, 0.03751756, 0.03769563,
#        0.05394318, 0.0356967 , 0.03845967, 0.03917329, 0.03478969,
#        0.03959604, 0.03595638], dtype=float32)

# %%
sample_class26 = df_val.loc[df_val['class'] == 26]

sample_class26.shape
sample_class26 = sample_class26.sample(n=5)
input_class26 = sample_class26.drop('class', axis=1)
target_class26 = sample_class26['class']

class_26_dataset = Combined_Dataset(sample_class26, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_26_dataset, batch_size=batch_size)

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")
# Out:
# Sample: Loss 4.542147159576416, Accuracy 0.2

# %%
sample_attentions_26 = sample_attentions.mean(0)
sample_attentions_26
# Out:
# array([0.03464029, 0.03331156, 0.03595095, 0.03388268, 0.04152764,
#        0.03806076, 0.0377672 , 0.03557708, 0.03663414, 0.03612276,
#        0.03254031, 0.0330268 , 0.03924193, 0.03247105, 0.03882633,
#        0.03766539, 0.03329498, 0.03667985, 0.03479533, 0.03887164,
#        0.04505768, 0.0359477 , 0.04640037, 0.04030536, 0.03644719,
#        0.03848486, 0.03646822], dtype=float32)

# %%
dist1 = sample_attentions_26
dist2 = sample_attentions_76

# Creating feature indices for x-axis ticks (assuming 27 features)
features = np.arange(1, 28)

# Plotting bar plots for comparison
plt.figure(figsize=(12, 6))

# Offset for bar width
bar_width = 0.35
index = np.arange(len(features))

# Plotting bars for each class
plt.bar(index, dist1, bar_width, label='Class 26', alpha=0.8)
plt.bar(index + bar_width, dist2, bar_width, label='Class 76', alpha=0.8)

plt.xlabel('Features')
plt.ylabel('Attention Scores')
plt.title('Comparison of Attention Scores for Corresponding Features')
plt.xticks(index + bar_width / 2, features)
plt.legend()
plt.tight_layout()
plt.show()

# %%
ft_model = MyFTTransformer(n_cont=len(cont_columns),
                       cat_feat=[],
                       targets_classes=target_classes,
                       get_attn=True,
                       num_layers=5).to(device_in_use)
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=ft_model.parameters(), lr = 0.0001)

early_stopping = EarlyStopping(patience=5, verbose=True)

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 

train_attns = []
test_attns = []

epochs = 200

for t in range(epochs):
    train_loss, train_acc, train_attn = train(regression_on=False, 
                                  get_attn=True,
                                   dataloader=train_dataloader, 
                                   model=ft_model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_acc, test_attn = test(regression_on=False,
                               get_attn=True,
                               dataloader=test_dataloader,
                               model=ft_model,
                               loss_function=loss_function,
                               device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_accuracies_1.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies_1.append(test_acc)
    train_attns.append(train_attn)
    test_attns.append(test_attn)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, Accuracy {(train_acc)}"
    test_metrics = f"Test: Loss {(test_loss)}, Accuracy {(test_acc)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_acc, ft_model)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break


attention_log.add_attention_scores('FT', 5, 'Helena', train_attns, test_attns)
# Out:
# Epoch [ 1/200]  | Train: Loss 4.208391044392932, Accuracy 0.08657448999715144       | Test: Loss 3.767695610339825, Accuracy 0.14989775051124746
# Validation score improved. Saving model...
# Epoch [ 2/200]  | Train: Loss 3.5902762000121218, Accuracy 0.18697548042158774      | Test: Loss 3.3041814473959117, Accuracy 0.25674846625766873
# Validation score improved. Saving model...
# Epoch [ 3/200]  | Train: Loss 3.2844049038167773, Accuracy 0.24878935951092315      | Test: Loss 3.1389529643914638, Accuracy 0.26942740286298567
# Validation score improved. Saving model...
# Epoch [ 4/200]  | Train: Loss 3.1514953594633988, Accuracy 0.27199421522010647      | Test: Loss 3.0402441941774807, Accuracy 0.29151329243353785
# Validation score improved. Saving model...
# Epoch [ 5/200]  | Train: Loss 3.047432748965045, Accuracy 0.29042224510813597       | Test: Loss 2.944227756598057, Accuracy 0.3061349693251534
# Validation score improved. Saving model...
# Epoch [ 6/200]  | Train: Loss 2.977907993274028, Accuracy 0.3015316519490764        | Test: Loss 2.9047333093789907, Accuracy 0.3123721881390593
# Validation score improved. Saving model...
# Epoch [ 7/200]  | Train: Loss 2.927930757320127, Accuracy 0.30863115454565376       | Test: Loss 2.8607793037707987, Accuracy 0.3193251533742331
# Validation score improved. Saving model...
# Epoch [ 8/200]  | Train: Loss 2.8833868703362664, Accuracy 0.3156430089620264       | Test: Loss 2.8390821615854898, Accuracy 0.3229038854805726
# Validation score improved. Saving model...
# Epoch [ 9/200]  | Train: Loss 2.8493407425267736, Accuracy 0.3187106952691895       | Test: Loss 2.805668763625316, Accuracy 0.32791411042944785
# Validation score improved. Saving model...
# Epoch [10/200]  | Train: Loss 2.819033390982857, Accuracy 0.32386002585621315       | Test: Loss 2.779915730158488, Accuracy 0.3324130879345603
# Validation score improved. Saving model...
# Epoch [11/200]  | Train: Loss 2.7979342111662113, Accuracy 0.32833008304665073      | Test: Loss 2.7594817601717434, Accuracy 0.3388548057259714
# Validation score improved. Saving model...
# Epoch [12/200]  | Train: Loss 2.7782589656680656, Accuracy 0.33128820912855794      | Test: Loss 2.7415539607023582, Accuracy 0.3421267893660532
# Validation score improved. Saving model...
# Epoch [13/200]  | Train: Loss 2.7578958745775277, Accuracy 0.33352323772377673      | Test: Loss 2.7357078271034436, Accuracy 0.3407975460122699
# EarlyStopping counter: 1 out of 5
# Epoch [14/200]  | Train: Loss 2.7377674339869835, Accuracy 0.33902316103161906      | Test: Loss 2.7284987767537436, Accuracy 0.3389570552147239
# EarlyStopping counter: 2 out of 5
# Epoch [15/200]  | Train: Loss 2.7250103870583646, Accuracy 0.3391984573920284       | Test: Loss 2.716750811307858, Accuracy 0.3474437627811861
# Validation score improved. Saving model...
# Epoch [16/200]  | Train: Loss 2.7093200896705327, Accuracy 0.34487367706028005      | Test: Loss 2.7132776578267417, Accuracy 0.35010224948875257
# Validation score improved. Saving model...
# Epoch [17/200]  | Train: Loss 2.6979165623307892, Accuracy 0.34498323728553587      | Test: Loss 2.714606138376089, Accuracy 0.34683026584867077
# EarlyStopping counter: 1 out of 5
# Epoch [18/200]  | Train: Loss 2.682511821139458, Accuracy 0.3473278261060105        | Test: Loss 2.6936294115506687, Accuracy 0.3506134969325153
# Validation score improved. Saving model...
# Epoch [19/200]  | Train: Loss 2.670477568770254, Accuracy 0.3500230076473037        | Test: Loss 2.677650598379282, Accuracy 0.3514314928425358
# Validation score improved. Saving model...
# Epoch [20/200]  | Train: Loss 2.6596931785178586, Accuracy 0.3523675964677783       | Test: Loss 2.6606893906226525, Accuracy 0.35408997955010224
# Validation score improved. Saving model...
# Epoch [21/200]  | Train: Loss 2.649764403284595, Accuracy 0.3550408659640204        | Test: Loss 2.6661232740451126, Accuracy 0.3562372188139059
# Validation score improved. Saving model...
# Epoch [22/200]  | Train: Loss 2.640020747424504, Accuracy 0.35607073208142515       | Test: Loss 2.656823971332648, Accuracy 0.35756646216768917
# Validation score improved. Saving model...
# Epoch [23/200]  | Train: Loss 2.630696918711316, Accuracy 0.35749501500975084       | Test: Loss 2.6563479594695263, Accuracy 0.3565439672801636
# EarlyStopping counter: 1 out of 5
# Epoch [24/200]  | Train: Loss 2.6221915796482365, Accuracy 0.3605188772268116       | Test: Loss 2.6491115398896046, Accuracy 0.35899795501022497
# Validation score improved. Saving model...
# Epoch [25/200]  | Train: Loss 2.6143723253431266, Accuracy 0.3604531410916581       | Test: Loss 2.653199024689503, Accuracy 0.3579754601226994
# EarlyStopping counter: 1 out of 5
# Epoch [26/200]  | Train: Loss 2.602256180853817, Accuracy 0.36481363805683986       | Test: Loss 2.6502054899166794, Accuracy 0.35695296523517384
# EarlyStopping counter: 2 out of 5
# Epoch [27/200]  | Train: Loss 2.598276174268243, Accuracy 0.36209654447049544       | Test: Loss 2.639837906910823, Accuracy 0.36595092024539877
# Validation score improved. Saving model...
# Epoch [28/200]  | Train: Loss 2.5858511498520493, Accuracy 0.36551482349847714      | Test: Loss 2.634575055195735, Accuracy 0.3604294478527607
# EarlyStopping counter: 1 out of 5
# Epoch [29/200]  | Train: Loss 2.5816264578750014, Accuracy 0.3673773473278261       | Test: Loss 2.6420705990913587, Accuracy 0.3642126789366053
# EarlyStopping counter: 2 out of 5
# Epoch [30/200]  | Train: Loss 2.5682022917870038, Accuracy 0.36630365712031904      | Test: Loss 2.619448973582341, Accuracy 0.36267893660531697
# EarlyStopping counter: 3 out of 5
# Epoch [31/200]  | Train: Loss 2.5616700715858842, Accuracy 0.36989723250871004      | Test: Loss 2.615050352536715, Accuracy 0.36809815950920244
# Validation score improved. Saving model...
# Epoch [32/200]  | Train: Loss 2.5476237262427475, Accuracy 0.372285645419287        | Test: Loss 2.640381641877003, Accuracy 0.3660531697341513
# EarlyStopping counter: 1 out of 5
# Epoch [33/200]  | Train: Loss 2.5467213065930583, Accuracy 0.3741700812936871       | Test: Loss 2.6258399669940653, Accuracy 0.36728016359918203
# EarlyStopping counter: 2 out of 5
# Epoch [34/200]  | Train: Loss 2.5414471266655947, Accuracy 0.375616276267064        | Test: Loss 2.609670700171055, Accuracy 0.36574642126789364
# EarlyStopping counter: 3 out of 5
# Epoch [35/200]  | Train: Loss 2.532151485954583, Accuracy 0.3748712667353244        | Test: Loss 2.6120308484786596, Accuracy 0.36922290388548057
# Validation score improved. Saving model...
# Epoch [36/200]  | Train: Loss 2.5234312944572066, Accuracy 0.37787321690733394      | Test: Loss 2.6113000160608535, Accuracy 0.3685071574642127
# EarlyStopping counter: 1 out of 5
# Epoch [37/200]  | Train: Loss 2.5179073677382657, Accuracy 0.3779389530424875       | Test: Loss 2.6199749005146518, Accuracy 0.37004089979550103
# Validation score improved. Saving model...
# Epoch [38/200]  | Train: Loss 2.511113923355188, Accuracy 0.377741744637027         | Test: Loss 2.6038799652686486, Accuracy 0.3731083844580777
# Validation score improved. Saving model...
# Epoch [39/200]  | Train: Loss 2.504844533664554, Accuracy 0.3779608650875386        | Test: Loss 2.617022978953826, Accuracy 0.37351738241308796
# Validation score improved. Saving model...
# Epoch [40/200]  | Train: Loss 2.4972756761412382, Accuracy 0.38102855139470165      | Test: Loss 2.6098080781789927, Accuracy 0.3712678936605317
# EarlyStopping counter: 1 out of 5
# Epoch [41/200]  | Train: Loss 2.4921696265982516, Accuracy 0.38067795867388304      | Test: Loss 2.612918217976888, Accuracy 0.37668711656441717
# Validation score improved. Saving model...
# Epoch [42/200]  | Train: Loss 2.486130479993767, Accuracy 0.3823432740977715        | Test: Loss 2.591328290792612, Accuracy 0.3754601226993865
# EarlyStopping counter: 1 out of 5
# Epoch [43/200]  | Train: Loss 2.477413201465287, Accuracy 0.3828691631789995        | Test: Loss 2.5946012154603615, Accuracy 0.37474437627811863
# EarlyStopping counter: 2 out of 5
# Epoch [44/200]  | Train: Loss 2.472410126105367, Accuracy 0.3841619738370182        | Test: Loss 2.5861311019995274, Accuracy 0.37678936605316976
# Validation score improved. Saving model...
# Epoch [45/200]  | Train: Loss 2.468628774142132, Accuracy 0.3857615531257532        | Test: Loss 2.590128336197291, Accuracy 0.3758691206543967
# EarlyStopping counter: 1 out of 5
# Epoch [46/200]  | Train: Loss 2.4563672808961496, Accuracy 0.3877555492254092       | Test: Loss 2.59852689351791, Accuracy 0.37658486707566463
# EarlyStopping counter: 2 out of 5
# Epoch [47/200]  | Train: Loss 2.4497984481257435, Accuracy 0.39007822600083264      | Test: Loss 2.582214661133595, Accuracy 0.3810838445807771
# Validation score improved. Saving model...
# Epoch [48/200]  | Train: Loss 2.4465743016930266, Accuracy 0.3903192584963955       | Test: Loss 2.5900102028479943, Accuracy 0.37852760736196317
# EarlyStopping counter: 1 out of 5
# Epoch [49/200]  | Train: Loss 2.4399972388198257, Accuracy 0.39099853189298156      | Test: Loss 2.577984712062738, Accuracy 0.37934560327198363
# EarlyStopping counter: 2 out of 5
# Epoch [50/200]  | Train: Loss 2.4325408083100557, Accuracy 0.39281723163222826      | Test: Loss 2.5808065915719056, Accuracy 0.38179959100204497
# Validation score improved. Saving model...
# Epoch [51/200]  | Train: Loss 2.4294155563056137, Accuracy 0.3936498893441725       | Test: Loss 2.578166350340232, Accuracy 0.3805725971370143
# EarlyStopping counter: 1 out of 5
# Epoch [52/200]  | Train: Loss 2.419508623677259, Accuracy 0.39450445910116794       | Test: Loss 2.577413870738103, Accuracy 0.3814928425357873
# EarlyStopping counter: 2 out of 5
# Epoch [53/200]  | Train: Loss 2.4117784113857335, Accuracy 0.39413195433529813      | Test: Loss 2.579910009335249, Accuracy 0.3783231083844581
# EarlyStopping counter: 3 out of 5
# Epoch [54/200]  | Train: Loss 2.4113911090616407, Accuracy 0.3969366961018472       | Test: Loss 2.57655145571782, Accuracy 0.3815950920245399
# EarlyStopping counter: 4 out of 5
# Epoch [55/200]  | Train: Loss 2.402737359094886, Accuracy 0.3979446501742008        | Test: Loss 2.584151102946355, Accuracy 0.38271983640081797
# Validation score improved. Saving model...
# Epoch [56/200]  | Train: Loss 2.394486154257918, Accuracy 0.39998247036395906       | Test: Loss 2.57613083643791, Accuracy 0.3814928425357873
# EarlyStopping counter: 1 out of 5
# Epoch [57/200]  | Train: Loss 2.3870717053972808, Accuracy 0.400771303985801        | Test: Loss 2.588616799085568, Accuracy 0.38333333333333336
# Validation score improved. Saving model...
# Epoch [58/200]  | Train: Loss 2.3844002811602376, Accuracy 0.4013410171571313       | Test: Loss 2.573227894611848, Accuracy 0.3830265848670757
# EarlyStopping counter: 1 out of 5
# Epoch [59/200]  | Train: Loss 2.3750902021397424, Accuracy 0.4020860266888709       | Test: Loss 2.589703309230315, Accuracy 0.38404907975460123
# Validation score improved. Saving model...
# Epoch [60/200]  | Train: Loss 2.3718474923565402, Accuracy 0.4033350132567873       | Test: Loss 2.58925854242765, Accuracy 0.38179959100204497
# EarlyStopping counter: 1 out of 5
# Epoch [61/200]  | Train: Loss 2.362793026023737, Accuracy 0.40410193483357804       | Test: Loss 2.574612959837302, Accuracy 0.38425357873210636
# Validation score improved. Saving model...
# Epoch [62/200]  | Train: Loss 2.356110647403994, Accuracy 0.4067532922847689        | Test: Loss 2.5753561166616588, Accuracy 0.3848670756646217
# Validation score improved. Saving model...
# Epoch [63/200]  | Train: Loss 2.352514200370405, Accuracy 0.4073887415912527        | Test: Loss 2.5739351419302134, Accuracy 0.3857873210633947
# Validation score improved. Saving model...
# Epoch [64/200]  | Train: Loss 2.346966414478238, Accuracy 0.4063369634287968        | Test: Loss 2.5752186347276735, Accuracy 0.38640081799591003
# Validation score improved. Saving model...
# Epoch [65/200]  | Train: Loss 2.3412624670806546, Accuracy 0.4106098122137739       | Test: Loss 2.580467927150237, Accuracy 0.38885480572597136
# Validation score improved. Saving model...
# Epoch [66/200]  | Train: Loss 2.330518001950653, Accuracy 0.4106317242588251        | Test: Loss 2.574543494444627, Accuracy 0.3852760736196319
# EarlyStopping counter: 1 out of 5
# Epoch [67/200]  | Train: Loss 2.3313304125929677, Accuracy 0.40909788110524353      | Test: Loss 2.567273965248695, Accuracy 0.3848670756646217
# EarlyStopping counter: 2 out of 5
# Epoch [68/200]  | Train: Loss 2.3205827694365433, Accuracy 0.4104345158533646       | Test: Loss 2.576389960753612, Accuracy 0.3871165644171779
# EarlyStopping counter: 3 out of 5
# Epoch [69/200]  | Train: Loss 2.315733138409407, Accuracy 0.41461971645813706       | Test: Loss 2.5721032986274133, Accuracy 0.38732106339468303
# EarlyStopping counter: 4 out of 5
# Epoch [70/200]  | Train: Loss 2.308704634618493, Accuracy 0.4148169248635975        | Test: Loss 2.5764175928556003, Accuracy 0.3914110429447853
# Validation score improved. Saving model...
# Epoch [71/200]  | Train: Loss 2.3040415867746877, Accuracy 0.4147073646383417       | Test: Loss 2.587733733348357, Accuracy 0.38660531697341516
# EarlyStopping counter: 1 out of 5
# Epoch [72/200]  | Train: Loss 2.2945515343596816, Accuracy 0.4170738655038675       | Test: Loss 2.5842934327247815, Accuracy 0.38548057259713703
# EarlyStopping counter: 2 out of 5
# Epoch [73/200]  | Train: Loss 2.287402464690821, Accuracy 0.4181475557113745        | Test: Loss 2.580930599799523, Accuracy 0.38701431492842536
# EarlyStopping counter: 3 out of 5
# Epoch [74/200]  | Train: Loss 2.28548136902921, Accuracy 0.42117141792843527        | Test: Loss 2.579313100912632, Accuracy 0.38660531697341516
# EarlyStopping counter: 4 out of 5
# Epoch [75/200]  | Train: Loss 2.2760721784730196, Accuracy 0.42130289019874223      | Test: Loss 2.5891691048940024, Accuracy 0.38701431492842536
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
train_scores, test_scores = attention_log.get_attention_scores('FT', 5, 'Helena')
print(np.array(test_scores).shape)
avg_test = np.array(test_scores).squeeze(0)
avg_test = avg_test.mean(1)
avg_test = avg_test.mean(1)
avg_test.shape
# Out:
# (1, 75, 39, 5, 27)
# (75, 27)

# %%
epochs = range(1, avg_test.shape[0]+1)  
num_features = avg_test.shape[1]

plt.figure(figsize=(10, 8))

# Plotting all features for the current layer
for feature_idx in range(num_features):
    plt.plot(epochs, avg_test[:, feature_idx], label=f'Feature {feature_idx + 1}')

plt.title(f'Attention Scores Across Features Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Attention Scores')
plt.legend(ncol=3) 
plt.grid(True)
plt.show()

# %%
# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

class_76_dataset = Combined_Dataset(sample_class76, cat_columns=[], num_columns=cont_columns, task1_column='class')

batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_76_dataset, batch_size=batch_size)

sample_loss, sample_accuracy, sample_attentions_ft_76 = evaluate(ft_model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")
# Out:
# Sample: Loss 2.515967845916748, Accuracy 0.6

# %%
sample_attentions_76_ft = sample_attentions_ft_76.mean(0)
sample_attentions_76_ft
# Out:
# array([0.0310835 , 0.0327855 , 0.03873812, 0.03399077, 0.04091477,
#        0.03480761, 0.03868224, 0.03585707, 0.03684332, 0.03264748,
#        0.03366082, 0.03323881, 0.03818139, 0.03051651, 0.0390249 ,
#        0.03260987, 0.03125048, 0.03621762, 0.03141911, 0.04069671,
#        0.04887843, 0.03269052, 0.03872082, 0.03703625, 0.03206807,
#        0.03891548, 0.03639298], dtype=float32)

# %%
dist1 = sample_attentions_76_ft
dist2 = sample_attentions_76

# Creating feature indices for x-axis ticks (assuming 27 features)
features = np.arange(1, 28)

# Plotting bar plots for comparison
plt.figure(figsize=(12, 6))

# Offset for bar width
bar_width = 0.35
index = np.arange(len(features))

# Plotting bars for each class
plt.bar(index, dist1, bar_width, label='Class 76 FT', alpha=0.8)
plt.bar(index + bar_width, dist2, bar_width, label='Class 76 CAT', alpha=0.8)

plt.xlabel('Features')
plt.ylabel('Attention Scores')
plt.title('Comparison of Attention Scores for Corresponding Features')
plt.xticks(index + bar_width / 2, features)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

class_26_dataset = Combined_Dataset(sample_class26, cat_columns=[], num_columns=cont_columns, task1_column='class')

batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_26_dataset, batch_size=batch_size)

sample_loss, sample_accuracy, sample_attentions_ft_26 = evaluate(ft_model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")
# Out:
# Sample: Loss 4.66142463684082, Accuracy 0.2

# %%
sample_attentions_26_ft = sample_attentions_ft_26.mean(0)
sample_attentions_26_ft
# Out:
# array([0.03019857, 0.03133032, 0.03886275, 0.03153955, 0.03797499,
#        0.03708183, 0.03981195, 0.03787117, 0.03435238, 0.03342924,
#        0.03435099, 0.03212962, 0.03778968, 0.03060104, 0.03903943,
#        0.03707358, 0.03107867, 0.03509497, 0.02928066, 0.04328587,
#        0.04285946, 0.03390401, 0.04170387, 0.03781075, 0.03226285,
#        0.04144077, 0.03537451], dtype=float32)

# %%
dist1 = sample_attentions_26_ft
dist2 = sample_attentions_26

# Creating feature indices for x-axis ticks (assuming 27 features)
features = np.arange(1, 28)

# Plotting bar plots for comparison
plt.figure(figsize=(12, 6))

# Offset for bar width
bar_width = 0.35
index = np.arange(len(features))

# Plotting bars for each class
plt.bar(index, dist1, bar_width, label='Class 26 FT', alpha=0.8)
plt.bar(index + bar_width, dist2, bar_width, label='Class 26 CAT', alpha=0.8)

plt.xlabel('Features')
plt.ylabel('Attention Scores')
plt.title('Comparison of Attention Scores for Corresponding Features')
plt.xticks(index + bar_width / 2, features)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# So there appears to be a slight difference between the two which we should expect. However, they are very very similar and would likely give similar feature rankings. 
# If we use only 1 layer, then we should expect basically no difference. Lets see what happens when we do such a thing

model = CATTransformer(n_cont=len(cont_columns),
                       cat_feat=[],
                       targets_classes=target_classes,
                       get_attn=True,
                       num_layers=1).to(device_in_use)
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001)

early_stopping = EarlyStopping(patience=5, verbose=True)

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 

train_attns = []
test_attns = []

epochs = 200

for t in range(epochs):
    train_loss, train_acc, train_attn = train(regression_on=False, 
                                  get_attn=True,
                                   dataloader=train_dataloader, 
                                   model=model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_acc, test_attn = test(regression_on=False,
                               get_attn=True,
                               dataloader=test_dataloader,
                               model=model,
                               loss_function=loss_function,
                               device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_accuracies_1.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies_1.append(test_acc)
    train_attns.append(train_attn)
    test_attns.append(test_attn)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, Accuracy {(train_acc)}"
    test_metrics = f"Test: Loss {(test_loss)}, Accuracy {(test_acc)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_acc, model)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break


attention_log.add_attention_scores('CAT', 1, 'Helena', train_attns, test_attns)
# Out:
# Epoch [ 1/200]  | Train: Loss 4.18542987274724, Accuracy 0.08644301772684444        | Test: Loss 3.7498328502361593, Accuracy 0.15102249488752556
# Validation score improved. Saving model...
# Epoch [ 2/200]  | Train: Loss 3.5962682156589443, Accuracy 0.19061287990008108      | Test: Loss 3.321420198831803, Accuracy 0.24171779141104294
# Validation score improved. Saving model...
# Epoch [ 3/200]  | Train: Loss 3.284681456049061, Accuracy 0.25091482788088615       | Test: Loss 3.1218024094899497, Accuracy 0.28445807770961146
# Validation score improved. Saving model...
# Epoch [ 4/200]  | Train: Loss 3.127841640451101, Accuracy 0.27815149987948373       | Test: Loss 3.0148393313090005, Accuracy 0.29703476482617586
# Validation score improved. Saving model...
# Epoch [ 5/200]  | Train: Loss 3.0356653229484345, Accuracy 0.29184652803646166      | Test: Loss 2.9411595356770053, Accuracy 0.3141104294478528
# Validation score improved. Saving model...
# Epoch [ 6/200]  | Train: Loss 2.9670868492659244, Accuracy 0.3014878278589741       | Test: Loss 2.893702580378606, Accuracy 0.31850715746421265
# Validation score improved. Saving model...
# Epoch [ 7/200]  | Train: Loss 2.9165292718557008, Accuracy 0.30887218704121655      | Test: Loss 2.842795048004542, Accuracy 0.3244376278118609
# Validation score improved. Saving model...
# Epoch [ 8/200]  | Train: Loss 2.873543102648005, Accuracy 0.31481035125008217       | Test: Loss 2.8300968316885142, Accuracy 0.32791411042944785
# Validation score improved. Saving model...
# Epoch [ 9/200]  | Train: Loss 2.841156304215586, Accuracy 0.32070469136884544       | Test: Loss 2.7882551291050057, Accuracy 0.331799591002045
# Validation score improved. Saving model...
# Epoch [10/200]  | Train: Loss 2.812966521225828, Accuracy 0.3228520717838596        | Test: Loss 2.773537904788286, Accuracy 0.33813905930470345
# Validation score improved. Saving model...
# Epoch [11/200]  | Train: Loss 2.79099753981862, Accuracy 0.3278041939654228         | Test: Loss 2.750538367491502, Accuracy 0.33957055214723925
# Validation score improved. Saving model...
# Epoch [12/200]  | Train: Loss 2.7712653402509635, Accuracy 0.3312005609483533       | Test: Loss 2.7491328838544016, Accuracy 0.3392638036809816
# EarlyStopping counter: 1 out of 5
# Epoch [13/200]  | Train: Loss 2.7523921055500735, Accuracy 0.3360212108596095       | Test: Loss 2.7340908539600863, Accuracy 0.3416155419222904
# Validation score improved. Saving model...
# Epoch [14/200]  | Train: Loss 2.7314108776646617, Accuracy 0.3384534478602888       | Test: Loss 2.7190366647182365, Accuracy 0.3488752556237219
# Validation score improved. Saving model...
# Epoch [15/200]  | Train: Loss 2.7186233358010234, Accuracy 0.3395271380677959       | Test: Loss 2.7098999267969375, Accuracy 0.34427402862985684
# EarlyStopping counter: 1 out of 5
# Epoch [16/200]  | Train: Loss 2.706347215109031, Accuracy 0.3430988014111357        | Test: Loss 2.7146880687811437, Accuracy 0.34478527607361964
# EarlyStopping counter: 2 out of 5
# Epoch [17/200]  | Train: Loss 2.6906678316979433, Accuracy 0.34513662160089403      | Test: Loss 2.690080764966133, Accuracy 0.35593047034764824
# Validation score improved. Saving model...
# Epoch [18/200]  | Train: Loss 2.674111540757078, Accuracy 0.35078992922409447       | Test: Loss 2.6755850192828055, Accuracy 0.35419222903885483
# EarlyStopping counter: 1 out of 5
# Epoch [19/200]  | Train: Loss 2.6641793797136017, Accuracy 0.3503736003681224       | Test: Loss 2.672328838935265, Accuracy 0.3512269938650307
# EarlyStopping counter: 2 out of 5
# Epoch [20/200]  | Train: Loss 2.6540241188177185, Accuracy 0.3538137914411552       | Test: Loss 2.6767302720974655, Accuracy 0.35265848670756644
# EarlyStopping counter: 3 out of 5
# Epoch [21/200]  | Train: Loss 2.6464195930758003, Accuracy 0.35521616232442976      | Test: Loss 2.6674614808498283, Accuracy 0.3596114519427403
# Validation score improved. Saving model...
# Epoch [22/200]  | Train: Loss 2.6377041286596374, Accuracy 0.3568376536582159       | Test: Loss 2.6607213570521426, Accuracy 0.35848670756646217
# EarlyStopping counter: 1 out of 5
# Epoch [23/200]  | Train: Loss 2.621659990129524, Accuracy 0.35749501500975084       | Test: Loss 2.6449152934245572, Accuracy 0.36257668711656443
# Validation score improved. Saving model...
# Epoch [24/200]  | Train: Loss 2.612592041825449, Accuracy 0.3606065254070162        | Test: Loss 2.6436153252919516, Accuracy 0.36134969325153377
# EarlyStopping counter: 1 out of 5
# Epoch [25/200]  | Train: Loss 2.6048438788792274, Accuracy 0.361373446983807        | Test: Loss 2.6298210865412, Accuracy 0.3618609406952965
# EarlyStopping counter: 2 out of 5
# Epoch [26/200]  | Train: Loss 2.5963718371684323, Accuracy 0.3628634660472862       | Test: Loss 2.6489507296146493, Accuracy 0.36339468302658484
# Validation score improved. Saving model...
# Epoch [27/200]  | Train: Loss 2.5900407157130747, Accuracy 0.3647479019216863       | Test: Loss 2.634198249914707, Accuracy 0.3638036809815951
# Validation score improved. Saving model...
# Epoch [28/200]  | Train: Loss 2.5752729770191554, Accuracy 0.3663693932554725       | Test: Loss 2.628540528126252, Accuracy 0.36881390593047036
# Validation score improved. Saving model...
# Epoch [29/200]  | Train: Loss 2.5701597948980064, Accuracy 0.3699629686438635       | Test: Loss 2.619838549540593, Accuracy 0.37096114519427403
# Validation score improved. Saving model...
# Epoch [30/200]  | Train: Loss 2.562231145091563, Accuracy 0.3697876722834542        | Test: Loss 2.6299325625101724, Accuracy 0.36789366053169736
# EarlyStopping counter: 1 out of 5
# Epoch [31/200]  | Train: Loss 2.5523977506094138, Accuracy 0.3722199092841335       | Test: Loss 2.6305931959396753, Accuracy 0.3712678936605317
# Validation score improved. Saving model...
# Epoch [32/200]  | Train: Loss 2.549112200071026, Accuracy 0.37287727063566845       | Test: Loss 2.624424995520176, Accuracy 0.37157464212678937
# Validation score improved. Saving model...
# Epoch [33/200]  | Train: Loss 2.5399262572134007, Accuracy 0.37305256699607775      | Test: Loss 2.624366210057185, Accuracy 0.37116564417177916
# EarlyStopping counter: 1 out of 5
# Epoch [34/200]  | Train: Loss 2.5317845664210825, Accuracy 0.37412625720358483      | Test: Loss 2.61213319729536, Accuracy 0.37116564417177916
# EarlyStopping counter: 2 out of 5
# Epoch [35/200]  | Train: Loss 2.5222740852633003, Accuracy 0.3760545171680873       | Test: Loss 2.605471831101638, Accuracy 0.37566462167689163
# Validation score improved. Saving model...
# Epoch [36/200]  | Train: Loss 2.5211505130682577, Accuracy 0.37885925893463634      | Test: Loss 2.602399929975852, Accuracy 0.37208588957055216
# EarlyStopping counter: 1 out of 5
# Epoch [37/200]  | Train: Loss 2.5153104486412174, Accuracy 0.3777636566820781       | Test: Loss 2.609716299252632, Accuracy 0.37392638036809817
# EarlyStopping counter: 2 out of 5
# Epoch [38/200]  | Train: Loss 2.5017332398025682, Accuracy 0.38109428752985514      | Test: Loss 2.6156521760500393, Accuracy 0.3725971370143149
# EarlyStopping counter: 3 out of 5
# Epoch [39/200]  | Train: Loss 2.498638561984014, Accuracy 0.38078751889913887       | Test: Loss 2.594914075655815, Accuracy 0.3791411042944785
# Validation score improved. Saving model...
# Epoch [40/200]  | Train: Loss 2.488373902922902, Accuracy 0.3852137519994741        | Test: Loss 2.600802024205526, Accuracy 0.37556237218813904
# EarlyStopping counter: 1 out of 5
# Epoch [41/200]  | Train: Loss 2.483373315640668, Accuracy 0.38536713631483227       | Test: Loss 2.6018138787685294, Accuracy 0.3721881390593047
# EarlyStopping counter: 2 out of 5
# Epoch [42/200]  | Train: Loss 2.4755182252915877, Accuracy 0.386659946972851        | Test: Loss 2.58076059512603, Accuracy 0.3801635991820041
# Validation score improved. Saving model...
# Epoch [43/200]  | Train: Loss 2.468561216439615, Accuracy 0.386397002432237         | Test: Loss 2.593796277657533, Accuracy 0.37842535787321063
# EarlyStopping counter: 1 out of 5
# Epoch [44/200]  | Train: Loss 2.465567908473521, Accuracy 0.387733637180358         | Test: Loss 2.5873732016636777, Accuracy 0.37791411042944784
# EarlyStopping counter: 2 out of 5
# Epoch [45/200]  | Train: Loss 2.4590073883866466, Accuracy 0.3895085128295024       | Test: Loss 2.6039041922642636, Accuracy 0.37535787321063396
# EarlyStopping counter: 3 out of 5
# Epoch [46/200]  | Train: Loss 2.452100733804969, Accuracy 0.39045073076670245       | Test: Loss 2.576645423204471, Accuracy 0.38312883435582823
# Validation score improved. Saving model...
# Epoch [47/200]  | Train: Loss 2.4441618652983084, Accuracy 0.390253522361242        | Test: Loss 2.577657864643977, Accuracy 0.38179959100204497
# EarlyStopping counter: 1 out of 5
# Epoch [48/200]  | Train: Loss 2.4387337881759557, Accuracy 0.39343076889366085      | Test: Loss 2.569210095283313, Accuracy 0.38118609406952964
# EarlyStopping counter: 2 out of 5
# Epoch [49/200]  | Train: Loss 2.427055883673982, Accuracy 0.3959944781646471        | Test: Loss 2.572972609446599, Accuracy 0.38415132924335377
# Validation score improved. Saving model...
# Epoch [50/200]  | Train: Loss 2.4245394408369862, Accuracy 0.3960602142998006       | Test: Loss 2.579032763456687, Accuracy 0.38026584867075663
# EarlyStopping counter: 1 out of 5
# Epoch [51/200]  | Train: Loss 2.418970805972648, Accuracy 0.39783508994894495       | Test: Loss 2.5883487432430954, Accuracy 0.3852760736196319
# Validation score improved. Saving model...
# Epoch [52/200]  | Train: Loss 2.4109225053361008, Accuracy 0.3976597935885356       | Test: Loss 2.5944990744957557, Accuracy 0.37985685071574643
# EarlyStopping counter: 1 out of 5
# Epoch [53/200]  | Train: Loss 2.4020218143250025, Accuracy 0.40015776672436837      | Test: Loss 2.57586731054844, Accuracy 0.38047034764826176
# EarlyStopping counter: 2 out of 5
# Epoch [54/200]  | Train: Loss 2.3994021588863608, Accuracy 0.3996537896881916       | Test: Loss 2.5671573602236233, Accuracy 0.38558282208588956
# Validation score improved. Saving model...
# Epoch [55/200]  | Train: Loss 2.3945984267655698, Accuracy 0.3999167342288056       | Test: Loss 2.5582576348231387, Accuracy 0.38333333333333336
# EarlyStopping counter: 1 out of 5
# Epoch [56/200]  | Train: Loss 2.3884564285171765, Accuracy 0.4002892389946754       | Test: Loss 2.566133963756072, Accuracy 0.38588957055214723
# Validation score improved. Saving model...
# Epoch [57/200]  | Train: Loss 2.3786297030955055, Accuracy 0.4039923746083222       | Test: Loss 2.564594415517954, Accuracy 0.38548057259713703
# EarlyStopping counter: 1 out of 5
# Epoch [58/200]  | Train: Loss 2.3741015309062083, Accuracy 0.4048031202752153       | Test: Loss 2.5621726451775966, Accuracy 0.38660531697341516
# Validation score improved. Saving model...
# Epoch [59/200]  | Train: Loss 2.371561656451092, Accuracy 0.4052851852663409        | Test: Loss 2.574388393988976, Accuracy 0.38261758691206543
# EarlyStopping counter: 1 out of 5
# Epoch [60/200]  | Train: Loss 2.362478832958797, Accuracy 0.40798036680763416       | Test: Loss 2.5717921318152013, Accuracy 0.3869120654396728
# Validation score improved. Saving model...
# Epoch [61/200]  | Train: Loss 2.3551125060246645, Accuracy 0.40778315840217366      | Test: Loss 2.559772246923202, Accuracy 0.3848670756646217
# EarlyStopping counter: 1 out of 5
# Epoch [62/200]  | Train: Loss 2.35006418441261, Accuracy 0.4075202138615597         | Test: Loss 2.567826020411956, Accuracy 0.3857873210633947
# EarlyStopping counter: 2 out of 5
# Epoch [63/200]  | Train: Loss 2.34422449959057, Accuracy 0.409558034051318          | Test: Loss 2.5633977437630677, Accuracy 0.38752556237218816
# Validation score improved. Saving model...
# Epoch [64/200]  | Train: Loss 2.3376160453817696, Accuracy 0.41227512763766244      | Test: Loss 2.5713479152092567, Accuracy 0.3856850715746421
# EarlyStopping counter: 1 out of 5
# Epoch [65/200]  | Train: Loss 2.3311421018738985, Accuracy 0.4120340951420996       | Test: Loss 2.5728495793464856, Accuracy 0.38609406952965236
# EarlyStopping counter: 2 out of 5
# Epoch [66/200]  | Train: Loss 2.3258493892307386, Accuracy 0.4121436553673554       | Test: Loss 2.5660354724297156, Accuracy 0.3889570552147239
# Validation score improved. Saving model...
# Epoch [67/200]  | Train: Loss 2.3191855406627973, Accuracy 0.41499222122400686      | Test: Loss 2.567201180335803, Accuracy 0.3878323108384458
# EarlyStopping counter: 1 out of 5
# Epoch [68/200]  | Train: Loss 2.3143808841705322, Accuracy 0.41602208734141155      | Test: Loss 2.5725492391830835, Accuracy 0.38660531697341516
# EarlyStopping counter: 2 out of 5
# Epoch [69/200]  | Train: Loss 2.3086589454938578, Accuracy 0.4166356246028442       | Test: Loss 2.5628219567812405, Accuracy 0.3890593047034765
# Validation score improved. Saving model...
# Epoch [70/200]  | Train: Loss 2.304017812846093, Accuracy 0.41862962070250015       | Test: Loss 2.565126724732228, Accuracy 0.39192229038854803
# Validation score improved. Saving model...
# Epoch [71/200]  | Train: Loss 2.2953447176757473, Accuracy 0.4183009400267327       | Test: Loss 2.568298896153768, Accuracy 0.3869120654396728
# EarlyStopping counter: 1 out of 5
# Epoch [72/200]  | Train: Loss 2.2874314318822084, Accuracy 0.4207770011175143       | Test: Loss 2.564377839748676, Accuracy 0.3889570552147239
# EarlyStopping counter: 2 out of 5
# Epoch [73/200]  | Train: Loss 2.2856223862930385, Accuracy 0.4202291999912352       | Test: Loss 2.5769306818644204, Accuracy 0.3876278118609407
# EarlyStopping counter: 3 out of 5
# Epoch [74/200]  | Train: Loss 2.2728186219764157, Accuracy 0.4226176129018121       | Test: Loss 2.561055379036145, Accuracy 0.38773006134969323
# EarlyStopping counter: 4 out of 5
# Epoch [75/200]  | Train: Loss 2.270352787145689, Accuracy 0.42419528014549596       | Test: Loss 2.5645570755004883, Accuracy 0.39192229038854803
# Validation score improved. Saving model...
# Epoch [76/200]  | Train: Loss 2.2667515264543074, Accuracy 0.42377895128952386      | Test: Loss 2.5629303577618723, Accuracy 0.3914110429447853
# EarlyStopping counter: 1 out of 5
# Epoch [77/200]  | Train: Loss 2.2642805110142885, Accuracy 0.4244144005960076       | Test: Loss 2.5796770682701697, Accuracy 0.3903885480572597
# EarlyStopping counter: 2 out of 5
# Epoch [78/200]  | Train: Loss 2.2563983195320856, Accuracy 0.4254223546683612       | Test: Loss 2.5690604050954184, Accuracy 0.3918200408997955
# EarlyStopping counter: 3 out of 5
# Epoch [79/200]  | Train: Loss 2.2503151174364144, Accuracy 0.425926331704538        | Test: Loss 2.5762147169846754, Accuracy 0.39335378323108383
# Validation score improved. Saving model...
# Epoch [80/200]  | Train: Loss 2.240886337930264, Accuracy 0.42958564322808246       | Test: Loss 2.5712498212471986, Accuracy 0.39069529652351737
# EarlyStopping counter: 1 out of 5
# Epoch [81/200]  | Train: Loss 2.235751653516759, Accuracy 0.43164537546289194       | Test: Loss 2.588115698251969, Accuracy 0.3913087934560327
# EarlyStopping counter: 2 out of 5
# Epoch [82/200]  | Train: Loss 2.2300497579840974, Accuracy 0.43127287069702214      | Test: Loss 2.5716079076131186, Accuracy 0.39192229038854803
# EarlyStopping counter: 3 out of 5
# Epoch [83/200]  | Train: Loss 2.2286883139743487, Accuracy 0.4314919911475338       | Test: Loss 2.5694979704343357, Accuracy 0.39069529652351737
# EarlyStopping counter: 4 out of 5
# Epoch [84/200]  | Train: Loss 2.218641265810535, Accuracy 0.4329381861209107        | Test: Loss 2.569124937057495, Accuracy 0.3885480572597137
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
class_76_dataset = Combined_Dataset(sample_class76, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_76_dataset, batch_size=batch_size)

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")

sample_attentions_76 = sample_attentions.mean(0)

class_26_dataset = Combined_Dataset(sample_class26, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_26_dataset, batch_size=batch_size)

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")

sample_attentions_26 = sample_attentions.mean(0)

dist1 = sample_attentions_76
dist2 = sample_attentions_26

# Creating feature indices for x-axis ticks (assuming 27 features)
features = np.arange(1, 28)

# Plotting bar plots for comparison
plt.figure(figsize=(12, 6))

# Offset for bar width
bar_width = 0.35
index = np.arange(len(features))

# Plotting bars for each class
plt.bar(index, dist1, bar_width, label='Class 76 CAT', alpha=0.8)
plt.bar(index + bar_width, dist2, bar_width, label='Class 26 CAT', alpha=0.8)

plt.xlabel('Features')
plt.ylabel('Attention Scores')
plt.title('Comparison of Attention Scores for Corresponding Features')
plt.xticks(index + bar_width / 2, features)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Sample: Loss 2.5446441173553467, Accuracy 0.6
# Sample: Loss 3.6051406860351562, Accuracy 0.4

# %%
ft_model = MyFTTransformer(n_cont=len(cont_columns),
                       cat_feat=[],
                       targets_classes=target_classes,
                       get_attn=True,
                       num_layers=1).to(device_in_use)
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=ft_model.parameters(), lr = 0.0001)

early_stopping = EarlyStopping(patience=5, verbose=True)

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 

train_attns = []
test_attns = []

epochs = 200

for t in range(epochs):
    train_loss, train_acc, train_attn = train(regression_on=False, 
                                  get_attn=True,
                                   dataloader=train_dataloader, 
                                   model=ft_model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_acc, test_attn = test(regression_on=False,
                               get_attn=True,
                               dataloader=test_dataloader,
                               model=ft_model,
                               loss_function=loss_function,
                               device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_accuracies_1.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies_1.append(test_acc)
    train_attns.append(train_attn)
    test_attns.append(test_attn)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, Accuracy {(train_acc)}"
    test_metrics = f"Test: Loss {(test_loss)}, Accuracy {(test_acc)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_acc, ft_model)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break


attention_log.add_attention_scores('FT', 1, 'Helena', train_attns, test_attns)
# Out:
# Epoch [ 1/200]  | Train: Loss 4.186946055076642, Accuracy 0.0797817560312904        | Test: Loss 3.7731036650828824, Accuracy 0.12065439672801637
# Validation score improved. Saving model...
# Epoch [ 2/200]  | Train: Loss 3.61270814234984, Accuracy 0.18042377895128953        | Test: Loss 3.343708735245925, Accuracy 0.24171779141104294
# Validation score improved. Saving model...
# Epoch [ 3/200]  | Train: Loss 3.3009804294096026, Accuracy 0.24977540153822556      | Test: Loss 3.1406095700386243, Accuracy 0.27791411042944786
# Validation score improved. Saving model...
# Epoch [ 4/200]  | Train: Loss 3.1535616387202086, Accuracy 0.27287069702215305      | Test: Loss 3.0425472993117113, Accuracy 0.29478527607361965
# Validation score improved. Saving model...
# Epoch [ 5/200]  | Train: Loss 3.0521110329548073, Accuracy 0.28950193921598705      | Test: Loss 2.9704242119422326, Accuracy 0.3075664621676892
# Validation score improved. Saving model...
# Epoch [ 6/200]  | Train: Loss 2.979201564575707, Accuracy 0.3019041567149462        | Test: Loss 2.8977335599752574, Accuracy 0.31104294478527605
# Validation score improved. Saving model...
# Epoch [ 7/200]  | Train: Loss 2.923098970391897, Accuracy 0.31049367837500275       | Test: Loss 2.8548650986109023, Accuracy 0.3193251533742331
# Validation score improved. Saving model...
# Epoch [ 8/200]  | Train: Loss 2.8803156407851747, Accuracy 0.31581830532243577      | Test: Loss 2.824896298922025, Accuracy 0.3266871165644172
# Validation score improved. Saving model...
# Epoch [ 9/200]  | Train: Loss 2.842871054590747, Accuracy 0.3226548633783991        | Test: Loss 2.7941746406066112, Accuracy 0.328118609406953
# Validation score improved. Saving model...
# Epoch [10/200]  | Train: Loss 2.8157726466322743, Accuracy 0.3265771194425576       | Test: Loss 2.781345153466249, Accuracy 0.33537832310838445
# Validation score improved. Saving model...
# Epoch [11/200]  | Train: Loss 2.7884904698952617, Accuracy 0.3292284768937485       | Test: Loss 2.7450485046093283, Accuracy 0.3367075664621677
# Validation score improved. Saving model...
# Epoch [12/200]  | Train: Loss 2.7696961237731594, Accuracy 0.3327782281920372       | Test: Loss 2.7440350972689114, Accuracy 0.3411042944785276
# Validation score improved. Saving model...
# Epoch [13/200]  | Train: Loss 2.7443962696544286, Accuracy 0.3370291649319631       | Test: Loss 2.7201907390203233, Accuracy 0.3416155419222904
# Validation score improved. Saving model...
# Epoch [14/200]  | Train: Loss 2.732881358215929, Accuracy 0.33941757784254006       | Test: Loss 2.713205099105835, Accuracy 0.34498977505112477
# Validation score improved. Saving model...
# Epoch [15/200]  | Train: Loss 2.716566061840377, Accuracy 0.34209084733878214       | Test: Loss 2.712120526876205, Accuracy 0.34775051124744377
# Validation score improved. Saving model...
# Epoch [16/200]  | Train: Loss 2.6978074198994557, Accuracy 0.34524618182614986      | Test: Loss 2.697612988643157, Accuracy 0.35153374233128837
# Validation score improved. Saving model...
# Epoch [17/200]  | Train: Loss 2.689464439892902, Accuracy 0.3463636961237592        | Test: Loss 2.689122279485067, Accuracy 0.3512269938650307
# EarlyStopping counter: 1 out of 5
# Epoch [18/200]  | Train: Loss 2.6753212300092812, Accuracy 0.3477441549619826       | Test: Loss 2.6911935011545816, Accuracy 0.3521472392638037
# Validation score improved. Saving model...
# Epoch [19/200]  | Train: Loss 2.663446735403391, Accuracy 0.3492999101606153        | Test: Loss 2.6809328825045853, Accuracy 0.35368098159509204
# Validation score improved. Saving model...
# Epoch [20/200]  | Train: Loss 2.652642722902351, Accuracy 0.35197317965685737       | Test: Loss 2.6792588784144473, Accuracy 0.3565439672801636
# Validation score improved. Saving model...
# Epoch [21/200]  | Train: Loss 2.6425976979665915, Accuracy 0.35453688892784363      | Test: Loss 2.662972181271284, Accuracy 0.3577709611451943
# Validation score improved. Saving model...
# Epoch [22/200]  | Train: Loss 2.629590585911074, Accuracy 0.3581523763612858        | Test: Loss 2.659783259416238, Accuracy 0.3571574642126789
# EarlyStopping counter: 1 out of 5
# Epoch [23/200]  | Train: Loss 2.6238165567707084, Accuracy 0.35731971864934153      | Test: Loss 2.6443950640849576, Accuracy 0.3605316973415133
# Validation score improved. Saving model...
# Epoch [24/200]  | Train: Loss 2.609599152090829, Accuracy 0.3611762385783465        | Test: Loss 2.648327717414269, Accuracy 0.35695296523517384
# EarlyStopping counter: 1 out of 5
# Epoch [25/200]  | Train: Loss 2.6005203404240103, Accuracy 0.36078182176742557      | Test: Loss 2.6473435071798472, Accuracy 0.36226993865030677
# Validation score improved. Saving model...
# Epoch [26/200]  | Train: Loss 2.5963592995478453, Accuracy 0.3631702346780025       | Test: Loss 2.628095345619397, Accuracy 0.3623721881390593
# Validation score improved. Saving model...
# Epoch [27/200]  | Train: Loss 2.5808886482728925, Accuracy 0.3647698139667375       | Test: Loss 2.6386005205985827, Accuracy 0.36441717791411044
# Validation score improved. Saving model...
# Epoch [28/200]  | Train: Loss 2.5785307218242624, Accuracy 0.3668733702916493       | Test: Loss 2.6197994977999954, Accuracy 0.36298568507157464
# EarlyStopping counter: 1 out of 5
# Epoch [29/200]  | Train: Loss 2.5674361596560344, Accuracy 0.36882354230120296      | Test: Loss 2.62110449717595, Accuracy 0.3642126789366053
# EarlyStopping counter: 2 out of 5
# Epoch [30/200]  | Train: Loss 2.560524920511512, Accuracy 0.3710366588513706        | Test: Loss 2.624996325908563, Accuracy 0.36830265848670757
# Validation score improved. Saving model...
# Epoch [31/200]  | Train: Loss 2.5515293195926945, Accuracy 0.3716501961128032       | Test: Loss 2.6257870564093957, Accuracy 0.36717791411042944
# EarlyStopping counter: 1 out of 5
# Epoch [32/200]  | Train: Loss 2.5449445647234357, Accuracy 0.37200078883362186      | Test: Loss 2.6225646825937123, Accuracy 0.36871165644171777
# Validation score improved. Saving model...
# Epoch [33/200]  | Train: Loss 2.53719015094821, Accuracy 0.3733593356267941         | Test: Loss 2.613364965487749, Accuracy 0.3698364008179959
# Validation score improved. Saving model...
# Epoch [34/200]  | Train: Loss 2.5286951065063477, Accuracy 0.3735784560773057       | Test: Loss 2.609463324913612, Accuracy 0.36912065439672803
# EarlyStopping counter: 1 out of 5
# Epoch [35/200]  | Train: Loss 2.521834513328595, Accuracy 0.3763612857988036        | Test: Loss 2.6009498131580844, Accuracy 0.3721881390593047
# Validation score improved. Saving model...
# Epoch [36/200]  | Train: Loss 2.5114874666629556, Accuracy 0.3777636566820781       | Test: Loss 2.6241714037381687, Accuracy 0.3685071574642127
# EarlyStopping counter: 1 out of 5
# Epoch [37/200]  | Train: Loss 2.5071579770668926, Accuracy 0.3779170409974363       | Test: Loss 2.604281804500482, Accuracy 0.37321063394683024
# Validation score improved. Saving model...
# Epoch [38/200]  | Train: Loss 2.499944295297122, Accuracy 0.3799548611871946        | Test: Loss 2.600731311700283, Accuracy 0.37157464212678937
# EarlyStopping counter: 1 out of 5
# Epoch [39/200]  | Train: Loss 2.4945624913583253, Accuracy 0.38326357998992044      | Test: Loss 2.579127916922936, Accuracy 0.37464212678936604
# Validation score improved. Saving model...
# Epoch [40/200]  | Train: Loss 2.488415133353718, Accuracy 0.3834827004404321        | Test: Loss 2.5912859990046573, Accuracy 0.37607361963190183
# Validation score improved. Saving model...
# Epoch [41/200]  | Train: Loss 2.4808114427428007, Accuracy 0.382671954773539        | Test: Loss 2.5929216054769664, Accuracy 0.37607361963190183
# Validation score improved. Saving model...
# Epoch [42/200]  | Train: Loss 2.4742188866578, Accuracy 0.3840305015667112          | Test: Loss 2.5925488961048617, Accuracy 0.37750511247443763
# Validation score improved. Saving model...
# Epoch [43/200]  | Train: Loss 2.463583049827448, Accuracy 0.38821570217148366       | Test: Loss 2.586262617355738, Accuracy 0.37801635991820043
# Validation score improved. Saving model...
# Epoch [44/200]  | Train: Loss 2.4594628704326778, Accuracy 0.38830335035168834      | Test: Loss 2.596397039217827, Accuracy 0.3792433537832311
# Validation score improved. Saving model...
# Epoch [45/200]  | Train: Loss 2.4514257734714273, Accuracy 0.38786510945066505      | Test: Loss 2.587437330148159, Accuracy 0.3774028629856851
# EarlyStopping counter: 1 out of 5
# Epoch [46/200]  | Train: Loss 2.4436553044026126, Accuracy 0.3916778052895677       | Test: Loss 2.5861065143193955, Accuracy 0.37955010224948876
# Validation score improved. Saving model...
# Epoch [47/200]  | Train: Loss 2.440570841954407, Accuracy 0.39058220303700947       | Test: Loss 2.581012096160497, Accuracy 0.3820040899795501
# Validation score improved. Saving model...
# Epoch [48/200]  | Train: Loss 2.43442493710438, Accuracy 0.39378136161447946        | Test: Loss 2.572775871325762, Accuracy 0.38282208588957056
# Validation score improved. Saving model...
# Epoch [49/200]  | Train: Loss 2.4242208257067803, Accuracy 0.3956219733987773       | Test: Loss 2.5817984617673435, Accuracy 0.37852760736196317
# EarlyStopping counter: 1 out of 5
# Epoch [50/200]  | Train: Loss 2.421767811535457, Accuracy 0.39549050112847034       | Test: Loss 2.580332236412244, Accuracy 0.38128834355828223
# EarlyStopping counter: 2 out of 5
# Epoch [51/200]  | Train: Loss 2.4131954515446497, Accuracy 0.39689287201174483      | Test: Loss 2.588099864812998, Accuracy 0.3825153374233129
# EarlyStopping counter: 3 out of 5
# Epoch [52/200]  | Train: Loss 2.4081579653244445, Accuracy 0.39790082608409844      | Test: Loss 2.578509251276652, Accuracy 0.38333333333333336
# Validation score improved. Saving model...
# Epoch [53/200]  | Train: Loss 2.402182946658001, Accuracy 0.3981199465346101        | Test: Loss 2.575737354082939, Accuracy 0.38732106339468303
# Validation score improved. Saving model...
# Epoch [54/200]  | Train: Loss 2.392195319330226, Accuracy 0.4003987992199312        | Test: Loss 2.5600634538210354, Accuracy 0.38445807770961143
# EarlyStopping counter: 1 out of 5
# Epoch [55/200]  | Train: Loss 2.389987628553167, Accuracy 0.40044262331003355       | Test: Loss 2.5811073718926845, Accuracy 0.3834355828220859
# EarlyStopping counter: 2 out of 5
# Epoch [56/200]  | Train: Loss 2.383012297433182, Accuracy 0.3994127571926288        | Test: Loss 2.572743324133066, Accuracy 0.38466257668711656
# EarlyStopping counter: 3 out of 5
# Epoch [57/200]  | Train: Loss 2.3735398780034243, Accuracy 0.4035979577974012       | Test: Loss 2.5599989218589587, Accuracy 0.3869120654396728
# EarlyStopping counter: 4 out of 5
# Epoch [58/200]  | Train: Loss 2.3714851067718845, Accuracy 0.4056796020772619       | Test: Loss 2.5761678218841553, Accuracy 0.3872188139059305
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
class_76_dataset = Combined_Dataset(sample_class76, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_76_dataset, batch_size=batch_size)

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(ft_model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")

sample_attentions_76_ft = sample_attentions.mean(0)

class_26_dataset = Combined_Dataset(sample_class26, cat_columns=[], num_columns=cont_columns, task1_column='class')

# Create a mini-dataloader
batch_size = 5  # Adjust batch size as needed
sample_dataloader = DataLoader(class_26_dataset, batch_size=batch_size)

# Evaluate the model on the mini-dataloader
loss_function = torch.nn.CrossEntropyLoss()  # Define your loss function

sample_loss, sample_accuracy, sample_attentions = evaluate(ft_model, sample_dataloader, loss_function, device_in_use)

print(f"Sample: Loss {sample_loss}, Accuracy {sample_accuracy}")

sample_attentions_26_ft = sample_attentions.mean(0)
# Out:
# Sample: Loss 2.6406641006469727, Accuracy 0.6
# Sample: Loss 3.7913451194763184, Accuracy 0.6

# %%
dist1 = sample_attentions_26
dist2 = sample_attentions_26_ft

# Creating feature indices for x-axis ticks (assuming 27 features)
features = np.arange(1, 28)

# Plotting bar plots for comparison
plt.figure(figsize=(12, 6))

# Offset for bar width
bar_width = 0.35
index = np.arange(len(features))

# Plotting bars for each class
plt.bar(index, dist1, bar_width, label='Class 26 CAT', alpha=0.8)
plt.bar(index + bar_width, dist2, bar_width, label='Class 26 ft', alpha=0.8)

plt.xlabel('Features')
plt.ylabel('Attention Scores')
plt.title('Comparison of Attention Scores for Corresponding Features')
plt.xticks(index + bar_width / 2, features)
plt.legend()
plt.tight_layout()
plt.show()
