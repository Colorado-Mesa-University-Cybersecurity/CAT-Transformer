# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import torch.nn
import os
import sys
import importlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
sys.path.append('../../model/')
from updatedModel import CATTransformer, train, test
import time

# Run regardless if you do or do not have GPU so all tensors are moved to right location later on
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")

df_train = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/train.csv')
df_test = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/test.csv')
df_val = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/validation.csv') #READ FROM RIGHT SPOT

# df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\train.csv')
# df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\test.csv')
# df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\validation.csv') #READ FROM RIGHT SPOT

#SET cat-columns TO NONE IF THERE ARE NO CATEGORICAL FEATURES
cat_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
cont_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
target = ['income']

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cat_columns + cont_columns + target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

cat_feat = [10,16,7,16,6,5,2,43]

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
print(target_classes)
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, cat_columns, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.float32).values

        self.cate = df[cat_columns].astype(np.int64).values
        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        cat_features = self.cate[idx]
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return cat_features, num_features, labels_task1

#Wrapping in Dataset
train_dataset = SingleTaskDataset(df_train, cat_columns, cont_columns, 'income')
val_dataset = SingleTaskDataset(df_val, cat_columns, cont_columns, 'income')
test_dataset = SingleTaskDataset(df_test, cat_columns, cont_columns, 'income')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
#Also try looking to see what other papers have done
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# GPU is available and being used
# [2]

# %%
model = CATTransformer(rff_on=True,
                       sigma=2,
                       embed_size=160,
                       heads=5,
                       forward_expansion=8,
                       pre_norm_on=False,
                       mlp_scale_classification=8,
                       embedding_dropout=0.1,
                       decoder_dropout=0,
                       classification_dropout=0.1,
                       targets_classes=target_classes,
                       n_cont=len(cont_columns),
                       cat_feat=cat_feat).to(device_in_use)
class UncertaintyLoss(nn.Module):
    def __init__(self, num_tasks):
        super(UncertaintyLoss, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions[0]
        loss_fn = self.loss_fns[0]

        task_loss = loss_fn(prediction, target)
        
        return task_loss
def format_metric(value): # Used to format the metrics output
    return f"{value:.5f}"

loss_functions = UncertaintyLoss(1)
optimizer = torch.optim.Adam(params=model.parameters(), lr = 0.0001) # Maybe try messing around with optimizers. try other torch optimizers with different configurations.
epochs = 100 #Set the number of epochs

train_losses = []
train_accuracies_1 = [] 
test_losses = []
test_accuracies_1 = [] 
test_f1_scores = [] 


#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Plotting the accuracy curves
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs+1), train_accuracies_1, label='Train Accuracy')
plt.plot(range(1, epochs+1), test_accuracies_1, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix for income")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.42940, Accuracy 0.79684                             | Test: Loss 0.35420, Accuracy 0.83781, F1 0.82510
# Epoch [ 2/100]       | Train: Loss 0.33113, Accuracy 0.84600                             | Test: Loss 0.32731, Accuracy 0.85032, F1 0.84330
# Epoch [ 3/100]       | Train: Loss 0.31977, Accuracy 0.85150                             | Test: Loss 0.31703, Accuracy 0.85305, F1 0.84257
# Epoch [ 4/100]       | Train: Loss 0.31124, Accuracy 0.85560                             | Test: Loss 0.33081, Accuracy 0.84406, F1 0.82239
# Epoch [ 5/100]       | Train: Loss 0.30814, Accuracy 0.85639                             | Test: Loss 0.32463, Accuracy 0.85316, F1 0.84051
# Epoch [ 6/100]       | Train: Loss 0.30278, Accuracy 0.85802                             | Test: Loss 0.31139, Accuracy 0.85930, F1 0.85166
# Epoch [ 7/100]       | Train: Loss 0.29828, Accuracy 0.86162                             | Test: Loss 0.32279, Accuracy 0.84713, F1 0.84957
# Epoch [ 8/100]       | Train: Loss 0.29817, Accuracy 0.86136                             | Test: Loss 0.31149, Accuracy 0.85316, F1 0.85355
# Epoch [ 9/100]       | Train: Loss 0.29585, Accuracy 0.86174                             | Test: Loss 0.30517, Accuracy 0.86135, F1 0.85815
# Epoch [10/100]       | Train: Loss 0.29379, Accuracy 0.86148                             | Test: Loss 0.30776, Accuracy 0.86021, F1 0.85640
# Epoch [11/100]       | Train: Loss 0.29264, Accuracy 0.86224                             | Test: Loss 0.30913, Accuracy 0.86033, F1 0.85765
# Epoch [12/100]       | Train: Loss 0.29113, Accuracy 0.86487                             | Test: Loss 0.30437, Accuracy 0.86237, F1 0.85471
# Epoch [13/100]       | Train: Loss 0.29146, Accuracy 0.86349                             | Test: Loss 0.30265, Accuracy 0.86192, F1 0.85737
# Epoch [14/100]       | Train: Loss 0.28932, Accuracy 0.86408                             | Test: Loss 0.30518, Accuracy 0.85965, F1 0.85800
# Epoch [15/100]       | Train: Loss 0.28873, Accuracy 0.86490                             | Test: Loss 0.30578, Accuracy 0.86215, F1 0.85457
# Epoch [16/100]       | Train: Loss 0.28743, Accuracy 0.86428                             | Test: Loss 0.30246, Accuracy 0.86237, F1 0.85710
# Epoch [17/100]       | Train: Loss 0.28783, Accuracy 0.86461                             | Test: Loss 0.30336, Accuracy 0.86146, F1 0.85825
# Epoch [18/100]       | Train: Loss 0.28605, Accuracy 0.86592                             | Test: Loss 0.31022, Accuracy 0.84975, F1 0.85240
# Epoch [19/100]       | Train: Loss 0.28463, Accuracy 0.86610                             | Test: Loss 0.29923, Accuracy 0.86454, F1 0.85939
# Epoch [20/100]       | Train: Loss 0.28285, Accuracy 0.86718                             | Test: Loss 0.30358, Accuracy 0.86408, F1 0.85990
# Epoch [21/100]       | Train: Loss 0.28344, Accuracy 0.86692                             | Test: Loss 0.30482, Accuracy 0.86033, F1 0.85810
# Epoch [22/100]       | Train: Loss 0.28134, Accuracy 0.86747                             | Test: Loss 0.30753, Accuracy 0.86044, F1 0.84837
# Epoch [23/100]       | Train: Loss 0.28186, Accuracy 0.86779                             | Test: Loss 0.30507, Accuracy 0.85862, F1 0.85805
# Epoch [24/100]       | Train: Loss 0.28021, Accuracy 0.86861                             | Test: Loss 0.30039, Accuracy 0.86374, F1 0.86036
# Epoch [25/100]       | Train: Loss 0.27901, Accuracy 0.87013                             | Test: Loss 0.29836, Accuracy 0.86454, F1 0.85603
# Epoch [26/100]       | Train: Loss 0.28006, Accuracy 0.86826                             | Test: Loss 0.30373, Accuracy 0.86101, F1 0.84819
# Epoch [27/100]       | Train: Loss 0.27932, Accuracy 0.86891                             | Test: Loss 0.29800, Accuracy 0.86681, F1 0.86293
# Epoch [28/100]       | Train: Loss 0.27788, Accuracy 0.87025                             | Test: Loss 0.29577, Accuracy 0.86374, F1 0.86108
# Epoch [29/100]       | Train: Loss 0.27623, Accuracy 0.87130                             | Test: Loss 0.29715, Accuracy 0.86510, F1 0.86184
# Epoch [30/100]       | Train: Loss 0.27588, Accuracy 0.87072                             | Test: Loss 0.29489, Accuracy 0.86545, F1 0.85764
# Epoch [31/100]       | Train: Loss 0.27565, Accuracy 0.87016                             | Test: Loss 0.29711, Accuracy 0.86442, F1 0.85765
# Epoch [32/100]       | Train: Loss 0.27488, Accuracy 0.87119                             | Test: Loss 0.29914, Accuracy 0.86442, F1 0.86109
# Epoch [33/100]       | Train: Loss 0.27288, Accuracy 0.87256                             | Test: Loss 0.29991, Accuracy 0.86192, F1 0.85185
# Epoch [34/100]       | Train: Loss 0.27508, Accuracy 0.87186                             | Test: Loss 0.29850, Accuracy 0.86237, F1 0.85163
# Epoch [35/100]       | Train: Loss 0.27277, Accuracy 0.87209                             | Test: Loss 0.29914, Accuracy 0.86385, F1 0.86108
# Epoch [36/100]       | Train: Loss 0.27157, Accuracy 0.87429                             | Test: Loss 0.29735, Accuracy 0.86397, F1 0.86097
# Epoch [37/100]       | Train: Loss 0.27276, Accuracy 0.87165                             | Test: Loss 0.29398, Accuracy 0.86624, F1 0.86236
# Epoch [38/100]       | Train: Loss 0.26935, Accuracy 0.87338                             | Test: Loss 0.30242, Accuracy 0.86397, F1 0.86068
# Epoch [39/100]       | Train: Loss 0.27062, Accuracy 0.87303                             | Test: Loss 0.29609, Accuracy 0.86647, F1 0.85830
# Epoch [40/100]       | Train: Loss 0.26889, Accuracy 0.87423                             | Test: Loss 0.29815, Accuracy 0.86567, F1 0.86129
# Epoch [41/100]       | Train: Loss 0.26879, Accuracy 0.87309                             | Test: Loss 0.29678, Accuracy 0.86567, F1 0.86262
# Epoch [42/100]       | Train: Loss 0.26754, Accuracy 0.87490                             | Test: Loss 0.29901, Accuracy 0.86704, F1 0.86042
# Epoch [43/100]       | Train: Loss 0.26725, Accuracy 0.87385                             | Test: Loss 0.29778, Accuracy 0.86636, F1 0.86136
# Epoch [44/100]       | Train: Loss 0.26610, Accuracy 0.87373                             | Test: Loss 0.29423, Accuracy 0.86294, F1 0.85164
# Epoch [45/100]       | Train: Loss 0.26617, Accuracy 0.87519                             | Test: Loss 0.29942, Accuracy 0.86146, F1 0.84789
# Epoch [46/100]       | Train: Loss 0.26520, Accuracy 0.87446                             | Test: Loss 0.30260, Accuracy 0.86294, F1 0.86291
# Epoch [47/100]       | Train: Loss 0.26516, Accuracy 0.87455                             | Test: Loss 0.29128, Accuracy 0.86715, F1 0.85906
# Epoch [48/100]       | Train: Loss 0.26364, Accuracy 0.87639                             | Test: Loss 0.29891, Accuracy 0.86476, F1 0.86203
# Epoch [49/100]       | Train: Loss 0.26288, Accuracy 0.87569                             | Test: Loss 0.29358, Accuracy 0.86704, F1 0.85975
# Epoch [50/100]       | Train: Loss 0.26239, Accuracy 0.87701                             | Test: Loss 0.29256, Accuracy 0.86260, F1 0.86157
# Epoch [51/100]       | Train: Loss 0.26188, Accuracy 0.87651                             | Test: Loss 0.29492, Accuracy 0.86647, F1 0.86126
# Epoch [52/100]       | Train: Loss 0.26101, Accuracy 0.87721                             | Test: Loss 0.29827, Accuracy 0.86658, F1 0.86010
# Epoch [53/100]       | Train: Loss 0.25961, Accuracy 0.87701                             | Test: Loss 0.29283, Accuracy 0.86533, F1 0.86175
# Epoch [54/100]       | Train: Loss 0.26157, Accuracy 0.87680                             | Test: Loss 0.29940, Accuracy 0.86727, F1 0.86268
# Epoch [55/100]       | Train: Loss 0.25936, Accuracy 0.87733                             | Test: Loss 0.29314, Accuracy 0.86727, F1 0.86124
# Epoch [56/100]       | Train: Loss 0.25661, Accuracy 0.87905                             | Test: Loss 0.29930, Accuracy 0.86761, F1 0.85991
# Epoch [57/100]       | Train: Loss 0.25654, Accuracy 0.87824                             | Test: Loss 0.29876, Accuracy 0.86499, F1 0.86214
# Epoch [58/100]       | Train: Loss 0.25669, Accuracy 0.87853                             | Test: Loss 0.29544, Accuracy 0.86283, F1 0.86213
# Epoch [59/100]       | Train: Loss 0.25569, Accuracy 0.87996                             | Test: Loss 0.29629, Accuracy 0.86727, F1 0.86315
# Epoch [60/100]       | Train: Loss 0.25418, Accuracy 0.87984                             | Test: Loss 0.30865, Accuracy 0.86351, F1 0.86256
# Epoch [61/100]       | Train: Loss 0.25379, Accuracy 0.88011                             | Test: Loss 0.29927, Accuracy 0.86613, F1 0.86462
# Epoch [62/100]       | Train: Loss 0.25245, Accuracy 0.88119                             | Test: Loss 0.30190, Accuracy 0.86704, F1 0.86267
# Epoch [63/100]       | Train: Loss 0.25112, Accuracy 0.88125                             | Test: Loss 0.30705, Accuracy 0.86613, F1 0.86005
# Epoch [64/100]       | Train: Loss 0.24949, Accuracy 0.88213                             | Test: Loss 0.31537, Accuracy 0.86522, F1 0.86027
# Epoch [65/100]       | Train: Loss 0.25094, Accuracy 0.88084                             | Test: Loss 0.31432, Accuracy 0.86317, F1 0.86041
# Epoch [66/100]       | Train: Loss 0.24696, Accuracy 0.88391                             | Test: Loss 0.29849, Accuracy 0.86556, F1 0.86166
# Epoch [67/100]       | Train: Loss 0.24683, Accuracy 0.88435                             | Test: Loss 0.32212, Accuracy 0.85908, F1 0.85902
# Epoch [68/100]       | Train: Loss 0.24888, Accuracy 0.88242                             | Test: Loss 0.31416, Accuracy 0.86431, F1 0.85852
# Epoch [69/100]       | Train: Loss 0.24505, Accuracy 0.88368                             | Test: Loss 0.31046, Accuracy 0.86454, F1 0.85753
# Epoch [70/100]       | Train: Loss 0.24395, Accuracy 0.88493                             | Test: Loss 0.30696, Accuracy 0.86545, F1 0.85992
# Epoch [71/100]       | Train: Loss 0.24124, Accuracy 0.88607                             | Test: Loss 0.31729, Accuracy 0.86647, F1 0.86295
# Epoch [72/100]       | Train: Loss 0.23959, Accuracy 0.88751                             | Test: Loss 0.31088, Accuracy 0.86397, F1 0.85827
# Epoch [73/100]       | Train: Loss 0.23964, Accuracy 0.88660                             | Test: Loss 0.31173, Accuracy 0.86328, F1 0.85971
# Epoch [74/100]       | Train: Loss 0.23658, Accuracy 0.88806                             | Test: Loss 0.32090, Accuracy 0.86306, F1 0.85837
# Epoch [75/100]       | Train: Loss 0.23386, Accuracy 0.88979                             | Test: Loss 0.32212, Accuracy 0.86078, F1 0.85872
# Epoch [76/100]       | Train: Loss 0.23289, Accuracy 0.89064                             | Test: Loss 0.32671, Accuracy 0.86465, F1 0.86019
# Epoch [77/100]       | Train: Loss 0.23161, Accuracy 0.89096                             | Test: Loss 0.33027, Accuracy 0.86488, F1 0.86090
# Epoch [78/100]       | Train: Loss 0.22861, Accuracy 0.89075                             | Test: Loss 0.35095, Accuracy 0.86328, F1 0.85786
# Epoch [79/100]       | Train: Loss 0.22647, Accuracy 0.89266                             | Test: Loss 0.33769, Accuracy 0.86306, F1 0.85846
# Epoch [80/100]       | Train: Loss 0.22378, Accuracy 0.89418                             | Test: Loss 0.35888, Accuracy 0.86101, F1 0.85583
# Epoch [81/100]       | Train: Loss 0.22244, Accuracy 0.89432                             | Test: Loss 0.34334, Accuracy 0.86056, F1 0.85841
# Epoch [82/100]       | Train: Loss 0.21944, Accuracy 0.89637                             | Test: Loss 0.33906, Accuracy 0.85999, F1 0.85737
# Epoch [83/100]       | Train: Loss 0.21656, Accuracy 0.89859                             | Test: Loss 0.33558, Accuracy 0.85987, F1 0.85700
# Epoch [84/100]       | Train: Loss 0.21348, Accuracy 0.89970                             | Test: Loss 0.34535, Accuracy 0.85999, F1 0.85602
# Epoch [85/100]       | Train: Loss 0.21199, Accuracy 0.90064                             | Test: Loss 0.36816, Accuracy 0.85885, F1 0.85497
# Epoch [86/100]       | Train: Loss 0.20694, Accuracy 0.90067                             | Test: Loss 0.37431, Accuracy 0.85111, F1 0.84859
# Epoch [87/100]       | Train: Loss 0.20345, Accuracy 0.90476                             | Test: Loss 0.37761, Accuracy 0.85407, F1 0.85154
# Epoch [88/100]       | Train: Loss 0.20313, Accuracy 0.90617                             | Test: Loss 0.37298, Accuracy 0.84759, F1 0.84764
# Epoch [89/100]       | Train: Loss 0.19437, Accuracy 0.90930                             | Test: Loss 0.39210, Accuracy 0.85635, F1 0.85454
# Epoch [90/100]       | Train: Loss 0.19315, Accuracy 0.91099                             | Test: Loss 0.42164, Accuracy 0.85555, F1 0.85311
# Epoch [91/100]       | Train: Loss 0.18876, Accuracy 0.91287                             | Test: Loss 0.42670, Accuracy 0.84998, F1 0.84852
# Epoch [92/100]       | Train: Loss 0.18461, Accuracy 0.91486                             | Test: Loss 0.46094, Accuracy 0.85214, F1 0.85043
# Epoch [93/100]       | Train: Loss 0.18118, Accuracy 0.91632                             | Test: Loss 0.43600, Accuracy 0.85293, F1 0.85285
# Epoch [94/100]       | Train: Loss 0.17520, Accuracy 0.91992                             | Test: Loss 0.44241, Accuracy 0.85282, F1 0.85143
# Epoch [95/100]       | Train: Loss 0.17109, Accuracy 0.92076                             | Test: Loss 0.47639, Accuracy 0.85373, F1 0.85183
# Epoch [96/100]       | Train: Loss 0.16647, Accuracy 0.92334                             | Test: Loss 0.47080, Accuracy 0.84782, F1 0.84678
# Epoch [97/100]       | Train: Loss 0.16029, Accuracy 0.92579                             | Test: Loss 0.48054, Accuracy 0.85168, F1 0.85095
# Epoch [98/100]       | Train: Loss 0.15645, Accuracy 0.92895                             | Test: Loss 0.50119, Accuracy 0.84759, F1 0.84536
# Epoch [99/100]       | Train: Loss 0.15191, Accuracy 0.93162                             | Test: Loss 0.49395, Accuracy 0.85157, F1 0.84767
# Epoch [100/100]      | Train: Loss 0.14596, Accuracy 0.93483                             | Test: Loss 0.55457, Accuracy 0.84020, F1 0.84173
# Confusion Matrix for income
# [[5912  765]
#  [ 640 1475]]
# Best accuracy 0.867606915377616
# Best F1 0.8599091933398149
# 100 epochs of training and evaluation took, 263.761627866
