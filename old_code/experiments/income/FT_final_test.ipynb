# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os
import optuna
from optuna.trial import TrialState
from tab_transformer_pytorch import FTTransformer
import time

# %%
# Run regardless if you do or do not have GPU so all tensors are moved to right location later on
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")
# Out:
# GPU is available and being used

# %% [markdown]
# # LOAD AND PROCESS DATA
# **EXAMPLE WITH Income**

# %%
df_train = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/train.csv')
df_test = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/test.csv')
df_val = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/income/validation.csv') #READ FROM RIGHT SPOT

# df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\train.csv')
# df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\test.csv')
# df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\income\validation.csv') #READ FROM RIGHT SPOT

#Take a look at what the datasets look like initially to get an idea
df_train.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
cont_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
       'hours-per-week']
cat_columns = ['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'race', 'sex', 'native-country']
target = ['income']

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cont_columns + cat_columns+target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

# %%
#Get class counts and store in a list below

for x in cat_columns:
    print(max(len(df_train[x].value_counts()), len(df_val[x].value_counts()), len(df_test[x].value_counts())))
# Out:
# 10
# 16
# 7
# 16
# 6
# 5
# 2
# 43

# %%
# Manually enter class counts in the same order
cat_features = (10,16,7,16,6,5,2,43)

# %%
#Getting the number of classes in your classification target
target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
target_classes = target_classes[0]

# %%
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

# %%
class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, cat_columns, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.float32).values

        self.cate = df[cat_columns].astype(np.int64).values
        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        cat_features = self.cate[idx]
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return cat_features, num_features, labels_task1

#Wrapping in Dataset
train_dataset = SingleTaskDataset(df_train, cat_columns, cont_columns, 'income')
val_dataset = SingleTaskDataset(df_val, cat_columns, cont_columns, 'income')
test_dataset = SingleTaskDataset(df_test, cat_columns, cont_columns, 'income')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
#Also try looking to see what other papers have done
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
# each task loss is scaled by its own learnable parameter, then regularization is applied 
class LossFunctions(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunctions, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions
        loss_fn = self.loss_fns[0]
        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
# Training and Testing Loops
def train(dataloader, model, loss_function, optimizer, device_in_use):
    model.train()

    total_loss = 0
    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    for (categorical, numerical, labels_task1) in dataloader:
        categorical, numerical, labels_task1 = categorical.to(device_in_use), numerical.to(device_in_use), labels_task1.to(device_in_use)
        
        #running them through model and modifying the shape slightly for the loss function
        task_predictions = model(categorical, numerical)
        task_predictions = task_predictions.squeeze(1)
        
        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()
        
        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions, dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())


        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1

    return avg_loss, accuracy_1

def test(dataloader, model, loss_function, device_in_use):
    model.eval()
    total_loss = 0
    
    total_loss = 0
    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    with torch.no_grad():
        for (categorical, numerical, labels_task1) in dataloader:
            categorical, numerical, labels_task1 = categorical.to(device_in_use), numerical.to(device_in_use), labels_task1.to(device_in_use)
            
            #running them through model and modifying the shape slightly for the loss function
            task_predictions = model(categorical, numerical)
            task_predictions = task_predictions.squeeze(1)
            loss = loss_function(task_predictions, labels_task1)
            total_loss += loss.item()
            
            #computing accuracy for first target
            y_pred_softmax_1 = torch.softmax(task_predictions, dim=1)
            _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
            total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
            total_samples_1 += labels_task1.size(0)
            all_targets_1.extend(labels_task1.cpu().numpy())
            all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

    avg = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    f1_1 = f1_score(all_targets_1, all_predictions_1, average='weighted')

    return avg, accuracy_1, all_predictions_1, all_targets_1, f1_1

def format_metric(value): # Used to format the metrics output
    return f"{value:.4f}"

# %%
#Testing against the test dataset
model = FTTransformer(categories=cat_features,
                          num_continuous=len(cont_columns),
                          dim=192,
                          depth=3,
                          heads=8,
                          dim_out=target_classes,
                          attn_dropout=0.2,
                          ff_dropout=0.1).to(device_in_use)
loss_functions = LossFunctions(1)
optimizer = torch.optim.AdamW(params=model.parameters(), lr = 0.0001, weight_decay=0.00001)
epochs = 100

train_losses = []
train_accuracies_1 = [] 

test_losses = []
test_accuracies_1 = []
  
test_f1_scores = [] 
all_attention_scores = []

#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 1, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.4209, Accuracy 0.7942                               | Test: Loss 0.3209, Accuracy 0.8536, F1 0.8473
# Epoch [ 2/100]       | Train: Loss 0.3145, Accuracy 0.8547                               | Test: Loss 0.3121, Accuracy 0.8584, F1 0.8529
# Epoch [ 3/100]       | Train: Loss 0.3079, Accuracy 0.8569                               | Test: Loss 0.3128, Accuracy 0.8563, F1 0.8494
# Epoch [ 4/100]       | Train: Loss 0.3050, Accuracy 0.8571                               | Test: Loss 0.3075, Accuracy 0.8561, F1 0.8494
# Epoch [ 5/100]       | Train: Loss 0.3033, Accuracy 0.8586                               | Test: Loss 0.3085, Accuracy 0.8558, F1 0.8467
# Epoch [ 6/100]       | Train: Loss 0.3030, Accuracy 0.8579                               | Test: Loss 0.3069, Accuracy 0.8603, F1 0.8560
# Epoch [ 7/100]       | Train: Loss 0.3009, Accuracy 0.8592                               | Test: Loss 0.3157, Accuracy 0.8559, F1 0.8448
# Epoch [ 8/100]       | Train: Loss 0.3000, Accuracy 0.8598                               | Test: Loss 0.3093, Accuracy 0.8571, F1 0.8551
# Epoch [ 9/100]       | Train: Loss 0.2980, Accuracy 0.8600                               | Test: Loss 0.3064, Accuracy 0.8582, F1 0.8528
# Epoch [10/100]       | Train: Loss 0.2978, Accuracy 0.8623                               | Test: Loss 0.3083, Accuracy 0.8584, F1 0.8525
# Epoch [11/100]       | Train: Loss 0.2963, Accuracy 0.8600                               | Test: Loss 0.3077, Accuracy 0.8584, F1 0.8554
# Epoch [12/100]       | Train: Loss 0.2967, Accuracy 0.8622                               | Test: Loss 0.3113, Accuracy 0.8586, F1 0.8580
# Epoch [13/100]       | Train: Loss 0.2951, Accuracy 0.8624                               | Test: Loss 0.3076, Accuracy 0.8595, F1 0.8544
# Epoch [14/100]       | Train: Loss 0.2942, Accuracy 0.8627                               | Test: Loss 0.3087, Accuracy 0.8600, F1 0.8526
# Epoch [15/100]       | Train: Loss 0.2938, Accuracy 0.8618                               | Test: Loss 0.3049, Accuracy 0.8600, F1 0.8535
# Epoch [16/100]       | Train: Loss 0.2928, Accuracy 0.8619                               | Test: Loss 0.3054, Accuracy 0.8602, F1 0.8562
# Epoch [17/100]       | Train: Loss 0.2928, Accuracy 0.8625                               | Test: Loss 0.3070, Accuracy 0.8601, F1 0.8539
# Epoch [18/100]       | Train: Loss 0.2922, Accuracy 0.8621                               | Test: Loss 0.3066, Accuracy 0.8591, F1 0.8558
# Epoch [19/100]       | Train: Loss 0.2908, Accuracy 0.8644                               | Test: Loss 0.3070, Accuracy 0.8595, F1 0.8537
# Epoch [20/100]       | Train: Loss 0.2912, Accuracy 0.8624                               | Test: Loss 0.3107, Accuracy 0.8574, F1 0.8563
# Epoch [21/100]       | Train: Loss 0.2891, Accuracy 0.8640                               | Test: Loss 0.3079, Accuracy 0.8602, F1 0.8529
# Epoch [22/100]       | Train: Loss 0.2890, Accuracy 0.8639                               | Test: Loss 0.3095, Accuracy 0.8592, F1 0.8560
# Epoch [23/100]       | Train: Loss 0.2871, Accuracy 0.8651                               | Test: Loss 0.3112, Accuracy 0.8586, F1 0.8502
# Epoch [24/100]       | Train: Loss 0.2868, Accuracy 0.8649                               | Test: Loss 0.3136, Accuracy 0.8590, F1 0.8497
# Epoch [25/100]       | Train: Loss 0.2852, Accuracy 0.8655                               | Test: Loss 0.3120, Accuracy 0.8618, F1 0.8564
# Epoch [26/100]       | Train: Loss 0.2850, Accuracy 0.8652                               | Test: Loss 0.3136, Accuracy 0.8616, F1 0.8552
# Epoch [27/100]       | Train: Loss 0.2841, Accuracy 0.8665                               | Test: Loss 0.3110, Accuracy 0.8601, F1 0.8560
# Epoch [28/100]       | Train: Loss 0.2818, Accuracy 0.8663                               | Test: Loss 0.3135, Accuracy 0.8585, F1 0.8540
# Epoch [29/100]       | Train: Loss 0.2818, Accuracy 0.8671                               | Test: Loss 0.3109, Accuracy 0.8585, F1 0.8521
# Epoch [30/100]       | Train: Loss 0.2791, Accuracy 0.8681                               | Test: Loss 0.3140, Accuracy 0.8578, F1 0.8545
# Epoch [31/100]       | Train: Loss 0.2792, Accuracy 0.8676                               | Test: Loss 0.3164, Accuracy 0.8606, F1 0.8553
# Epoch [32/100]       | Train: Loss 0.2778, Accuracy 0.8683                               | Test: Loss 0.3156, Accuracy 0.8606, F1 0.8532
# Epoch [33/100]       | Train: Loss 0.2759, Accuracy 0.8695                               | Test: Loss 0.3131, Accuracy 0.8574, F1 0.8553
# Epoch [34/100]       | Train: Loss 0.2747, Accuracy 0.8698                               | Test: Loss 0.3151, Accuracy 0.8599, F1 0.8534
# Epoch [35/100]       | Train: Loss 0.2730, Accuracy 0.8704                               | Test: Loss 0.3212, Accuracy 0.8586, F1 0.8530
# Epoch [36/100]       | Train: Loss 0.2716, Accuracy 0.8704                               | Test: Loss 0.3185, Accuracy 0.8594, F1 0.8553
# Epoch [37/100]       | Train: Loss 0.2685, Accuracy 0.8708                               | Test: Loss 0.3235, Accuracy 0.8581, F1 0.8533
# Epoch [38/100]       | Train: Loss 0.2674, Accuracy 0.8737                               | Test: Loss 0.3268, Accuracy 0.8585, F1 0.8520
# Epoch [39/100]       | Train: Loss 0.2657, Accuracy 0.8729                               | Test: Loss 0.3285, Accuracy 0.8563, F1 0.8528
# Epoch [40/100]       | Train: Loss 0.2641, Accuracy 0.8733                               | Test: Loss 0.3253, Accuracy 0.8546, F1 0.8504
# Epoch [41/100]       | Train: Loss 0.2616, Accuracy 0.8741                               | Test: Loss 0.3324, Accuracy 0.8497, F1 0.8498
# Epoch [42/100]       | Train: Loss 0.2579, Accuracy 0.8776                               | Test: Loss 0.3284, Accuracy 0.8541, F1 0.8489
# Epoch [43/100]       | Train: Loss 0.2552, Accuracy 0.8790                               | Test: Loss 0.3422, Accuracy 0.8544, F1 0.8487
# Epoch [44/100]       | Train: Loss 0.2536, Accuracy 0.8792                               | Test: Loss 0.3390, Accuracy 0.8515, F1 0.8488
# Epoch [45/100]       | Train: Loss 0.2519, Accuracy 0.8803                               | Test: Loss 0.3434, Accuracy 0.8512, F1 0.8472
# Epoch [46/100]       | Train: Loss 0.2494, Accuracy 0.8813                               | Test: Loss 0.3426, Accuracy 0.8526, F1 0.8480
# Epoch [47/100]       | Train: Loss 0.2466, Accuracy 0.8835                               | Test: Loss 0.3496, Accuracy 0.8507, F1 0.8453
# Epoch [48/100]       | Train: Loss 0.2444, Accuracy 0.8812                               | Test: Loss 0.3507, Accuracy 0.8499, F1 0.8457
# Epoch [49/100]       | Train: Loss 0.2414, Accuracy 0.8861                               | Test: Loss 0.3495, Accuracy 0.8535, F1 0.8470
# Epoch [50/100]       | Train: Loss 0.2372, Accuracy 0.8883                               | Test: Loss 0.3612, Accuracy 0.8499, F1 0.8467
# Epoch [51/100]       | Train: Loss 0.2355, Accuracy 0.8886                               | Test: Loss 0.3654, Accuracy 0.8460, F1 0.8425
# Epoch [52/100]       | Train: Loss 0.2305, Accuracy 0.8902                               | Test: Loss 0.3705, Accuracy 0.8496, F1 0.8444
# Epoch [53/100]       | Train: Loss 0.2296, Accuracy 0.8922                               | Test: Loss 0.3692, Accuracy 0.8480, F1 0.8433
# Epoch [54/100]       | Train: Loss 0.2252, Accuracy 0.8922                               | Test: Loss 0.3817, Accuracy 0.8490, F1 0.8455
# Epoch [55/100]       | Train: Loss 0.2223, Accuracy 0.8946                               | Test: Loss 0.3833, Accuracy 0.8402, F1 0.8380
# Epoch [56/100]       | Train: Loss 0.2211, Accuracy 0.8949                               | Test: Loss 0.3971, Accuracy 0.8463, F1 0.8425
# Epoch [57/100]       | Train: Loss 0.2187, Accuracy 0.8961                               | Test: Loss 0.3912, Accuracy 0.8405, F1 0.8388
# Epoch [58/100]       | Train: Loss 0.2161, Accuracy 0.8980                               | Test: Loss 0.4099, Accuracy 0.8461, F1 0.8433
# Epoch [59/100]       | Train: Loss 0.2137, Accuracy 0.8990                               | Test: Loss 0.4020, Accuracy 0.8381, F1 0.8354
# Epoch [60/100]       | Train: Loss 0.2092, Accuracy 0.9008                               | Test: Loss 0.4145, Accuracy 0.8400, F1 0.8389
# Epoch [61/100]       | Train: Loss 0.2073, Accuracy 0.9017                               | Test: Loss 0.4165, Accuracy 0.8428, F1 0.8343
# Epoch [62/100]       | Train: Loss 0.2069, Accuracy 0.9032                               | Test: Loss 0.4150, Accuracy 0.8408, F1 0.8372
# Epoch [63/100]       | Train: Loss 0.1998, Accuracy 0.9055                               | Test: Loss 0.4242, Accuracy 0.8389, F1 0.8366
# Epoch [64/100]       | Train: Loss 0.1963, Accuracy 0.9069                               | Test: Loss 0.4361, Accuracy 0.8401, F1 0.8362
# Epoch [65/100]       | Train: Loss 0.1966, Accuracy 0.9075                               | Test: Loss 0.4323, Accuracy 0.8345, F1 0.8318
# Epoch [66/100]       | Train: Loss 0.1964, Accuracy 0.9076                               | Test: Loss 0.4352, Accuracy 0.8388, F1 0.8370
# Epoch [67/100]       | Train: Loss 0.1901, Accuracy 0.9113                               | Test: Loss 0.4532, Accuracy 0.8347, F1 0.8328
# Epoch [68/100]       | Train: Loss 0.1897, Accuracy 0.9105                               | Test: Loss 0.4578, Accuracy 0.8392, F1 0.8369
# Epoch [69/100]       | Train: Loss 0.1878, Accuracy 0.9125                               | Test: Loss 0.4625, Accuracy 0.8366, F1 0.8328
# Epoch [70/100]       | Train: Loss 0.1858, Accuracy 0.9115                               | Test: Loss 0.4570, Accuracy 0.8369, F1 0.8360
# Epoch [71/100]       | Train: Loss 0.1833, Accuracy 0.9144                               | Test: Loss 0.4679, Accuracy 0.8368, F1 0.8328
# Epoch [72/100]       | Train: Loss 0.1815, Accuracy 0.9145                               | Test: Loss 0.4716, Accuracy 0.8363, F1 0.8344
# Epoch [73/100]       | Train: Loss 0.1813, Accuracy 0.9141                               | Test: Loss 0.4675, Accuracy 0.8334, F1 0.8317
# Epoch [74/100]       | Train: Loss 0.1796, Accuracy 0.9153                               | Test: Loss 0.4774, Accuracy 0.8339, F1 0.8321
# Epoch [75/100]       | Train: Loss 0.1773, Accuracy 0.9165                               | Test: Loss 0.4800, Accuracy 0.8350, F1 0.8331
# Epoch [76/100]       | Train: Loss 0.1753, Accuracy 0.9187                               | Test: Loss 0.5034, Accuracy 0.8370, F1 0.8338
# Epoch [77/100]       | Train: Loss 0.1725, Accuracy 0.9184                               | Test: Loss 0.4982, Accuracy 0.8343, F1 0.8300
# Epoch [78/100]       | Train: Loss 0.1721, Accuracy 0.9186                               | Test: Loss 0.4997, Accuracy 0.8375, F1 0.8355
# Epoch [79/100]       | Train: Loss 0.1677, Accuracy 0.9210                               | Test: Loss 0.5018, Accuracy 0.8336, F1 0.8327
# Epoch [80/100]       | Train: Loss 0.1642, Accuracy 0.9246                               | Test: Loss 0.5085, Accuracy 0.8330, F1 0.8308
# Epoch [81/100]       | Train: Loss 0.1643, Accuracy 0.9235                               | Test: Loss 0.5335, Accuracy 0.8359, F1 0.8327
# Epoch [82/100]       | Train: Loss 0.1646, Accuracy 0.9237                               | Test: Loss 0.5312, Accuracy 0.8338, F1 0.8313
# Epoch [83/100]       | Train: Loss 0.1635, Accuracy 0.9225                               | Test: Loss 0.5092, Accuracy 0.8336, F1 0.8320
# Epoch [84/100]       | Train: Loss 0.1623, Accuracy 0.9226                               | Test: Loss 0.5168, Accuracy 0.8331, F1 0.8313
# Epoch [85/100]       | Train: Loss 0.1589, Accuracy 0.9266                               | Test: Loss 0.5280, Accuracy 0.8325, F1 0.8287
# Epoch [86/100]       | Train: Loss 0.1592, Accuracy 0.9261                               | Test: Loss 0.5350, Accuracy 0.8335, F1 0.8326
# Epoch [87/100]       | Train: Loss 0.1550, Accuracy 0.9269                               | Test: Loss 0.5459, Accuracy 0.8308, F1 0.8300
# Epoch [88/100]       | Train: Loss 0.1561, Accuracy 0.9271                               | Test: Loss 0.5488, Accuracy 0.8323, F1 0.8303
# Epoch [89/100]       | Train: Loss 0.1547, Accuracy 0.9281                               | Test: Loss 0.5561, Accuracy 0.8238, F1 0.8227
# Epoch [90/100]       | Train: Loss 0.1515, Accuracy 0.9310                               | Test: Loss 0.5650, Accuracy 0.8316, F1 0.8303
# Epoch [91/100]       | Train: Loss 0.1511, Accuracy 0.9286                               | Test: Loss 0.5646, Accuracy 0.8320, F1 0.8295
# Epoch [92/100]       | Train: Loss 0.1505, Accuracy 0.9294                               | Test: Loss 0.5711, Accuracy 0.8267, F1 0.8251
# Epoch [93/100]       | Train: Loss 0.1482, Accuracy 0.9299                               | Test: Loss 0.5586, Accuracy 0.8285, F1 0.8268
# Epoch [94/100]       | Train: Loss 0.1472, Accuracy 0.9306                               | Test: Loss 0.5714, Accuracy 0.8286, F1 0.8253
# Epoch [95/100]       | Train: Loss 0.1473, Accuracy 0.9313                               | Test: Loss 0.5770, Accuracy 0.8269, F1 0.8257
# Epoch [96/100]       | Train: Loss 0.1433, Accuracy 0.9337                               | Test: Loss 0.6009, Accuracy 0.8331, F1 0.8300
# Epoch [97/100]       | Train: Loss 0.1427, Accuracy 0.9326                               | Test: Loss 0.6025, Accuracy 0.8250, F1 0.8247
# Epoch [98/100]       | Train: Loss 0.1420, Accuracy 0.9348                               | Test: Loss 0.5918, Accuracy 0.8267, F1 0.8249
# Epoch [99/100]       | Train: Loss 0.1414, Accuracy 0.9338                               | Test: Loss 0.5942, Accuracy 0.8320, F1 0.8304
# Epoch [100/100]      | Train: Loss 0.1382, Accuracy 0.9358                               | Test: Loss 0.6002, Accuracy 0.8248, F1 0.8234
# Confusion Matrix
# [[5957  720]
#  [ 820 1295]]
# Best accuracy 0.8618061874431301
# Best F1 0.8564331111710518
# 100 epochs of training and evaluation took, 306.870079303
