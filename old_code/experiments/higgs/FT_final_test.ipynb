# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from rff.layers import GaussianEncoding #pip install random-fourier-features-pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os
import optuna
from optuna.trial import TrialState
from tab_transformer_pytorch import FTTransformer
import time

# %%
# Run regardless if you do or do not have GPU so all tensors are moved to right location later on
if torch.cuda.is_available():
    device_in_use = torch.device("cuda")
    print("GPU is available and being used")
else:
    device_in_use = torch.device("cpu")
    print("GPU is not available, using CPU instead")
# Out:
# GPU is not available, using CPU instead

# %% [markdown]
# # LOAD AND PROCESS DATA
# **EXAMPLE WITH Income**

# %%
df_train = pd.read_csv('../../datasets/higgs/train.csv')
df_test = pd.read_csv('../../datasets/higgs/test.csv')
df_val = pd.read_csv('../../datasets/higgs/validation.csv') #READ FROM RIGHT SPOT

# %%
def categorize_columns(dataframe, target):
    categorical_columns = []
    continuous_columns = []
    unique_classes_per_column = []  # To hold the number of unique classes for each categorical column

    for column in dataframe.columns:
        if dataframe[column].dtype == 'object' or len(dataframe[column].unique()) <= 10:
            # If the column's data type is 'object' or it has 10 or fewer unique values, consider it categorical.
            if column != target:
                categorical_columns.append(column)
                unique_classes_per_column.append(dataframe[column].nunique())  # Store the number of unique classes
        else:
            # Otherwise, consider it continuous.
            continuous_columns.append(column)

    return categorical_columns, continuous_columns, unique_classes_per_column

# %%
target = 'class'
cat_columns, cont_columns, unique_classes_per_column = categorize_columns(df_train, target)

if target in cont_columns:
    cont_columns.remove(target)
elif target in cat_columns:
    print("in here")
    cat_columns.remove(target)

print("Target:", target)
print("Categorical: ", cat_columns)
print("Continous: ", cont_columns)
print("Unique Classes per Column: ", unique_classes_per_column)

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cat_columns + cont_columns + [target]
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
print(target_classes)
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

# label encode target...
le = LabelEncoder()
df_train[target] = le.fit_transform(df_train[target])
df_test[target] = le.fit_transform(df_test[target])
df_val[target] = le.fit_transform(df_val[target])

#label encode cat features
for feature in cat_columns:
    df_train[feature] = le.fit_transform(df_train[feature])
    df_test[feature] = le.fit_transform(df_test[feature])
    df_val[feature] = le.fit_transform(df_val[feature])

print(df_train['jet1b-tag'].value_counts())

class SingleTaskDataset(Dataset):
    def __init__(self, df : pd.DataFrame, cat_columns, num_columns,task1_column):
        self.n = df.shape[0]
        
        self.task1_labels = df[task1_column].astype(np.float32).values

        self.cate = df[cat_columns].astype(np.int64).values
        self.num = df[num_columns].astype(np.float32).values


    def __len__(self):
        return self.n
    
    def __getitem__(self, idx):
        # Retrieve features and labels from the dataframe using column names
        cat_features = self.cate[idx]
        num_features = self.num[idx]
        labels_task1 = self.task1_labels[idx]

        return cat_features, num_features, labels_task1

#Wrapping in Dataset
train_dataset = SingleTaskDataset(df_train, cat_columns, cont_columns, 'class')
val_dataset = SingleTaskDataset(df_val, cat_columns, cont_columns, 'class')
test_dataset = SingleTaskDataset(df_test, cat_columns, cont_columns, 'class')

#This is a hyperparameter that is not tuned. Maybe mess with what makes sense here
#Also try looking to see what other papers have done
batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Target: class
# Categorical:  ['jet1b-tag', 'jet2b-tag', 'jet3b-tag', 'jet4b-tag']
# Continous:  ['lepton_pT', 'lepton_eta', 'lepton_phi', 'missing_energy_magnitude', 'missing_energy_phi', 'jet1pt', 'jet1eta', 'jet1phi', 'jet2pt', 'jet2eta', 'jet2phi', 'jet3pt', 'jet3eta', 'jet3phi', 'jet4pt', 'jet4eta', 'jet4phi', 'm_jj', 'm_jjj', 'm_lv', 'm_jlv', 'm_bb', 'm_wbb', 'm_wwbb']
# Unique Classes per Column:  [3, 3, 3, 3]
# [2]
# jet1b-tag
# 0    33704
# 2    28139
# 1     6791
# Name: count, dtype: int64

# %%
# each task loss is scaled by its own learnable parameter, then regularization is applied 
class LossFunctions(nn.Module):
    def __init__(self, num_tasks):
        super(LossFunctions, self).__init__()
        self.num_tasks = num_tasks

        self.loss_fns = [nn.CrossEntropyLoss() for x in range(num_tasks)] 

    def forward(self, predictions, labels_task1):

        #task 1
        target = labels_task1.long()
        prediction = predictions
        loss_fn = self.loss_fns[0]
        task_loss = loss_fn(prediction, target)
        
        return task_loss
    
# Training and Testing Loops
def train(dataloader, model, loss_function, optimizer, device_in_use):
    model.train()

    total_loss = 0
    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    for (categorical, numerical, labels_task1) in dataloader:
        categorical, numerical, labels_task1 = categorical.to(device_in_use), numerical.to(device_in_use), labels_task1.to(device_in_use)
        
        #running them through model and modifying the shape slightly for the loss function
        task_predictions = model(categorical, numerical)
        task_predictions = task_predictions.squeeze(1)
        
        loss = loss_function(task_predictions, labels_task1)
        total_loss += loss.item()
        
        #computing accuracy for first target
        y_pred_softmax_1 = torch.softmax(task_predictions, dim=1)
        _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
        total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
        total_samples_1 += labels_task1.size(0)
        all_targets_1.extend(labels_task1.cpu().numpy())
        all_predictions_1.extend(y_pred_labels_1.cpu().numpy())


        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    avg_loss = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1

    return avg_loss, accuracy_1

def test(dataloader, model, loss_function, device_in_use):
    model.eval()
    total_loss = 0
    
    total_loss = 0
    total_correct_1 = 0
    total_samples_1 = 0
    all_targets_1 = []
    all_predictions_1 = []

    with torch.no_grad():
        for (categorical, numerical, labels_task1) in dataloader:
            categorical, numerical, labels_task1 = categorical.to(device_in_use), numerical.to(device_in_use), labels_task1.to(device_in_use)
            
            #running them through model and modifying the shape slightly for the loss function
            task_predictions = model(categorical, numerical)
            task_predictions = task_predictions.squeeze(1)
            loss = loss_function(task_predictions, labels_task1)
            total_loss += loss.item()
            
            #computing accuracy for first target
            y_pred_softmax_1 = torch.softmax(task_predictions, dim=1)
            _, y_pred_labels_1 = torch.max(y_pred_softmax_1, dim=1)
            total_correct_1 += (y_pred_labels_1 == labels_task1).sum().item()
            total_samples_1 += labels_task1.size(0)
            all_targets_1.extend(labels_task1.cpu().numpy())
            all_predictions_1.extend(y_pred_labels_1.cpu().numpy())

    avg = total_loss/len(dataloader)
    accuracy_1 = total_correct_1 / total_samples_1
    f1_1 = f1_score(all_targets_1, all_predictions_1, average='weighted')

    return avg, accuracy_1, all_predictions_1, all_targets_1, f1_1

def format_metric(value): # Used to format the metrics output
    return f"{value:.4f}"

# %%
#Testing against the test dataset
model = FTTransformer(categories=tuple(unique_classes_per_column),
                          num_continuous=len(cont_columns),
                          dim=192,
                          depth=3,
                          heads=8,
                          dim_out=target_classes[0],
                          attn_dropout=0.2,
                          ff_dropout=0.1).to(device_in_use)
loss_functions = LossFunctions(1)
optimizer = torch.optim.AdamW(params=model.parameters(), lr = 0.0001, weight_decay=0.00001)
epochs = 100

train_losses = []
train_accuracies_1 = [] 

test_losses = []
test_accuracies_1 = []
  
test_f1_scores = [] 
all_attention_scores = []

#Time will be recorded for all 100 epochs - This means the results will not be comparable to Xgboost but that is ok, we will only compare between transformer models who will also train for 100 epochs
start_time = time.process_time()

for t in range(epochs):
  train_loss, train_accuracy_1 = train(train_dataloader, model, loss_functions, optimizer, device_in_use=device_in_use)
  test_loss, test_accuracy_1, all_predictions_1, all_targets_1, f1_1 = test(test_dataloader, model, loss_functions, device_in_use=device_in_use)
  train_losses.append(train_loss)
  train_accuracies_1.append(train_accuracy_1)
  # train_accuracies_2.append(train_accuracy_2)
  # train_recalls.append(train_recall) 
  # train_f1_scores.append(train_f1)
  test_losses.append(test_loss)
  test_accuracies_1.append(test_accuracy_1)
  # test_accuracies_2.append(test_accuracy_2)
  # test_recalls.append(test_recall)
  test_f1_scores.append(f1_1)
  # Formatting for easier reading
  epoch_str = f"Epoch [{t+1:2}/{epochs}]"
  train_metrics = f"Train: Loss {format_metric(train_loss)}, Accuracy {format_metric(train_accuracy_1)}"
  test_metrics = f"Test: Loss {format_metric(test_loss)}, Accuracy {format_metric(test_accuracy_1)}, F1 {format_metric(f1_1)}"
  print(f"{epoch_str:20} | {train_metrics:65} | {test_metrics}")

total_time = time.process_time() - start_time

# Plotting the loss curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 1, 1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, epochs+1), [l for l in test_losses], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curve')
plt.legend()

# Display confusion matrix for the first task (Traffic Type) on test data
conf_matrix_1 = confusion_matrix(all_targets_1, all_predictions_1)
print("Confusion Matrix")
print(conf_matrix_1)

best_index = test_accuracies_1.index(max(test_accuracies_1))
print(f"Best accuracy {test_accuracies_1[best_index]}")
print(f"Best F1 {test_f1_scores[best_index]}")
print(f"100 epochs of training and evaluation took, {total_time}")
# Out:
# Epoch [ 1/100]       | Train: Loss 0.6250, Accuracy 0.6407                               | Test: Loss 0.5902, Accuracy 0.6817, F1 0.6783
# Epoch [ 2/100]       | Train: Loss 0.5758, Accuracy 0.6941                               | Test: Loss 0.5592, Accuracy 0.7036, F1 0.7028
# Epoch [ 3/100]       | Train: Loss 0.5628, Accuracy 0.7038                               | Test: Loss 0.5587, Accuracy 0.7053, F1 0.7046
# Epoch [ 4/100]       | Train: Loss 0.5565, Accuracy 0.7072                               | Test: Loss 0.5500, Accuracy 0.7105, F1 0.7100
# Epoch [ 5/100]       | Train: Loss 0.5506, Accuracy 0.7127                               | Test: Loss 0.5430, Accuracy 0.7162, F1 0.7162
# Epoch [ 6/100]       | Train: Loss 0.5473, Accuracy 0.7151                               | Test: Loss 0.5388, Accuracy 0.7199, F1 0.7198
# Epoch [ 7/100]       | Train: Loss 0.5413, Accuracy 0.7178                               | Test: Loss 0.5383, Accuracy 0.7206, F1 0.7205
# Epoch [ 8/100]       | Train: Loss 0.5394, Accuracy 0.7216                               | Test: Loss 0.5333, Accuracy 0.7229, F1 0.7221
# Epoch [ 9/100]       | Train: Loss 0.5364, Accuracy 0.7228                               | Test: Loss 0.5335, Accuracy 0.7228, F1 0.7228
# Epoch [10/100]       | Train: Loss 0.5338, Accuracy 0.7250                               | Test: Loss 0.5313, Accuracy 0.7229, F1 0.7231
# Epoch [11/100]       | Train: Loss 0.5307, Accuracy 0.7278                               | Test: Loss 0.5407, Accuracy 0.7170, F1 0.7159
# Epoch [12/100]       | Train: Loss 0.5280, Accuracy 0.7281                               | Test: Loss 0.5276, Accuracy 0.7282, F1 0.7282
# Epoch [13/100]       | Train: Loss 0.5252, Accuracy 0.7312                               | Test: Loss 0.5302, Accuracy 0.7242, F1 0.7243
# Epoch [14/100]       | Train: Loss 0.5227, Accuracy 0.7322                               | Test: Loss 0.5334, Accuracy 0.7258, F1 0.7255
# Epoch [15/100]       | Train: Loss 0.5217, Accuracy 0.7335                               | Test: Loss 0.5255, Accuracy 0.7308, F1 0.7306
# Epoch [16/100]       | Train: Loss 0.5171, Accuracy 0.7364                               | Test: Loss 0.5276, Accuracy 0.7308, F1 0.7303
# Epoch [17/100]       | Train: Loss 0.5159, Accuracy 0.7363                               | Test: Loss 0.5287, Accuracy 0.7297, F1 0.7288
# Epoch [18/100]       | Train: Loss 0.5146, Accuracy 0.7402                               | Test: Loss 0.5306, Accuracy 0.7287, F1 0.7278
# Epoch [19/100]       | Train: Loss 0.5111, Accuracy 0.7407                               | Test: Loss 0.5281, Accuracy 0.7302, F1 0.7300
# Epoch [20/100]       | Train: Loss 0.5097, Accuracy 0.7422                               | Test: Loss 0.5306, Accuracy 0.7283, F1 0.7282
# Epoch [21/100]       | Train: Loss 0.5054, Accuracy 0.7452                               | Test: Loss 0.5308, Accuracy 0.7304, F1 0.7297
# Epoch [22/100]       | Train: Loss 0.5031, Accuracy 0.7461                               | Test: Loss 0.5308, Accuracy 0.7321, F1 0.7322
# Epoch [23/100]       | Train: Loss 0.5008, Accuracy 0.7483                               | Test: Loss 0.5295, Accuracy 0.7316, F1 0.7316
# Epoch [24/100]       | Train: Loss 0.4971, Accuracy 0.7513                               | Test: Loss 0.5352, Accuracy 0.7312, F1 0.7311
# Epoch [25/100]       | Train: Loss 0.4950, Accuracy 0.7532                               | Test: Loss 0.5362, Accuracy 0.7289, F1 0.7287
# Epoch [26/100]       | Train: Loss 0.4918, Accuracy 0.7551                               | Test: Loss 0.5353, Accuracy 0.7285, F1 0.7279
# Epoch [27/100]       | Train: Loss 0.4886, Accuracy 0.7559                               | Test: Loss 0.5372, Accuracy 0.7268, F1 0.7265
# Epoch [28/100]       | Train: Loss 0.4844, Accuracy 0.7605                               | Test: Loss 0.5384, Accuracy 0.7291, F1 0.7288
# Epoch [29/100]       | Train: Loss 0.4808, Accuracy 0.7615                               | Test: Loss 0.5411, Accuracy 0.7261, F1 0.7261
# Epoch [30/100]       | Train: Loss 0.4751, Accuracy 0.7659                               | Test: Loss 0.5438, Accuracy 0.7274, F1 0.7272
# Epoch [31/100]       | Train: Loss 0.4724, Accuracy 0.7672                               | Test: Loss 0.5446, Accuracy 0.7255, F1 0.7254
# Epoch [32/100]       | Train: Loss 0.4691, Accuracy 0.7703                               | Test: Loss 0.5515, Accuracy 0.7258, F1 0.7259
# Epoch [33/100]       | Train: Loss 0.4642, Accuracy 0.7730                               | Test: Loss 0.5472, Accuracy 0.7254, F1 0.7255
# Epoch [34/100]       | Train: Loss 0.4597, Accuracy 0.7769                               | Test: Loss 0.5520, Accuracy 0.7253, F1 0.7249
# Epoch [35/100]       | Train: Loss 0.4541, Accuracy 0.7809                               | Test: Loss 0.5558, Accuracy 0.7228, F1 0.7225
# Epoch [36/100]       | Train: Loss 0.4491, Accuracy 0.7822                               | Test: Loss 0.5604, Accuracy 0.7193, F1 0.7194
# Epoch [37/100]       | Train: Loss 0.4441, Accuracy 0.7867                               | Test: Loss 0.5695, Accuracy 0.7199, F1 0.7199
# Epoch [38/100]       | Train: Loss 0.4379, Accuracy 0.7907                               | Test: Loss 0.5724, Accuracy 0.7165, F1 0.7162
# Epoch [39/100]       | Train: Loss 0.4307, Accuracy 0.7948                               | Test: Loss 0.5784, Accuracy 0.7204, F1 0.7204
# Epoch [40/100]       | Train: Loss 0.4268, Accuracy 0.7986                               | Test: Loss 0.5834, Accuracy 0.7164, F1 0.7163
# Epoch [41/100]       | Train: Loss 0.4211, Accuracy 0.7998                               | Test: Loss 0.5904, Accuracy 0.7151, F1 0.7151
# Epoch [42/100]       | Train: Loss 0.4148, Accuracy 0.8053                               | Test: Loss 0.5964, Accuracy 0.7178, F1 0.7177
# Epoch [43/100]       | Train: Loss 0.4078, Accuracy 0.8097                               | Test: Loss 0.5987, Accuracy 0.7117, F1 0.7115
# Epoch [44/100]       | Train: Loss 0.4014, Accuracy 0.8122                               | Test: Loss 0.6068, Accuracy 0.7079, F1 0.7075
# Epoch [45/100]       | Train: Loss 0.3963, Accuracy 0.8166                               | Test: Loss 0.6083, Accuracy 0.7083, F1 0.7084
# Epoch [46/100]       | Train: Loss 0.3893, Accuracy 0.8191                               | Test: Loss 0.6257, Accuracy 0.7090, F1 0.7086
# Epoch [47/100]       | Train: Loss 0.3842, Accuracy 0.8225                               | Test: Loss 0.6277, Accuracy 0.7070, F1 0.7059
# Epoch [48/100]       | Train: Loss 0.3766, Accuracy 0.8278                               | Test: Loss 0.6390, Accuracy 0.7061, F1 0.7055
# Epoch [49/100]       | Train: Loss 0.3668, Accuracy 0.8328                               | Test: Loss 0.6515, Accuracy 0.7095, F1 0.7095
# Epoch [50/100]       | Train: Loss 0.3612, Accuracy 0.8368                               | Test: Loss 0.6390, Accuracy 0.7100, F1 0.7100
# Epoch [51/100]       | Train: Loss 0.3570, Accuracy 0.8386                               | Test: Loss 0.6596, Accuracy 0.7051, F1 0.7047
# Epoch [52/100]       | Train: Loss 0.3513, Accuracy 0.8415                               | Test: Loss 0.6729, Accuracy 0.7051, F1 0.7049
# Epoch [53/100]       | Train: Loss 0.3424, Accuracy 0.8467                               | Test: Loss 0.6862, Accuracy 0.7030, F1 0.7022
# Epoch [54/100]       | Train: Loss 0.3384, Accuracy 0.8491                               | Test: Loss 0.6827, Accuracy 0.7031, F1 0.7028
# Epoch [55/100]       | Train: Loss 0.3301, Accuracy 0.8538                               | Test: Loss 0.6919, Accuracy 0.7049, F1 0.7049
# Epoch [56/100]       | Train: Loss 0.3250, Accuracy 0.8560                               | Test: Loss 0.6966, Accuracy 0.6996, F1 0.6995
# Epoch [57/100]       | Train: Loss 0.3174, Accuracy 0.8595                               | Test: Loss 0.7189, Accuracy 0.6977, F1 0.6971
# Epoch [58/100]       | Train: Loss 0.3115, Accuracy 0.8627                               | Test: Loss 0.7300, Accuracy 0.7025, F1 0.7025
# Epoch [59/100]       | Train: Loss 0.3039, Accuracy 0.8680                               | Test: Loss 0.7269, Accuracy 0.6957, F1 0.6956
# Epoch [60/100]       | Train: Loss 0.2991, Accuracy 0.8684                               | Test: Loss 0.7486, Accuracy 0.6940, F1 0.6938
# Epoch [61/100]       | Train: Loss 0.2945, Accuracy 0.8719                               | Test: Loss 0.7554, Accuracy 0.6990, F1 0.6987
# Epoch [62/100]       | Train: Loss 0.2870, Accuracy 0.8750                               | Test: Loss 0.7618, Accuracy 0.7000, F1 0.6997
# Epoch [63/100]       | Train: Loss 0.2781, Accuracy 0.8799                               | Test: Loss 0.7898, Accuracy 0.6894, F1 0.6883
# Epoch [64/100]       | Train: Loss 0.2766, Accuracy 0.8819                               | Test: Loss 0.7726, Accuracy 0.6989, F1 0.6987
# Epoch [65/100]       | Train: Loss 0.2681, Accuracy 0.8851                               | Test: Loss 0.7867, Accuracy 0.6947, F1 0.6944
# Epoch [66/100]       | Train: Loss 0.2625, Accuracy 0.8876                               | Test: Loss 0.7910, Accuracy 0.6934, F1 0.6933
# Epoch [67/100]       | Train: Loss 0.2587, Accuracy 0.8899                               | Test: Loss 0.8143, Accuracy 0.6876, F1 0.6872
# Epoch [68/100]       | Train: Loss 0.2531, Accuracy 0.8934                               | Test: Loss 0.8208, Accuracy 0.6905, F1 0.6901
# Epoch [69/100]       | Train: Loss 0.2469, Accuracy 0.8964                               | Test: Loss 0.8187, Accuracy 0.6980, F1 0.6978
# Epoch [70/100]       | Train: Loss 0.2475, Accuracy 0.8972                               | Test: Loss 0.8285, Accuracy 0.6936, F1 0.6934
# Epoch [71/100]       | Train: Loss 0.2361, Accuracy 0.8998                               | Test: Loss 0.8415, Accuracy 0.6938, F1 0.6936
# Epoch [72/100]       | Train: Loss 0.2346, Accuracy 0.9009                               | Test: Loss 0.8579, Accuracy 0.6885, F1 0.6884
# Epoch [73/100]       | Train: Loss 0.2303, Accuracy 0.9028                               | Test: Loss 0.8634, Accuracy 0.6941, F1 0.6942
# Epoch [74/100]       | Train: Loss 0.2233, Accuracy 0.9064                               | Test: Loss 0.8701, Accuracy 0.6947, F1 0.6948
# Epoch [75/100]       | Train: Loss 0.2170, Accuracy 0.9104                               | Test: Loss 0.8885, Accuracy 0.6940, F1 0.6935
# Epoch [76/100]       | Train: Loss 0.2134, Accuracy 0.9116                               | Test: Loss 0.9050, Accuracy 0.6912, F1 0.6909
# Epoch [77/100]       | Train: Loss 0.2117, Accuracy 0.9133                               | Test: Loss 0.9087, Accuracy 0.6914, F1 0.6913
# Epoch [78/100]       | Train: Loss 0.2061, Accuracy 0.9161                               | Test: Loss 0.9089, Accuracy 0.6928, F1 0.6925
# Epoch [79/100]       | Train: Loss 0.2047, Accuracy 0.9158                               | Test: Loss 0.9164, Accuracy 0.6938, F1 0.6936
# Epoch [80/100]       | Train: Loss 0.1986, Accuracy 0.9183                               | Test: Loss 0.9252, Accuracy 0.6900, F1 0.6899
# Epoch [81/100]       | Train: Loss 0.1941, Accuracy 0.9206                               | Test: Loss 0.9452, Accuracy 0.6870, F1 0.6865
# Epoch [82/100]       | Train: Loss 0.1923, Accuracy 0.9218                               | Test: Loss 0.9426, Accuracy 0.6913, F1 0.6913
# Epoch [83/100]       | Train: Loss 0.1878, Accuracy 0.9248                               | Test: Loss 0.9477, Accuracy 0.6902, F1 0.6900
# Epoch [84/100]       | Train: Loss 0.1819, Accuracy 0.9283                               | Test: Loss 0.9546, Accuracy 0.6894, F1 0.6888
# Epoch [85/100]       | Train: Loss 0.1788, Accuracy 0.9288                               | Test: Loss 0.9634, Accuracy 0.6877, F1 0.6870
# Epoch [86/100]       | Train: Loss 0.1740, Accuracy 0.9309                               | Test: Loss 0.9713, Accuracy 0.6881, F1 0.6881
# Epoch [87/100]       | Train: Loss 0.1738, Accuracy 0.9317                               | Test: Loss 0.9821, Accuracy 0.6913, F1 0.6910
# Epoch [88/100]       | Train: Loss 0.1688, Accuracy 0.9326                               | Test: Loss 0.9921, Accuracy 0.6943, F1 0.6941
# Epoch [89/100]       | Train: Loss 0.1652, Accuracy 0.9347                               | Test: Loss 1.0109, Accuracy 0.6885, F1 0.6884
# Epoch [90/100]       | Train: Loss 0.1642, Accuracy 0.9346                               | Test: Loss 1.0112, Accuracy 0.6880, F1 0.6873
# Epoch [91/100]       | Train: Loss 0.1620, Accuracy 0.9364                               | Test: Loss 1.0133, Accuracy 0.6889, F1 0.6882
# Epoch [92/100]       | Train: Loss 0.1531, Accuracy 0.9400                               | Test: Loss 1.0323, Accuracy 0.6916, F1 0.6915
# Epoch [93/100]       | Train: Loss 0.1543, Accuracy 0.9388                               | Test: Loss 1.0306, Accuracy 0.6920, F1 0.6919
# Epoch [94/100]       | Train: Loss 0.1525, Accuracy 0.9407                               | Test: Loss 1.0322, Accuracy 0.6881, F1 0.6882
# Epoch [95/100]       | Train: Loss 0.1479, Accuracy 0.9413                               | Test: Loss 1.0594, Accuracy 0.6927, F1 0.6927
# Epoch [96/100]       | Train: Loss 0.1504, Accuracy 0.9411                               | Test: Loss 1.0542, Accuracy 0.6927, F1 0.6928
# Epoch [97/100]       | Train: Loss 0.1449, Accuracy 0.9437                               | Test: Loss 1.0510, Accuracy 0.6932, F1 0.6926
# Epoch [98/100]       | Train: Loss 0.1434, Accuracy 0.9446                               | Test: Loss 1.0770, Accuracy 0.6900, F1 0.6897
# Epoch [99/100]       | Train: Loss 0.1373, Accuracy 0.9463                               | Test: Loss 1.0867, Accuracy 0.6924, F1 0.6923
# Epoch [100/100]      | Train: Loss 0.1347, Accuracy 0.9488                               | Test: Loss 1.0781, Accuracy 0.6918, F1 0.6910
# Confusion Matrix
# [[4527 2502]
#  [2031 5648]]
# Best accuracy 0.732050584715801
# Best F1 0.7321558387637039
# 100 epochs of training and evaluation took, 97736.171875
