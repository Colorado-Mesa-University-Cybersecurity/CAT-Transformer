# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import pickle
import matplotlib.pyplot as plt
from rtdl_revisiting_models import FTTransformer

from helpers import ModelPerformanceLog

import sys
sys.path.insert(0, '/home/wdwatson2/projects/CAT-Transformer/model')
from testingModel import CATTransformer, MyFTTransformer, Combined_Dataset, train, test, EarlyStopping, count_parameters
import for_rtdl

device_in_use = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device_in_use)
# Out:
# cuda

# %%
#GET California

# df_train = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/california/train.csv')
# df_test = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/california/test.csv')
# df_val = pd.read_csv('/home/cscadmin/CyberResearch/CAT-Transformer/datasets/california/validation.csv') #READ FROM RIGHT SPOT

# df_train = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\california\train.csv')
# df_test = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\california\test.csv')
# df_val = pd.read_csv(r'C:\Users\smbm2\projects\CAT-Transformer\datasets\california\validation.csv') #READ FROM RIGHT SPOT

df_train = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/california/train.csv')
df_test = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/california/test.csv')
df_val = pd.read_csv('/home/wdwatson2/projects/CAT-Transformer/datasets/california/validation.csv')

cont_columns = [ 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
       'Latitude', 'Longitude']
target = ['MedInc']
cat_columns=[]

#CHECKING TO MAKE SURE YOUR LIST IS CORRECT (NO NEED TO TOUCH)
yourlist = cont_columns + target
yourlist.sort()
oglist = list(df_train.columns)
oglist.sort()

cat_features=()

assert(yourlist == oglist), "You may of spelled feature name wrong or you forgot to put on of them in the list"

target_classes = [max(len(df_train[target].value_counts()), len(df_val[target].value_counts()),len(df_test[target].value_counts()))]
print(target_classes)
# Create a StandardScaler and fit it to the cont features
scaler = StandardScaler()
scaler.fit(df_train[cont_columns])

# Transform the training, test, and validation datasets
df_train[cont_columns] = scaler.transform(df_train[cont_columns])
df_test[cont_columns] = scaler.transform(df_test[cont_columns])
df_val[cont_columns] = scaler.transform(df_val[cont_columns])

#Wrapping in Dataset
train_dataset = Combined_Dataset(df_train, cat_columns=cat_columns, num_columns=cont_columns, task1_column=target[0])
val_dataset = Combined_Dataset(df_val, cat_columns=cat_columns, num_columns=cont_columns, task1_column=target[0])
test_dataset = Combined_Dataset(df_test, cat_columns=cat_columns, num_columns=cont_columns, task1_column=target[0])

batch_size = 256

# Wrapping with DataLoader for easy batch extraction
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)


#CAT
cat_model = CATTransformer(n_cont=len(cont_columns),
                       cat_feat=cat_features,
                       targets_classes=target_classes,
                       get_attn=False,
                       num_layers=1,
                       regression_on=True).to(device_in_use)

optimizer = torch.optim.Adam(params=cat_model.parameters(), lr=0.0001)
loss_function = nn.MSELoss()

early_stopping = EarlyStopping(patience=10, verbose=True, mode='min') #for regression

train_losses = []
train_rmse_1 = [] 
test_losses = []
test_rmse_1 = [] 

epochs = 400

for t in range(epochs):
    train_loss, train_rmse = train(regression_on=True, 
                                  get_attn=False,
                                   dataloader=train_dataloader, 
                                   model=cat_model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_rmse = test(regression_on=True, 
                                  get_attn=False,
                                   dataloader=train_dataloader, 
                                   model=cat_model, 
                                   loss_function=loss_function, 
                                   device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_rmse_1.append(train_rmse)
    test_losses.append(test_loss)
    test_rmse_1.append(test_rmse)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, RMSE {(train_rmse)}"
    test_metrics = f"Test: Loss {(test_loss)}, RMSE {(test_rmse)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_rmse)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# [9851]
# Epoch [ 1/400]  | Train: Loss 5.193376796287403, RMSE 2.19560762664728              | Test: Loss 3.638174057006836, RMSE 1.9012684633857326
# Epoch [ 2/400]  | Train: Loss 3.614687338209989, RMSE 1.8949875036875408            | Test: Loss 3.560952299519589, RMSE 1.882282905411302
# Epoch [ 3/400]  | Train: Loss 2.9391942317025705, RMSE 1.7016084842514574           | Test: Loss 2.2080772362257304, RMSE 1.482116184736553
# Epoch [ 4/400]  | Train: Loss 1.905451396055389, RMSE 1.3748023509979248            | Test: Loss 1.6686916915993941, RMSE 1.2875199443415593
# Epoch [ 5/400]  | Train: Loss 1.4377571543057759, RMSE 1.193960754494918            | Test: Loss 1.5628408883747302, RMSE 1.24812314384862
# Epoch [ 6/400]  | Train: Loss 1.285210112730662, RMSE 1.130036076955628             | Test: Loss 1.2538657836746752, RMSE 1.116260484645241
# Epoch [ 7/400]  | Train: Loss 1.2080854438898856, RMSE 1.0962108509582387           | Test: Loss 1.233208223393089, RMSE 1.1071766959993463
# Epoch [ 8/400]  | Train: Loss 1.1956146579039724, RMSE 1.089609724387788            | Test: Loss 1.436786273069549, RMSE 1.196584322996307
# EarlyStopping counter: 1 out of 10
# Epoch [ 9/400]  | Train: Loss 1.1568824429261058, RMSE 1.0719412324721354           | Test: Loss 1.2760011867473, RMSE 1.127139267168547
# EarlyStopping counter: 2 out of 10
# Epoch [10/400]  | Train: Loss 1.1430451524885077, RMSE 1.0654519419921071           | Test: Loss 1.3081389320524115, RMSE 1.1414938569068909
# EarlyStopping counter: 3 out of 10
# Epoch [11/400]  | Train: Loss 1.131097842726791, RMSE 1.0590908537831223            | Test: Loss 1.1994195109919499, RMSE 1.092872070638757
# Epoch [12/400]  | Train: Loss 1.1110779245694478, RMSE 1.0497484248981142           | Test: Loss 1.2187670406542326, RMSE 1.1019255477085448
# EarlyStopping counter: 1 out of 10
# Epoch [13/400]  | Train: Loss 1.1381782199207104, RMSE 1.0622972595064264           | Test: Loss 1.1575820006822284, RMSE 1.0723202479513068
# Epoch [14/400]  | Train: Loss 1.1152071158091228, RMSE 1.0535219353541994           | Test: Loss 1.2141242895209998, RMSE 1.0990180080397087
# EarlyStopping counter: 1 out of 10
# Epoch [15/400]  | Train: Loss 1.0915185924161945, RMSE 1.040460939992938            | Test: Loss 1.2976348933420683, RMSE 1.136774834833647
# EarlyStopping counter: 2 out of 10
# Epoch [16/400]  | Train: Loss 1.0837565336311072, RMSE 1.0369930842466522           | Test: Loss 1.0358077036707025, RMSE 1.0147859851519268
# Epoch [17/400]  | Train: Loss 1.0797078055247926, RMSE 1.035679046522107            | Test: Loss 1.1381965405062626, RMSE 1.0648952283357318
# EarlyStopping counter: 1 out of 10
# Epoch [18/400]  | Train: Loss 1.0560338821327477, RMSE 1.024276434329518            | Test: Loss 1.265146503323003, RMSE 1.1222089842746132
# EarlyStopping counter: 2 out of 10
# Epoch [19/400]  | Train: Loss 1.058867033113513, RMSE 1.0250877497488993            | Test: Loss 1.0103865129905834, RMSE 1.0021390601208335
# Epoch [20/400]  | Train: Loss 1.066707130064044, RMSE 1.0294524546255146            | Test: Loss 1.0868608669230813, RMSE 1.0403365220939904
# EarlyStopping counter: 1 out of 10
# Epoch [21/400]  | Train: Loss 1.0604476228094937, RMSE 1.0258620381355286           | Test: Loss 1.0728952246799803, RMSE 1.0330697779069866
# EarlyStopping counter: 2 out of 10
# Epoch [22/400]  | Train: Loss 1.0395468368864895, RMSE 1.0152395221225001           | Test: Loss 1.2109873765393306, RMSE 1.0977106219843815
# EarlyStopping counter: 3 out of 10
# Epoch [23/400]  | Train: Loss 1.0507092998738874, RMSE 1.021545812749026            | Test: Loss 1.005945714942196, RMSE 0.9997980876972801
# Epoch [24/400]  | Train: Loss 1.036873928287573, RMSE 1.0144307864339728            | Test: Loss 1.1529872856642072, RMSE 1.0702574786386991
# EarlyStopping counter: 1 out of 10
# Epoch [25/400]  | Train: Loss 1.0515835567524559, RMSE 1.0212398997524328           | Test: Loss 1.1091518789006953, RMSE 1.0497765948897915
# EarlyStopping counter: 2 out of 10
# Epoch [26/400]  | Train: Loss 1.0559374219492863, RMSE 1.0233334731637387           | Test: Loss 0.9992529216565584, RMSE 0.9967475366174129
# Epoch [27/400]  | Train: Loss 1.0248866363575584, RMSE 1.0085544418870358           | Test: Loss 1.131480388474046, RMSE 1.0620715816815693
# EarlyStopping counter: 1 out of 10
# Epoch [28/400]  | Train: Loss 1.039608711736244, RMSE 1.0164555781765987            | Test: Loss 1.0161920608135693, RMSE 1.0048119258462338
# EarlyStopping counter: 2 out of 10
# Epoch [29/400]  | Train: Loss 1.0422525081718177, RMSE 1.0186358366096229           | Test: Loss 0.9922825830024585, RMSE 0.99231898889207
# Epoch [30/400]  | Train: Loss 1.0336034297943115, RMSE 1.0127935357261122           | Test: Loss 1.099357383293018, RMSE 1.0448576295584964
# EarlyStopping counter: 1 out of 10
# Epoch [31/400]  | Train: Loss 1.0216261619015743, RMSE 1.0075249483710842           | Test: Loss 0.9836782990840444, RMSE 0.9886521780700014
# Epoch [32/400]  | Train: Loss 1.001509233524925, RMSE 0.9970786749270925            | Test: Loss 0.9777164124605948, RMSE 0.9840988454065824
# Epoch [33/400]  | Train: Loss 1.0152272090577243, RMSE 1.0039239306198924           | Test: Loss 1.0054428692449604, RMSE 0.9997831258857459
# EarlyStopping counter: 1 out of 10
# Epoch [34/400]  | Train: Loss 1.0132757467136049, RMSE 1.0030530126471269           | Test: Loss 0.9797085094870183, RMSE 0.9851385334081817
# EarlyStopping counter: 2 out of 10
# Epoch [35/400]  | Train: Loss 1.0309563185039319, RMSE 1.0106694238227711           | Test: Loss 1.006757212312598, RMSE 1.0011694661357946
# EarlyStopping counter: 3 out of 10
# Epoch [36/400]  | Train: Loss 1.0526185788606341, RMSE 1.0214033450996667           | Test: Loss 1.0086412785346048, RMSE 1.0010050556115937
# EarlyStopping counter: 4 out of 10
# Epoch [37/400]  | Train: Loss 0.9986883297301176, RMSE 0.9968533881923609           | Test: Loss 1.0697655949676246, RMSE 1.0310950551116675
# EarlyStopping counter: 5 out of 10
# Epoch [38/400]  | Train: Loss 0.9965078276500368, RMSE 0.9950425133370516           | Test: Loss 1.0300272975051612, RMSE 1.0117500717179817
# EarlyStopping counter: 6 out of 10
# Epoch [39/400]  | Train: Loss 1.0101523336611296, RMSE 1.0013074718023602           | Test: Loss 1.0162546634674072, RMSE 1.0053655452895582
# EarlyStopping counter: 7 out of 10
# Epoch [40/400]  | Train: Loss 0.9963091643233049, RMSE 0.9932680516912226           | Test: Loss 0.9616793205863551, RMSE 0.9766703321222674
# Epoch [41/400]  | Train: Loss 0.9992778144384685, RMSE 0.995986841226879            | Test: Loss 0.9893260284474021, RMSE 0.9925685368086162
# EarlyStopping counter: 1 out of 10
# Epoch [42/400]  | Train: Loss 0.993510481558348, RMSE 0.9940430312825922            | Test: Loss 1.1000233919996965, RMSE 1.045947149134519
# EarlyStopping counter: 2 out of 10
# Epoch [43/400]  | Train: Loss 0.9917509921810084, RMSE 0.9922719158624348           | Test: Loss 1.0985194977961088, RMSE 1.0454376141230266
# EarlyStopping counter: 3 out of 10
# Epoch [44/400]  | Train: Loss 0.9995004179184896, RMSE 0.9964373969195182           | Test: Loss 1.0018791953722637, RMSE 0.9977343552990964
# EarlyStopping counter: 4 out of 10
# Epoch [45/400]  | Train: Loss 0.9936311182222868, RMSE 0.9942643391458612           | Test: Loss 0.980363038548252, RMSE 0.9866308162086889
# EarlyStopping counter: 5 out of 10
# Epoch [46/400]  | Train: Loss 0.9857331618928072, RMSE 0.9882746903519881           | Test: Loss 1.0498681873605962, RMSE 1.0206535374909116
# EarlyStopping counter: 6 out of 10
# Epoch [47/400]  | Train: Loss 0.9921585551479406, RMSE 0.9928187445590371           | Test: Loss 1.0542004474422388, RMSE 1.0238735194791828
# EarlyStopping counter: 7 out of 10
# Epoch [48/400]  | Train: Loss 0.9881038906281454, RMSE 0.9905252791287606           | Test: Loss 0.9628957028974566, RMSE 0.9772552115875378
# EarlyStopping counter: 8 out of 10
# Epoch [49/400]  | Train: Loss 0.9713065195501897, RMSE 0.9818022679864314           | Test: Loss 0.9421446658017343, RMSE 0.9676762923859713
# Epoch [50/400]  | Train: Loss 0.9807490748271608, RMSE 0.9854128747655634           | Test: Loss 0.9360845590892591, RMSE 0.9629836281140646
# Epoch [51/400]  | Train: Loss 0.9630289736546969, RMSE 0.9779103534263477           | Test: Loss 1.1452720510332208, RMSE 1.0686280246366535
# EarlyStopping counter: 1 out of 10
# Epoch [52/400]  | Train: Loss 0.9744648881125868, RMSE 0.9840701326989291           | Test: Loss 1.2771626459924799, RMSE 1.1281825931448686
# EarlyStopping counter: 2 out of 10
# Epoch [53/400]  | Train: Loss 0.9664205082675867, RMSE 0.9795535834212052           | Test: Loss 1.079404264165644, RMSE 1.0357000200371993
# EarlyStopping counter: 3 out of 10
# Epoch [54/400]  | Train: Loss 0.9500720678714284, RMSE 0.9706046330301386           | Test: Loss 1.0200129548708599, RMSE 1.0072270213511951
# EarlyStopping counter: 4 out of 10
# Epoch [55/400]  | Train: Loss 0.968862443639521, RMSE 0.9805890457671985            | Test: Loss 0.9969558736734223, RMSE 0.9954312150938469
# EarlyStopping counter: 5 out of 10
# Epoch [56/400]  | Train: Loss 0.9680921686323065, RMSE 0.9803747597493624           | Test: Loss 0.955573786768997, RMSE 0.9750058765996966
# EarlyStopping counter: 6 out of 10
# Epoch [57/400]  | Train: Loss 0.9643217168356243, RMSE 0.9783138423635248           | Test: Loss 0.938914888783505, RMSE 0.9647424911197863
# EarlyStopping counter: 7 out of 10
# Epoch [58/400]  | Train: Loss 0.9222699623358878, RMSE 0.9562238778984338           | Test: Loss 0.8878857733910543, RMSE 0.9388260621773569
# Epoch [59/400]  | Train: Loss 0.930503929916181, RMSE 0.9611297709900036            | Test: Loss 0.9439044992129008, RMSE 0.9686644851115712
# EarlyStopping counter: 1 out of 10
# Epoch [60/400]  | Train: Loss 0.9025719876874957, RMSE 0.9472723279082984           | Test: Loss 0.9057416319847107, RMSE 0.9474448666237948
# EarlyStopping counter: 2 out of 10
# Epoch [61/400]  | Train: Loss 0.9060838525755364, RMSE 0.9479571214893407           | Test: Loss 0.9339889685312907, RMSE 0.9637828636587712
# EarlyStopping counter: 3 out of 10
# Epoch [62/400]  | Train: Loss 0.8932273053286368, RMSE 0.9411886282134474           | Test: Loss 0.8655705912071362, RMSE 0.9270566210412142
# Epoch [63/400]  | Train: Loss 0.8946414527140165, RMSE 0.9420523831718847           | Test: Loss 0.9961396528963458, RMSE 0.9958480220091971
# EarlyStopping counter: 1 out of 10
# Epoch [64/400]  | Train: Loss 0.8880296067187661, RMSE 0.9390668889932465           | Test: Loss 0.8673709515939679, RMSE 0.9285732831871301
# EarlyStopping counter: 2 out of 10
# Epoch [65/400]  | Train: Loss 0.8749336370250635, RMSE 0.9316073206433079           | Test: Loss 0.8832536214276364, RMSE 0.9369042745807714
# EarlyStopping counter: 3 out of 10
# Epoch [66/400]  | Train: Loss 0.8641079465548197, RMSE 0.9254450076504758           | Test: Loss 0.861047577439693, RMSE 0.9243078001758509
# Epoch [67/400]  | Train: Loss 0.8720556382547345, RMSE 0.9300838855274937           | Test: Loss 0.9663778355247096, RMSE 0.9803345161571837
# EarlyStopping counter: 1 out of 10
# Epoch [68/400]  | Train: Loss 0.8591097520108808, RMSE 0.9232443257382041           | Test: Loss 0.8473250876393235, RMSE 0.9170730030327513
# Epoch [69/400]  | Train: Loss 0.8661532109243828, RMSE 0.9269870728777166           | Test: Loss 0.8821170277762831, RMSE 0.9365216660917851
# EarlyStopping counter: 1 out of 10
# Epoch [70/400]  | Train: Loss 0.8647295686236599, RMSE 0.9253083509311342           | Test: Loss 0.9467838166052835, RMSE 0.9704389049295794
# EarlyStopping counter: 2 out of 10
# Epoch [71/400]  | Train: Loss 0.837081463713395, RMSE 0.9106509560032895            | Test: Loss 0.8535412947336832, RMSE 0.9210143476201776
# EarlyStopping counter: 3 out of 10
# Epoch [72/400]  | Train: Loss 0.8538075131282472, RMSE 0.920664742327573            | Test: Loss 0.9175698621231213, RMSE 0.9549675092362521
# EarlyStopping counter: 4 out of 10
# Epoch [73/400]  | Train: Loss 0.8606286582193876, RMSE 0.9245269089414362           | Test: Loss 0.8649698537692689, RMSE 0.9264444959791083
# EarlyStopping counter: 5 out of 10
# Epoch [74/400]  | Train: Loss 0.8582886185562402, RMSE 0.921077779510565            | Test: Loss 0.8856414315993326, RMSE 0.938236277354391
# EarlyStopping counter: 6 out of 10
# Epoch [75/400]  | Train: Loss 0.842872587212345, RMSE 0.915972303925899             | Test: Loss 0.8361949638316506, RMSE 0.9114458320433634
# Epoch [76/400]  | Train: Loss 0.8442717790603638, RMSE 0.9139977442590814           | Test: Loss 1.0610545089370327, RMSE 1.027965315601282
# EarlyStopping counter: 1 out of 10
# Epoch [77/400]  | Train: Loss 0.8583056759416011, RMSE 0.9224930750696283           | Test: Loss 0.8917654951413473, RMSE 0.9407746122594465
# EarlyStopping counter: 2 out of 10
# Epoch [78/400]  | Train: Loss 0.8349365696572421, RMSE 0.9094981227004737           | Test: Loss 0.8686623615131044, RMSE 0.9291604307659885
# EarlyStopping counter: 3 out of 10
# Epoch [79/400]  | Train: Loss 0.8338869004918817, RMSE 0.9096720406883642           | Test: Loss 0.9195401563979032, RMSE 0.9563704237603304
# EarlyStopping counter: 4 out of 10
# Epoch [80/400]  | Train: Loss 0.8398762784506145, RMSE 0.9128077647142243           | Test: Loss 1.0546972197398805, RMSE 1.024665955911603
# EarlyStopping counter: 5 out of 10
# Epoch [81/400]  | Train: Loss 0.8393804577358982, RMSE 0.9112697107750073           | Test: Loss 0.7948513700250994, RMSE 0.887085379215709
# Epoch [82/400]  | Train: Loss 0.8182472952625208, RMSE 0.901288694457004            | Test: Loss 0.7963293853558993, RMSE 0.8888918663326063
# EarlyStopping counter: 1 out of 10
# Epoch [83/400]  | Train: Loss 0.8262030064013967, RMSE 0.9060566582177815           | Test: Loss 0.8206233214913753, RMSE 0.9025294948042485
# EarlyStopping counter: 2 out of 10
# Epoch [84/400]  | Train: Loss 0.8367807227268553, RMSE 0.909446468478755            | Test: Loss 0.8990243798808047, RMSE 0.9445643707325584
# EarlyStopping counter: 3 out of 10
# Epoch [85/400]  | Train: Loss 0.8270581709711176, RMSE 0.9045325371257046           | Test: Loss 0.8806635496909159, RMSE 0.9353993378187481
# EarlyStopping counter: 4 out of 10
# Epoch [86/400]  | Train: Loss 0.8155577109571088, RMSE 0.8995767267126786           | Test: Loss 0.7851535688366806, RMSE 0.8811756571133932
# Epoch [87/400]  | Train: Loss 0.8452201642488179, RMSE 0.9153868796532614           | Test: Loss 0.9169808636631882, RMSE 0.9545462445208901
# EarlyStopping counter: 1 out of 10
# Epoch [88/400]  | Train: Loss 0.820175640415727, RMSE 0.9008793715845075            | Test: Loss 0.9836980491353754, RMSE 0.9899668243893406
# EarlyStopping counter: 2 out of 10
# Epoch [89/400]  | Train: Loss 0.8156945590387311, RMSE 0.899045467376709            | Test: Loss 0.8726221176615933, RMSE 0.9307547922719989
# EarlyStopping counter: 3 out of 10
# Epoch [90/400]  | Train: Loss 0.813711612893824, RMSE 0.8986225713763321            | Test: Loss 0.8498535584985164, RMSE 0.9196421514477646
# EarlyStopping counter: 4 out of 10
# Epoch [91/400]  | Train: Loss 0.8247076042911463, RMSE 0.904990109435299            | Test: Loss 0.8663325665289896, RMSE 0.9274704560898898
# EarlyStopping counter: 5 out of 10
# Epoch [92/400]  | Train: Loss 0.819709979651267, RMSE 0.9012019435564677            | Test: Loss 0.8088881613915426, RMSE 0.8953840408408851
# EarlyStopping counter: 6 out of 10
# Epoch [93/400]  | Train: Loss 0.8121212992751807, RMSE 0.8965936209026136           | Test: Loss 0.7816204250904552, RMSE 0.8811133179748267
# Epoch [94/400]  | Train: Loss 0.8138976484014276, RMSE 0.8990189067104406           | Test: Loss 0.7818664741097835, RMSE 0.8811444315993995
# EarlyStopping counter: 1 out of 10
# Epoch [95/400]  | Train: Loss 0.7995567530916449, RMSE 0.8903282326564455           | Test: Loss 0.7614849701262357, RMSE 0.869377122636427
# Epoch [96/400]  | Train: Loss 0.8032184943818209, RMSE 0.8933218487522059           | Test: Loss 0.8015218931331969, RMSE 0.8911910454432169
# EarlyStopping counter: 1 out of 10
# Epoch [97/400]  | Train: Loss 0.7977697232313323, RMSE 0.8887872539068523           | Test: Loss 0.7896034874414143, RMSE 0.8860925592874226
# EarlyStopping counter: 2 out of 10
# Epoch [98/400]  | Train: Loss 0.8019567968552572, RMSE 0.8909149556829218           | Test: Loss 0.821795642375946, RMSE 0.9013888323516176
# EarlyStopping counter: 3 out of 10
# Epoch [99/400]  | Train: Loss 0.8184298255987335, RMSE 0.9010038825503567           | Test: Loss 0.7661617586487218, RMSE 0.8720748131735283
# EarlyStopping counter: 4 out of 10
# Epoch [100/400] | Train: Loss 0.8046775522984957, RMSE 0.8925414566408124           | Test: Loss 0.8891730496757909, RMSE 0.9401691252725166
# EarlyStopping counter: 5 out of 10
# Epoch [101/400] | Train: Loss 0.7905783360464531, RMSE 0.8858109158382081           | Test: Loss 0.7662496106666431, RMSE 0.8712452137679384
# EarlyStopping counter: 6 out of 10
# Epoch [102/400] | Train: Loss 0.796949099030411, RMSE 0.8885726269922758            | Test: Loss 0.8109814273683649, RMSE 0.8974802985525968
# EarlyStopping counter: 7 out of 10
# Epoch [103/400] | Train: Loss 0.8024829793394658, RMSE 0.8923701518460324           | Test: Loss 0.7955439446265238, RMSE 0.8885189472583302
# EarlyStopping counter: 8 out of 10
# Epoch [104/400] | Train: Loss 0.7933826164195412, RMSE 0.8872128976018805           | Test: Loss 0.8391713019002948, RMSE 0.912884675619895
# EarlyStopping counter: 9 out of 10
# Epoch [105/400] | Train: Loss 0.8052409092585245, RMSE 0.8935393942029852           | Test: Loss 0.7964312015918263, RMSE 0.8887780455120823
# EarlyStopping counter: 10 out of 10
# Early stopping

# %%
#CAT
cat_model = MyFTTransformer(n_cont=len(cont_columns),
                       cat_feat=cat_features,
                       targets_classes=target_classes,
                       get_attn=False,
                       num_layers=1,
                       regression_on=True).to(device_in_use)

optimizer = torch.optim.Adam(params=cat_model.parameters(), lr=0.0001)
loss_function = nn.MSELoss()

early_stopping = EarlyStopping(patience=10, verbose=True, mode='min') #for regression

train_losses = []
train_rmse_1 = [] 
test_losses = []
test_rmse_1 = [] 

epochs = 400

for t in range(epochs):
    train_loss, train_rmse = train(regression_on=True, 
                                  get_attn=False,
                                   dataloader=train_dataloader, 
                                   model=cat_model, 
                                   loss_function=loss_function, 
                                   optimizer=optimizer, 
                                   device_in_use=device_in_use)
    test_loss, test_rmse = test(regression_on=True, 
                                  get_attn=False,
                                   dataloader=train_dataloader, 
                                   model=cat_model, 
                                   loss_function=loss_function, 
                                   device_in_use=device_in_use)
    train_losses.append(train_loss)
    train_rmse_1.append(train_rmse)
    test_losses.append(test_loss)
    test_rmse_1.append(test_rmse)

    epoch_str = f"Epoch [{t+1:2}/{epochs}]"
    train_metrics = f"Train: Loss {(train_loss)}, RMSE {(train_rmse)}"
    test_metrics = f"Test: Loss {(test_loss)}, RMSE {(test_rmse)}"
    print(f"{epoch_str:15} | {train_metrics:65} | {test_metrics:65}")

    early_stopping(test_rmse)
    
    if early_stopping.early_stop:
        print("Early stopping")
        break
# Out:
# Epoch [ 1/400]  | Train: Loss 4.607941962125008, RMSE 2.1087919829184547            | Test: Loss 3.844277151843958, RMSE 1.9546232934583698
# Epoch [ 2/400]  | Train: Loss 3.7079148250713683, RMSE 1.9197469322304976           | Test: Loss 3.5835742741300347, RMSE 1.8889808048281753
# Epoch [ 3/400]  | Train: Loss 3.0384796962403415, RMSE 1.7310896045283268           | Test: Loss 1.9783846704583419, RMSE 1.4003181603916905
# Epoch [ 4/400]  | Train: Loss 1.8177328883555897, RMSE 1.34063132185685             | Test: Loss 1.7941072865536338, RMSE 1.3376275217323972
# Epoch [ 5/400]  | Train: Loss 1.3870009246625399, RMSE 1.173615430530749            | Test: Loss 1.383191466331482, RMSE 1.1740278026513886
# Epoch [ 6/400]  | Train: Loss 1.2759044850081729, RMSE 1.125741067685579            | Test: Loss 1.2857237385030378, RMSE 1.1303558328695464
# Epoch [ 7/400]  | Train: Loss 1.2290444781905727, RMSE 1.1024125051080136           | Test: Loss 1.2080832730259812, RMSE 1.0964938328977216
# Epoch [ 8/400]  | Train: Loss 1.2051955879780285, RMSE 1.0934173569344638           | Test: Loss 1.2768406564729256, RMSE 1.1272344693802951
# EarlyStopping counter: 1 out of 10
# Epoch [ 9/400]  | Train: Loss 1.1517125253091778, RMSE 1.069112101144958            | Test: Loss 1.124483208907278, RMSE 1.0583077784170185
# Epoch [10/400]  | Train: Loss 1.1357779743378622, RMSE 1.0613395508966947           | Test: Loss 1.2151315494587547, RMSE 1.0989947643196374
# EarlyStopping counter: 1 out of 10
# Epoch [11/400]  | Train: Loss 1.1171407385876304, RMSE 1.0528067967347932           | Test: Loss 1.2504827453379046, RMSE 1.1159700029774715
# EarlyStopping counter: 2 out of 10
# Epoch [12/400]  | Train: Loss 1.1254467462238513, RMSE 1.0574881476268434           | Test: Loss 1.096288171776554, RMSE 1.0434109422198512
# Epoch [13/400]  | Train: Loss 1.104176520255574, RMSE 1.048247702289046             | Test: Loss 1.2050996663277609, RMSE 1.0948184603138973
# EarlyStopping counter: 1 out of 10
# Epoch [14/400]  | Train: Loss 1.1111717590114527, RMSE 1.0495470553113704           | Test: Loss 1.1087418261327242, RMSE 1.0501375606185512
# EarlyStopping counter: 2 out of 10
# Epoch [15/400]  | Train: Loss 1.1017754370706123, RMSE 1.0453416412336785           | Test: Loss 1.1190049156808017, RMSE 1.055927734625967
# EarlyStopping counter: 3 out of 10
# Epoch [16/400]  | Train: Loss 1.0897025800587838, RMSE 1.039262568741514            | Test: Loss 1.0312727543345668, RMSE 1.0133378599819385
# Epoch [17/400]  | Train: Loss 1.0975327272164195, RMSE 1.043895000951332            | Test: Loss 1.2555580662007917, RMSE 1.1187326280694259
# EarlyStopping counter: 1 out of 10
# Epoch [18/400]  | Train: Loss 1.0814145677968074, RMSE 1.0359755388477392           | Test: Loss 1.1281244629307796, RMSE 1.0597479280672575
# EarlyStopping counter: 2 out of 10
# Epoch [19/400]  | Train: Loss 1.0825563439151697, RMSE 1.0371122203375165           | Test: Loss 1.1016011143985547, RMSE 1.0458509075014215
# EarlyStopping counter: 3 out of 10
# Epoch [20/400]  | Train: Loss 1.072489831531257, RMSE 1.0327140898035283            | Test: Loss 1.08005375297446, RMSE 1.0364062901128803
# EarlyStopping counter: 4 out of 10
# Epoch [21/400]  | Train: Loss 1.0725526380957218, RMSE 1.0311426436691953           | Test: Loss 1.2169120740472226, RMSE 1.1011259430333187
# EarlyStopping counter: 5 out of 10
# Epoch [22/400]  | Train: Loss 1.0610007706441378, RMSE 1.0265993915106122           | Test: Loss 1.008974578296929, RMSE 1.0009401482448244
# Epoch [23/400]  | Train: Loss 1.0549147913330479, RMSE 1.0235668744957238           | Test: Loss 1.0150141977427298, RMSE 1.002853786736204
# EarlyStopping counter: 1 out of 10
# Epoch [24/400]  | Train: Loss 1.0775142845354582, RMSE 1.0351741847239042           | Test: Loss 1.2514807696928059, RMSE 1.1160034066752385
# EarlyStopping counter: 2 out of 10
# Epoch [25/400]  | Train: Loss 1.0793244545919853, RMSE 1.0355781118075054           | Test: Loss 1.0580750902493794, RMSE 1.0260567225907977
# EarlyStopping counter: 3 out of 10
# Epoch [26/400]  | Train: Loss 1.0602717410054123, RMSE 1.026654883434898            | Test: Loss 1.0697245953375834, RMSE 1.031577191854778
# EarlyStopping counter: 4 out of 10
# Epoch [27/400]  | Train: Loss 1.027515056886171, RMSE 1.0106062941383898            | Test: Loss 0.9988674071797153, RMSE 0.9960109194119772
# Epoch [28/400]  | Train: Loss 1.0325738055664195, RMSE 1.011322623804996            | Test: Loss 1.0389565626780193, RMSE 1.0166088740030925
# EarlyStopping counter: 1 out of 10
# Epoch [29/400]  | Train: Loss 1.0370029357441686, RMSE 1.0150298904954342           | Test: Loss 1.0009280903297557, RMSE 0.997039492715869
# EarlyStopping counter: 2 out of 10
# Epoch [30/400]  | Train: Loss 1.0455916994496395, RMSE 1.0190725744816296           | Test: Loss 1.1562355505792719, RMSE 1.072172741095225
# EarlyStopping counter: 3 out of 10
# Epoch [31/400]  | Train: Loss 1.0321364381857085, RMSE 1.0124154990179497           | Test: Loss 0.9772972307707134, RMSE 0.9854366329678318
# Epoch [32/400]  | Train: Loss 1.0263595392829494, RMSE 1.0086924998383773           | Test: Loss 1.062379563063906, RMSE 1.0272233716228552
# EarlyStopping counter: 1 out of 10
# Epoch [33/400]  | Train: Loss 1.008710173138401, RMSE 1.0008688412214581            | Test: Loss 1.0142771193855686, RMSE 1.0040820324630069
# EarlyStopping counter: 2 out of 10
# Epoch [34/400]  | Train: Loss 1.0208318547198647, RMSE 1.0073071237196003           | Test: Loss 1.003772965648718, RMSE 0.9993415286666468
# EarlyStopping counter: 3 out of 10
# Epoch [35/400]  | Train: Loss 1.0114950213515967, RMSE 1.0011393365107084           | Test: Loss 1.023293862217351, RMSE 1.0091854929924011
# EarlyStopping counter: 4 out of 10
# Epoch [36/400]  | Train: Loss 0.9996000402852109, RMSE 0.9964614866072672           | Test: Loss 1.007319892707624, RMSE 1.000603317168721
# EarlyStopping counter: 5 out of 10
# Epoch [37/400]  | Train: Loss 1.0018337055256492, RMSE 0.995067368473923            | Test: Loss 1.0924574335416157, RMSE 1.042351274113906
# EarlyStopping counter: 6 out of 10
# Epoch [38/400]  | Train: Loss 1.000395231079637, RMSE 0.9955287847602576            | Test: Loss 0.9373766738071776, RMSE 0.9655963632098415
# Epoch [39/400]  | Train: Loss 0.9786528673088342, RMSE 0.9858956044180351           | Test: Loss 0.9232159319676851, RMSE 0.9579815069834391
# Epoch [40/400]  | Train: Loss 0.9725725180224368, RMSE 0.9815543220754255           | Test: Loss 0.9790688627644589, RMSE 0.9858339125649971
# EarlyStopping counter: 1 out of 10
# Epoch [41/400]  | Train: Loss 0.943112313747406, RMSE 0.9660390082158541            | Test: Loss 0.8922968904177347, RMSE 0.9402011235555013
# Epoch [42/400]  | Train: Loss 0.9399174294973675, RMSE 0.965333290267409            | Test: Loss 0.920150359471639, RMSE 0.9556368181579992
# EarlyStopping counter: 1 out of 10
# Epoch [43/400]  | Train: Loss 0.9052475711755585, RMSE 0.9465944934309575           | Test: Loss 0.8544308846456963, RMSE 0.9204006529690927
# Epoch [44/400]  | Train: Loss 0.9376643132745174, RMSE 0.9646039207776388           | Test: Loss 0.983385563942424, RMSE 0.9891652883144847
# EarlyStopping counter: 1 out of 10
# Epoch [45/400]  | Train: Loss 0.9033406157242624, RMSE 0.9476358921904313           | Test: Loss 0.9351672373319927, RMSE 0.9630546601195085
# EarlyStopping counter: 2 out of 10
# Epoch [46/400]  | Train: Loss 0.8825324993384512, RMSE 0.9361547670866314           | Test: Loss 0.862582592587722, RMSE 0.9255831795826293
# EarlyStopping counter: 3 out of 10
# Epoch [47/400]  | Train: Loss 0.8867965968031633, RMSE 0.9378025625881395           | Test: Loss 0.9438262226288778, RMSE 0.9687173680255288
# EarlyStopping counter: 4 out of 10
# Epoch [48/400]  | Train: Loss 0.8770521178580167, RMSE 0.9325989756667823           | Test: Loss 0.8367168756953457, RMSE 0.9115431381945025
# Epoch [49/400]  | Train: Loss 0.8899001081784567, RMSE 0.9400906395493892           | Test: Loss 1.1323790571145844, RMSE 1.0621946025312992
# EarlyStopping counter: 1 out of 10
# Epoch [50/400]  | Train: Loss 0.8822311173405564, RMSE 0.9360454385740715           | Test: Loss 0.8819500207901001, RMSE 0.9360146616634569
# EarlyStopping counter: 2 out of 10
# Epoch [51/400]  | Train: Loss 0.8761352300643921, RMSE 0.932831046874063            | Test: Loss 0.9946843981742859, RMSE 0.9943832106757582
# EarlyStopping counter: 3 out of 10
# Epoch [52/400]  | Train: Loss 0.8630676102219966, RMSE 0.9243920644124349           | Test: Loss 0.8433891712573537, RMSE 0.9147047578242787
# EarlyStopping counter: 4 out of 10
# Epoch [53/400]  | Train: Loss 0.8604983248208699, RMSE 0.9228089378591169           | Test: Loss 0.824079668312742, RMSE 0.9048876061774137
# Epoch [54/400]  | Train: Loss 0.888946885602516, RMSE 0.9384047922335172            | Test: Loss 0.8569302234733314, RMSE 0.9232292405345983
# EarlyStopping counter: 1 out of 10
# Epoch [55/400]  | Train: Loss 0.8761274730950072, RMSE 0.9312337323238975           | Test: Loss 0.8333028722227666, RMSE 0.9086253528009381
# EarlyStopping counter: 2 out of 10
# Epoch [56/400]  | Train: Loss 0.8522599234915617, RMSE 0.9190481796599271           | Test: Loss 0.8770204291009066, RMSE 0.9329062794384203
# EarlyStopping counter: 3 out of 10
# Epoch [57/400]  | Train: Loss 0.8376525337235969, RMSE 0.9114219284894174           | Test: Loss 0.8208061655362447, RMSE 0.902567654325251
# Epoch [58/400]  | Train: Loss 0.8696616501138922, RMSE 0.9277117743826749           | Test: Loss 0.8087629257586965, RMSE 0.8955329196494922
# Epoch [59/400]  | Train: Loss 0.8391927114704198, RMSE 0.9123350026314718           | Test: Loss 0.8134819624716776, RMSE 0.8980035750489486
# EarlyStopping counter: 1 out of 10
# Epoch [60/400]  | Train: Loss 0.8435268391642654, RMSE 0.9135733016750269           | Test: Loss 0.8226238321839717, RMSE 0.9032629393694693
# EarlyStopping counter: 2 out of 10
# Epoch [61/400]  | Train: Loss 0.8374178921967222, RMSE 0.9120821429972064           | Test: Loss 0.8068132536453113, RMSE 0.8938332095480802
# Epoch [62/400]  | Train: Loss 0.8333179772945872, RMSE 0.9097002828330324           | Test: Loss 0.8847455947022689, RMSE 0.9370208905454267
# EarlyStopping counter: 1 out of 10
# Epoch [63/400]  | Train: Loss 0.8302087083197477, RMSE 0.9074159630557947           | Test: Loss 0.8079761988238284, RMSE 0.8954951344874867
# EarlyStopping counter: 2 out of 10
# Epoch [64/400]  | Train: Loss 0.8339013321357861, RMSE 0.9102472328303153           | Test: Loss 0.9276298200874998, RMSE 0.960296138336784
# EarlyStopping counter: 3 out of 10
# Epoch [65/400]  | Train: Loss 0.837286887461679, RMSE 0.9107777120774252            | Test: Loss 0.8317529600963258, RMSE 0.9090734437892312
# EarlyStopping counter: 4 out of 10
# Epoch [66/400]  | Train: Loss 0.8346420704272756, RMSE 0.9096812239864416           | Test: Loss 0.845017859810277, RMSE 0.9159423604346159
# EarlyStopping counter: 5 out of 10
# Epoch [67/400]  | Train: Loss 0.8309892489199053, RMSE 0.9082385657126444           | Test: Loss 0.7909133779375177, RMSE 0.8855157243578058
# Epoch [68/400]  | Train: Loss 0.8372640944363778, RMSE 0.9107278700460467           | Test: Loss 0.8325730018448412, RMSE 0.9083172365238792
# EarlyStopping counter: 1 out of 10
# Epoch [69/400]  | Train: Loss 0.8326884947325054, RMSE 0.9088227560645655           | Test: Loss 0.8211300519474766, RMSE 0.903465887956452
# EarlyStopping counter: 2 out of 10
# Epoch [70/400]  | Train: Loss 0.8174874604794017, RMSE 0.9005473611647623           | Test: Loss 0.8682339892052767, RMSE 0.9289479893550538
# EarlyStopping counter: 3 out of 10
# Epoch [71/400]  | Train: Loss 0.8192004665993807, RMSE 0.9008750309023941           | Test: Loss 0.9337268063896581, RMSE 0.9632467345187539
# EarlyStopping counter: 4 out of 10
# Epoch [72/400]  | Train: Loss 0.8436927994092306, RMSE 0.9147666096687317           | Test: Loss 0.8001930980305922, RMSE 0.8906446172479998
# EarlyStopping counter: 5 out of 10
# Epoch [73/400]  | Train: Loss 0.8092966330678839, RMSE 0.8956412955334312           | Test: Loss 0.9024411607206914, RMSE 0.9470079290239435
# EarlyStopping counter: 6 out of 10
# Epoch [74/400]  | Train: Loss 0.8064966776914764, RMSE 0.8949848476209139           | Test: Loss 0.7852130218556053, RMSE 0.8829229191729897
# Epoch [75/400]  | Train: Loss 0.8134541417423048, RMSE 0.8986750799312926           | Test: Loss 1.0634827425605373, RMSE 1.0289409620720043
# EarlyStopping counter: 1 out of 10
# Epoch [76/400]  | Train: Loss 0.8283815896301939, RMSE 0.9072585095439041           | Test: Loss 0.7976303832572803, RMSE 0.8894171903007909
# EarlyStopping counter: 2 out of 10
# Epoch [77/400]  | Train: Loss 0.8031052832017865, RMSE 0.8919142097757574           | Test: Loss 0.7657616326683446, RMSE 0.8712771430350187
# Epoch [78/400]  | Train: Loss 0.8008965557081658, RMSE 0.8914075619296024           | Test: Loss 0.7957959635215893, RMSE 0.8897011520569784
# EarlyStopping counter: 1 out of 10
# Epoch [79/400]  | Train: Loss 0.7887732470244692, RMSE 0.8845639605271188           | Test: Loss 0.7828898837691859, RMSE 0.8820806323436269
# EarlyStopping counter: 2 out of 10
# Epoch [80/400]  | Train: Loss 0.8052841728193718, RMSE 0.8936391870180765           | Test: Loss 0.8539840171211645, RMSE 0.9199074276706629
# EarlyStopping counter: 3 out of 10
# Epoch [81/400]  | Train: Loss 0.8101460222612348, RMSE 0.8961605565589771           | Test: Loss 0.7949603764634383, RMSE 0.888103209043804
# EarlyStopping counter: 4 out of 10
# Epoch [82/400]  | Train: Loss 0.8018942198209595, RMSE 0.8916229480191281           | Test: Loss 0.792974683276394, RMSE 0.8876959859279164
# EarlyStopping counter: 5 out of 10
# Epoch [83/400]  | Train: Loss 0.7949460185410684, RMSE 0.8884119025447912           | Test: Loss 0.8064433064377099, RMSE 0.89498251781129
# EarlyStopping counter: 6 out of 10
# Epoch [84/400]  | Train: Loss 0.79193367456135, RMSE 0.8857660481804296             | Test: Loss 0.7804859829576392, RMSE 0.879055779231222
# EarlyStopping counter: 7 out of 10
# Epoch [85/400]  | Train: Loss 0.7939200683643943, RMSE 0.8858498021175987           | Test: Loss 0.7669243247885453, RMSE 0.8717643127106783
# EarlyStopping counter: 8 out of 10
# Epoch [86/400]  | Train: Loss 0.7921171240639269, RMSE 0.8868864942015263           | Test: Loss 0.8266374907995525, RMSE 0.9061982924478096
# EarlyStopping counter: 9 out of 10
# Epoch [87/400]  | Train: Loss 0.8022807135916593, RMSE 0.8923684818702832           | Test: Loss 0.8882832652644107, RMSE 0.9384651403678091
# EarlyStopping counter: 10 out of 10
# Early stopping
